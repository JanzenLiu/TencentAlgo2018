# %%
# Target
# 'SalePrice': log transform

# Numerical Feature
# 'MSSubClass': treat as cat_feat 
# 'LotFrontage': clip large value, log/boxcox transform OR NOT
# 'LotArea': clip large value, log/boxcox transform OR NOT
# 'OverallQual': treat as cat_feat and merge rare values
# 'OverallCond': treat as cat_feat and merge rare values
# 'YearBuilt': clip small values OR binning
# 'YearRemodAdd': split into two features: (1950 as one, and or other values as another)
# 'MasVnrArea': split into two features OR just discard it
# 'BsmtFinSF1': split into two features OR just discard it
# 'BsmtFinSF2': split into two features OR just discard it
# 'BsmtUnfSF': split into two features, log/boxcox transform
# 'TotalBsmtSF': split into two features (OR NOT), clip large values, log/boxcox transform OR NOT
# '1stFlrSF': clip large values, log/boxcox transform OR NOT
# '2ndFlrSF': split into two features, clip large values
# 'LowQualFinSF': [split into two features, and binning] OR just discard it
# 'GrLivArea': clip large values, log/boxcox transform OR NOT
# 'BsmtFullBath': treat as cat_feat
# 'BsmtHalfBath': treat as cat_feat
# 'FullBath': treat as cat_feat, throw out '0' OR NOT
# 'HalfBath': treat as cat_feat, throw out '0' OR NOT
# 'BedroomAbvGr': treat as cat_feat, merge large value
# 'KitchenAbvGr': treat as cat_feat, throw out '0' OR NOT
# 'TotRmsAbvGrd': log/boxcox transform
# 'Fireplaces': treat as cat_feat, merge large value
# 'GarageYrBlt': clip outliers, binning OR log/boxcox transform
# 'GarageCars': treat as cat_feat, merge rare values
# 'GarageArea': split into two features, binning OR log/boxcox transform
# 'WoodDeckSF': split into two features, clip large values OR log/boxcox transform
# 'OpenPorchSF': split into two features, clip large values OR log/boxcox transform
# 'EnclosedPorch': split into two features, clip large values OR log/boxcox transform OR binning 
# '3SsnPorch': split into two features OR just discard it
# 'ScreenPorch': split into two features OR just discard it
# 'PoolArea': split into two featurs OR just discard it 
# 'MiscVal': split into two features OR just discard it
# 'MoSold': treat as cat_feat OR NOT
# 'YrSold': treat as cat_feat

# Categorical Feature
# 'MSZoning': TargetEncoding with Bayesian Smoothing
# 'Street': TargetEncoding with Bayesian Smoothing
# 'Alley': TargetEncoding with Bayesian Smoothing
# 'LotShape': TargetEncoding with Bayesian Smoothing
# 'LandContour': TargetEncoding with Bayesian Smoothing
# 'Utilities': Discard
# 'LotConfig': 
# 'LandSlope': 
# 'Neighborhood': 
# 'Condition1': 
# 'Condition2': 
# 'BldgType': 
# 'HouseStyle': 
# 'RoofStyle': 
# 'RoofMatl': 
# 'Exterior1st': 
# 'Exterior2nd': 
# 'MasVnrType': 
# 'ExterQual': 
# 'ExterCond': 
# 'Foundation': 
# 'BsmtQual': 
# 'BsmtCond': 
# 'BsmtExposure': 
# 'BsmtFinType1': 
# 'BsmtFinType2': 
# 'Heating': 
# 'HeatingQC': 
# 'CentralAir': 
# 'Electrical': 
# 'KitchenQual': 
# 'Functional': 
# 'FireplaceQu': 
# 'GarageType': 
# 'GarageFinish': 
# 'GarageQual': 
# 'GarageCond': 
# 'PavedDrive': 
# 'PoolQC': 
# 'Fence': 
# 'MiscFeature': 
# 'SaleType': 
# 'SaleCondition':

# %%
cols = ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']
for col in cols:
    print("# \'{}\': ".format(col))
# Out:
# # 'MSZoning':
# # 'Street':
# # 'Alley':
# # 'LotShape':
# # 'LandContour':
# # 'Utilities':
# # 'LotConfig':
# # 'LandSlope':
# # 'Neighborhood':
# # 'Condition1':
# # 'Condition2':
# # 'BldgType':
# # 'HouseStyle':
# # 'RoofStyle':
# # 'RoofMatl':
# # 'Exterior1st':
# # 'Exterior2nd':
# # 'MasVnrType':
# # 'ExterQual':
# # 'ExterCond':
# # 'Foundation':
# # 'BsmtQual':
# # 'BsmtCond':
# # 'BsmtExposure':
# # 'BsmtFinType1':
# # 'BsmtFinType2':
# # 'Heating':
# # 'HeatingQC':
# # 'CentralAir':
# # 'Electrical':
# # 'KitchenQual':
# # 'Functional':
# # 'FireplaceQu':
# # 'GarageType':
# # 'GarageFinish':
# # 'GarageQual':
# # 'GarageCond':
# # 'PavedDrive':
# # 'PoolQC':
# # 'Fence':
# # 'MiscFeature':
# # 'SaleType':
# # 'SaleCondition':
