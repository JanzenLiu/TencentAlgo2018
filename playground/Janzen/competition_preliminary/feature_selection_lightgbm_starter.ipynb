# %%
from sklearn.model_selection import StratifiedKFold
from collections import Counter
import lightgbm as lgb
import scipy.sparse as sparse
import pandas as pd
import numpy as np
import tqdm
import gc
import os
import sys
sys.path.append('../../../code/utils')
import data_utils as du
import perf_utils as pu

# %%
df_train = du.load_raw_data("train")
df_test = du.load_raw_data("test")
df_ad = du.load_raw_data("ad")

# %%
user_one_feat_names = ['age', 'gender', 'education', 'consumptionAbility', 'LBS',
                  'carrier', 'house']  # one user has only one value
user_multi_feat_names = ['marriageStatus', 'interest1', 'interest2', 'interest3',
                   'interest4', 'interest5', 'kw1', 'kw2', 'kw3', 'topic1',
                   'topic2', 'topic3', 'appIdInstall', 'appIdAction', 'ct', 'os']  # one user can have more than one value
user_feat_names = user_one_feat_names + user_multi_feat_names

# %%
ad_num_feat_names = ['creativeSize']
ad_cat_feat_names = ['advertiserId', 'campaignId', 'creativeId', 'adCategoryId', 'productId', 'productType']
ad_feat_names = ad_num_feat_names + ad_cat_feat_names

# %%
with pu.profiler("loading and joining user and ad data"):
    X, feat_names = du.quick_join(ad_user=df_train, 
                                  user_feat_names=user_one_feat_names, 
                                  ad_feat_names=ad_cat_feat_names)
gc.collect()
print("Combined Matrix Shape: {}".format(X.shape))
print("Feature Names Count: {}".format(len(feat_names)))
print("Memory usage at this moment :{}".format(pu.get_memory_str()))
# Out:
# loading user matrices: 100%|██████████| 7/7 [02:44<00:00, 23.50s/it]
# loading ad matrices: 100%|██████████| 6/6 [00:22<00:00,  3.69s/it]
# [06:55:19] Finish loading and joining user and ad data. △M: +1002.48MB. △T: 3.1 minutes.
# Combined Matrix Shape: (8798814, 1349)
# Feature Names Count: 1349
# Memory usage at this moment :1.3GB

# %%
y = df_train['label'].values
y = (y + 1) / 2
assert X.shape[0] == y.shape[0]

# %%
n_splits = 3  # use 3 instead of 5 to save time
skf = StratifiedKFold(n_splits=n_splits)
split_indices = [(train_index, valid_index) for train_index, valid_index in skf.split(df_train, y)]

# %%
X = sparse.csr_matrix(X)

# %%
train_index, valid_index = split_indices[0]

X_train, y_train = X[train_index, :], y[train_index]
X_valid, y_valid = X[valid_index, :], y[valid_index]

lgb_train = lgb.Dataset(X_train.astype(np.float32), y_train, feature_name=feat_names)
lgb_valid = lgb.Dataset(X_valid.astype(np.float32), y_valid, feature_name=feat_names)

# %%
params = {
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': 'auc',
    'max_depth': 6,
    'num_leaves': 31,
    'learning_rate': 0.15,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'verbose': 0
}
num_rounds = 100

lgbm = lgb.train(params,
                 lgb_train,
                 num_boost_round=num_rounds,
                 valid_sets=[lgb_train, lgb_valid], 
                 valid_names=['train', 'valid1'],
                 early_stopping_rounds=50)
# Out:
# [1]	train's auc: 0.604395	valid1's auc: 0.605676
# Training until validation scores don't improve for 50 rounds.
# [2]	train's auc: 0.606304	valid1's auc: 0.607287
# [3]	train's auc: 0.609834	valid1's auc: 0.61127
# [4]	train's auc: 0.611244	valid1's auc: 0.612525
# [5]	train's auc: 0.614005	valid1's auc: 0.615161
# [6]	train's auc: 0.615834	valid1's auc: 0.617013
# [7]	train's auc: 0.616394	valid1's auc: 0.617442
# [8]	train's auc: 0.616818	valid1's auc: 0.618057
# [9]	train's auc: 0.619163	valid1's auc: 0.620461
# [10]	train's auc: 0.618998	valid1's auc: 0.620193
# [11]	train's auc: 0.619531	valid1's auc: 0.62076
# [12]	train's auc: 0.619286	valid1's auc: 0.620556
# [13]	train's auc: 0.619629	valid1's auc: 0.620829
# [14]	train's auc: 0.620364	valid1's auc: 0.621582
# [15]	train's auc: 0.620877	valid1's auc: 0.622107
# [16]	train's auc: 0.621327	valid1's auc: 0.622707
# [17]	train's auc: 0.622288	valid1's auc: 0.623592
# [18]	train's auc: 0.622655	valid1's auc: 0.623963
# [19]	train's auc: 0.623423	valid1's auc: 0.62477
# [20]	train's auc: 0.623666	valid1's auc: 0.624958
# [21]	train's auc: 0.624318	valid1's auc: 0.625555
# [22]	train's auc: 0.625063	valid1's auc: 0.626358
# [23]	train's auc: 0.625413	valid1's auc: 0.626615
# [24]	train's auc: 0.626015	valid1's auc: 0.6273
# [25]	train's auc: 0.626265	valid1's auc: 0.627483
# [26]	train's auc: 0.627065	valid1's auc: 0.628264
# [27]	train's auc: 0.627301	valid1's auc: 0.628424
# [28]	train's auc: 0.627818	valid1's auc: 0.628976
# [29]	train's auc: 0.628961	valid1's auc: 0.630083
# [30]	train's auc: 0.629613	valid1's auc: 0.63067
# [31]	train's auc: 0.630232	valid1's auc: 0.631221
# [32]	train's auc: 0.630607	valid1's auc: 0.631557
# [33]	train's auc: 0.631034	valid1's auc: 0.631966
# [34]	train's auc: 0.631531	valid1's auc: 0.632451
# [35]	train's auc: 0.632009	valid1's auc: 0.63291
# [36]	train's auc: 0.632605	valid1's auc: 0.633382
# [37]	train's auc: 0.633406	valid1's auc: 0.63419
# [38]	train's auc: 0.633567	valid1's auc: 0.634292
# [39]	train's auc: 0.634069	valid1's auc: 0.634826
# [40]	train's auc: 0.634347	valid1's auc: 0.635081
# [41]	train's auc: 0.634702	valid1's auc: 0.635459
# [42]	train's auc: 0.635	valid1's auc: 0.635708
# [43]	train's auc: 0.635368	valid1's auc: 0.636093
# [44]	train's auc: 0.635729	valid1's auc: 0.636387
# [45]	train's auc: 0.636101	valid1's auc: 0.636709
# [46]	train's auc: 0.636398	valid1's auc: 0.637003
# [47]	train's auc: 0.637033	valid1's auc: 0.637563
# [48]	train's auc: 0.637391	valid1's auc: 0.637853
# [49]	train's auc: 0.637478	valid1's auc: 0.637865
# [50]	train's auc: 0.637853	valid1's auc: 0.63817
# [51]	train's auc: 0.638206	valid1's auc: 0.638493
# [52]	train's auc: 0.638375	valid1's auc: 0.638572
# [53]	train's auc: 0.638594	valid1's auc: 0.638702
# [54]	train's auc: 0.638836	valid1's auc: 0.638858
# [55]	train's auc: 0.639159	valid1's auc: 0.639158
# [56]	train's auc: 0.639308	valid1's auc: 0.639268
# [57]	train's auc: 0.639411	valid1's auc: 0.639354
# [58]	train's auc: 0.639633	valid1's auc: 0.639509
# [59]	train's auc: 0.639962	valid1's auc: 0.639808
# [60]	train's auc: 0.640297	valid1's auc: 0.640117
# [61]	train's auc: 0.640413	valid1's auc: 0.640178
# [62]	train's auc: 0.640522	valid1's auc: 0.640294
# [63]	train's auc: 0.640776	valid1's auc: 0.640532
# [64]	train's auc: 0.641027	valid1's auc: 0.640718
# [65]	train's auc: 0.641158	valid1's auc: 0.640785
# [66]	train's auc: 0.641262	valid1's auc: 0.640844
# [67]	train's auc: 0.641345	valid1's auc: 0.640918
# [68]	train's auc: 0.641597	valid1's auc: 0.64112
# [69]	train's auc: 0.641737	valid1's auc: 0.641186
# [70]	train's auc: 0.641849	valid1's auc: 0.641223
# [71]	train's auc: 0.641933	valid1's auc: 0.641277
# [72]	train's auc: 0.642047	valid1's auc: 0.641321
# [73]	train's auc: 0.642271	valid1's auc: 0.641502
# [74]	train's auc: 0.6425	valid1's auc: 0.6417
# [75]	train's auc: 0.642607	valid1's auc: 0.641764
# [76]	train's auc: 0.64284	valid1's auc: 0.64197
# [77]	train's auc: 0.643015	valid1's auc: 0.642107
# [78]	train's auc: 0.643248	valid1's auc: 0.642287
# [79]	train's auc: 0.643335	valid1's auc: 0.642335
# [80]	train's auc: 0.643476	valid1's auc: 0.642427
# [81]	train's auc: 0.643574	valid1's auc: 0.64248
# [82]	train's auc: 0.64375	valid1's auc: 0.642625
# [83]	train's auc: 0.643908	valid1's auc: 0.642742
# [84]	train's auc: 0.644056	valid1's auc: 0.642853
# [85]	train's auc: 0.644253	valid1's auc: 0.643033
# [86]	train's auc: 0.644479	valid1's auc: 0.643236
# [87]	train's auc: 0.644555	valid1's auc: 0.643284
# [88]	train's auc: 0.644854	valid1's auc: 0.643522
# [89]	train's auc: 0.644965	valid1's auc: 0.643602
# [90]	train's auc: 0.645082	valid1's auc: 0.643684
# [91]	train's auc: 0.645151	valid1's auc: 0.643705
# [92]	train's auc: 0.645266	valid1's auc: 0.643753
# [93]	train's auc: 0.645419	valid1's auc: 0.643881
# [94]	train's auc: 0.645677	valid1's auc: 0.644077
# [95]	train's auc: 0.645779	valid1's auc: 0.644143
# [96]	train's auc: 0.645894	valid1's auc: 0.644223
# [97]	train's auc: 0.64604	valid1's auc: 0.644286
# [98]	train's auc: 0.64628	valid1's auc: 0.644488
# [99]	train's auc: 0.646447	valid1's auc: 0.644635
# [100]	train's auc: 0.646496	valid1's auc: 0.644661

# %%
feat_importance_dict = dict(zip(feat_names, lgbm.feature_importance()))
print(feat_importance_dict)
# Out:
# {'LBS_117': 0, 'adCategoryId_9': 0, 'LBS_161': 0, 'LBS_657': 0, 'campaignId_174407': 2, 'LBS_735': 0, 'LBS_692': 0, 'LBS_203': 2, 'LBS_695': 0, 'LBS_636': 0, 'LBS_428': 0, 'LBS_791': 0, 'LBS_319': 1, 'LBS_118': 0, 'LBS_578': 0, 'LBS_649': 0, 'campaignId_159118': 0, 'campaignId_4833': 2, 'advertiserId_9106': 22, 'creativeId_43877': 0, 'LBS_125': 0, 'LBS_289': 0, 'productId_38': 0, 'LBS_201': 1, 'campaignId_59293': 0, 'LBS_897': 0, 'LBS_186': 0, 'LBS_987': 0, 'LBS_917': 0, 'LBS_955': 0, 'LBS_813': 1, 'creativeId_832650': 0, 'advertiserId_9571': 0, 'adCategoryId_81': 0, 'LBS_650': 0, 'LBS_589': 0, 'LBS_758': 0, 'creativeId_1160702': 0, 'LBS_224': 0, 'campaignId_7527': 0, 'campaignId_84178': 0, 'LBS_335': 3, 'LBS_549': 0, 'advertiserId_8203': 28, 'LBS_965': 1, 'LBS_429': 0, 'creativeId_1724522': 1, 'LBS_932': 0, 'LBS_581': 0, 'LBS_716': 0, 'LBS_114': 6, 'LBS_30': 0, 'LBS_569': 0, 'LBS_953': 0, 'productId_17614': 0, 'LBS_56': 3, 'creativeId_1147463': 14, 'LBS_792': 0, 'creativeId_585909': 0, 'LBS_245': 0, 'creativeId_131847': 0, 'LBS_940': 0, 'LBS_360': 0, 'LBS_97': 0, 'LBS_173': 0, 'LBS_104': 0, 'LBS_665': 0, 'LBS_171': 0, 'adCategoryId_4': 13, 'LBS_961': 0, 'LBS_741': 0, 'campaignId_241577': 1, 'LBS_426': 0, 'creativeId_154811': 0, 'LBS_455': 0, 'advertiserId_15174': 4, 'LBS_427': 0, 'LBS_137': 0, 'LBS_809': 5, 'LBS_507': 0, 'LBS_268': 2, 'adCategoryId_140': 0, 'creativeId_869346': 0, 'LBS_251': 0, 'advertiserId_10055': 9, 'LBS_593': 2, 'LBS_715': 1, 'LBS_737': 1, 'creativeId_1464074': 0, 'LBS_333': 2, 'advertiserId_285': 1, 'LBS_912': 0, 'advertiserId_11487': 2, 'productId_5615': 0, 'LBS_451': 0, 'LBS_588': 0, 'creativeId_104188': 0, 'LBS_120': 0, 'LBS_753': 0, 'LBS_494': 0, 'LBS_132': 0, 'LBS_275': 10, 'productType_9': 64, 'LBS_626': 0, 'campaignId_295940': 13, 'LBS_462': 1, 'LBS_420': 0, 'LBS_706': 0, 'LBS_220': 0, 'LBS_835': 0, 'campaignId_487541': 0, 'LBS_754': 0, 'LBS_697': 0, 'LBS_395': 1, 'LBS_39': 0, 'adCategoryId_8': 0, 'LBS_768': 0, 'LBS_122': 0, 'LBS_798': 0, 'LBS_598': 0, 'creativeId_43862': 0, 'creativeId_1211265': 0, 'creativeId_58465': 1, 'LBS_988': 0, 'LBS_367': 0, 'LBS_870': 0, 'creativeId_619519': 1, 'creativeId_220558': 0, 'LBS_14': 0, 'LBS_627': 0, 'LBS_123': 0, 'LBS_613': 0, 'LBS_69': 0, 'creativeId_1146648': 0, 'advertiserId_728': 13, 'LBS_579': 0, 'LBS_597': 0, 'productId_70': 0, 'LBS_966': 0, 'creativeId_1230210': 0, 'LBS_284': 1, 'advertiserId_101662': 11, 'LBS_551': 0, 'LBS_286': 0, 'LBS_237': 5, 'campaignId_3372': 0, 'LBS_651': 0, 'LBS_885': 0, 'advertiserId_2509': 0, 'LBS_250': 0, 'LBS_817': 0, 'LBS_181': 0, 'creativeId_416399': 0, 'LBS_168': 0, 'creativeId_1589088': 0, 'LBS_524': 0, 'LBS_972': 1, 'LBS_402': 1, 'LBS_328': 0, 'LBS_55': 0, 'creativeId_1354071': 0, 'LBS_852': 0, 'LBS_425': 4, 'LBS_948': 1, 'LBS_633': 0, 'education_4': 5, 'LBS_788': 0, 'LBS_840': 0, 'LBS_445': 0, 'LBS_878': 0, 'LBS_7': 1, 'LBS_621': 0, 'LBS_908': 4, 'LBS_325': 0, 'creativeId_1401261': 0, 'advertiserId_75748': 0, 'advertiserId_7565': 0, 'LBS_103': 0, 'advertiserId_821': 4, 'campaignId_86429': 0, 'LBS_50': 0, 'LBS_839': 1, 'creativeId_1755470': 8, 'creativeId_326633': 0, 'LBS_262': 0, 'creativeId_666210': 1, 'LBS_359': 0, 'creativeId_469197': 0, 'campaignId_49189': 0, 'LBS_323': 0, 'age_1': 91, 'LBS_793': 0, 'LBS_679': 0, 'LBS_661': 0, 'LBS_311': 0, 'LBS_111': 0, 'advertiserId_14818': 0, 'LBS_498': 0, 'creativeId_1271219': 1, 'creativeId_1083112': 0, 'LBS_291': 0, 'LBS_294': 1, 'productId_5336': 0, 'LBS_887': 0, 'creativeId_991964': 0, 'creativeId_1205997': 0, 'LBS_381': 0, 'LBS_671': 0, 'LBS_911': 0, 'creativeId_1500666': 1, 'adCategoryId_149': 0, 'LBS_659': 0, 'LBS_702': 0, 'productId_3826': 0, 'LBS_935': 0, 'adCategoryId_25': 0, 'LBS_881': 0, 'LBS_926': 0, 'LBS_163': 0, 'LBS_86': 0, 'LBS_707': 0, 'LBS_408': 0, 'creativeId_1513931': 2, 'campaignId_18683': 0, 'LBS_48': 3, 'LBS_94': 5, 'LBS_688': 0, 'productId_28986': 0, 'creativeId_857791': 0, 'creativeId_638911': 1, 'LBS_683': 0, 'LBS_326': 1, 'creativeId_1340722': 1, 'LB ...

# %%
feat_importance_counter = Counter(feat_importance_dict)
feat_importance_counter.most_common(1000)
# Out:
# [('carrier_0', 118),
#  ('gender_2', 115),
#  ('age_3', 108),
#  ('age_2', 105),
#  ('consumptionAbility_2', 91),
#  ('age_1', 91),
#  ('consumptionAbility_0', 90),
#  ('age_5', 80),
#  ('age_4', 71),
#  ('education_2', 71),
#  ('productType_9', 64),
#  ('consumptionAbility_1', 64),
#  ('gender_1', 43),
#  ('adCategoryId_51', 39),
#  ('campaignId_40405', 38),
#  ('education_6', 35),
#  ('education_7', 34),
#  ('advertiserId_6946', 34),
#  ('house_1', 31),
#  ('advertiserId_8203', 28),
#  ('advertiserId_370', 28),
#  ('LBS_258', 26),
#  ('advertiserId_17597', 26),
#  ('adCategoryId_67', 25),
#  ('advertiserId_9106', 22),
#  ('advertiserId_8864', 22),
#  ('productId_113', 22),
#  ('adCategoryId_24', 21),
#  ('campaignId_5616', 20),
#  ('carrier_1', 20),
#  ('education_1', 20),
#  ('productType_11', 20),
#  ('creativeId_1610899', 19),
#  ('advertiserId_25485', 17),
#  ('advertiserId_83042', 17),
#  ('creativeId_27461', 17),
#  ('productType_4', 16),
#  ('advertiserId_158679', 16),
#  ('advertiserId_8350', 16),
#  ('advertiserId_11195', 15),
#  ('creativeId_1147463', 14),
#  ('adCategoryId_27', 14),
#  ('LBS_458', 13),
#  ('campaignId_163120', 13),
#  ('education_3', 13),
#  ('LBS_112', 13),
#  ('adCategoryId_4', 13),
#  ('campaignId_295940', 13),
#  ('advertiserId_728', 13),
#  ('advertiserId_327', 12),
#  ('advertiserId_44008', 12),
#  ('education_0', 12),
#  ('carrier_3', 12),
#  ('creativeId_455396', 12),
#  ('LBS_585', 12),
#  ('advertiserId_388', 12),
#  ('advertiserId_6841', 11),
#  ('advertiserId_11437', 11),
#  ('campaignId_243160', 11),
#  ('education_5', 11),
#  ('advertiserId_101662', 11),
#  ('campaignId_115759', 11),
#  ('advertiserId_3387', 10),
#  ('campaignId_50138', 10),
#  ('LBS_275', 10),
#  ('advertiserId_1025', 10),
#  ('campaignId_134068', 10),
#  ('advertiserId_133292', 9),
#  ('advertiserId_10055', 9),
#  ('campaignId_13953', 9),
#  ('creativeId_1246897', 9),
#  ('campaignId_18552', 9),
#  ('LBS_346', 9),
#  ('creativeId_794412', 8),
#  ('creativeId_1636465', 8),
#  ('creativeId_1755470', 8),
#  ('advertiserId_24704', 8),
#  ('LBS_209', 8),
#  ('productType_6', 8),
#  ('LBS_424', 8),
#  ('campaignId_50305', 8),
#  ('advertiserId_14315', 8),
#  ('carrier_2', 8),
#  ('advertiserId_702', 8),
#  ('advertiserId_1082', 8),
#  ('campaignId_12724', 8),
#  ('LBS_341', 7),
#  ('LBS_705', 7),
#  ('adCategoryId_21', 7),
#  ('LBS_72', 7),
#  ('advertiserId_243', 7),
#  ('campaignId_12711', 7),
#  ('creativeId_798752', 7),
#  ('adCategoryId_10', 7),
#  ('advertiserId_2676', 6),
#  ('advertiserId_47823', 6),
#  ('LBS_85', 6),
#  ('house_[nan]', 6),
#  ('LBS_114', 6),
#  ('advertiserId_79', 6),
#  ('creativeId_1434096', 6),
#  ('LBS_13', 6),
#  ('LBS_809', 5),
#  ('LBS_237', 5),
#  ('advertiserId_21359', 5),
#  ('adCategoryId_89', 5),
#  ('education_4', 5),
#  ('LBS_94', 5),
#  ('campaignId_111645', 5),
#  ('advertiserId_25420', 5),
#  ('campaignId_20048', 5),
#  ('adCategoryId_1', 5),
#  ('advertiserId_990', 5),
#  ('LBS_783', 5),
#  ('LBS_471', 5),
#  ('campaignId_296367', 5),
#  ('creativeId_1081485', 5),
#  ('campaignId_696695', 5),
#  ('LBS_0', 5),
#  ('creativeId_267290', 5),
#  ('LBS_514', 5),
#  ('advertiserId_15174', 4),
#  ('campaignId_52258', 4),
#  ('LBS_425', 4),
#  ('LBS_908', 4),
#  ('advertiserId_821', 4),
#  ('creativeId_1012717', 4),
#  ('LBS_964', 4),
#  ('campaignId_13044', 4),
#  ('LBS_802', 4),
#  ('advertiserId_19441', 4),
#  ('LBS_339', 4),
#  ('LBS_958', 4),
#  ('LBS_879', 4),
#  ('advertiserId_10122', 4),
#  ('campaignId_888', 4),
#  ('LBS_432', 4),
#  ('LBS_152', 4),
#  ('advertiserId_149', 4),
#  ('LBS_27', 4),
#  ('campaignId_358536', 4),
#  ('adCategoryId_43', 4),
#  ('advertiserId_22802', 4),
#  ('LBS_555', 4),
#  ('advertiserId_5552', 4),
#  ('campaignId_51385', 4),
#  ('advertiserId_58643', 4),
#  ('advertiserId_27367', 4),
#  ('advertiserId_9619', 4),
#  ('campaignId_31020', 4),
#  ('campaignId_25739', 4),
#  ('LBS_978', 4),
#  ('LBS_287', 4),
#  ('LBS_894', 4),
#  ('LBS_464', 4),
#  ('LBS_434', 4),
#  ('creativeId_1099732', 3),
#  ('LBS_623', 3),
#  ('campaignId_7686', 3),
#  ('creativeId_962151', 3),
#  ('advertiserId_45705', 3),
#  ('LBS_32', 3),
#  ('campaignId_158101', 3),
#  ('LBS_115', 3),
#  ('LBS_364', 3),
#  ('advertiserId_8668', 3),
#  ('advertiserId_6937', 3),
#  ('LBS_309', 3),
#  ('LBS_682', 3),
#  ('advertiserId_18621', 3),
#  ('creativeId_1083491', 3),
#  ('LBS_533', 3),
#  ('age_0', 3),
#  ('campaignId_286844', 3),
#  ('campaignId_745599', 3),
#  ('LBS_56', 3),
#  ('campaignId_475236', 3),
#  ('campaignId_104406', 3),
#  ('LBS_48', 3),
#  ('LBS_128', 3),
#  ('LBS_399', 3),
#  ('campaignId_12128', 3),
#  ('LBS_335', 3),
#  ('LBS_967', 3),
#  ('creativeId_1673644', 3),
#  ('LBS_219', 3),
#  ('campaignId_90700', 3),
#  ('LBS_686', 3),
#  ('LBS_609', 3),
#  ('campaignId_42625', 3),
#  ('campaignId_280832', 3),
#  ('campaignId_19215', 3),
#  ('LBS_392', 3),
#  ('LBS_176', 3),
#  ('LBS_431', 3),
#  ('LBS_194', 3),
#  ('LBS_338', 3),
#  ('campaignId_404', 3),
#  ('creativeId_1753448', 3),
#  ('LBS_116', 3),
#  ('creativeId_5977', 3),
#  ('LBS_823', 3),
#  ('campaignId_174407', 2),
#  ('campaignId_4833', 2),
#  ('creativeId_1608684', 2),
#  ('LBS_593', 2),
#  ('LBS_333', 2),
#  ('gender_0', 2),
#  ('advertiserId_915', 2),
#  ('campaignId_132657', 2),
#  ('LBS_658', 2),
#  ('LBS_576', 2),
#  ('LBS_532', 2),
#  ('LBS_170', 2),
#  ('creativeId_1236432', 2),
#  ('LBS_950', 2),
#  ('campaignId_163957', 2),
#  ('LBS_928', 2),
#  ('LBS_358', 2),
#  ('campaignId_209098', 2),
#  ('LBS_667', 2),
#  ('campaignId_766460', 2),
#  ('campaignId_219802', 2),
#  ('creativeId_476885', 2),
#  ('LBS_492', 2),
#  ('LBS_38', 2),
#  ('LBS_562', 2),
#  ('advertiserId_11487', 2),
#  ('campaignId_310473', 2),
#  ('LBS_57', 2),
#  ('LBS_71', 2),
#  ('LBS_945', 2),
#  ('LBS_986', 2),
#  ('productId_4669', 2),
#  ('adCategoryId_142', 2),
#  ('productId_12193', 2),
#  ('LBS_189', 2),
#  ('adCategoryId_59', 2),
#  ('campaignId_244601', 2),
#  ('LBS_865', 2),
#  ('advertiserId_5459', 2),
#  ('LBS_6', 2),
#  ('LBS_921', 2),
#  ('productId_0', 2),
#  ('LBS_859', 2),
#  ('advertiserId_16770', 2),
#  ('creativeId_1249596', 2),
#  ('LBS_680', 2),
#  ('LBS_268', 2),
#  ('creativeId_1360276', 2),
#  ('LBS_769', 2),
#  ('LBS_43', 2),
#  ('LBS_857', 2),
#  ('LBS_203', 2),
#  ('LBS_174', 2),
#  ('LBS_244', 2),
#  ('LBS_370', 2),
#  ('LBS_421', 2),
#  ('LBS_18', 2),
#  ('LBS_66', 2),
#  ('creativeId_1391569', 2),
#  ('LBS_711', 2),
#  ('creativeId_660519', 2),
#  ('creativeId_1513931', 2),
#  ('creativeId_1187573', 2),
#  ('advertiserId_71505', 2),
#  ('campaignId_33813', 2),
#  ('creativeId_418462', 2),
#  ('LBS_459', 2),
#  ('LBS_232', 2),
#  ('campaignId_47118', 2),
#  ('creativeId_546986', 2),
#  ('LBS_273', 2),
#  ('advertiserId_2775', 2),
#  ('LBS_127', 2),
#  ('LBS_810', 2),
#  ('LBS_319', 1),
#  ('LBS_201', 1),
#  ('LBS_813', 1),
#  ('advertiserId_41806', 1),
#  ('creativeId_492484', 1),
#  ('campaignId_420987', 1),
#  ('LBS_284', 1),
#  ('LBS_972', 1),
#  ('creativeId_108752', 1),
#  ('LBS_839', 1),
#  ('LBS_294', 1),
#  ('LBS_317', 1),
#  ('LBS_808', 1),
#  ('creativeId_638911', 1),
#  ('creativeId_1340722', 1),
#  ('LBS_385', 1),
#  ('creativeId_1172593', 1),
#  ('LBS_329', 1),
#  ('creativeId_1106145', 1),
#  ('creativeId_1628574', 1),
#  ('creativeId_220179', 1),
#  ('advertiserId_104071', 1),
#  ('campaignId_178687', 1),
#  ('LBS_270', 1),
#  ('LBS_192', 1),
#  ('LBS_310', 1),
#  ('LBS_910', 1),
#  ('LBS_946', 1),
#  ('LBS_541', 1),
#  ('adCategoryId_94', 1),
#  ('LBS_750', 1),
#  ('advertiserId_66025', 1),
#  ('campaignId_741453', 1),
#  ('campaignId_67127', 1),
#  ('creativeId_1724522', 1),
#  ('campaignId_241577', 1),
#  ('LBS_678', 1),
#  ('creativeId_332490', 1),
#  ('LBS_61', 1),
#  ('LBS_106', 1),
#  ('advertiserId_7300', 1),
#  ('LBS_312', 1),
#  ('LBS_154', 1),
#  ('LBS_131', 1),
#  ('creativeId_1500666', 1),
#  ('LBS_49', 1),
#  ('campaignId_76252', 1),
#  ('LBS_880', 1),
#  ('advertiserId_7229', 1),
#  ('LBS_246', 1),
#  ('productId_3733', 1),
#  ('LBS_954', 1),
#  ('campaignId_68476', 1),
#  ('LBS_923', 1),
#  ('LBS_165', 1),
#  ('adCategoryId_13', 1),
#  ('creativeId_1427984', 1),
#  ('LBS_366', 1),
#  ('campaignId_170445', 1),
#  ('LBS_296', 1),
#  ('LBS_638', 1),
#  ('campaignId_135565', 1),
#  ('creativeId_1655556', 1),
#  ('creativeId_883304', 1),
#  ('LBS_877', 1),
#  ('LBS_933', 1),
#  ('campaignId_262085', 1),
#  ('creativeId_202309', 1),
#  ('LBS_708', 1),
#  ('adCategoryId_22', 1),
#  ('creativeId_1321733', 1),
#  ('LBS_715', 1),
#  ('campaignId_154634', 1),
#  ('LBS_547', 1),
#  ('LBS_965', 1),
#  ('LBS_737', 1),
#  ('advertiserId_285', 1),
#  ('LBS_462', 1),
#  ('LBS_395', 1),
#  ('creativeId_58465', 1),
#  ('LBS_108', 1),
#  ('LBS_402', 1),
#  ('LBS_948', 1),
#  ('LBS_7', 1),
#  ('creativeId_1271219', 1),
#  ('advertiserId_49772', 1),
#  ('LBS_326', 1),
#  ('LBS_901', 1),
#  ('campaignId_100565', 1),
#  ('LBS_240', 1),
#  ('campaignId_63752', 1),
#  ('advertiserId_452', 1),
#  ('advertiserId_29704', 1),
#  ('campaignId_331396', 1),
#  ('LBS_105', 1),
#  ('LBS_446', 1),
#  ('advertiserId_3993', 1),
#  ('creativeId_619519', 1),
#  ('LBS_748', 1),
#  ('LBS_430', 1),
#  ('LBS_540', 1),
#  ('LBS_592', 1),
#  ('LBS_142', 1),
#  ('LBS_8', 1),
#  ('LBS_687', 1),
#  ('campaignId_645468', 1),
#  ('LBS_100', 1),
#  ('advertiserId_21017', 1),
#  ('creativeId_608495', 1),
#  ('LBS_456', 1),
#  ('LBS_271', 1),
#  ('LBS_265', 1),
#  ('LBS_530', 1),
#  ('campaignId_80', 1),
#  ('campaignId_57846', 1),
#  ('LBS_210', 1),
#  ('creativeId_666210', 1),
#  ('advertiserId_18630', 1),
#  ('advertiserId_8494', 1),
#  ('campaignId_172796', 1),
#  ('LBS_45', 1),
#  ('creativeId_884105', 1),
#  ('LBS_29', 1),
#  ('LBS_803', 1),
#  ('creativeId_1367823', 1),
#  ('LBS_87', 1),
#  ('LBS_816', 1),
#  ('advertiserId_5758', 1),
#  ('LBS_486', 1),
#  ('LBS_225', 1),
#  ('LBS_62', 1),
#  ('creativeId_240336', 1),
#  ('campaignId_42614', 1),
#  ('campaignId_170485', 1),
#  ('LBS_101', 1),
#  ('LBS_939', 1),
#  ('creativeId_838056', 1),
#  ('campaignId_42104', 1),
#  ('campaignId_662422', 1),
#  ('LBS_263', 1),
#  ('LBS_567', 1),
#  ('LBS_652', 1),
#  ('LBS_121', 1),
#  ('productId_439', 0),
#  ('LBS_161', 0),
#  ('LBS_657', 0),
#  ('adCategoryId_81', 0),
#  ('LBS_695', 0),
#  ('LBS_428', 0),
#  ('LBS_649', 0),
#  ('LBS_125', 0),
#  ('productId_38', 0),
#  ('LBS_897', 0),
#  ('LBS_917', 0),
#  ('LBS_955', 0),
#  ('LBS_549', 0),
#  ('LBS_794', 0),
#  ('LBS_429', 0),
#  ('LBS_82', 0),
#  ('campaignId_199508', 0),
#  ('LBS_721', 0),
#  ('LBS_792', 0),
#  ('LBS_504', 0),
#  ('creativeId_477814', 0),
#  ('LBS_940', 0),
#  ('LBS_371', 0),
#  ('LBS_426', 0),
#  ('creativeId_154811', 0),
#  ('LBS_410', 0),
#  ('LBS_507', 0),
#  ('LBS_550', 0),
#  ('creativeId_869346', 0),
#  ('LBS_403', 0),
#  ('creativeId_43877', 0),
#  ('LBS_588', 0),
#  ('LBS_120', 0),
#  ('LBS_494', 0),
#  ('LBS_132', 0),
#  ('LBS_626', 0),
#  ('LBS_706', 0),
#  ('LBS_835', 0),
#  ('LBS_544', 0),
#  ('LBS_353', 0),
#  ('LBS_768', 0),
#  ('LBS_316', 0),
#  ('LBS_988', 0),
#  ('LBS_870', 0),
#  ('creativeId_220558', 0),
#  ('creativeId_1464074', 0),
#  ('LBS_69', 0),
#  ('creativeId_1146648', 0),
#  ('LBS_579', 0),
#  ('LBS_597', 0),
#  ('productId_70', 0),
#  ('LBS_966', 0),
#  ('LBS_286', 0),
#  ('LBS_250', 0),
#  ('LBS_817', 0),
#  ('LBS_524', 0),
#  ('LBS_665', 0),
#  ('creativeId_1354071', 0),
#  ('LBS_633', 0),
#  ('LBS_788', 0),
#  ('advertiserId_7565', 0),
#  ('LBS_103', 0),
#  ('campaignId_86429', 0),
#  ('LBS_50', 0),
#  ('creativeId_469197', 0),
#  ('campaignId_134120', 0),
#  ('LBS_793', 0),
#  ('LBS_860', 0),
#  ('LBS_643', 0),
#  ('creativeId_1083112', 0),
#  ('LBS_291', 0),
#  ('productId_5336', 0),
#  ('LBS_887', 0),
#  ('creativeId_991964', 0),
#  ('LBS_671', 0),
#  ('adCategoryId_149', 0),
#  ('productId_3791', 0),
#  ('LBS_163', 0),
#  ('creativeId_1305307', 0),
#  ('LBS_688', 0),
#  ('creativeId_979528', 0),
#  ('LBS_322', 0),
#  ('LBS_685', 0),
#  ('LBS_916', 0),
#  ('creativeId_43862', 0),
#  ('LBS_539', 0),
#  ('LBS_474', 0),
#  ('LBS_766', 0),
#  ('LBS_298', 0),
#  ('LBS_696', 0),
#  ('creativeId_1702986', 0),
#  ('LBS_217', 0),
#  ('LBS_926', 0),
#  ('creativeId_1266652', 0),
#  ('LBS_2', 0),
#  ('LBS_104', 0),
#  ('LBS_990', 0),
#  ('creativeId_832650', 0),
#  ('creativeId_565415', 0),
#  ('LBS_159', 0),
#  ('LBS_102', 0),
#  ('LBS_858', 0),
#  ('LBS_355', 0),
#  ('creativeId_731679', 0),
#  ('LBS_229', 0),
#  ('LBS_570', 0),
#  ('LBS_655', 0),
#  ('LBS_158', 0),
#  ('LBS_267', 0),
#  ('LBS_336', 0),
#  ('creativeId_1451219', 0),
#  ('creativeId_767513', 0),
#  ('adCategoryId_282', 0),
#  ('LBS_236', 0),
#  ('LBS_775', 0),
#  ('LBS_144', 0),
#  ('LBS_883', 0),
#  ('LBS_468', 0),
#  ('creativeId_864509', 0),
#  ('LBS_872', 0),
#  ('LBS_746', 0),
#  ('LBS_415', 0),
#  ('LBS_970', 0),
#  ('productId_15454', 0),
#  ('LBS_518', 0),
#  ('LBS_119', 0),
#  ('LBS_617', 0),
#  ('LBS_218', 0),
#  ('creativeId_1758880', 0),
#  ('LBS_314', 0),
#  ('LBS_956', 0),
#  ('LBS_796', 0),
#  ('creativeId_1383456', 0),
#  ('creativeId_1606251', 0),
#  ('LBS_644', 0),
#  ('LBS_482', 0),
#  ('campaignId_473537', 0),
#  ('LBS_563', 0),
#  ('LBS_938', 0),
#  ('LBS_412', 0),
#  ('LBS_510', 0),
#  ('LBS_936', 0),
#  ('LBS_477', 0),
#  ('LBS_538', 0),
#  ('LBS_527', 0),
#  ('adCategoryId_100', 0),
#  ('LBS_909', 0),
#  ('LBS_10', 0),
#  ('creativeId_838455', 0),
#  ('LBS_274', 0),
#  ('LBS_502', 0),
#  ('LBS_297', 0),
#  ('LBS_893', 0),
#  ('LBS_362', 0),
#  ('LBS_357', 0),
#  ('creativeId_1441131', 0),
#  ('LBS_373', 0),
#  ('LBS_554', 0),
#  ('LBS_856', 0),
#  ('LBS_137', 0),
#  ('LBS_922', 0),
#  ('adCategoryId_8', 0),
#  ('LBS_779', 0),
#  ('LBS_759', 0),
#  ('LBS_347', 0),
#  ('LBS_253', 0),
#  ('LBS_184', 0),
#  ('LBS_451', 0),
#  ('LBS_406', 0),
#  ('LBS_23', 0),
#  ('LBS_765', 0),
#  ('LBS_993', 0),
#  ('LBS_327', 0),
#  ('LBS_892', 0),
#  ('LBS_927', 0),
#  ('LBS_996', 0),
#  ('LBS_758', 0),
#  ('LBS_484', 0),
#  ('productId_16791', 0),
#  ('LBS_53', 0),
#  ('LBS_448', 0),
#  ('LBS_356', 0),
#  ('LBS_11', 0),
#  ('campaignId_155063', 0),
#  ('LBS_375', 0),
#  ('LBS_632', 0),
#  ('LBS_630', 0),
#  ('LBS_80', 0),
#  ('creativeId_474978', 0),
#  ('LBS_580', 0),
#  ('campaignId_51315', 0),
#  ('creativeId_1016027', 0),
#  ('LBS_281', 0),
#  ('LBS_95', 0),
#  ('LBS_824', 0),
#  ('LBS_19', 0),
#  ('LBS_929', 0),
#  ('campaignId_378648', 0),
#  ('productId_27855', 0),
#  ('creativeId_1512679', 0),
#  ('LBS_890', 0),
#  ('LBS_525', 0),
#  ('LBS_875', 0),
#  ('LBS_645', 0),
#  ('campaignId_10460', 0),
#  ('LBS_536', 0),
#  ('LBS_994', 0),
#  ('campaignId_18237', 0),
#  ('LBS_734', 0),
#  ('LBS_83', 0),
#  ('LBS_991', 0),
#  ('LBS_819', 0),
#  ('LBS_797', 0),
#  ('LBS_413', 0),
#  ('LBS_739', 0),
#  ('LBS_200', 0),
#  ('LBS_91', 0),
#  ('LBS_65', 0),
#  ('creativeId_1554384', 0),
#  ('LBS_811', 0),
#  ('LBS_937', 0),
#  ('LBS_850', 0),
#  ('LBS_963', 0),
#  ('LBS_930', 0),
#  ('campaignId_204378', 0),
#  ('creativeId_1589088', 0),
#  ('LBS_99', 0),
#  ('LBS_959', 0),
#  ('creativeId_192305', 0),
#  ('campaignId_1123', 0),
#  ('campaignId_40877', 0),
#  ('LBS_495', 0),
#  ('adCategoryId_218', 0),
#  ('LBS_315', 0),
#  ('LBS_135', 0),
#  ('creativeId_1205997', 0),
#  ('LBS_717', 0),
#  ('LBS_804', 0),
#  ('LBS_419', 0),
#  ('LBS_740', 0),
#  ('campaignId_186348', 0),
#  ('LBS_379', 0),
#  ('LBS_350', 0),
#  ('LBS_866', 0),
#  ('LBS_292', 0),
#  ('creativeId_585909', 0),
#  ('adCategoryId_137', 0),
#  ('LBS_261', 0),
#  ('advertiserId_75748', 0),
#  ('advertiserId_11459', 0),
#  ('LBS_460', 0),
#  ('productId_17614', 0),
#  ('LBS_627', 0),
#  ('LBS_509', 0),
#  ('LBS_157', 0),
#  ('productId_14314', 0),
#  ('LBS_381', 0),
#  ('LBS_914', 0),
#  ('LBS_461', 0),
#  ('creativeId_1442655', 0),
#  ('LBS_902', 0),
#  ('LBS_442', 0),
#  ('creativeId_425385', 0),
#  ('LBS_848', 0),
#  ('LBS_971', 0),
#  ('creativeId_1769240', 0),
#  ('LBS_616', 0),
#  ('LBS_490', 0),
#  ('creativeId_416399', 0),
#  ('LBS_145', 0),
#  ('LBS_885', 0),
#  ('LBS_543', 0),
#  ('LBS_942', 0),
#  ('LBS_763', 0),
#  ('LBS_513', 0),
#  ('LBS_1', 0),
#  ('campaignId_36763', 0),
#  ('campaignId_169332', 0),
#  ('creativeId_287080', 0),
#  ('LBS_845', 0),
#  ('creativeId_745048', 0),
#  ('LBS_63', 0),
#  ('LBS_452', 0),
#  ('creativeId_210057', 0),
#  ('LBS_653', 0),
#  ('LBS_199', 0),
#  ('LBS_107', 0),
#  ('LBS_25', 0),
#  ('LBS_677', 0),
#  ('LBS_272', 0),
#  ('LBS_724', 0),
#  ('LBS_81', 0),
#  ('productId_19256', 0),
#  ('LBS_197', 0),
#  ('LBS_557', 0),
#  ('LBS_844', 0),
#  ('creativeId_1562482', 0),
#  ('LBS_407', 0),
#  ('LBS_254', 0),
#  ('LBS_666', 0),
#  ('LBS_559', 0),
#  ('LBS_374', 0),
#  ('LBS_560', 0),
#  ('adCategoryId_30', 0),
#  ('LBS_185', 0),
#  ('campaignId_73450', 0),
#  ('creativeId_1040130', 0),
#  ('LBS_767', 0),
#  ('adCategoryId_265', 0),
#  ('LBS_242', 0),
#  ('LBS_238', 0),
#  ('creativeId_1612095', 0),
#  ('LBS_730', 0),
#  ('creativeId_1661158', 0),
#  ('adCategoryId_121', 0),
#  ('creativeId_221432', 0),
#  ('LBS_60', 0),
#  ('LBS_183', 0),
#  ('LBS_467', 0),
#  ('LBS_40', 0),
#  ('LBS_663', 0),
#  ('creativeId_1211265', 0),
#  ('LBS_634', 0),
#  ('LBS_795', 0),
#  ('LBS_582', 0),
#  ('LBS_612', 0),
#  ('LBS_288', 0),
#  ('LBS_417', 0),
#  ('creativeId_1772271', 0),
#  ('LBS_624', 0),
#  ('creativeId_904288', 0),
#  ('LBS_435', 0),
#  ('campaignId_487541', 0),
#  ('campaignId_358059', 0),
#  ('LBS_761', 0),
#  ('LBS_191', 0),
#  ('advertiserId_7926', 0),
#  ('LBS_506', 0),
#  ('adCategoryId_140', 0),
#  ('LBS_304', 0),
#  ('LBS_534', 0),
#  ('campaignId_131853', 0),
#  ('LBS_89', 0),
#  ('campaignId_643438', 0),
#  ('LBS_354', 0),
#  ('creativeId_1401261', 0),
#  ('LBS_234', 0),
#  ('LBS_997', 0),
#  ('LBS_449', 0),
#  ('LBS_457', 0),
#  ('LBS_211', 0),
#  ('LBS_822', 0),
#  ('LBS_512', 0),
#  ('LBS_806', 0),
#  ('LBS_594', 0),
#  ('LBS_641', 0),
#  ('LBS_826', 0),
#  ('LBS_862', 0),
#  ('productId_4772', 0),
#  ('LBS_14', 0),
#  ('campaignId_734054', 0),
#  ('LBS_215', 0),
#  ('LBS_689', 0),
#  ('LBS_556', 0),
#  ('campaignId_994', 0),
#  ('LBS_791', 0),
#  ('LBS_476', 0),
#  ('LBS_302', 0),
#  ('LBS_377', 0),
#  ('creativeId_717054', 0),
#  ('productId_542', 0),
#  ('LBS_572', 0),
#  ('LBS_719', 0),
#  ('creativeId_731893', 0),
#  ('LBS_70', 0),
#  ('creativeId_913588', 0),
#  ('LBS_175', 0),
#  ('LBS_736', 0),
#  ('LBS_212', 0),
#  ('LBS_306', 0),
#  ('campaignId_141893', 0),
#  ('LBS_153', 0),
#  ('campaignId_84178', 0),
#  ('LBS_889', 0),
#  ('LBS_485', 0),
#  ('LBS_849', 0),
#  ('campaignId_352827', 0),
#  ('LBS_130', 0),
#  ('LBS_827', 0),
#  ('LBS_499', 0),
#  ('LBS_743', 0),
#  ('creativeId_181137', 0),
#  ('LBS_720', 0),
#  ('LBS_545', 0),
#  ('LBS_611', 0),
#  ('LBS_487', 0),
#  ('LBS_76', 0),
#  ('LBS_54', 0),
#  ('LBS_423', 0),
#  ('LBS_684', 0),
#  ('creativeId_141973', 0),
#  ('LBS_491', 0),
#  ('LBS_36', 0),
#  ('LBS_838', 0),
#  ('advertiserId_9571', 0),
#  ('LBS_828', 0),
#  ('LBS_[nan]', 0),
#  ('campaignId_76011', 0),
#  ('LBS_321', 0),
#  ('LBS_551', 0),
#  ('campaignId_3372', 0),
#  ('LBS_325', 0),
#  ('LBS_852', 0),
#  ('LBS_679', 0),
#  ('LBS_365', 0),
#  ('LBS_380', 0),
#  ('LBS_911', 0),
#  ('adCategoryId_25', 0),
#  ('LBS_67', 0),
#  ('LBS_873', 0),
#  ('LBS_789', 0),
#  ('LBS_344', 0),
#  ('LBS_489', 0),
#  ('LBS_151', 0),
#  ('adCategoryId_179', 0),
#  ('LBS_352', 0),
#  ('LBS_389', 0),
#  ('LBS_515', 0),
#  ('LBS_439', 0),
#  ('LBS_698', 0),
#  ('LBS_755', 0),
#  ('LBS_596', 0),
#  ('productId_13727', 0),
#  ('LBS_68', 0),
#  ('creativeId_792238', 0),
#  ('creativeId_1080962', 0),
#  ('LBS_742', 0),
#  ('LBS_618', 0),
#  ('LBS_31', 0),
#  ('LBS_190', 0),
#  ('creativeId_145496', 0),
#  ('creativeId_797661', 0),
#  ('creativeId_808799', 0),
#  ('creativeId_1462184', 0),
#  ('LBS_605', 0),
#  ('LBS_441', 0),
#  ('LBS_147', 0),
#  ('LBS_615', 0),
#  ('LBS_573', 0),
#  ('productId_9760', 0),
#  ('campaignId_26003', 0),
#  ('creativeId_1229175', 0),
#  ('LBS_126', 0),
#  ('creativeId_1260597', 0),
#  ('LBS_416', 0),
#  ('LBS_853', 0),
#  ('LBS_968', 0),
#  ('campaignId_464828', 0),
#  ('creativeId_1494257', 0),
#  ('LBS_437', 0),
#  ('LBS_898', 0),
#  ('campaignId_167166', 0),
#  ('LBS_575', 0),
#  ('creativeId_1765755', 0),
#  ('LBS_198', 0),
#  ('LBS_51', 0),
#  ('campaignId_61383', 0),
#  ('LBS_4', 0),
#  ('LBS_303', 0),
#  ('LBS_642', 0),
#  ('LBS_243', 0),
#  ('advertiserId_20943', 0),
#  ('LBS_282', 0),
#  ('LBS_974', 0),
#  ('LBS_829', 0),
#  ('LBS_587', 0),
#  ('LBS_718', 0),
#  ('creativeId_440096', 0),
#  ('LBS_669', 0),
#  ('LBS_235', 0),
#  ('LBS_149', 0),
#  ('LBS_601', 0),
#  ('LBS_404', 0),
#  ('LBS_919', 0),
#  ('LBS_725', 0),
#  ('LBS_117', 0),
#  ('adCategoryId_9', 0),
#  ('LBS_578', 0),
#  ('LBS_735', 0),
#  ('campaignId_7527', 0),
#  ('LBS_636', 0),
#  ('creativeId_131847', 0),
#  ('LBS_118', 0),
#  ('campaignId_159118', 0),
#  ('LBS_289', 0),
#  ('campaignId_59293', 0),
#  ('LBS_871', 0),
#  ('LBS_186', 0),
#  ('LBS_987', 0),
#  ('LBS_650', 0),
#  ('creativeId_72027', 0),
#  ('creativeId_1160702', 0),
#  ('LBS_224', 0),
#  ('LBS_581', 0),
#  ('LBS_886', 0),
#  ('LBS_30', 0),
#  ('LBS_569', 0),
#  ('LBS_953', 0),
#  ('LBS_245', 0),
#  ('adCategoryId_192', 0),
#  ('LBS_360', 0),
#  ('LBS_97', 0),
#  ('LBS_173', 0),
#  ('LBS_171', 0),
#  ('LBS_961', 0),
#  ('LBS_741', 0),
#  ('campaignId_23303', 0),
#  ('LBS_307', 0),
#  ('LBS_455', 0),
#  ('LBS_427', 0),
#  ('LBS_631', 0),
#  ('creativeId_1640724', 0),
#  ('LBS_251', 0),
#  ('LBS_912', 0),
#  ('LBS_305', 0),
#  ('LBS_753', 0),
#  ('LBS_9', 0),
#  ('LBS_420', 0),
#  ('LBS_220', 0),
#  ('LBS_754', 0),
#  ('LBS_697', 0),
#  ('LBS_39', 0),
#  ('LBS_122', 0),
#  ('LBS_798', 0),
#  ('LBS_598', 0),
#  ('LBS_367', 0),
#  ('campaignId_233191', 0),
#  ('LBS_123', 0),
#  ('LBS_613', 0),
#  ('LBS_252', 0),
#  ('LBS_651', 0),
#  ('LBS_181', 0),
#  ('LBS_168', 0),
#  ('LBS_328', 0),
#  ('LBS_55', 0),
#  ('LBS_861', 0),
#  ('LBS_840', 0),
#  ('LBS_445', 0),
#  ('LBS_878', 0),
#  ('LBS_621', 0),
#  ('LBS_262', 0),
#  ('LBS_359', 0),
#  ('LBS_323', 0),
#  ('LBS_661', 0),
#  ('LBS_311', 0),
#  ('LBS_111', 0),
#  ('LBS_498', 0),
#  ('LBS_659', 0),
#  ('LBS_702', 0),
#  ('LBS_935', 0),
#  ('productId_25730', 0),
#  ('LBS_86', 0),
#  ('LBS_707', 0),
#  ('LBS_408', 0),
#  ('campaignId_18683', 0),
#  ('productId_28986', 0),
#  ('LBS_683', 0),
#  ('LBS_280', 0),
#  ('LBS_716', 0),
#  ('LBS_414', 0),
#  ('LBS_369', 0),
#  ('LBS_729', 0),
#  ('LBS_952', 0),
#  ('LBS_259', 0),
#  ('LBS_92', 0),
#  ('LBS_277', 0),
#  ('LBS_388', 0),
#  ('LBS_976', 0),
#  ('LBS_751', 0),
#  ('LBS_177', 0),
#  ('LBS_814', 0)]
