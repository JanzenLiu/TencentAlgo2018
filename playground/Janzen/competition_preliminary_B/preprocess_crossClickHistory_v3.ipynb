# %%
from sklearn.model_selection import StratifiedKFold
import pandas as pd
import numpy as np
import operator
import pickle
import tqdm
import time
import os
import gc
import matplotlib.pyplot as plt
import sys
sys.path.append("../../../code/utils")
sys.path.append("../../../code/feature")
sys.path.append("../../../code/pipeline")
sys.path.append("../../../code")
import data_jointer as dj
import data_utils as du
import perf_utils as pu
from clickrate import BayesianSmoothedClickrate
import history
import config

# %%
clickhist_folder = os.path.join(config.DATA_DIR, "click_history/user_cross")


def click_history_fold_dir(num_folds, create=True):
    folder = "{}[StratifiedKFold_{}]".format(clickhist_folder, num_folds)
    if create:
        os.makedirs(folder, exist_ok=True)
    return folder


def click_history_path(num_folds, fold_index, user_feat_name1, user_feat_name2, user1_val, create=True):
    folder = click_history_fold_dir(num_folds, create)
    folder = os.path.join(folder, str(fold_index), "[featureName='{}']".format(user_feat_name2))
    filename = "[{}='{}'].csv".format(user_feat_name1, user1_val)
    filepath = os.path.join(folder, filename)
    if create:
        os.makedirs(folder, exist_ok=True)
    return filepath


def load_split_indices(num_folds):
    fold_dir = os.path.join(config.DATA_DIR, "click_history/simple_cross/byUserFeatureName")
    fold_dir = "{}[StratifiedKFold_{}]".format(fold_dir, num_folds)
    index_file = "indices.pkl"
    index_path = os.path.join(fold_dir, index_file)
    split_indices = du.load_pickle(index_path)
    return split_indices

# %%
n_splits = 5
split_indices = load_split_indices(n_splits)

pair_dict = {}
for i, user_feat1 in enumerate(config.USER_SINGLE_FEAT_NAMES[:-1]):
    pair_dict[user_feat1] = config.USER_SINGLE_FEAT_NAMES[i + 1:]

df_train = du.load_raw_data("train")
df_test = du.load_raw_data("test2")
train_size = df_train.shape[0]
test_size = df_test.shape[0]

train = df_train.copy()
user_jointer = dj.PandasPandasJointer("uid")
for ufeat in config.USER_SINGLE_FEAT_NAMES:
    with pu.profiler("loading and joining '{}'".format(ufeat)):
        df_feat = du.load_user_feature(ufeat).fillna("[nan]")
        train = user_jointer.join(df1=train, df2=df_feat)
assert train.isnull().sum().sum() == 0
# Out:
# [14:53:26] Finish loading and joining 'age'. △M: +330.41MB. △T: 11.0 seconds.
# [14:53:37] Finish loading and joining 'gender'. △M: +67.16MB. △T: 10.5 seconds.
# [14:53:47] Finish loading and joining 'education'. △M: +67.14MB. △T: 10.7 seconds.
# [14:53:58] Finish loading and joining 'consumptionAbility'. △M: +67.13MB. △T: 11.0 seconds.
# [14:54:10] Finish loading and joining 'LBS'. △M: +68.38MB. △T: 11.7 seconds.
# [14:54:22] Finish loading and joining 'carrier'. △M: +67.13MB. △T: 12.1 seconds.
# [14:54:35] Finish loading and joining 'house'. △M: +67.13MB. △T: 12.7 seconds.

# %%
# ad_feat_name <=> user_feat_name1
# user_feat_name <=> user_feat_name2
for user_feat_name2, user_feat_names1 in pair_dict.items():
    row_uids, (val_to_index, matrix) = du.load_user_cnt(user_feat_name2)
    col_names = history.dict_to_list(val_to_index)
    for user_feat_name1 in user_feat_names1:
        avals_unique = train[user_feat_name1].unique()
        kfold_manager = history.MatrixCounterManager(matrix, col_names, row_uids, train, 
                                                     groupby=user_feat_name1, gvals=avals_unique)
        for i, (train_index, valid_index) in enumerate(split_indices):
            with pu.profiler("counting '{}' x '{}' fold {}/{} ...".format(user_feat_name2, user_feat_name1, 
                                                                          i + 1, n_splits)):
                mc = kfold_manager.build_matrix_counter(train_index)
                for aval in avals_unique:
                    out_path = click_history_path(n_splits, i, user_feat_name1, user_feat_name2, aval)
                    df_records = mc.group_count(aval)
                    df_records.rename(columns={1: "positive", -1:"negative"}, inplace=True)
                    df_records = df_records[["value", "positive", "negative"]]
                    df_records.to_csv(out_path, index=False)
                    del df_records
                del mc
                gc.collect()
# Out:
# [14:55:16] Finish counting 'carrier' x 'house' fold 1/5 .... △M: -12.91MB. △T: 34.8 seconds.
# [14:55:50] Finish counting 'carrier' x 'house' fold 2/5 .... △M: +2.07MB. △T: 34.3 seconds.
# [14:56:21] Finish counting 'carrier' x 'house' fold 3/5 .... △M: +4.0KB. △T: 30.9 seconds.
# [14:56:52] Finish counting 'carrier' x 'house' fold 4/5 .... △M: +0B. △T: 30.8 seconds.
# [14:57:24] Finish counting 'carrier' x 'house' fold 5/5 .... △M: +4.0KB. △T: 32.3 seconds.
# [14:57:58] Finish counting 'LBS' x 'carrier' fold 1/5 .... △M: +41.93MB. △T: 33.5 seconds.
# [14:58:31] Finish counting 'LBS' x 'carrier' fold 2/5 .... △M: -256.0KB. △T: 32.6 seconds.
# [14:59:03] Finish counting 'LBS' x 'carrier' fold 3/5 .... △M: -12.0KB. △T: 32.2 seconds.
# [14:59:38] Finish counting 'LBS' x 'carrier' fold 4/5 .... △M: +16.0KB. △T: 35.3 seconds.
# [15:00:11] Finish counting 'LBS' x 'carrier' fold 5/5 .... △M: -8.0KB. △T: 32.6 seconds.
# [15:00:42] Finish counting 'LBS' x 'house' fold 1/5 .... △M: -1.56MB. △T: 31.4 seconds.
# [15:01:13] Finish counting 'LBS' x 'house' fold 2/5 .... △M: -48.0KB. △T: 30.7 seconds.
# [15:01:45] Finish counting 'LBS' x 'house' fold 3/5 .... △M: +1.07MB. △T: 31.7 seconds.
# [15:02:18] Finish counting 'LBS' x 'house' fold 4/5 .... △M: -1.05MB. △T: 32.9 seconds.
# [15:02:50] Finish counting 'LBS' x 'house' fold 5/5 .... △M: +4.0KB. △T: 32.4 seconds.
# [15:03:22] Finish counting 'education' x 'consumptionAbility' fold 1/5 .... △M: +53.09MB. △T: 31.8 seconds.
# [15:03:56] Finish counting 'education' x 'consumptionAbility' fold 2/5 .... △M: +184.0KB. △T: 33.4 seconds.
# [15:04:28] Finish counting 'education' x 'consumptionAbility' fold 3/5 .... △M: -232.0KB. △T: 32.2 seconds.
# [15:05:00] Finish counting 'education' x 'consumptionAbility' fold 4/5 .... △M: +200.0KB. △T: 32.4 seconds.
# [15:05:31] Finish counting 'education' x 'consumptionAbility' fold 5/5 .... △M: -192.0KB. △T: 30.9 seconds.
# [15:06:11] Finish counting 'education' x 'LBS' fold 1/5 .... △M: +232.62MB. △T: 39.0 seconds.
# [15:06:54] Finish counting 'education' x 'LBS' fold 2/5 .... △M: +12.81MB. △T: 43.7 seconds.
# [15:07:41] Finish counting 'education' x 'LBS' fold 3/5 .... △M: +12.58MB. △T: 47.0 seconds.
# [15:08:29] Finish counting 'education' x 'LBS' fold 4/5 .... △M: +32.0KB. △T: 47.8 seconds.
# [15:09:15] Finish counting 'education' x 'LBS' fold 5/5 .... △M: -260.0KB. △T: 45.8 seconds.
# [15:09:54] Finish counting 'education' x 'carrier' fold 1/5 .... △M: -19.95MB. △T: 38.5 seconds.
# [15:10:32] Finish counting 'education' x 'carrier' fold 2/5 .... △M: +0B. △T: 38.7 seconds.
# [15:11:11] Finish counting 'education' x 'carrier' fold 3/5 .... △M: +4.0KB. △T: 39.1 seconds.
# [15:11:59] Finish counting 'education' x 'carrier' fold 4/5 .... △M: +0B. △T: 47.2 seconds.
# [15:12:46] Finish counting 'education' x 'carrier' fold 5/5 .... △M: +0B. △T: 47.7 seconds.
# [15:13:30] Finish counting 'education' x 'house' fold 1/5 .... △M: -7.52MB. △T: 43.8 seconds.
# [15:14:10] Finish counting 'education' x 'house' fold 2/5 .... △M: -12.0KB. △T: 39.3 seconds.
# [15:14:52] Finish counting 'education' x 'house' fold 3/5 .... △M: +10.76MB. △T: 41.8 seconds.
# [15:15:29] Finish counting 'education' x 'house' fold 4/5 .... △M: -10.75MB. △T: 37.2 seconds.
# [15:16:03] Finish counting 'education' x 'house' fold 5/5 .... △M: +0B. △T: 34.5 seconds.
# [15:16:41] Finish counting 'age' x 'gender' fold 1/5 .... △M: +38.69MB. △T: 37.1 seconds.
# [15:17:21] Finish counting 'age' x 'gender' fold 2/5 .... △M: -4.0KB. △T: 40.3 seconds.
# [15:17:55] Finish counting 'age' x 'gender' fold 3/5 .... △M: -16.0KB. △T: 33.6 seconds.
# [15:18:29] Finish counting 'age' x 'gender' fold 4/5 .... △M: +28.0KB. △T: 34.1 seconds.
# [15:19:02] Finish counting 'age' x 'gender' fold 5/5 .... △M: +4.0KB. △T: 33.4 seconds.
# [15:19:37] Finish counting 'age' x 'education' fold 1/5 .... △M: -844.0KB. △T: 34.4 seconds.
# [15:20:11] Finish counting 'age' x 'education' fold 2/5 .... △M: -52.81MB. △T: 34.0 seconds.
# [15:20:44] Finish counting 'age' x 'education' fold 3/5 .... △M: +53.03MB. △T: 33.3 seconds.
# [15:21:18] Finish counting 'age' x 'education' fold 4/5 .... △M: -53.03MB. △T: 34.1 seconds.
# [15:21:54] Finish counting 'age' x 'education' fold 5/5 .... △M: +53.03MB. △T: 35.7 seconds.
# [15:22:29] Finish counting 'age' x 'consumptionAbility' fold 1/5 .... △M: -5.03MB. △T: 34.8 seconds.
# [15:23:06] Finish counting 'age' x 'consumptionAbility' fold 2/5 .... △M: +0B. △T: 36.5 seconds.
# [15:23:40] Finish counting 'age' x 'consumptionAbility' fold 3/5 .... △M: +0B. △T: 34.7 seconds.
# [15:24:13] Finish counting 'age' x 'consumptionAbility' fold 4/5 .... △M: +0B. △T: 32.8 seconds.
# [15:24:47] Finish counting 'age' x 'consumptionAbility' fold 5/5 .... △M: +0B. △T: 33.8 seconds.
# [15:25:29] Finish counting 'age' x 'LBS' fold 1/5 .... △M: +124.0KB. △T: 42.2 seconds.
# [15:26:11] Finish counting 'age' x 'LBS' fold 2/5 .... △M: +252.0KB. △T: 41.7 seconds.
# [15:26:52] Finish counting 'age' x 'LBS' fold 3/5 .... △M: -48.0KB. △T: 41.0 seconds.
# [15:27:33] Finish counting 'age' x 'LBS' fold 4/5 .... △M: +32.0KB. △T: 40.9 seconds.
# [15:28:12] Finish counting 'age' x 'LBS' fold 5/5 .... △M: -8.0KB. △T: 39.3 seconds.
# [15:28:45] Finish counting 'age' x 'carrier' fold 1/5 .... △M: -32.08MB. △T: 32.6 seconds.
# [15:29:18] Finish counting 'age' x 'carrier' fold 2/5 .... △M: +0B. △T: 33.1 seconds.
# [15:29:52] Finish counting 'age' x 'carrier' fold 3/5 .... △M: +0B. △T: 33.8 seconds.
# [15:30:26] Finish counting 'age' x 'carrier' fold 4/5 .... △M: +0B. △T: 33.9 seconds.
# [15:30:58] Finish counting 'age' x 'carrier' fold 5/5 .... △M: +0B. △T: 32.2 seconds.
# [15:31:31] Finish counting 'age' x 'house' fold 1/5 .... △M: -16.0MB. △T: 32.7 seconds.
# [15:32:05] Finish counting 'age' x 'house' fold 2/5 .... △M: -256.0KB. △T: 34.0 seconds.
# [15:32:38] Finish counting 'age' x 'house' fold 3/5 .... △M: +0B. △T: 32.5 seconds.
# [15:33:11] Finish counting 'age' x 'house' fold 4/5 .... △M: +0B. △T: 33.3 seconds.
# [15:33:44] Finish counting 'age' x 'house' fold 5/5 .... △M: +0B. △T: 33.2 seconds.
# [15:34:18] Finish counting 'gender' x 'education' fold 1/5 .... △M: +50.65MB. △T: 33.0 seconds.
# [15:34:50] Finish counting 'gender' x 'education' fold 2/5 .... △M: -61.54MB. △T: 32.8 seconds.
# [15:35:25] Finish counting 'gender' x 'education' fold 3/5 .... △M: +61.54MB. △T: 34.6 seconds.
# [15:35:59] Finish counting 'gender' x 'education' fold 4/5 .... △M: -61.54MB. △T: 33.9 seconds.
# [15:36:32] Finish counting 'gender' x 'education' fold 5/5 .... △M: +61.53MB. △T: 33.5 seconds.
# [15:37:07] Finish counting 'gender' x 'consumptionAbility' fold 1/5 .... △M: -61.53MB. △T: 34.4 seconds.
# [15:37:41] Finish counting 'gender' x 'consumptionAbility' fold 2/5 .... △M: +10.23MB. △T: 34.2 seconds.
# [15:38:16] Finish counting 'gender' x 'consumptionAbility' fold 3/5 .... △M: +4.0KB. △T: 35.2 seconds.
# [15:38:51] Finish counting 'gender' x 'consumptionAbility' fold 4/5 .... △M: -12.0KB. △T: 34.5 seconds.
# [15:39:26] Finish counting 'gender' x 'consumptionAbility' fold 5/5 .... △M: +4.0KB. △T: 35.1 seconds.
# [15:40:09] Finish counting 'gender' x 'LBS' fold 1/5 .... △M: +26.0MB. △T: 42.3 seconds.
# [15:40:51] Finish counting 'gender' x 'LBS' fold 2/5 .... △M: -4.0KB. △T: 41.8 seconds.
# [15:41:33] Finish counting 'gender' x 'LBS' fold 3/5 .... △M: -48.0KB. △T: 42.6 seconds.
# [15:42:16] Finish counting 'gender' x 'LBS' fold 4/5 .... △M: +32.0KB. △T: 42.9 seconds.
# [15:42:59] Finish counting 'gender' x 'LBS' fold 5/5 .... △M: -8.0KB. △T: 42.7 seconds.
# [15:43:34] Finish counting 'gender' x 'carrier' fold 1/5 .... △M: -19.95MB. △T: 35.4 seconds.
# [15:44:09] Finish counting 'gender' x 'carrier' fold 2/5 .... △M: +0B. △T: 34.6 seconds.
# [15:44:42] Finish counting 'gender' x 'carrier' fold 3/5 .... △M: +0B. △T: 33.3 seconds.
# [15:45:16] Finish counting 'gender' x 'carrier' fold 4/5 .... △M: +0B. △T: 33.5 seconds.
# [15:45:49] Finish counting 'gender' x 'carrier' fold 5/5 .... △M: +0B. △T: 32.7 seconds.
# [15:46:22] Finish counting 'gender' x 'house' fold 1/5 .... △M: -7.77MB. △T: 32.8 seconds.
# [15:46:54] Finish counting 'gender' x 'house' fold 2/5 .... △M: -16.0KB. △T: 32.6 seconds.
# [15:47:27] Finish counting 'gender' x 'house' fold 3/5 .... △M: +0B. △T: 33.1 seconds.
# [15:48:02] Finish counting 'gender' x 'house' fold 4/5 .... △M: +4.0KB. △T: 34.4 seconds.
# [15:48:35] Finish counting 'gender' x 'house' fold 5/5 .... △M: +0B. △T: 33.2 seconds.
# [15:49:16] Finish counting 'consumptionAbility' x 'LBS' fold 1/5 .... △M: +36.11MB. △T: 40.8 seconds.
# [15:49:57] Finish counting 'consumptionAbility' x 'LBS' fold 2/5 .... △M: -4.0KB. △T: 41.0 seconds.
# [15:50:41] Finish counting 'consumptionAbility' x 'LBS' fold 3/5 .... △M: -48.0KB. △T: 44.1 seconds.
# [15:51:22] Finish counting 'consumptionAbility' x 'LBS' fold 4/5 .... △M: +32.0KB. △T: 40.9 seconds.
# [15:52:08] Finish counting 'consumptionAbility' x 'LBS' fold 5/5 .... △M: +248.0KB. △T: 45.3 seconds.
# [15:52:44] Finish counting 'consumptionAbility' x 'carrier' fold 1/5 .... △M: -19.7MB. △T: 36.3 seconds.
# [15:53:21] Finish counting 'consumptionAbility' x 'carrier' fold 2/5 .... △M: -512.0KB. △T: 37.2 seconds.
# [15:53:59] Finish counting 'consumptionAbility' x 'carrier' fold 3/5 .... △M: +0B. △T: 37.2 seconds.
# [15:54:34] Finish counting 'consumptionAbility' x 'carrier' fold 4/5 .... △M: +0B. △T: 35.0 seconds.
# [15:55:09] Finish counting 'consumptionAbility' x 'carrier' fold 5/5 .... △M: +0B. △T: 35.2 seconds.
# [15:55:44] Finish counting 'consumptionAbility' x 'house' fold 1/5 .... △M: -16.0MB. △T: 34.6 seconds.
# [15:56:19] Finish counting 'consumptionAbility' x 'house' fold 2/5 .... △M: +0B. △T: 35.0 seconds.
# [15:56:53] Finish counting 'consumptionAbility' x 'house' fold 3/5 .... △M: +0B. △T: 34.6 seconds.
# [15:57:28] Finish counting 'consumptionAbility' x 'house' fold 4/5 .... △M: +0B. △T: 35.0 seconds.
# [15:58:05] Finish counting 'consumptionAbility' x 'house' fold 5/5 .... △M: +0B. △T: 36.8 seconds.
