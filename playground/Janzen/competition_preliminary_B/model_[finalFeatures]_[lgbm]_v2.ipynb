# %%
from sklearn.model_selection import StratifiedShuffleSplit, StratifiedKFold
from sklearn import metrics
from contextlib import redirect_stdout
import scipy.sparse as sparse
import lightgbm as lgb
import pandas as pd
import numpy as np
import json
import tqdm
import os
import gc
import sys
sys.path.append('../../../code/pipeline/')
sys.path.append('../../../code/utils/')
sys.path.append('../../../code/')
import data_pipeline as dp
import data_utils as du
import perf_utils as pu
import eval_utils as eu
import io_utils as iu
import config

# %%
# load multiple data and stack them together
input_folder = os.path.join(config.DATA_DIR, "input_final")
dm = dp.DataManager(input_folder)

lc_v1 = dm.build_data('aggregate.listCount_v1')
lc_v2 = dm.build_data('aggregate.listCount_v2')
clk_v1 = dm.build_data('clickStats.crossWordCount_v1')
clk_v2 = dm.build_data('clickStats.crossWordCount_v2')
stack_cross_v1 = dm.build_data('stacking.lr.crossWordCount_v1')
stack_cross_v1_all = dm.build_data('stacking.lr.crossWordCount_v1_all')
stack_cross_v2 = dm.build_data('stacking.lr.crossWordCount_v2')
stack_cross_v3 = dm.build_data('stacking.lr.crossWordCount_v3')
stack_cross_v3_all = dm.build_data('stacking.lr.crossWordCount_v3_all')
stack_emb = dm.build_data('stacking.lr.wordEmbedding')
stack_tfidf = dm.build_data('stacking.lr.wordTfIdf')
cross = dm.build_data('cross.wordCount_v2')
raw = dm.build_data('raw.wordCount')

# %%
union_loader = dp.DataUnion(lc_v1, lc_v2, 
                            clk_v1, clk_v2,
                            stack_cross_v1, stack_cross_v1_all, 
                            stack_cross_v2, 
                            stack_cross_v3, stack_cross_v3_all, 
                            stack_emb, 
                            stack_tfidf, 
                            cross, 
                            raw)

# %%
with pu.profiler("loading training data"):
    cols_train, X_tv = union_loader.load("train")
    X_tv = sparse.csr_matrix(X_tv)
    gc.collect()
print("Train Data Shape: {}".format(X_tv.shape))
print("Train Column Numbers: {}".format(len(cols_train)))

df_train = du.load_raw_data("train")
y = df_train['label'].values.copy()
y = (y + 1) / 2  # -1, 1 -> 0, 1
# Out:
# loading data: 100%|██████████| 13/13 [06:23<00:00, 29.52s/it]
# [01:48:04] Finish loading training data. △M: +19.2GB. △T: 7.4 minutes.
# Train Data Shape: (8798814, 499726)
# Train Column Numbers: 499726

# %%
n_splits = 5
sss = StratifiedShuffleSplit(n_splits=n_splits, test_size=0.2, random_state=2018)  # for reproducibility
split_indices = [(train_index, valid_index) for train_index, valid_index in sss.split(df_train, y)]
# n_splits = 5  # use 3 instead of 5 to save time
# skf = StratifiedKFold(n_splits=n_splits, random_state=2018)
# split_indices = [(train_index, valid_index) for train_index, valid_index in skf.split(df_train, y)]

aids = df_train['aid'].values
with pu.profiler("splitting train/valid set"):
    train_index, valid_index = split_indices[0]
    X_train, X_valid = X_tv[train_index, :], X_tv[valid_index, :]
    y_train, y_valid = y[train_index], y[valid_index]
    aids_train, aids_valid = aids[train_index], aids[valid_index]
    assert X_train.shape[0] + X_valid.shape[0] == X_tv.shape[0]
    
    del X_tv
    gc.collect()
    
print("Training Set Size: {}".format(X_train.shape))
print("Validation Set Size: {}".format(X_valid.shape))
# Out:
# [01:49:41] Finish splitting train/valid set. △M: -15.6GB. △T: 1.3 minutes.
# Training Set Size: (7039051, 499726)
# Validation Set Size: (1759763, 499726)

# %%
with pu.profiler("preparing LightGBM data"):
    lgb_train = lgb.Dataset(X_train.astype(np.float32), y_train)
    del X_train  # to save memory
    gc.collect()
    
    lgb_valid = lgb.Dataset(X_valid.astype(np.float32), y_valid)
    gc.collect()
# Out:
# [01:51:04] Finish preparing LightGBM data. △M: +12.8GB. △T: 53.3 seconds.

# %%
version_name = "final/v3"
log_folder = os.path.join(config.LOG_DIR, 'lgbm/{}'.format(version_name))
os.makedirs(log_folder, exist_ok=True)

params = {
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': 'auc',
    'max_depth': 6,
    'num_leaves': 64,
    'learning_rate': 0.16,
    'feature_fraction': 0.8,
    'bagging_fraction': 0.8,
    'verbose': 0
}
num_rounds = 480

log_file = 'params.json'
log_path = os.path.join(log_folder, log_file)
with open(log_path, 'w') as f:
    json.dump(params, f, indent=4)

log_file = 'log.txt'
log_path = os.path.join(log_folder, log_file)
eval_auc = eu.build_lightgbm_online_auc_eval(aids_train, aids_valid)
with iu.DuplicatedLogger(log_path):
    lgbm = lgb.train(params,
                     lgb_train,
                     num_boost_round=num_rounds,
                     valid_sets=[lgb_train, lgb_valid], 
                     valid_names=['train', 'valid'],
                     feval = eval_auc,
                     early_stopping_rounds=50)
# Out:
# [1]	train's auc: 0.702302	train's online_auc: 0.700284	valid's auc: 0.699138	valid's online_auc: 0.698175
# Training until validation scores don't improve for 50 rounds.
# [2]	train's auc: 0.714534	train's online_auc: 0.712605	valid's auc: 0.711118	valid's online_auc: 0.710127
# [3]	train's auc: 0.718374	train's online_auc: 0.71623	valid's auc: 0.714986	valid's online_auc: 0.714076
# [4]	train's auc: 0.721249	train's online_auc: 0.718872	valid's auc: 0.717959	valid's online_auc: 0.71695
# [5]	train's auc: 0.723473	train's online_auc: 0.720745	valid's auc: 0.720148	valid's online_auc: 0.719142
# [6]	train's auc: 0.724244	train's online_auc: 0.721508	valid's auc: 0.721071	valid's online_auc: 0.720062
# [7]	train's auc: 0.725026	train's online_auc: 0.722313	valid's auc: 0.721622	valid's online_auc: 0.72064
# [8]	train's auc: 0.726011	train's online_auc: 0.722955	valid's auc: 0.722423	valid's online_auc: 0.720877
# [9]	train's auc: 0.726713	train's online_auc: 0.723544	valid's auc: 0.723132	valid's online_auc: 0.721539
# [10]	train's auc: 0.727368	train's online_auc: 0.723965	valid's auc: 0.72371	valid's online_auc: 0.721826
# [11]	train's auc: 0.727521	train's online_auc: 0.723944	valid's auc: 0.723795	valid's online_auc: 0.721766
# [12]	train's auc: 0.728393	train's online_auc: 0.725085	valid's auc: 0.72482	valid's online_auc: 0.722933
# [13]	train's auc: 0.728619	train's online_auc: 0.72498	valid's auc: 0.724966	valid's online_auc: 0.722846
# [14]	train's auc: 0.729058	train's online_auc: 0.725321	valid's auc: 0.725457	valid's online_auc: 0.72299
# [15]	train's auc: 0.729425	train's online_auc: 0.725199	valid's auc: 0.72563	valid's online_auc: 0.722762
# [16]	train's auc: 0.729974	train's online_auc: 0.725768	valid's auc: 0.726148	valid's online_auc: 0.723217
# [17]	train's auc: 0.730633	train's online_auc: 0.726369	valid's auc: 0.726737	valid's online_auc: 0.723745
# [18]	train's auc: 0.731245	train's online_auc: 0.727075	valid's auc: 0.727394	valid's online_auc: 0.72445
# [19]	train's auc: 0.731844	train's online_auc: 0.727468	valid's auc: 0.72784	valid's online_auc: 0.724671
# [20]	train's auc: 0.732292	train's online_auc: 0.72796	valid's auc: 0.728223	valid's online_auc: 0.725006
# [21]	train's auc: 0.732988	train's online_auc: 0.728683	valid's auc: 0.728843	valid's online_auc: 0.725756
# [22]	train's auc: 0.733368	train's online_auc: 0.729054	valid's auc: 0.729209	valid's online_auc: 0.726102
# [23]	train's auc: 0.733879	train's online_auc: 0.729532	valid's auc: 0.729663	valid's online_auc: 0.72649
# [24]	train's auc: 0.734397	train's online_auc: 0.730011	valid's auc: 0.730026	valid's online_auc: 0.726828
# [25]	train's auc: 0.734921	train's online_auc: 0.730568	valid's auc: 0.730375	valid's online_auc: 0.727222
# [26]	train's auc: 0.735455	train's online_auc: 0.731166	valid's auc: 0.7308	valid's online_auc: 0.727748
# [27]	train's auc: 0.73598	train's online_auc: 0.731603	valid's auc: 0.731228	valid's online_auc: 0.728113
# [28]	train's auc: 0.736417	train's online_auc: 0.731971	valid's auc: 0.731608	valid's online_auc: 0.728349
# [29]	train's auc: 0.736858	train's online_auc: 0.732261	valid's auc: 0.731895	valid's online_auc: 0.728446
# [30]	train's auc: 0.737365	train's online_auc: 0.732695	valid's auc: 0.732314	valid's online_auc: 0.728769
# [31]	train's auc: 0.737836	train's online_auc: 0.733188	valid's auc: 0.732688	valid's online_auc: 0.729098
# [32]	train's auc: 0.738192	train's online_auc: 0.733632	valid's auc: 0.732911	valid's online_auc: 0.729347
# [33]	train's auc: 0.738582	train's online_auc: 0.734008	valid's auc: 0.733206	valid's online_auc: 0.729551
# [34]	train's auc: 0.739068	train's online_auc: 0.734548	valid's auc: 0.733595	valid's online_auc: 0.730024
# [35]	train's auc: 0.739437	train's online_auc: 0.735013	valid's auc: 0.733816	valid's online_auc: 0.730252
# [36]	train's auc: 0.739844	train's online_auc: 0.735347	valid's auc: 0.734096	valid's online_auc: 0.730447
# [37]	train's auc: 0.740135	train's online_auc: 0.735668	valid's auc: 0.734252	valid's online_auc: 0.730674
# [38]	train's auc: 0.740541	train's online_auc: 0.736047	valid's auc: 0.734546	valid's online_auc: 0.73098
# [39]	train's auc: 0.740833	train's online_auc: 0.736357	valid's auc: 0.734749	valid's online_auc: 0.731287
# [40]	train's auc: 0.741105	train's online_auc: 0.736685	valid's auc: 0.734935	valid's online_auc: 0.731392
# [41]	train's auc: 0.741431	train's online_auc: 0.736978	valid's auc: 0.735207	valid's online_auc: 0.731728
# [42]	train's auc: 0.741682	train's online_auc: 0.737276	valid's auc: 0.735409	valid's online_auc: 0.731934
# [43]	train's auc: 0.741978	train's online_auc: 0.737616	valid's auc: 0.735565	valid's online_auc: 0.732026
# [44]	train's auc: 0.742244	train's online_auc: 0.73796	valid's auc: 0.735773	valid's online_auc: 0.732266
# [45]	train's auc: 0.742497	train's online_auc: 0.738362	valid's auc: 0.735891	valid's online_auc: 0.732432
# [46]	train's auc: 0.742709	train's online_auc: 0.738553	valid's auc: 0.736008	valid's online_auc: 0.732526
# [47]	train's auc: 0.742932	train's online_auc: 0.738682	valid's auc: 0.73621	valid's online_auc: 0.732659
# [48]	train's auc: 0.743284	train's online_auc: 0.739018	valid's auc: 0.736469	valid's online_auc: 0.73295
# [49]	train's auc: 0.743479	train's online_auc: 0.739144	valid's auc: 0.736629	valid's online_auc: 0.733012
# [50]	train's auc: 0.743752	train's online_auc: 0.739388	valid's auc: 0.73682	valid's online_auc: 0.733224
# [51]	train's auc: 0.743902	train's online_auc: 0.739568	valid's auc: 0.736926	valid's online_auc: 0.733298
# [52]	train's auc: 0.744058	train's online_auc: 0.739847	valid's auc: 0.737013	valid's online_auc: 0.73334
# [53]	train's auc: 0.744244	train's online_auc: 0.740062	valid's auc: 0.737088	valid's online_auc: 0.73338
# [54]	train's auc: 0.744424	train's online_auc: 0.740363	valid's auc: 0.737171	valid's online_auc: 0.733545
# [55]	train's auc: 0.744531	train's online_auc: 0.740435	valid's auc: 0.737225	valid's online_auc: 0.733575
# [56]	train's auc: 0.744731	train's online_auc: 0.740716	valid's auc: 0.73736	valid's online_auc: 0.733691
# [57]	train's auc: 0.744928	train's online_auc: 0.740914	valid's auc: 0.73747	valid's online_auc: 0.733733
# [58]	train's auc: 0.745165	train's online_auc: 0.741283	valid's auc: 0.737602	valid's online_auc: 0.733912
# [59]	train's auc: 0.745273	train's online_auc: 0.741422	valid's auc: 0.73768	valid's online_auc: 0.733961
# [60]	train's auc: 0.745434	train's online_auc: 0.741532	valid's auc: 0.737773	valid's online_auc: 0.734013
# [61]	train's auc: 0.745534	train's online_auc: 0.741693	valid's auc: 0.737816	valid's online_auc: 0.734047
# [62]	train's auc: 0.745709	train's online_auc: 0.74188	valid's auc: 0.737928	valid's online_auc: 0.734128
# [63]	train's auc: 0.745825	train's online_auc: 0.742049	valid's auc: 0.737983	valid's online_auc: 0.734185
# [64]	train's auc: 0.745985	train's online_auc: 0.742203	valid's auc: 0.738004	valid's online_auc: 0.734178
# [65]	train's auc: 0.746206	train's online_auc: 0.742523	valid's auc: 0.738135	valid's online_auc: 0.734383
# [66]	train's auc: 0.746347	train's online_auc: 0.742678	valid's auc: 0.738226	valid's online_auc: 0.734478
# [67]	train's auc: 0.746466	train's online_auc: 0.742792	valid's auc: 0.738296	valid's online_auc: 0.734539
# [68]	train's auc: 0.746691	train's online_auc: 0.743044	valid's auc: 0.73843	valid's online_auc: 0.734697
# [69]	train's auc: 0.746819	train's online_auc: 0.743223	valid's auc: 0.738474	valid's online_auc: 0.734723
# [70]	train's auc: 0.746966	train's online_auc: 0.743317	valid's auc: 0.738532	valid's online_auc: 0.734738
# [71]	train's auc: 0.747092	train's online_auc: 0.743448	valid's auc: 0.738639	valid's online_auc: 0.734857
# [72]	train's auc: 0.747174	train's online_auc: 0.743554	valid's auc: 0.738683	valid's online_auc: 0.734906
# [73]	train's auc: 0.747285	train's online_auc: 0.743635	valid's auc: 0.738748	valid's online_auc: 0.73492
# [74]	train's auc: 0.747355	train's online_auc: 0.743702	valid's auc: 0.738783	valid's online_auc: 0.734939
# [75]	train's auc: 0.747526	train's online_auc: 0.743872	valid's auc: 0.738908	valid's online_auc: 0.73501
# [158]	train's auc: 0.755254	train's online_auc: 0.753769	valid's auc: 0.741613	valid's online_auc: 0.737327
# [159]	train's auc: 0.755301	train's online_auc: 0.753815	valid's auc: 0.741629	valid's online_auc: 0.737343
# [160]	train's auc: 0.755351	train's online_auc: 0.753853	valid's auc: 0.74162	valid's online_auc: 0.737335
# [161]	train's auc: 0.7554	train's online_auc: 0.753988	valid's auc: 0.741618	valid's online_auc: 0.737333
# [162]	train's auc: 0.755452	train's online_auc: 0.754043	valid's auc: 0.741613	valid's online_auc: 0.737337
# [163]	train's auc: 0.755482	train's online_auc: 0.754089	valid's auc: 0.741626	valid's online_auc: 0.73734
# [164]	train's auc: 0.755624	train's online_auc: 0.754267	valid's auc: 0.741665	valid's online_auc: 0.737393
# [165]	train's auc: 0.755694	train's online_auc: 0.754291	valid's auc: 0.74168	valid's online_auc: 0.737394
# [166]	train's auc: 0.755835	train's online_auc: 0.75443	valid's auc: 0.74178	valid's online_auc: 0.737413
# [167]	train's auc: 0.755891	train's online_auc: 0.754481	valid's auc: 0.741801	valid's online_auc: 0.737437
# [168]	train's auc: 0.755972	train's online_auc: 0.754582	valid's auc: 0.741808	valid's online_auc: 0.737442
# [169]	train's auc: 0.756048	train's online_auc: 0.754755	valid's auc: 0.741814	valid's online_auc: 0.737457
# [170]	train's auc: 0.756115	train's online_auc: 0.75496	valid's auc: 0.741805	valid's online_auc: 0.737434
# [171]	train's auc: 0.756136	train's online_auc: 0.754981	valid's auc: 0.741801	valid's online_auc: 0.737426
# [172]	train's auc: 0.756179	train's online_auc: 0.755049	valid's auc: 0.741797	valid's online_auc: 0.737427
# [173]	train's auc: 0.756212	train's online_auc: 0.755116	valid's auc: 0.741794	valid's online_auc: 0.737425
# [174]	train's auc: 0.756276	train's online_auc: 0.755186	valid's auc: 0.741817	valid's online_auc: 0.737449
# [175]	train's auc: 0.756306	train's online_auc: 0.755216	valid's auc: 0.741805	valid's online_auc: 0.737442
# [176]	train's auc: 0.756353	train's online_auc: 0.75529	valid's auc: 0.741825	valid's online_auc: 0.73747
# [177]	train's auc: 0.75649	train's online_auc: 0.755483	valid's auc: 0.741945	valid's online_auc: 0.737621
# [178]	train's auc: 0.756581	train's online_auc: 0.755552	valid's auc: 0.741994	valid's online_auc: 0.737635
# [179]	train's auc: 0.756657	train's online_auc: 0.75566	valid's auc: 0.742	valid's online_auc: 0.73765
# [180]	train's auc: 0.756746	train's online_auc: 0.755765	valid's auc: 0.742019	valid's online_auc: 0.737664
# [181]	train's auc: 0.756815	train's online_auc: 0.755823	valid's auc: 0.742013	valid's online_auc: 0.737691
# [182]	train's auc: 0.756883	train's online_auc: 0.75587	valid's auc: 0.742013	valid's online_auc: 0.737682
# [183]	train's auc: 0.756922	train's online_auc: 0.755932	valid's auc: 0.74202	valid's online_auc: 0.737697
# [184]	train's auc: 0.756969	train's online_auc: 0.756008	valid's auc: 0.742023	valid's online_auc: 0.737716
# [185]	train's auc: 0.757068	train's online_auc: 0.756149	valid's auc: 0.742052	valid's online_auc: 0.737777
# [324]	train's auc: 0.763984	train's online_auc: 0.765074	valid's auc: 0.743021	valid's online_auc: 0.738395
# [325]	train's auc: 0.763999	train's online_auc: 0.765096	valid's auc: 0.74302	valid's online_auc: 0.738394
# [326]	train's auc: 0.764029	train's online_auc: 0.765135	valid's auc: 0.743011	valid's online_auc: 0.738384
# [327]	train's auc: 0.764067	train's online_auc: 0.765201	valid's auc: 0.74303	valid's online_auc: 0.738443
# [328]	train's auc: 0.764107	train's online_auc: 0.765234	valid's auc: 0.743026	valid's online_auc: 0.738455
# [329]	train's auc: 0.76416	train's online_auc: 0.7653	valid's auc: 0.743054	valid's online_auc: 0.738467
# [330]	train's auc: 0.764196	train's online_auc: 0.765323	valid's auc: 0.743051	valid's online_auc: 0.73847
# [331]	train's auc: 0.764274	train's online_auc: 0.765405	valid's auc: 0.743041	valid's online_auc: 0.738446
# [332]	train's auc: 0.764337	train's online_auc: 0.765453	valid's auc: 0.743067	valid's online_auc: 0.738461
# [333]	train's auc: 0.764373	train's online_auc: 0.765486	valid's auc: 0.743076	valid's online_auc: 0.738476
# [334]	train's auc: 0.764408	train's online_auc: 0.765526	valid's auc: 0.743078	valid's online_auc: 0.738506
# [335]	train's auc: 0.764426	train's online_auc: 0.765562	valid's auc: 0.743084	valid's online_auc: 0.73852
# [336]	train's auc: 0.764479	train's online_auc: 0.765702	valid's auc: 0.743092	valid's online_auc: 0.738521
# [337]	train's auc: 0.764516	train's online_auc: 0.765749	valid's auc: 0.743096	valid's online_auc: 0.738526
# [338]	train's auc: 0.764539	train's online_auc: 0.765763	valid's auc: 0.743094	valid's online_auc: 0.738523
# [339]	train's auc: 0.764603	train's online_auc: 0.765907	valid's auc: 0.743084	valid's online_auc: 0.738535
# [340]	train's auc: 0.764622	train's online_auc: 0.765925	valid's auc: 0.743085	valid's online_auc: 0.738538
# [341]	train's auc: 0.76466	train's online_auc: 0.76598	valid's auc: 0.743076	valid's online_auc: 0.738516
# [342]	train's auc: 0.764706	train's online_auc: 0.766037	valid's auc: 0.743075	valid's online_auc: 0.73851
# [343]	train's auc: 0.764743	train's online_auc: 0.766104	valid's auc: 0.743071	valid's online_auc: 0.73851
# [344]	train's auc: 0.76477	train's online_auc: 0.76613	valid's auc: 0.743072	valid's online_auc: 0.73851
# [345]	train's auc: 0.764845	train's online_auc: 0.76641	valid's auc: 0.743064	valid's online_auc: 0.738463
# [346]	train's auc: 0.764861	train's online_auc: 0.76644	valid's auc: 0.743067	valid's online_auc: 0.73846
# [347]	train's auc: 0.764888	train's online_auc: 0.766472	valid's auc: 0.743074	valid's online_auc: 0.738459
# [348]	train's auc: 0.764905	train's online_auc: 0.766502	valid's auc: 0.743081	valid's online_auc: 0.738482
# [349]	train's auc: 0.764956	train's online_auc: 0.766542	valid's auc: 0.743086	valid's online_auc: 0.738479
# [350]	train's auc: 0.764977	train's online_auc: 0.766557	valid's auc: 0.743086	valid's online_auc: 0.738481
# [351]	train's auc: 0.765033	train's online_auc: 0.766587	valid's auc: 0.743078	valid's online_auc: 0.738472
# [352]	train's auc: 0.765047	train's online_auc: 0.766608	valid's auc: 0.743077	valid's online_auc: 0.738469
# [353]	train's auc: 0.765066	train's online_auc: 0.766639	valid's auc: 0.743079	valid's online_auc: 0.738467
# [354]	train's auc: 0.765097	train's online_auc: 0.76667	valid's auc: 0.743071	valid's online_auc: 0.738455
# [355]	train's auc: 0.765124	train's online_auc: 0.766688	valid's auc: 0.743085	valid's online_auc: 0.738477
# [356]	train's auc: 0.765152	train's online_auc: 0.766713	valid's auc: 0.743087	valid's online_auc: 0.738464
# [357]	train's auc: 0.765171	train's online_auc: 0.766735	valid's auc: 0.743091	valid's online_auc: 0.738463
# [358]	train's auc: 0.765232	train's online_auc: 0.766783	valid's auc: 0.743121	valid's online_auc: 0.738478
# [359]	train's auc: 0.765242	train's online_auc: 0.766795	valid's auc: 0.74312	valid's online_auc: 0.738482
# [360]	train's auc: 0.765287	train's online_auc: 0.766855	valid's auc: 0.743109	valid's online_auc: 0.738469
# [361]	train's auc: 0.765299	train's online_auc: 0.766866	valid's auc: 0.743105	valid's online_auc: 0.738464
# [362]	train's auc: 0.765316	train's online_auc: 0.766887	valid's auc: 0.743099	valid's online_auc: 0.73846
# [363]	train's auc: 0.765353	train's online_auc: 0.766926	valid's auc: 0.743101	valid's online_auc: 0.738456
# [364]	train's auc: 0.765379	train's online_auc: 0.766952	valid's auc: 0.743106	valid's online_auc: 0.738484
# [365]	train's auc: 0.765433	train's online_auc: 0.766997	valid's auc: 0.743101	valid's online_auc: 0.738477
# [366]	train's auc: 0.765513	train's online_auc: 0.767083	valid's auc: 0.743108	valid's online_auc: 0.738506
# [367]	train's auc: 0.765555	train's online_auc: 0.767213	valid's auc: 0.743112	valid's online_auc: 0.738546
# [368]	train's auc: 0.765585	train's online_auc: 0.76724	valid's auc: 0.743111	valid's online_auc: 0.738547
# [369]	train's auc: 0.765601	train's online_auc: 0.767264	valid's auc: 0.7431	valid's online_auc: 0.738547
# [370]	train's auc: 0.765643	train's online_auc: 0.767329	valid's auc: 0.743094	valid's online_auc: 0.738543
# [371]	train's auc: 0.765669	train's online_auc: 0.767356	valid's auc: 0.743096	valid's online_auc: 0.738546
# [372]	train's auc: 0.765711	train's online_auc: 0.767402	valid's auc: 0.7431	valid's online_auc: 0.738559
# [373]	train's auc: 0.765802	train's online_auc: 0.767484	valid's auc: 0.743101	valid's online_auc: 0.738564
# [374]	train's auc: 0.765859	train's online_auc: 0.767607	valid's auc: 0.7431	valid's online_auc: 0.738565
# [375]	train's auc: 0.765911	train's online_auc: 0.767677	valid's auc: 0.743112	valid's online_auc: 0.738561
# [376]	train's auc: 0.765932	train's online_auc: 0.767703	valid's auc: 0.743107	valid's online_auc: 0.738568
# [377]	train's auc: 0.765974	train's online_auc: 0.767747	valid's auc: 0.74311	valid's online_auc: 0.73857
# [378]	train's auc: 0.766017	train's online_auc: 0.767779	valid's auc: 0.743115	valid's online_auc: 0.738572
# [379]	train's auc: 0.766043	train's online_auc: 0.767837	valid's auc: 0.74311	valid's online_auc: 0.738555
# [380]	train's auc: 0.766082	train's online_auc: 0.76789	valid's auc: 0.743107	valid's online_auc: 0.73854
# [381]	train's auc: 0.766129	train's online_auc: 0.767993	valid's auc: 0.743106	valid's online_auc: 0.738536
# [382]	train's auc: 0.76619	train's online_auc: 0.76809	valid's auc: 0.743099	valid's online_auc: 0.73854
# [383]	train's auc: 0.766195	train's online_auc: 0.7681	valid's auc: 0.743099	valid's online_auc: 0.738537
# [384]	train's auc: 0.766228	train's online_auc: 0.768131	valid's auc: 0.74311	valid's online_auc: 0.73855
# [385]	train's auc: 0.766293	train's online_auc: 0.768178	valid's auc: 0.743149	valid's online_auc: 0.738541
# [386]	train's auc: 0.76634	train's online_auc: 0.768218	valid's auc: 0.743162	valid's online_auc: 0.738546
# [387]	train's auc: 0.7664	train's online_auc: 0.768298	valid's auc: 0.74316	valid's online_auc: 0.738534
# [388]	train's auc: 0.76643	train's online_auc: 0.768323	valid's auc: 0.743159	valid's online_auc: 0.738538
# [389]	train's auc: 0.766459	train's online_auc: 0.768361	valid's auc: 0.74316	valid's online_auc: 0.738534
# [390]	train's auc: 0.766553	train's online_auc: 0.768549	valid's auc: 0.743178	valid's online_auc: 0.738582
# [391]	train's auc: 0.766602	train's online_auc: 0.768606	valid's auc: 0.743169	valid's online_auc: 0.738572
# [392]	train's auc: 0.766643	train's online_auc: 0.768649	valid's auc: 0.743164	valid's online_auc: 0.738581
# [393]	train's auc: 0.766669	train's online_auc: 0.768673	valid's auc: 0.743163	valid's online_auc: 0.738576
# [394]	train's auc: 0.766689	train's online_auc: 0.768702	valid's auc: 0.743159	valid's online_auc: 0.73856
# [395]	train's auc: 0.766732	train's online_auc: 0.768796	valid's auc: 0.743151	valid's online_auc: 0.738541
# [396]	train's auc: 0.766782	train's online_auc: 0.768871	valid's auc: 0.743151	valid's online_auc: 0.738547
# [397]	train's auc: 0.76682	train's online_auc: 0.768901	valid's auc: 0.74315	valid's online_auc: 0.738554
# [398]	train's auc: 0.7669	train's online_auc: 0.768971	valid's auc: 0.743158	valid's online_auc: 0.73856
# [399]	train's auc: 0.76694	train's online_auc: 0.768999	valid's auc: 0.743158	valid's online_auc: 0.738566
# [400]	train's auc: 0.766979	train's online_auc: 0.769058	valid's auc: 0.743156	valid's online_auc: 0.738566
# [401]	train's auc: 0.767019	train's online_auc: 0.769092	valid's auc: 0.743158	valid's online_auc: 0.738564
# [402]	train's auc: 0.76709	train's online_auc: 0.769158	valid's auc: 0.74315	valid's online_auc: 0.738559
# [403]	train's auc: 0.767111	train's online_auc: 0.76918	valid's auc: 0.743154	valid's online_auc: 0.73856
# [404]	train's auc: 0.767139	train's online_auc: 0.769236	valid's auc: 0.743147	valid's online_auc: 0.738554
# [405]	train's auc: 0.767203	train's online_auc: 0.769341	valid's auc: 0.743135	valid's online_auc: 0.738522
# [406]	train's auc: 0.767268	train's online_auc: 0.769459	valid's auc: 0.743144	valid's online_auc: 0.738555
# [407]	train's auc: 0.767282	train's online_auc: 0.769475	valid's auc: 0.743138	valid's online_auc: 0.738552
# [408]	train's auc: 0.767296	train's online_auc: 0.769497	valid's auc: 0.743143	valid's online_auc: 0.73857
# [409]	train's auc: 0.767305	train's online_auc: 0.76952	valid's auc: 0.743143	valid's online_auc: 0.738573
# [410]	train's auc: 0.767317	train's online_auc: 0.76953	valid's auc: 0.743142	valid's online_auc: 0.738577
# [411]	train's auc: 0.76737	train's online_auc: 0.769633	valid's auc: 0.743146	valid's online_auc: 0.738576
# [412]	train's auc: 0.767399	train's online_auc: 0.769654	valid's auc: 0.743152	valid's online_auc: 0.738581
# [413]	train's auc: 0.767429	train's online_auc: 0.769714	valid's auc: 0.743152	valid's online_auc: 0.738575
# [414]	train's auc: 0.767484	train's online_auc: 0.769794	valid's auc: 0.743137	valid's online_auc: 0.738554
# [415]	train's auc: 0.767516	train's online_auc: 0.769823	valid's auc: 0.743128	valid's online_auc: 0.738541
# [416]	train's auc: 0.767529	train's online_auc: 0.769843	valid's auc: 0.743125	valid's online_auc: 0.738538
# [417]	train's auc: 0.76758	train's online_auc: 0.769889	valid's auc: 0.743115	valid's online_auc: 0.738533
# [418]	train's auc: 0.767638	train's online_auc: 0.769944	valid's auc: 0.743135	valid's online_auc: 0.738529
# [419]	train's auc: 0.767697	train's online_auc: 0.77	valid's auc: 0.743132	valid's online_auc: 0.73852
# [420]	train's auc: 0.767727	train's online_auc: 0.770017	valid's auc: 0.743141	valid's online_auc: 0.738523
# [421]	train's auc: 0.767758	train's online_auc: 0.770046	valid's auc: 0.743136	valid's online_auc: 0.738524
# [422]	train's auc: 0.767795	train's online_auc: 0.770085	valid's auc: 0.743129	valid's online_auc: 0.738512
# [423]	train's auc: 0.767819	train's online_auc: 0.77012	valid's auc: 0.743133	valid's online_auc: 0.738519
# [424]	train's auc: 0.767837	train's online_auc: 0.770142	valid's auc: 0.743138	valid's online_auc: 0.738527
# [425]	train's auc: 0.767874	train's online_auc: 0.770189	valid's auc: 0.743126	valid's online_auc: 0.738511
# [426]	train's auc: 0.767889	train's online_auc: 0.77023	valid's auc: 0.743123	valid's online_auc: 0.738523
# [427]	train's auc: 0.767923	train's online_auc: 0.770263	valid's auc: 0.743116	valid's online_auc: 0.738512
# [428]	train's auc: 0.767974	train's online_auc: 0.770324	valid's auc: 0.743098	valid's online_auc: 0.738493
# [429]	train's auc: 0.768004	train's online_auc: 0.770344	valid's auc: 0.743104	valid's online_auc: 0.738493
# [430]	train's auc: 0.768051	train's online_auc: 0.770418	valid's auc: 0.743098	valid's online_auc: 0.738479
# [431]	train's auc: 0.768088	train's online_auc: 0.770465	valid's auc: 0.743095	valid's online_auc: 0.738469
# [432]	train's auc: 0.768103	train's online_auc: 0.770478	valid's auc: 0.743091	valid's online_auc: 0.738465
# [433]	train's auc: 0.768139	train's online_auc: 0.770503	valid's auc: 0.743094	valid's online_auc: 0.738455
# [434]	train's auc: 0.768175	train's online_auc: 0.770538	valid's auc: 0.743102	valid's online_auc: 0.738474
# [435]	train's auc: 0.768214	train's online_auc: 0.770566	valid's auc: 0.743117	valid's online_auc: 0.738526
# [436]	train's auc: 0.768253	train's online_auc: 0.770621	valid's auc: 0.74311	valid's online_auc: 0.738539
# [437]	train's auc: 0.768296	train's online_auc: 0.77067	valid's auc: 0.743105	valid's online_auc: 0.738526
# [438]	train's auc: 0.768327	train's online_auc: 0.770711	valid's auc: 0.743094	valid's online_auc: 0.738497
# [439]	train's auc: 0.768364	train's online_auc: 0.770729	valid's auc: 0.743094	valid's online_auc: 0.738493
# [440]	train's auc: 0.768414	train's online_auc: 0.770768	valid's auc: 0.743091	valid's online_auc: 0.738493
# Early stopping, best iteration is:
# [390]	train's auc: 0.766553	train's online_auc: 0.768549	valid's auc: 0.743178	valid's online_auc: 0.738582

# %%
log_file = 'feature_importance.csv'
log_path = os.path.join(log_folder, log_file)

df_feature_importance = pd.DataFrame({"feature": cols_train, "importance": lgbm.feature_importance()})
df_feature_importance = df_feature_importance.sort_values("importance", ascending=False)
df_feature_importance.to_csv(log_path, index=False)

# %%
df_valid = df_train.iloc[valid_index]
proba_valid = lgbm.predict(X_valid.astype(np.float32))
df_score = eu.online_auc(df_valid['aid'], y_valid, proba_valid, ret_verbose=True)

online_auc = df_score['auc'].mean()
simple_auc = metrics.roc_auc_score(y_valid, proba_valid)
print("Online AUC: {:.6f}".format(online_auc))
print("Simple AUC: {:.6f}".format(simple_auc))

log_file = 'online_auc.csv'
log_path = os.path.join(log_folder, log_file)
df_score.rename(columns={'selector': 'aid'}, inplace=True)
df_score = df_score[['aid', 'auc']]  # sort columns
df_score = df_score.sort_values("auc", ascending=False)
df_score.to_csv(log_path, index=False)
# Out:
# Online AUC: 0.738582
# Simple AUC: 0.743178

# %%
with pu.profiler("cleaning memory"):
    del lgb_train
    del lgb_valid
    # del X_train
    del X_valid
    gc.collect()
# Out:
# [03:11:18] Finish cleaning memory. △M: -10.9GB. △T: 1.7 seconds.

# %%
with pu.profiler("loading testing data"):
    cols_test, X_test = union_loader.load("test2")
    X_test = sparse.csr_matrix(X_test)
    gc.collect()
print("Test Data Shape: {}".format(X_test.shape))
print("Test Column Numbers: {}".format(len(cols_test)))

df_test = du.load_raw_data("test2")
X_test = X_test.astype(np.float32)

with pu.profiler("making prediction on testing set"):
    proba_test = lgbm.predict(X_test)
    assert len(proba_test.shape) == 1
    assert proba_test.shape[0] == df_test.shape[0]
    
subm_folder = '../../../subm/lgbm/{}'.format(version_name)
subm_file = 'submission.csv'
subm_path = os.path.join(subm_folder, subm_file)
os.makedirs(subm_folder, exist_ok=True)

subm = df_test.copy()
subm["score"] = proba_test
subm.to_csv(subm_path, index=False)
# Out:
# loading data: 100%|██████████| 13/13 [01:04<00:00,  4.99s/it]
# [03:12:29] Finish loading testing data. △M: +3.32GB. △T: 1.2 minutes.
# Test Data Shape: (2265879, 469011)
# Test Column Numbers: 469011
# [03:13:05] Finish making prediction on testing set. △M: +0B. △T: 32.8 seconds.
