# %%
import os
import gc
import time
import json
import pickle
import pandas as pd
import numpy as np
import itertools
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from scipy.sparse import csr_matrix
from contextlib import contextmanager
import sys
sys.path.append('../code/utils')
sys.path.append('../code/pipeline')
sys.path.append('../code')
import data_utils as du
import perf_utils as pu
import config

# %%
FEATURE_DIR = '../data/split/preliminary_contest_data/byUserFeatureName/'
VOCAB_DIR = '../data/vocabulary/preliminary_contest_data/'


def feature_path(feat_name):
    filename = "userFeature.[featureName='{}'].data".format(feat_name)
    return os.path.join(FEATURE_DIR, filename)


def vocab_path(feat_name="all"):
    if feat_name == "all":
        filename = "userFeature.pkl"
    else:
        filename = "userFeature.[featureName='{}'].pkl".format(feat_name)
    return os.path.join(VOCAB_DIR, filename)


def load_feature(feat_name, **kw):
    sep = kw.pop('sep', '|')
    dtype = kw.pop('dtype', {feat_name: str})
    filepath = feature_path(feat_name)
    return pd.read_csv(filepath, sep=sep, dtype=dtype, **kw)


def load_vocab(feat_name='all'):
    filepath = vocab_path(feat_name)
    return du.load_pickle(filepath)

# %%
def tokenizer(string):
    return string.split()


cnt_dir = '../data/nlp_count/preliminary_contest_data/byUserFeatureName/'
tfidf_dir = '../data/nlp_tfidf/preliminary_contest_data/byUserFeatureName/'
os.makedirs(cnt_dir, exist_ok=True)
os.makedirs(tfidf_dir, exist_ok=True)

for i, feat_name in enumerate(config.USER_FEAT_NAMES):
    print("-" * 80)
    print("Processing '{}'...".format(feat_name))
    with pu.profiler("loading and preprocessing"):
        df = load_feature(feat_name)  # pd.DataFrame
        vocab = load_vocab(feat_name)  # list
        docs = df[feat_name]  # pd.Series
        if docs.isnull().sum() > 0:
            fill_value = "[nan]"  # don't use [NaN]; fxxk sklearn
            vocab += [fill_value]
            docs = docs.fillna(fill_value)
        
    with pu.profiler("count vectorizing (ngram=1) [sklearn]"):
        cnt_vectorizer = CountVectorizer(vocabulary=vocab, tokenizer=tokenizer, dtype=np.int8)
        cnt_vec_sk = cnt_vectorizer.fit_transform(docs)
    
    with pu.profiler("saving count vectors"):
        cnt_file = "userFeature.[featureName='{}'].pkl".format(feat_name)
        cnt_path = os.path.join(cnt_dir, cnt_file)
        du.save_pickle((cnt_vectorizer.vocabulary_, cnt_vec_sk), cnt_path) # save mapping as well for further analysis
        if i == 0:
            uid_file = "uid.pkl"
            uid_path = os.path.join(cnt_dir, uid_file)
            du.save_pickle(df['uid'].values, uid_path)  # save uid for further analysis
        del cnt_vec_sk
        del cnt_vectorizer
        gc.collect()

    with pu.profiler("TFIDF vectorizing (ngram=1) transformation"):
        tfidf_vectorizer = TfidfVectorizer(vocabulary=vocab, tokenizer=tokenizer, dtype=np.float32)
        tfidf_vec = tfidf_vectorizer.fit_transform(docs)
        

    with pu.profiler("saving TFIDF vectors"):
        tfidf_file = "userFeature.[featureName='{}'].pkl".format(feat_name)
        tfidf_path = os.path.join(tfidf_dir, tfidf_file)
        du.save_pickle((tfidf_vectorizer.vocabulary_, tfidf_vectorizer.idf_, tfidf_vec), tfidf_path)  # save mapping and idf as well
        if i == 0:
            uid_file = "uid.pkl"
            uid_path = os.path.join(tfidf_dir, uid_file)
            du.save_pickle(df['uid'].values, uid_path)  # save uid for further analysis
        del tfidf_vec
        del tfidf_vectorizer
        gc.collect()

    with pu.profiler("cleaning"):
        del [[docs, df]]
        del vocab
        gc.collect()
# Out:
# --------------------------------------------------------------------------------
# Processing 'age'...
# [09:38:10] Finish loading and preprocessing. △M: +175.23MB. △T: 2.4 seconds.
# [09:38:34] Finish count vectorizing (ngram=1) [sklearn]. △M: +97.93MB. △T: 23.3 seconds.
# [09:38:34] Finish saving count vectors. △M: -71.11MB. △T: 0.2 seconds.
# [09:38:58] Finish TFIDF vectorizing (ngram=1) transformation. △M: +147.6MB. △T: 24.1 seconds.
# [09:38:58] Finish saving TFIDF vectors. △M: -158.35MB. △T: 0.2 seconds.
# [09:38:58] Finish cleaning. △M: -174.25MB. △T: 0.1 seconds.
# --------------------------------------------------------------------------------
# Processing 'gender'...
# [09:39:01] Finish loading and preprocessing. △M: +158.39MB. △T: 2.3 seconds.
# [09:39:32] Finish count vectorizing (ngram=1) [sklearn]. △M: +114.29MB. △T: 31.4 seconds.
# [09:39:32] Finish saving count vectors. △M: -87.13MB. △T: 0.1 seconds.
# [09:40:14] Finish TFIDF vectorizing (ngram=1) transformation. △M: +147.1MB. △T: 41.7 seconds.
# [09:40:14] Finish saving TFIDF vectors. △M: -158.39MB. △T: 0.2 seconds.
# [09:40:14] Finish cleaning. △M: -174.26MB. △T: 0.1 seconds.
# --------------------------------------------------------------------------------
# Processing 'marriageStatus'...
# [09:40:19] Finish loading and preprocessing. △M: +267.25MB. △T: 4.7 seconds.
# [09:41:03] Finish count vectorizing (ngram=1) [sklearn]. △M: +101.0MB. △T: 44.4 seconds.
# [09:41:03] Finish saving count vectors. △M: -93.79MB. △T: 0.1 seconds.
# [09:41:49] Finish TFIDF vectorizing (ngram=1) transformation. △M: +186.21MB. △T: 46.0 seconds.
# [09:41:50] Finish saving TFIDF vectors. △M: -199.19MB. △T: 0.2 seconds.
# [09:41:50] Finish cleaning. △M: -261.39MB. △T: 0.1 seconds.
# --------------------------------------------------------------------------------
# Processing 'education'...
# [09:41:54] Finish loading and preprocessing. △M: +158.38MB. △T: 3.8 seconds.
# [09:42:34] Finish count vectorizing (ngram=1) [sklearn]. △M: +100.95MB. △T: 40.7 seconds.
# [09:42:34] Finish saving count vectors. △M: -100.95MB. △T: 0.2 seconds.
# [09:43:13] Finish TFIDF vectorizing (ngram=1) transformation. △M: +174.26MB. △T: 38.6 seconds.
# [09:43:13] Finish saving TFIDF vectors. △M: -158.39MB. △T: 0.2 seconds.
# [09:43:13] Finish cleaning. △M: -174.26MB. △T: 0.1 seconds.
# --------------------------------------------------------------------------------
# Processing 'consumptionAbility'...
# [09:43:16] Finish loading and preprocessing. △M: +158.39MB. △T: 3.0 seconds.
# [09:43:57] Finish count vectorizing (ngram=1) [sklearn]. △M: +97.9MB. △T: 40.3 seconds.
# [09:43:57] Finish saving count vectors. △M: -71.13MB. △T: 0.1 seconds.
# [09:44:43] Finish TFIDF vectorizing (ngram=1) transformation. △M: +147.5MB. △T: 45.9 seconds.
# [09:44:43] Finish saving TFIDF vectors. △M: -158.39MB. △T: 0.6 seconds.
# [09:44:43] Finish cleaning. △M: -174.26MB. △T: 0.3 seconds.
# --------------------------------------------------------------------------------
# Processing 'LBS'...
# [09:44:49] Finish loading and preprocessing. △M: +268.43MB. △T: 5.7 seconds.
# [09:45:32] Finish count vectorizing (ngram=1) [sklearn]. △M: +84.36MB. △T: 43.0 seconds.
# [09:45:32] Finish saving count vectors. △M: -79.13MB. △T: 0.2 seconds.
# [09:46:14] Finish TFIDF vectorizing (ngram=1) transformation. △M: +166.38MB. △T: 41.6 seconds.
# [09:46:14] Finish saving TFIDF vectors. △M: -174.26MB. △T: 0.2 seconds.
# [09:46:14] Finish cleaning. △M: -262.14MB. △T: 0.1 seconds.
# --------------------------------------------------------------------------------
# Processing 'interest1'...
# [09:46:28] Finish loading and preprocessing. △M: +1.05GB. △T: 14.2 seconds.
# [09:48:45] Finish count vectorizing (ngram=1) [sklearn]. △M: +764.03MB. △T: 2.3 minutes.
# [09:48:45] Finish saving count vectors. △M: -764.0MB. △T: 0.7 seconds.
# [10:44:15] Finish TFIDF vectorizing (ngram=1) transformation. △M: +1.73GB. △T: 55.5 minutes.
# [10:44:17] Finish saving TFIDF vectors. △M: -1.73GB. △T: 1.2 seconds.
# [10:44:17] Finish cleaning. △M: -1.03GB. △T: 0.5 seconds.
# --------------------------------------------------------------------------------
# Processing 'interest2'...
# [10:44:22] Finish loading and preprocessing. △M: +468.43MB. △T: 5.3 seconds.
# [10:45:16] Finish count vectorizing (ngram=1) [sklearn]. △M: +263.16MB. △T: 53.4 seconds.
# [10:45:16] Finish saving count vectors. △M: -263.13MB. △T: 0.3 seconds.
# [10:46:20] Finish TFIDF vectorizing (ngram=1) transformation. △M: +570.59MB. △T: 1.1 minutes.
# [10:46:21] Finish saving TFIDF vectors. △M: -570.58MB. △T: 0.5 seconds.
# [10:46:21] Finish cleaning. △M: -464.89MB. △T: 0.3 seconds.
# --------------------------------------------------------------------------------
# Processing 'interest3'...
# [10:46:24] Finish loading and preprocessing. △M: +257.56MB. △T: 3.4 seconds.
# [10:47:04] Finish count vectorizing (ngram=1) [sklearn]. △M: +70.39MB. △T: 39.2 seconds.
# [10:47:04] Finish saving count vectors. △M: -78.76MB. △T: 0.2 seconds.
# [10:47:44] Finish TFIDF vectorizing (ngram=1) transformation. △M: +208.41MB. △T: 40.5 seconds.
# [10:47:45] Finish saving TFIDF vectors. △M: -196.02MB. △T: 0.3 seconds.
# [10:47:45] Finish cleaning. △M: -262.89MB. △T: 0.1 seconds.
# --------------------------------------------------------------------------------
# Processing 'interest4'...
# [10:47:49] Finish loading and preprocessing. △M: +257.14MB. △T: 4.2 seconds.
# [10:48:27] Finish count vectorizing (ngram=1) [sklearn]. △M: +65.32MB. △T: 38.0 seconds.
# [10:48:27] Finish saving count vectors. △M: -73.45MB. △T: 0.1 seconds.
# [10:49:08] Finish TFIDF vectorizing (ngram=1) transformation. △M: +164.96MB. △T: 41.5 seconds.
# [10:49:09] Finish saving TFIDF vectors. △M: -180.84MB. △T: 0.2 seconds.
# [10:49:09] Finish cleaning. △M: -261.64MB. △T: 0.1 seconds.
# --------------------------------------------------------------------------------
# Processing 'interest5'...
# [10:49:25] Finish loading and preprocessing. △M: +1.17GB. △T: 16.2 seconds.
# [10:52:03] Finish count vectorizing (ngram=1) [sklearn]. △M: +872.65MB. △T: 2.6 minutes.
# [10:52:04] Finish saving count vectors. △M: -865.56MB. △T: 0.9 seconds.
# [10:54:48] Finish TFIDF vectorizing (ngram=1) transformation. △M: +1.96GB. △T: 2.7 minutes.
# [10:54:49] Finish saving TFIDF vectors. △M: -1.97GB. △T: 1.5 seconds.
# [10:54:50] Finish cleaning. △M: -1.14GB. △T: 1.0 seconds.
# --------------------------------------------------------------------------------
# Processing 'kw1'...
# [10:55:07] Finish loading and preprocessing. △M: +1.11GB. △T: 17.1 seconds.
# [10:56:31] Finish count vectorizing (ngram=1) [sklearn]. △M: +308.66MB. △T: 1.4 minutes.
# [10:56:36] Finish saving count vectors. △M: -301.86MB. △T: 4.6 seconds.
# [10:58:07] Finish TFIDF vectorizing (ngram=1) transformation. △M: +660.79MB. △T: 1.5 minutes.
# [10:58:13] Finish saving TFIDF vectors. △M: -688.18MB. △T: 5.4 seconds.
# [10:58:13] Finish cleaning. △M: -1.1GB. △T: 0.4 seconds.
# --------------------------------------------------------------------------------
# Processing 'kw2'...
# [11:21:28] Finish loading and preprocessing. △M: +1.04GB. △T: 23.2 minutes.
# [11:22:12] Finish count vectorizing (ngram=1) [sklearn]. △M: +283.34MB. △T: 44.0 seconds.
# [11:22:12] Finish saving count vectors. △M: -304.42MB. △T: 0.7 seconds.
# [11:23:05] Finish TFIDF vectorizing (ngram=1) transformation. △M: +668.01MB. △T: 53.2 seconds.
# [11:23:07] Finish saving TFIDF vectors. △M: -651.99MB. △T: 1.3 seconds.
# [11:23:07] Finish cleaning. △M: -1.02GB. △T: 0.5 seconds.
# --------------------------------------------------------------------------------
# Processing 'kw3'...
# [11:23:12] Finish loading and preprocessing. △M: +318.68MB. △T: 4.5 seconds.
# [11:23:51] Finish count vectorizing (ngram=1) [sklearn]. △M: +91.91MB. △T: 39.5 seconds.
# [11:23:51] Finish saving count vectors. △M: -131.61MB. △T: 0.2 seconds.
# [11:24:34] Finish TFIDF vectorizing (ngram=1) transformation. △M: +197.86MB. △T: 42.1 seconds.
# [11:24:34] Finish saving TFIDF vectors. △M: -182.0MB. △T: 0.3 seconds.
# [11:24:34] Finish cleaning. △M: -297.64MB. △T: 0.2 seconds.
# --------------------------------------------------------------------------------
# Processing 'topic1'...
# [11:24:45] Finish loading and preprocessing. △M: +1.02GB. △T: 11.4 seconds.
# [11:25:45] Finish count vectorizing (ngram=1) [sklearn]. △M: +309.2MB. △T: 59.7 seconds.
# [11:25:46] Finish saving count vectors. △M: -298.11MB. △T: 0.4 seconds.
# [11:26:51] Finish TFIDF vectorizing (ngram=1) transformation. △M: +655.18MB. △T: 1.1 minutes.
# [11:26:52] Finish saving TFIDF vectors. △M: -654.94MB. △T: 0.7 seconds.
# [11:26:52] Finish cleaning. △M: -1.01GB. △T: 0.5 seconds.
# --------------------------------------------------------------------------------
# Processing 'topic2'...
# [11:27:03] Finish loading and preprocessing. △M: +833.25MB. △T: 10.9 seconds.
# [11:28:09] Finish count vectorizing (ngram=1) [sklearn]. △M: +318.19MB. △T: 1.1 minutes.
# [11:28:09] Finish saving count vectors. △M: -306.87MB. △T: 0.4 seconds.
# [11:29:21] Finish TFIDF vectorizing (ngram=1) transformation. △M: +691.6MB. △T: 1.2 minutes.
# [11:29:21] Finish saving TFIDF vectors. △M: -676.51MB. △T: 0.7 seconds.
# [11:29:22] Finish cleaning. △M: -846.39MB. △T: 0.4 seconds.
# --------------------------------------------------------------------------------
# Processing 'topic3'...
# [11:29:25] Finish loading and preprocessing. △M: +290.41MB. △T: 3.5 seconds.
# [11:30:03] Finish count vectorizing (ngram=1) [sklearn]. △M: +87.26MB. △T: 38.1 seconds.
# [11:30:04] Finish saving count vectors. △M: -127.12MB. △T: 0.2 seconds.
# [11:30:41] Finish TFIDF vectorizing (ngram=1) transformation. △M: +198.12MB. △T: 37.7 seconds.
# [11:30:42] Finish saving TFIDF vectors. △M: -181.62MB. △T: 0.2 seconds.
# [11:30:42] Finish cleaning. △M: -297.89MB. △T: 0.1 seconds.
# --------------------------------------------------------------------------------
# Processing 'appIdInstall'...
# [11:30:46] Finish loading and preprocessing. △M: +609.59MB. △T: 4.7 seconds.
# [11:31:45] Finish count vectorizing (ngram=1) [sklearn]. △M: +234.43MB. △T: 58.5 seconds.
# [11:31:46] Finish saving count vectors. △M: -222.06MB. △T: 0.9 seconds.
# [11:32:53] Finish TFIDF vectorizing (ngram=1) transformation. △M: +473.31MB. △T: 1.1 minutes.
# [11:32:54] Finish saving TFIDF vectors. △M: -473.35MB. △T: 1.0 seconds.
# [11:32:54] Finish cleaning. △M: -336.72MB. △T: 0.2 seconds.
# --------------------------------------------------------------------------------
# Processing 'appIdAction'...
# [11:32:57] Finish loading and preprocessing. △M: +185.95MB. △T: 3.2 seconds.
# [11:33:36] Finish count vectorizing (ngram=1) [sklearn]. △M: +49.59MB. △T: 38.5 seconds.
# [11:33:36] Finish saving count vectors. △M: -49.5MB. △T: 0.2 seconds.
# [11:34:20] Finish TFIDF vectorizing (ngram=1) transformation. △M: +148.66MB. △T: 44.0 seconds.
# [11:34:20] Finish saving TFIDF vectors. △M: -148.66MB. △T: 0.3 seconds.
# [11:34:20] Finish cleaning. △M: -186.51MB. △T: 0.1 seconds.
# --------------------------------------------------------------------------------
# Processing 'ct'...
# [11:34:24] Finish loading and preprocessing. △M: +7.52MB. △T: 3.7 seconds.
# [11:35:05] Finish count vectorizing (ngram=1) [sklearn]. △M: +64.46MB. △T: 41.5 seconds.
# [11:35:06] Finish saving count vectors. △M: -44.36MB. △T: 0.2 seconds.
# [11:35:51] Finish TFIDF vectorizing (ngram=1) transformation. △M: +296.38MB. △T: 45.8 seconds.
# [11:35:52] Finish saving TFIDF vectors. △M: -294.25MB. △T: 0.3 seconds.
# [11:35:52] Finish cleaning. △M: -87.63MB. △T: 0.1 seconds.
# --------------------------------------------------------------------------------
# Processing 'os'...
# [11:35:55] Finish loading and preprocessing. △M: -256.0KB. △T: 2.9 seconds.
# [11:36:31] Finish count vectorizing (ngram=1) [sklearn]. △M: +90.48MB. △T: 36.4 seconds.
# [11:36:31] Finish saving count vectors. △M: -90.48MB. △T: 0.1 seconds.
# [11:37:11] Finish TFIDF vectorizing (ngram=1) transformation. △M: +184.07MB. △T: 39.8 seconds.
# [11:37:11] Finish saving TFIDF vectors. △M: -184.32MB. △T: 0.2 seconds.
# [11:37:11] Finish cleaning. △M: -256.0KB. △T: 0.1 seconds.
# --------------------------------------------------------------------------------
# Processing 'carrier'...
# [11:37:14] Finish loading and preprocessing. △M: +0B. △T: 2.9 seconds.
# [11:37:50] Finish count vectorizing (ngram=1) [sklearn]. △M: +87.13MB. △T: 36.1 seconds.
# [11:37:50] Finish saving count vectors. △M: -87.13MB. △T: 0.2 seconds.
