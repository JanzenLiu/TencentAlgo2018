# %%
import pandas as pd
import numpy as np
import operator
import pickle
import time
import os
import matplotlib.pyplot as plt
import sys
sys.path.append("../code/utils")
import data_utils as du
import perf_utils as pu

# %%
clickhist_folder = "../data/click_history/simple_cross/byUserFeatureName/"
os.makedirs(clickhist_folder, exist_ok=True)

# %%
df_train = du.load_raw_data("train")
df_ad = du.load_raw_data("ad")
ad_user = pd.merge(df_train, df_ad, on='aid', how='left')
train_size = df_train.shape[0]

# %%
ad_feat_names = ['aid', 'advertiserId', 'campaignId', 'creativeId', 'creativeSize',
                 'adCategoryId', 'productId', 'productType']
user_feat_names = ["age", "gender", "marriageStatus", "education", "consumptionAbility", "LBS",
                   "interest1", "interest2", "interest3", "interest4", "interest5",
                   "kw1", "kw2", "kw3", "topic1", "topic2", "topic3", "appIdInstall",
                   "appIdAction", "ct", "os", "carrier", "house"]

# %%
avals = {ad_feat_name: df_ad[ad_feat_name].unique() for ad_feat_name in ad_feat_names}
with pu.profiler("calculating user index mapping for ad feature values"):
    aval_to_indices = {ad_feat_name: ad_user.groupby(ad_feat_name).groups for ad_feat_name in ad_feat_names}
# Out:
# [04:58:36] Finish calculating user index mapping for ad feature values. △M: +535.48MB. △T: 8.3 seconds.

# %%
for user_feat_name in user_feat_names:
    # Given a user feature
    # load dictionary and the sparse matrix
    uids, (ufeat_index, uvec) = du.load_user_cnt(user_feat_name)
    uid_to_index = dict(zip(uids, list(range(len(uids)))))  # mapping from uids to distinct indices
    ad_user["user_index"] = ad_user['uid'].map(uid_to_index)
    
    for ad_feat_name in ad_feat_names:
        print("[{}] counting ad['{}'] x user['{}']...".format(pu.get_time_str(), ad_feat_name, user_feat_name))
        total_count = 0
        for aval in avals[ad_feat_name]:
            # Given an ad feature value
            # get indices and select DataFrame
            indices = aval_to_indices[ad_feat_name][aval]  # indices of rows with [ad_feat_name=aval]
            df_selected = ad_user.loc[indices]  # rows with [ad_feat_name=aval]
            total_count += df_selected.shape[0]

            # select positive and netagive
            df_pos = df_selected[df_selected['label']==1]  # rows with [ad_feat_name=aval] and clicked
            df_neg = df_selected[df_selected['label']==-1]  # rows with [ad_feat_name=aval] and unclicked

            # get positive and negative indices to pick rows in the sparse matrix
            pos_uindex = df_pos['user_index'].values
            neg_uindex = df_neg['user_index'].values

            # pick up rows from the sparse matrix
            X_pos = uvec[pos_uindex,:]
            X_neg = uvec[neg_uindex,:]

            # count positive and negative
            pos_count = X_pos.sum(axis=0)
            pos_count = np.squeeze(np.asarray(pos_count))
            neg_count = X_neg.sum(axis=0)
            neg_count = np.squeeze(np.asarray(neg_count))

            # sort feature values by their indices
            sorted_index = sorted(ufeat_index.items(), key=operator.itemgetter(1))
            values = [k for k, v in sorted_index]

            # construct DataFrame
            counter = pd.DataFrame()
            counter["value"] = values
            counter["positive"] = pos_count
            counter["negative"] = neg_count

            # append aggregate
            counter = counter.append({"value": "all", 
                                      "positive": df_pos.shape[0], 
                                      "negative": df_neg.shape[0]}, 
                                     ignore_index=True)

            out_folder = os.path.join(clickhist_folder, "[featureName='{}']".format(user_feat_name))
            os.makedirs(out_folder, exist_ok=True)
            out_filename = "[{}='{}'].csv".format(ad_feat_name, aval)
            out_filepath = os.path.join(out_folder, out_filename)
            counter.to_csv(out_filepath, index=False)

        assert total_count == train_size
# Out:
# [04:59:02] counting ad['aid'] x user['age']...
# [04:59:16] counting ad['advertiserId'] x user['age']...
# [04:59:25] counting ad['campaignId'] x user['age']...
# [04:59:35] counting ad['creativeId'] x user['age']...
# [04:59:46] counting ad['creativeSize'] x user['age']...
# [04:59:53] counting ad['adCategoryId'] x user['age']...
# [05:00:02] counting ad['productId'] x user['age']...
# [05:00:10] counting ad['productType'] x user['age']...
# [05:00:43] counting ad['aid'] x user['gender']...
# [05:00:52] counting ad['advertiserId'] x user['gender']...
# [05:01:01] counting ad['campaignId'] x user['gender']...
# [05:01:11] counting ad['creativeId'] x user['gender']...
# [05:01:22] counting ad['creativeSize'] x user['gender']...
# [05:01:31] counting ad['adCategoryId'] x user['gender']...
# [05:01:39] counting ad['productId'] x user['gender']...
# [05:01:49] counting ad['productType'] x user['gender']...
# [05:02:26] counting ad['aid'] x user['marriageStatus']...
# [05:02:37] counting ad['advertiserId'] x user['marriageStatus']...
# [05:02:46] counting ad['campaignId'] x user['marriageStatus']...
# [05:02:55] counting ad['creativeId'] x user['marriageStatus']...
# [05:03:03] counting ad['creativeSize'] x user['marriageStatus']...
# [05:03:10] counting ad['adCategoryId'] x user['marriageStatus']...
# [05:03:17] counting ad['productId'] x user['marriageStatus']...
# [05:03:24] counting ad['productType'] x user['marriageStatus']...
# [05:04:00] counting ad['aid'] x user['education']...
# [05:04:11] counting ad['advertiserId'] x user['education']...
# [05:04:20] counting ad['campaignId'] x user['education']...
# [05:04:31] counting ad['creativeId'] x user['education']...
# [05:04:41] counting ad['creativeSize'] x user['education']...
# [05:04:50] counting ad['adCategoryId'] x user['education']...
# [05:05:00] counting ad['productId'] x user['education']...
# [05:05:09] counting ad['productType'] x user['education']...
# [05:05:45] counting ad['aid'] x user['consumptionAbility']...
# [05:05:56] counting ad['advertiserId'] x user['consumptionAbility']...
# [05:06:06] counting ad['campaignId'] x user['consumptionAbility']...
# [05:06:16] counting ad['creativeId'] x user['consumptionAbility']...
# [05:06:26] counting ad['creativeSize'] x user['consumptionAbility']...
# [05:06:36] counting ad['adCategoryId'] x user['consumptionAbility']...
# [05:06:45] counting ad['productId'] x user['consumptionAbility']...
# [05:06:54] counting ad['productType'] x user['consumptionAbility']...
# [05:07:32] counting ad['aid'] x user['LBS']...
# [05:07:44] counting ad['advertiserId'] x user['LBS']...
# [05:07:53] counting ad['campaignId'] x user['LBS']...
# [05:08:04] counting ad['creativeId'] x user['LBS']...
# [05:08:18] counting ad['creativeSize'] x user['LBS']...
# [05:08:27] counting ad['adCategoryId'] x user['LBS']...
# [05:08:37] counting ad['productId'] x user['LBS']...
# [05:08:44] counting ad['productType'] x user['LBS']...
# [05:09:15] counting ad['aid'] x user['interest1']...
# [05:09:27] counting ad['advertiserId'] x user['interest1']...
# [05:09:38] counting ad['campaignId'] x user['interest1']...
# [05:09:50] counting ad['creativeId'] x user['interest1']...
# [05:10:03] counting ad['creativeSize'] x user['interest1']...
# [05:10:14] counting ad['adCategoryId'] x user['interest1']...
# [05:10:24] counting ad['productId'] x user['interest1']...
# [05:10:36] counting ad['productType'] x user['interest1']...
# [05:11:10] counting ad['aid'] x user['interest2']...
# [05:11:21] counting ad['advertiserId'] x user['interest2']...
# [05:11:31] counting ad['campaignId'] x user['interest2']...
# [05:11:41] counting ad['creativeId'] x user['interest2']...
# [05:11:51] counting ad['creativeSize'] x user['interest2']...
# [05:12:00] counting ad['adCategoryId'] x user['interest2']...
# [05:12:08] counting ad['productId'] x user['interest2']...
# [05:12:16] counting ad['productType'] x user['interest2']...
# [05:12:53] counting ad['aid'] x user['interest3']...
# [05:13:05] counting ad['advertiserId'] x user['interest3']...
# [05:13:14] counting ad['campaignId'] x user['interest3']...
# [05:13:24] counting ad['creativeId'] x user['interest3']...
# [05:13:34] counting ad['creativeSize'] x user['interest3']...
# [05:13:43] counting ad['adCategoryId'] x user['interest3']...
# [05:13:52] counting ad['productId'] x user['interest3']...
# [05:14:00] counting ad['productType'] x user['interest3']...
# [05:14:34] counting ad['aid'] x user['interest4']...
# [05:14:46] counting ad['advertiserId'] x user['interest4']...
# [05:14:55] counting ad['campaignId'] x user['interest4']...
# [05:15:05] counting ad['creativeId'] x user['interest4']...
# [05:15:16] counting ad['creativeSize'] x user['interest4']...
# [05:15:25] counting ad['adCategoryId'] x user['interest4']...
# [05:15:34] counting ad['productId'] x user['interest4']...
# [05:15:43] counting ad['productType'] x user['interest4']...
# [05:16:22] counting ad['aid'] x user['interest5']...
# [05:16:37] counting ad['advertiserId'] x user['interest5']...
# [05:16:49] counting ad['campaignId'] x user['interest5']...
# [05:17:02] counting ad['creativeId'] x user['interest5']...
# [05:17:16] counting ad['creativeSize'] x user['interest5']...
# [05:17:30] counting ad['adCategoryId'] x user['interest5']...
# [05:17:44] counting ad['productId'] x user['interest5']...
# [05:17:57] counting ad['productType'] x user['interest5']...
# [05:18:39] counting ad['aid'] x user['kw1']...
# [05:24:33] counting ad['advertiserId'] x user['kw1']...
# [05:28:07] counting ad['campaignId'] x user['kw1']...
# [05:34:01] counting ad['creativeId'] x user['kw1']...
# [06:09:56] counting ad['creativeSize'] x user['kw1']...
# [06:10:27] counting ad['adCategoryId'] x user['kw1']...
# [06:11:32] counting ad['productId'] x user['kw1']...
# [06:12:31] counting ad['productType'] x user['kw1']...
# [06:13:11] counting ad['aid'] x user['kw2']...
# [06:14:12] counting ad['advertiserId'] x user['kw2']...
# [06:14:51] counting ad['campaignId'] x user['kw2']...
# [06:15:42] counting ad['creativeId'] x user['kw2']...
# [06:16:41] counting ad['creativeSize'] x user['kw2']...
# [06:16:58] counting ad['adCategoryId'] x user['kw2']...
# [06:17:23] counting ad['productId'] x user['kw2']...
# [06:17:44] counting ad['productType'] x user['kw2']...
# [06:18:19] counting ad['aid'] x user['kw3']...
# [06:18:35] counting ad['advertiserId'] x user['kw3']...
# [06:18:48] counting ad['campaignId'] x user['kw3']...
# [06:19:02] counting ad['creativeId'] x user['kw3']...
# [06:19:19] counting ad['creativeSize'] x user['kw3']...
# [06:19:28] counting ad['adCategoryId'] x user['kw3']...
# [06:19:38] counting ad['productId'] x user['kw3']...
# [06:19:47] counting ad['productType'] x user['kw3']...
# [06:20:13] counting ad['aid'] x user['topic1']...
# [06:20:31] counting ad['advertiserId'] x user['topic1']...
# [06:20:48] counting ad['campaignId'] x user['topic1']...
# [06:21:05] counting ad['creativeId'] x user['topic1']...
# [06:21:22] counting ad['creativeSize'] x user['topic1']...
# [06:21:34] counting ad['adCategoryId'] x user['topic1']...
# [06:21:47] counting ad['productId'] x user['topic1']...
# [06:21:59] counting ad['productType'] x user['topic1']...
# [06:22:29] counting ad['aid'] x user['topic2']...
# [06:22:46] counting ad['advertiserId'] x user['topic2']...
# [06:23:01] counting ad['campaignId'] x user['topic2']...
# [06:23:17] counting ad['creativeId'] x user['topic2']...
# [06:23:34] counting ad['creativeSize'] x user['topic2']...
# [06:23:45] counting ad['adCategoryId'] x user['topic2']...
# [06:23:57] counting ad['productId'] x user['topic2']...
# [06:24:07] counting ad['productType'] x user['topic2']...
# [06:24:36] counting ad['aid'] x user['topic3']...
# [06:24:47] counting ad['advertiserId'] x user['topic3']...
# [06:24:56] counting ad['campaignId'] x user['topic3']...
# [06:25:07] counting ad['creativeId'] x user['topic3']...
# [06:25:18] counting ad['creativeSize'] x user['topic3']...
# [06:25:25] counting ad['adCategoryId'] x user['topic3']...
# [06:25:33] counting ad['productId'] x user['topic3']...
# [06:25:41] counting ad['productType'] x user['topic3']...
# [06:26:08] counting ad['aid'] x user['appIdInstall']...
# [06:27:13] counting ad['advertiserId'] x user['appIdInstall']...
# [06:27:53] counting ad['campaignId'] x user['appIdInstall']...
# [06:28:49] counting ad['creativeId'] x user['appIdInstall']...
# [06:29:54] counting ad['creativeSize'] x user['appIdInstall']...
# [06:30:11] counting ad['adCategoryId'] x user['appIdInstall']...
# [06:30:35] counting ad['productId'] x user['appIdInstall']...
# [06:30:56] counting ad['productType'] x user['appIdInstall']...
# [06:31:25] counting ad['aid'] x user['appIdAction']...
# [06:31:37] counting ad['advertiserId'] x user['appIdAction']...
# [06:31:46] counting ad['campaignId'] x user['appIdAction']...
# [06:31:57] counting ad['creativeId'] x user['appIdAction']...
# [06:32:08] counting ad['creativeSize'] x user['appIdAction']...
# [06:32:16] counting ad['adCategoryId'] x user['appIdAction']...
# [06:32:24] counting ad['productId'] x user['appIdAction']...
# [06:32:32] counting ad['productType'] x user['appIdAction']...
# [06:32:57] counting ad['aid'] x user['ct']...
# [06:33:05] counting ad['advertiserId'] x user['ct']...
# [06:33:12] counting ad['campaignId'] x user['ct']...
# [06:33:19] counting ad['creativeId'] x user['ct']...
# [06:33:26] counting ad['creativeSize'] x user['ct']...
# [06:33:33] counting ad['adCategoryId'] x user['ct']...
# [06:33:39] counting ad['productId'] x user['ct']...
# [06:33:46] counting ad['productType'] x user['ct']...
# [06:34:12] counting ad['aid'] x user['os']...
# [06:34:19] counting ad['advertiserId'] x user['os']...
# [06:34:25] counting ad['campaignId'] x user['os']...
# [06:34:32] counting ad['creativeId'] x user['os']...
# [06:34:40] counting ad['creativeSize'] x user['os']...
# [06:34:46] counting ad['adCategoryId'] x user['os']...
# [06:34:52] counting ad['productId'] x user['os']...
# [06:34:58] counting ad['productType'] x user['os']...
# [06:35:22] counting ad['aid'] x user['carrier']...
# [06:35:30] counting ad['advertiserId'] x user['carrier']...
# [06:35:36] counting ad['campaignId'] x user['carrier']...
# [06:35:42] counting ad['creativeId'] x user['carrier']...
# [06:35:49] counting ad['creativeSize'] x user['carrier']...
# [06:35:55] counting ad['adCategoryId'] x user['carrier']...
# [06:36:01] counting ad['productId'] x user['carrier']...
# [06:36:07] counting ad['productType'] x user['carrier']...
# [06:36:32] counting ad['aid'] x user['house']...
# [06:36:39] counting ad['advertiserId'] x user['house']...
# [06:36:45] counting ad['campaignId'] x user['house']...
# [06:36:52] counting ad['creativeId'] x user['house']...
# [06:36:59] counting ad['creativeSize'] x user['house']...
# [06:37:05] counting ad['adCategoryId'] x user['house']...
# [06:37:12] counting ad['productId'] x user['house']...
# [06:37:18] counting ad['productType'] x user['house']...
