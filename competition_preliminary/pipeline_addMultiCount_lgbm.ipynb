# %%
from sklearn.model_selection import StratifiedShuffleSplit, StratifiedKFold
from contextlib import redirect_stdout
import scipy.sparse as sparse
import lightgbm as lgb
import pandas as pd
import numpy as np
import tqdm
import os
import gc
import sys
sys.path.append('../code/utils/')
sys.path.append('../code/')
import data_utils as du
import perf_utils as pu
import config

# %%
class DuplicatedLogger(object):
    """Lumberjack class - duplicates sys.stdout to a log file.
    
    Adapted from https://stackoverflow.com/q/616645
    """
    def __init__(self, filename, mode="a", buffer=10):
        self.stdout = sys.stdout
        self.file = open(filename, mode, buffer)
        sys.stdout = self

    def __del__(self):
        self.close()

    def __enter__(self):
        pass

    def __exit__(self, *args):
        self.close()

    def write(self, message):
        self.stdout.write(message)
        self.file.write(message)

    def flush(self):
        self.stdout.flush()
        self.file.flush()
        os.fsync(self.file.fileno())

    def close(self):
        if self.stdout is not None:
            sys.stdout = self.stdout
            self.stdout = None

        if self.file is not None:
            self.file.close()

# %%
input_folder = config.INPUT_DIR

def load_binary(mode="train"):
    if mode == "train":
        input_file = "train.raw.binary.pkl"
    elif mode == "test":
        input_file = "test1.raw.binary.pkl"
    else:
        raise ValueError("Unknown mode: {}".format(mode))
    input_path = os.path.join(input_folder, input_file)
    return du.load_pickle(input_path)


def load_multicount(mode="train"):
    if mode == "train":
        input_file = "train.raw.rowCount.pkl"
    elif mode == "test":
        input_file = "test1.raw.rowCount.pkl"
    else:
        raise ValueError("Unknown mode: {}".format(mode))
    input_path = os.path.join(input_folder, input_file)
    return du.load_pickle(input_path)

# %%
with pu.profiler("loading binary features"):
    bin_cols, X_bin = load_binary("train")

with pu.profiler("loading multi value count features"):
    multicount_cols, X_multicount = load_multicount("train")
    
assert X_bin.shape[1] == len(bin_cols)
assert X_multicount.shape[1] == len(multicount_cols)
assert X_bin.shape[0] == X_multicount.shape[0]
print("Binary Feature Shape: {}".format(X_bin.shape))
print("Multi-value Count Feature Shape: {}".format(X_multicount.shape))
# Out:
# [14:54:11] Finish loading binary features. △M: +3.26GB. △T: 10.8 seconds.
# [14:54:13] Finish loading multi value count features. △M: +963.44MB. △T: 2.7 seconds.
# Binary Feature Shape: (8798814, 419701)
# Multi-value Count Feature Shape: (8798814, 16)

# %%
with pu.profiler("joining data"):
    cols = bin_cols + multicount_cols
    X = sparse.hstack((X_bin, X_multicount))
    X = sparse.csr_matrix(X)
    del X_bin
    del X_multicount
    gc.collect()
    
print("Joined Data Shape: {}".format(X.shape))
print("Feature Names Count: {}".format(len(cols)))
print("Memory usage at this moment :{}".format(pu.get_memory_str()))
# Out:
# [14:55:28] Finish joining data. △M: +4.45GB. △T: 1.2 minutes.
# Joined Data Shape: (8798814, 419717)
# Feature Names Count: 419717
# Memory usage at this moment :8.75GB

# %%
df_train = du.load_raw_data("train")
y = df_train['label'].values.copy()
y = (y + 1) / 2  # -1, 1 -> 0, 1

# %%
# n_splits = 5
# sss = StratifiedShuffleSplit(n_splits=n_splits, test_size=0.2, random_state=20180505)
# split_indices = [(train_index, valid_index) for train_index, valid_index in sss.split(df_train, y)]

n_splits = 3  # use 3 instead of 5 to save time
skf = StratifiedKFold(n_splits=n_splits)
split_indices = [(train_index, valid_index) for train_index, valid_index in skf.split(df_train, y)]

# %%
with pu.profiler("splitting train/valid set"):
    train_index, valid_index = split_indices[0]
    X_train, X_valid = X[train_index], X[valid_index]
    y_train, y_valid = y[train_index], y[valid_index]
    assert X_train.shape[0] + X_valid.shape[0] == X.shape[0]
    
    del X
    gc.collect()
    
print("Training Set Size: {}".format(X_train.shape))
print("Validation Set Size: {}".format(X_valid.shape))
# Out:
# [14:56:03] Finish splitting train/valid set. △M: +69.94MB. △T: 28.5 seconds.
# Training Set Size: (5865875, 419717)
# Validation Set Size: (2932939, 419717)

# %%
with pu.profiler("preparing LightGBM data"):
    lgb_train = lgb.Dataset(X_train.astype(np.float32), y_train, feature_name=cols)
    lgb_valid = lgb.Dataset(X_valid.astype(np.float32), y_valid, feature_name=cols)
    gc.collect()
# Out:
# [14:56:22] Finish preparing LightGBM data. △M: +5.75GB. △T: 18.6 seconds.

# %%
log_folder = os.path.join(config.LOG_DIR, 'lgbm/pipeline/0505/')
log_file = 'v1.log'
log_path = os.path.join(log_folder, log_file)
os.makedirs(log_folder, exist_ok=True)

# %%
params = {
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': 'auc',
    'max_depth': 15,
    'num_leaves': 120,
    'learning_rate': 0.15,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'verbose': 0
}
num_rounds = 500

with DuplicatedLogger(log_path):
    lgbm = lgb.train(params,
                     lgb_train,
                     num_boost_round=num_rounds,
                     valid_sets=[lgb_train, lgb_valid], 
                     valid_names=['train', 'valid1'],
                     early_stopping_rounds=50)
# Out:
# [1]	train's auc: 0.644096	valid1's auc: 0.64484
# Training until validation scores don't improve for 50 rounds.
# [2]	train's auc: 0.67116	valid1's auc: 0.671451
# [3]	train's auc: 0.67542	valid1's auc: 0.675298
# [4]	train's auc: 0.679707	valid1's auc: 0.679858
# [5]	train's auc: 0.681723	valid1's auc: 0.681894
# [6]	train's auc: 0.682095	valid1's auc: 0.682318
# [7]	train's auc: 0.682466	valid1's auc: 0.682524
# [8]	train's auc: 0.683862	valid1's auc: 0.684055
# [9]	train's auc: 0.685492	valid1's auc: 0.685772
# [10]	train's auc: 0.686555	valid1's auc: 0.686728
# [11]	train's auc: 0.688598	valid1's auc: 0.688655
# [12]	train's auc: 0.689363	valid1's auc: 0.689375
# [13]	train's auc: 0.690337	valid1's auc: 0.690238
# [14]	train's auc: 0.691479	valid1's auc: 0.691443
# [15]	train's auc: 0.692156	valid1's auc: 0.692085
# [16]	train's auc: 0.692965	valid1's auc: 0.692781
# [17]	train's auc: 0.694087	valid1's auc: 0.693848
# [18]	train's auc: 0.695429	valid1's auc: 0.69512
# [19]	train's auc: 0.696424	valid1's auc: 0.696009
# [20]	train's auc: 0.69855	valid1's auc: 0.698064
# [21]	train's auc: 0.699833	valid1's auc: 0.699267
# [22]	train's auc: 0.701211	valid1's auc: 0.700541
# [23]	train's auc: 0.703161	valid1's auc: 0.702357
# [24]	train's auc: 0.704176	valid1's auc: 0.703165
# [25]	train's auc: 0.705671	valid1's auc: 0.704509
# [26]	train's auc: 0.70748	valid1's auc: 0.706233
# [27]	train's auc: 0.708997	valid1's auc: 0.707532
# [28]	train's auc: 0.710838	valid1's auc: 0.7092
# [29]	train's auc: 0.712229	valid1's auc: 0.710353
# [30]	train's auc: 0.713464	valid1's auc: 0.711545
# [31]	train's auc: 0.71434	valid1's auc: 0.712291
# [32]	train's auc: 0.715445	valid1's auc: 0.713239
# [33]	train's auc: 0.716363	valid1's auc: 0.71397
# [34]	train's auc: 0.717227	valid1's auc: 0.714671
# [35]	train's auc: 0.718456	valid1's auc: 0.715705
# [36]	train's auc: 0.719283	valid1's auc: 0.71629
# [37]	train's auc: 0.719925	valid1's auc: 0.716707
# [38]	train's auc: 0.720719	valid1's auc: 0.717391
# [39]	train's auc: 0.721523	valid1's auc: 0.718
# [40]	train's auc: 0.722298	valid1's auc: 0.718479
# [41]	train's auc: 0.722983	valid1's auc: 0.718958
# [42]	train's auc: 0.723943	valid1's auc: 0.719876
# [43]	train's auc: 0.724739	valid1's auc: 0.720388
# [44]	train's auc: 0.725402	valid1's auc: 0.720769
# [45]	train's auc: 0.725959	valid1's auc: 0.721193
# [46]	train's auc: 0.72651	valid1's auc: 0.721619
# [47]	train's auc: 0.727266	valid1's auc: 0.72217
# [48]	train's auc: 0.728105	valid1's auc: 0.722757
# [49]	train's auc: 0.728515	valid1's auc: 0.723087
# [50]	train's auc: 0.729295	valid1's auc: 0.723684
# [51]	train's auc: 0.729787	valid1's auc: 0.723984
# [52]	train's auc: 0.730369	valid1's auc: 0.724192
# [53]	train's auc: 0.730914	valid1's auc: 0.724459
# [54]	train's auc: 0.731307	valid1's auc: 0.724656
# [55]	train's auc: 0.731897	valid1's auc: 0.724962
# [56]	train's auc: 0.732463	valid1's auc: 0.725256
# [57]	train's auc: 0.732825	valid1's auc: 0.725439
# [58]	train's auc: 0.733122	valid1's auc: 0.725591
# [59]	train's auc: 0.733566	valid1's auc: 0.725725
# [60]	train's auc: 0.734005	valid1's auc: 0.726007
# [61]	train's auc: 0.734383	valid1's auc: 0.726172
# [62]	train's auc: 0.734802	valid1's auc: 0.726312
# [63]	train's auc: 0.735133	valid1's auc: 0.72647
# [64]	train's auc: 0.735508	valid1's auc: 0.726636
# [65]	train's auc: 0.735927	valid1's auc: 0.726878
# [66]	train's auc: 0.736392	valid1's auc: 0.727041
# [67]	train's auc: 0.736881	valid1's auc: 0.727201
# [68]	train's auc: 0.737327	valid1's auc: 0.727424
# [69]	train's auc: 0.737711	valid1's auc: 0.72764
# [70]	train's auc: 0.738103	valid1's auc: 0.727735
# [71]	train's auc: 0.738363	valid1's auc: 0.727814
# [72]	train's auc: 0.73911	valid1's auc: 0.728368
# [73]	train's auc: 0.739402	valid1's auc: 0.728481
# [74]	train's auc: 0.739627	valid1's auc: 0.728544
# [75]	train's auc: 0.739934	valid1's auc: 0.728637
# [76]	train's auc: 0.740339	valid1's auc: 0.728741
# [77]	train's auc: 0.740728	valid1's auc: 0.72884
# [78]	train's auc: 0.740995	valid1's auc: 0.728953
# [79]	train's auc: 0.741451	valid1's auc: 0.729142
# [80]	train's auc: 0.741902	valid1's auc: 0.729381
# [81]	train's auc: 0.74216	valid1's auc: 0.729453
# [82]	train's auc: 0.742519	valid1's auc: 0.729576
# [83]	train's auc: 0.742968	valid1's auc: 0.729705
# [84]	train's auc: 0.743219	valid1's auc: 0.729719
# [85]	train's auc: 0.743678	valid1's auc: 0.729878
# [86]	train's auc: 0.743954	valid1's auc: 0.729943
# [87]	train's auc: 0.744237	valid1's auc: 0.73009
# [88]	train's auc: 0.744632	valid1's auc: 0.730194
# [89]	train's auc: 0.74499	valid1's auc: 0.730319
# [90]	train's auc: 0.745346	valid1's auc: 0.730395
# [91]	train's auc: 0.745742	valid1's auc: 0.730543
# [92]	train's auc: 0.746074	valid1's auc: 0.730629
# [93]	train's auc: 0.746461	valid1's auc: 0.730709
# [94]	train's auc: 0.746796	valid1's auc: 0.73085
# [95]	train's auc: 0.747221	valid1's auc: 0.731062
# [96]	train's auc: 0.747401	valid1's auc: 0.731082
# [97]	train's auc: 0.747755	valid1's auc: 0.731142
# [98]	train's auc: 0.748051	valid1's auc: 0.731202
# [99]	train's auc: 0.748315	valid1's auc: 0.731238
# [100]	train's auc: 0.748643	valid1's auc: 0.731269
# [101]	train's auc: 0.748897	valid1's auc: 0.731343
# [102]	train's auc: 0.749247	valid1's auc: 0.731465
# [103]	train's auc: 0.749508	valid1's auc: 0.731516
# [104]	train's auc: 0.749721	valid1's auc: 0.731567
# [105]	train's auc: 0.749963	valid1's auc: 0.731582
# [106]	train's auc: 0.750322	valid1's auc: 0.731691
# [107]	train's auc: 0.750644	valid1's auc: 0.73178
# [108]	train's auc: 0.750939	valid1's auc: 0.731807
# [109]	train's auc: 0.751207	valid1's auc: 0.731877
# [110]	train's auc: 0.751517	valid1's auc: 0.73198
# [111]	train's auc: 0.751774	valid1's auc: 0.732027
# [112]	train's auc: 0.752075	valid1's auc: 0.732135
# [113]	train's auc: 0.752523	valid1's auc: 0.732289
# [114]	train's auc: 0.75275	valid1's auc: 0.732312
# [115]	train's auc: 0.753211	valid1's auc: 0.732439
# [116]	train's auc: 0.753473	valid1's auc: 0.732455
# [117]	train's auc: 0.753659	valid1's auc: 0.732523
# [118]	train's auc: 0.753911	valid1's auc: 0.732579
# [119]	train's auc: 0.754147	valid1's auc: 0.732613
# [120]	train's auc: 0.754489	valid1's auc: 0.732653
# [121]	train's auc: 0.754797	valid1's auc: 0.732739
# [122]	train's auc: 0.755134	valid1's auc: 0.732785
# [123]	train's auc: 0.75537	valid1's auc: 0.732848
# [124]	train's auc: 0.755669	valid1's auc: 0.73289
# [125]	train's auc: 0.755873	valid1's auc: 0.732891
# [126]	train's auc: 0.756252	valid1's auc: 0.733018
# [127]	train's auc: 0.756481	valid1's auc: 0.733037
# [128]	train's auc: 0.756831	valid1's auc: 0.733075
# [129]	train's auc: 0.757086	valid1's auc: 0.733126
# [130]	train's auc: 0.757273	valid1's auc: 0.733161
# [131]	train's auc: 0.757485	valid1's auc: 0.73317
# [132]	train's auc: 0.757727	valid1's auc: 0.733192
# [133]	train's auc: 0.758001	valid1's auc: 0.733232
# [134]	train's auc: 0.758283	valid1's auc: 0.733262
# [135]	train's auc: 0.758499	valid1's auc: 0.733309
# [136]	train's auc: 0.758775	valid1's auc: 0.733366
# [137]	train's auc: 0.758948	valid1's auc: 0.733394
# [138]	train's auc: 0.759245	valid1's auc: 0.733405
# [139]	train's auc: 0.75951	valid1's auc: 0.733545
# [140]	train's auc: 0.759783	valid1's auc: 0.733596
# [141]	train's auc: 0.759911	valid1's auc: 0.733604
# [142]	train's auc: 0.76018	valid1's auc: 0.733613
# [143]	train's auc: 0.760494	valid1's auc: 0.733671
# [144]	train's auc: 0.760771	valid1's auc: 0.73373
# [145]	train's auc: 0.761018	valid1's auc: 0.733778
# [146]	train's auc: 0.761517	valid1's auc: 0.734078
# [147]	train's auc: 0.761848	valid1's auc: 0.734132
# [148]	train's auc: 0.761991	valid1's auc: 0.734143
# [149]	train's auc: 0.762293	valid1's auc: 0.734191
# [150]	train's auc: 0.762795	valid1's auc: 0.734431
# [151]	train's auc: 0.763054	valid1's auc: 0.734453
# [152]	train's auc: 0.763309	valid1's auc: 0.734528
# [153]	train's auc: 0.763536	valid1's auc: 0.734545
# [154]	train's auc: 0.763712	valid1's auc: 0.734618
# [155]	train's auc: 0.763901	valid1's auc: 0.734643
# [156]	train's auc: 0.763997	valid1's auc: 0.734666
# [157]	train's auc: 0.764154	valid1's auc: 0.73469
# [158]	train's auc: 0.764344	valid1's auc: 0.734697
# [159]	train's auc: 0.764566	valid1's auc: 0.734703
# [160]	train's auc: 0.764777	valid1's auc: 0.734702
# [161]	train's auc: 0.764936	valid1's auc: 0.734759
# [162]	train's auc: 0.765188	valid1's auc: 0.734769
# [163]	train's auc: 0.765423	valid1's auc: 0.734763
# [164]	train's auc: 0.765585	valid1's auc: 0.734769
# [165]	train's auc: 0.765875	valid1's auc: 0.734769
# [166]	train's auc: 0.766159	valid1's auc: 0.734755
# [167]	train's auc: 0.766465	valid1's auc: 0.734799
# [168]	train's auc: 0.766873	valid1's auc: 0.734947
# [169]	train's auc: 0.767192	valid1's auc: 0.734912
# [170]	train's auc: 0.767421	valid1's auc: 0.734971
# [171]	train's auc: 0.767645	valid1's auc: 0.734995
# [172]	train's auc: 0.767758	valid1's auc: 0.735019
# [173]	train's auc: 0.768062	valid1's auc: 0.73506
# [174]	train's auc: 0.768239	valid1's auc: 0.735089
# [175]	train's auc: 0.768425	valid1's auc: 0.735098
# [176]	train's auc: 0.768609	valid1's auc: 0.735102
# [177]	train's auc: 0.768851	valid1's auc: 0.735146
# [178]	train's auc: 0.769066	valid1's auc: 0.735149
# [179]	train's auc: 0.769281	valid1's auc: 0.73515
# [180]	train's auc: 0.769393	valid1's auc: 0.73516
# [181]	train's auc: 0.769556	valid1's auc: 0.735162
# [182]	train's auc: 0.769772	valid1's auc: 0.735185
# [183]	train's auc: 0.770192	valid1's auc: 0.735264
# [184]	train's auc: 0.770372	valid1's auc: 0.735288
# [185]	train's auc: 0.770606	valid1's auc: 0.735305
# [186]	train's auc: 0.770762	valid1's auc: 0.735322
# [187]	train's auc: 0.770897	valid1's auc: 0.735358
# [188]	train's auc: 0.771055	valid1's auc: 0.735375
# [189]	train's auc: 0.771218	valid1's auc: 0.735391
# [190]	train's auc: 0.771487	valid1's auc: 0.735374
# [191]	train's auc: 0.771823	valid1's auc: 0.735447
# [192]	train's auc: 0.772044	valid1's auc: 0.73546
# [193]	train's auc: 0.772402	valid1's auc: 0.735525
# [194]	train's auc: 0.772685	valid1's auc: 0.735523
# [195]	train's auc: 0.772751	valid1's auc: 0.735527
# [196]	train's auc: 0.772968	valid1's auc: 0.735532
# [197]	train's auc: 0.773088	valid1's auc: 0.73555
# [198]	train's auc: 0.773321	valid1's auc: 0.735542
# [199]	train's auc: 0.773599	valid1's auc: 0.735589
# [200]	train's auc: 0.773724	valid1's auc: 0.735608
# [201]	train's auc: 0.7739	valid1's auc: 0.735623
# [202]	train's auc: 0.774116	valid1's auc: 0.735616
# [203]	train's auc: 0.774267	valid1's auc: 0.735647
# [204]	train's auc: 0.774458	valid1's auc: 0.735709
# [205]	train's auc: 0.774628	valid1's auc: 0.735716
# [206]	train's auc: 0.774746	valid1's auc: 0.735747
# [207]	train's auc: 0.774898	valid1's auc: 0.735728
# [208]	train's auc: 0.775105	valid1's auc: 0.735719
# [209]	train's auc: 0.775275	valid1's auc: 0.735714
# [210]	train's auc: 0.775455	valid1's auc: 0.735698
# [211]	train's auc: 0.775667	valid1's auc: 0.735696
# [212]	train's auc: 0.775842	valid1's auc: 0.735696
# [213]	train's auc: 0.776049	valid1's auc: 0.735691
# [214]	train's auc: 0.776239	valid1's auc: 0.735692
# [215]	train's auc: 0.776369	valid1's auc: 0.735708
# [216]	train's auc: 0.77654	valid1's auc: 0.735721
# [217]	train's auc: 0.776796	valid1's auc: 0.735724
# [218]	train's auc: 0.776961	valid1's auc: 0.73573
# [219]	train's auc: 0.777169	valid1's auc: 0.73573
# [220]	train's auc: 0.777362	valid1's auc: 0.73575
# [221]	train's auc: 0.777594	valid1's auc: 0.735768
# [222]	train's auc: 0.777747	valid1's auc: 0.73578
# [223]	train's auc: 0.777817	valid1's auc: 0.735762
# [224]	train's auc: 0.778074	valid1's auc: 0.7358
# [225]	train's auc: 0.778155	valid1's auc: 0.735783
# [226]	train's auc: 0.778252	valid1's auc: 0.735813
# [227]	train's auc: 0.778369	valid1's auc: 0.735835
# [228]	train's auc: 0.778589	valid1's auc: 0.73583
# [229]	train's auc: 0.778775	valid1's auc: 0.73584
# [230]	train's auc: 0.778957	valid1's auc: 0.735815
# [231]	train's auc: 0.779062	valid1's auc: 0.7358
# [232]	train's auc: 0.77934	valid1's auc: 0.735847
# [233]	train's auc: 0.779499	valid1's auc: 0.735842
# [234]	train's auc: 0.779649	valid1's auc: 0.735838
# [235]	train's auc: 0.77973	valid1's auc: 0.73583
# [236]	train's auc: 0.779896	valid1's auc: 0.73583
# [237]	train's auc: 0.780059	valid1's auc: 0.735822
# [238]	train's auc: 0.780265	valid1's auc: 0.735841
# [239]	train's auc: 0.780364	valid1's auc: 0.735852
# [240]	train's auc: 0.780489	valid1's auc: 0.735847
# [241]	train's auc: 0.780688	valid1's auc: 0.735843
# [242]	train's auc: 0.780991	valid1's auc: 0.735935
# [243]	train's auc: 0.781175	valid1's auc: 0.735948
# [244]	train's auc: 0.781368	valid1's auc: 0.735945
# [245]	train's auc: 0.781504	valid1's auc: 0.735975
# [246]	train's auc: 0.781659	valid1's auc: 0.735973
# [247]	train's auc: 0.781802	valid1's auc: 0.735958
# [248]	train's auc: 0.781989	valid1's auc: 0.735954
# [249]	train's auc: 0.782122	valid1's auc: 0.735942
# [250]	train's auc: 0.78232	valid1's auc: 0.735925
# [251]	train's auc: 0.782416	valid1's auc: 0.735909
# [252]	train's auc: 0.782546	valid1's auc: 0.735917
# [253]	train's auc: 0.782681	valid1's auc: 0.73592
# [254]	train's auc: 0.782902	valid1's auc: 0.735922
# [255]	train's auc: 0.783016	valid1's auc: 0.735948
# [256]	train's auc: 0.783099	valid1's auc: 0.735942
# [257]	train's auc: 0.783266	valid1's auc: 0.735977
# [258]	train's auc: 0.783392	valid1's auc: 0.735965
# [259]	train's auc: 0.783584	valid1's auc: 0.735985
# [260]	train's auc: 0.783781	valid1's auc: 0.735981
# [261]	train's auc: 0.78398	valid1's auc: 0.735987
# [262]	train's auc: 0.784236	valid1's auc: 0.736042
# [263]	train's auc: 0.784375	valid1's auc: 0.736034
# [264]	train's auc: 0.784557	valid1's auc: 0.736062
# [265]	train's auc: 0.784747	valid1's auc: 0.7361
# [266]	train's auc: 0.784849	valid1's auc: 0.736099
# [267]	train's auc: 0.784954	valid1's auc: 0.736087
# [268]	train's auc: 0.78508	valid1's auc: 0.736082
# [269]	train's auc: 0.785284	valid1's auc: 0.736046
# [270]	train's auc: 0.785425	valid1's auc: 0.736047
# [271]	train's auc: 0.785523	valid1's auc: 0.736055
# [272]	train's auc: 0.785634	valid1's auc: 0.736045
# [273]	train's auc: 0.785806	valid1's auc: 0.736033
# [274]	train's auc: 0.786043	valid1's auc: 0.736077
# [275]	train's auc: 0.786207	valid1's auc: 0.736074
# [276]	train's auc: 0.786271	valid1's auc: 0.736069
# [277]	train's auc: 0.786502	valid1's auc: 0.736052
# [278]	train's auc: 0.786639	valid1's auc: 0.736074
# [279]	train's auc: 0.786881	valid1's auc: 0.7361
# [280]	train's auc: 0.787098	valid1's auc: 0.736128
# [281]	train's auc: 0.78734	valid1's auc: 0.73619
# [282]	train's auc: 0.787556	valid1's auc: 0.736204
# [283]	train's auc: 0.787699	valid1's auc: 0.736188
# [284]	train's auc: 0.78788	valid1's auc: 0.736188
# [285]	train's auc: 0.788063	valid1's auc: 0.736199
# [286]	train's auc: 0.788177	valid1's auc: 0.7362
# [287]	train's auc: 0.788242	valid1's auc: 0.736206
# [288]	train's auc: 0.788387	valid1's auc: 0.736223
# [289]	train's auc: 0.788487	valid1's auc: 0.736221
# [290]	train's auc: 0.788685	valid1's auc: 0.736223
# [291]	train's auc: 0.78887	valid1's auc: 0.73621
# [292]	train's auc: 0.789027	valid1's auc: 0.736219
# [293]	train's auc: 0.789152	valid1's auc: 0.736233
# [294]	train's auc: 0.789304	valid1's auc: 0.736228
# [295]	train's auc: 0.789535	valid1's auc: 0.736245
# [296]	train's auc: 0.789617	valid1's auc: 0.736229
# [297]	train's auc: 0.789679	valid1's auc: 0.73623
# [298]	train's auc: 0.789816	valid1's auc: 0.736246
# [299]	train's auc: 0.789901	valid1's auc: 0.736251
# [300]	train's auc: 0.789985	valid1's auc: 0.736253
# [301]	train's auc: 0.790096	valid1's auc: 0.736262
# [302]	train's auc: 0.790167	valid1's auc: 0.736251
# [303]	train's auc: 0.790273	valid1's auc: 0.736249
# [304]	train's auc: 0.790474	valid1's auc: 0.736256
# [305]	train's auc: 0.790612	valid1's auc: 0.736251
# [306]	train's auc: 0.790714	valid1's auc: 0.736236
# [307]	train's auc: 0.790861	valid1's auc: 0.736268
# [308]	train's auc: 0.790976	valid1's auc: 0.736292
# [309]	train's auc: 0.791135	valid1's auc: 0.736292
# [310]	train's auc: 0.791278	valid1's auc: 0.736309
# [311]	train's auc: 0.791462	valid1's auc: 0.736309
# [312]	train's auc: 0.791554	valid1's auc: 0.736303
# [313]	train's auc: 0.791646	valid1's auc: 0.736293
# [314]	train's auc: 0.791802	valid1's auc: 0.736308
# [315]	train's auc: 0.791984	valid1's auc: 0.7363
# [316]	train's auc: 0.792152	valid1's auc: 0.736306
# [317]	train's auc: 0.792325	valid1's auc: 0.736291
# [318]	train's auc: 0.792469	valid1's auc: 0.736275
# [319]	train's auc: 0.7926	valid1's auc: 0.736278
# [320]	train's auc: 0.7927	valid1's auc: 0.736261
# [321]	train's auc: 0.792843	valid1's auc: 0.73625
# [322]	train's auc: 0.792961	valid1's auc: 0.736233
# [323]	train's auc: 0.793034	valid1's auc: 0.736243
# [324]	train's auc: 0.793183	valid1's auc: 0.736235
# [325]	train's auc: 0.793351	valid1's auc: 0.736228
# [326]	train's auc: 0.7935	valid1's auc: 0.736217
# [327]	train's auc: 0.793682	valid1's auc: 0.736207
# [328]	train's auc: 0.793751	valid1's auc: 0.736205
# [329]	train's auc: 0.793943	valid1's auc: 0.736209
# [330]	train's auc: 0.794081	valid1's auc: 0.736211
# [331]	train's auc: 0.794266	valid1's auc: 0.736199
# [332]	train's auc: 0.794432	valid1's auc: 0.736187
# [333]	train's auc: 0.794533	valid1's auc: 0.736189
# [334]	train's auc: 0.794645	valid1's auc: 0.736184
# [335]	train's auc: 0.794783	valid1's auc: 0.736186
# [336]	train's auc: 0.794921	valid1's auc: 0.736206
# [337]	train's auc: 0.79498	valid1's auc: 0.736206
# [338]	train's auc: 0.795041	valid1's auc: 0.736192
# [339]	train's auc: 0.795147	valid1's auc: 0.736197
# [340]	train's auc: 0.795276	valid1's auc: 0.736179
# [341]	train's auc: 0.795393	valid1's auc: 0.736186
# [342]	train's auc: 0.795511	valid1's auc: 0.736182
# [343]	train's auc: 0.795643	valid1's auc: 0.736177
# [344]	train's auc: 0.795739	valid1's auc: 0.736173
# [345]	train's auc: 0.795829	valid1's auc: 0.736166
# [346]	train's auc: 0.795937	valid1's auc: 0.736157
# [347]	train's auc: 0.796085	valid1's auc: 0.736148
# [348]	train's auc: 0.796282	valid1's auc: 0.736151
# [349]	train's auc: 0.796476	valid1's auc: 0.736149
# [350]	train's auc: 0.796514	valid1's auc: 0.736146
# [351]	train's auc: 0.796726	valid1's auc: 0.736164
# [352]	train's auc: 0.797048	valid1's auc: 0.736244
# [353]	train's auc: 0.797257	valid1's auc: 0.736273
# [354]	train's auc: 0.797467	valid1's auc: 0.736279
# [355]	train's auc: 0.797605	valid1's auc: 0.73629
# [356]	train's auc: 0.797778	valid1's auc: 0.736276
# [357]	train's auc: 0.797984	valid1's auc: 0.736287
# [358]	train's auc: 0.798227	valid1's auc: 0.736283
# [359]	train's auc: 0.798358	valid1's auc: 0.736272
# [360]	train's auc: 0.798436	valid1's auc: 0.736262
# Early stopping, best iteration is:
# [310]	train's auc: 0.791278	valid1's auc: 0.736309

# %%
log_file = 'v1.feature_importance.csv'
log_path = os.path.join(log_folder, log_file)

df_feature_importance = pd.DataFrame({"feature": cols, "importance": lgbm.feature_importance()})
df_feature_importance = df_feature_importance.sort_values("importance", ascending=False)
df_feature_importance.to_csv(log_path, index=False)
df_feature_importance.head(30)
# Out:
#                      feature  importance
# 419702  valueCount@interest1         719
# 419706  valueCount@interest5         641
# 419703  valueCount@interest2         523
# 419614       creativeSize_59         375
# 3                      age_2         252
# 419699         productType_9         210
# 419610       creativeSize_22         207
# 11         marriageStatus_10         168
# 419611       creativeSize_35         160
# 419697         productType_4         156
# 1057            interest2_54         153
# 419715         valueCount@ct         152
# 915             interest1_49         149
# 419612       creativeSize_42         142
# 5                      age_5         129
# 24               education_7         127
# 419630       adCategoryId_21         125
# 419640       adCategoryId_51         121
# 6                   gender_2         120
# 1214           interest5_129         119
# 1                      age_1         116
# 419207                  ct_1         114
# 4                      age_3         114
# 1061            interest2_10         113
# 419214             carrier_1         113
# 17         marriageStatus_11         112
# 31      consumptionAbility_1         111
# 419664           productId_0         106
# 1002            interest1_76         105
# 1003             interest1_6         104

# %%
with pu.profiler("cleaning memory"):
    del lgb_train
    del lgb_valid
    del X_train
    del X_valid
    gc.collect()
# Out:
# [15:56:08] Finish cleaning memory. △M: -15.22GB. △T: 3.1 seconds.

# %%
with pu.profiler("loading binary features"):
    bin_cols, X_bin = load_binary("test")

with pu.profiler("loading multi value count features"):
    multicount_cols, X_multicount = load_multicount("test")
    
assert X_bin.shape[1] == len(bin_cols)
assert X_multicount.shape[1] == len(multicount_cols)
assert X_bin.shape[0] == X_multicount.shape[0]
print("Binary Feature Shape: {}".format(X_bin.shape))
print("Multi-value Count Feature Shape: {}".format(X_multicount.shape))

with pu.profiler("joining data"):
    cols = bin_cols + multicount_cols
    X = sparse.hstack((X_bin, X_multicount))
    X = sparse.csr_matrix(X)
    del X_bin
    del X_multicount
    gc.collect()
    
print("Joined Data Shape: {}".format(X.shape))
print("Feature Names Count: {}".format(len(cols)))
print("Memory usage at this moment :{}".format(pu.get_memory_str()))
# Out:
# [15:56:48] Finish loading binary features. △M: +699.77MB. △T: 2.3 seconds.
# [15:56:48] Finish loading multi value count features. △M: +8.0KB. △T: 0.3 seconds.
# Binary Feature Shape: (2265989, 419701)
# Multi-value Count Feature Shape: (2265989, 16)
# [15:57:04] Finish joining data. △M: +836.12MB. △T: 16.0 seconds.
# Joined Data Shape: (2265989, 419717)
# Feature Names Count: 419717
# Memory usage at this moment :4.44GB

# %%
df_test = du.load_raw_data("test")
X = X.astype(np.float32)

with pu.profiler("making prediction on testing set"):
    proba_test = lgbm.predict(X)
    assert len(proba_test.shape) == 1
    assert proba_test.shape[0] == df_test.shape[0]
# Out:
# [15:59:15] Finish making prediction on testing set. △M: +1.23MB. △T: 1.1 minutes.

# %%
subm_folder = '../subm/lgbm/0505_v1'
subm_file = 'submission.csv'
subm_path = os.path.join(subm_folder, subm_file)
os.makedirs(subm_folder, exist_ok=True)

subm = df_test.copy()
subm["score"] = proba_test
subm.to_csv(subm_path, index=False)
