# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import lightgbm as lgb
import scipy.sparse as sparse
import pandas as pd
import numpy as np
import tqdm
import gc
import os
import sys
sys.path.append('../code/utils')
import data_utils as du
import perf_utils as pu

# %%
df_train = du.load_raw_data("train")
df_test = du.load_raw_data("test")
df_ad = du.load_raw_data("ad")

# %%
ad_num_feat_names = ['creativeSize']
ad_cat_feat_names = ['aid', 'advertiserId', 'campaignId', 'creativeId', 'adCategoryId', 'productId', 'productType']
ad_feat_names = ad_num_feat_names + ad_cat_feat_names

# %%
user_one_feat_names = ['age', 'gender', 'education', 'consumptionAbility', 'LBS',
                  'carrier', 'house']  # one user has only one value
user_multi_feat_names = ['marriageStatus', 'interest1', 'interest2', 'interest3',
                   'interest4', 'interest5', 'kw1', 'kw2', 'kw3', 'topic1',
                   'topic2', 'topic3', 'appIdInstall', 'appIdAction', 'ct', 'os']  # one user can have more than one value
user_feat_names = user_one_feat_names + user_multi_feat_names

# %%
with pu.profiler("loading and joining user and ad data"):
    X, feat_names = du.quick_join(ad_user=df_train, 
                                  user_feat_names=user_feat_names, 
                                  ad_feat_names=ad_feat_names)
del feat_names
gc.collect()
print("Memory usage at this moment :{}".format(pu.get_memory_str()))
# Out:
# loading user matrices: 100%|██████████| 23/23 [12:04<00:00, 31.51s/it]
# loading ad matrices: 100%|██████████| 8/8 [01:53<00:00, 14.20s/it]
# [07:05:12] Finish loading and joining user and ad data. △M: +5.89GB. △T: 14.0 minutes.
# Memory usage at this moment :6.19GB

# %%
X = sparse.csr_matrix(X)
print("Combined Matrix Shape: {}".format(X.shape))
gc.collect()
# Out:
# Combined Matrix Shape: (8798814, 419874)
# 0

# %%
y = df_train['label'].values
y = (y + 1) / 2
assert X.shape[0] == y.shape[0]

# %%
n_splits = 3  # use 3 instead of 5 to save time
skf = StratifiedKFold(n_splits=n_splits)
split_indices = [(train_index, valid_index) for train_index, valid_index in skf.split(df_train, y)]

# %%
train_index, valid_index = split_indices[0]

X_train, y_train = X[train_index, :], y[train_index]
X_valid, y_valid = X[valid_index, :], y[valid_index]

lgb_train = lgb.Dataset(X_train.astype(np.float32), y_train)
lgb_valid = lgb.Dataset(X_valid.astype(np.float32), y_valid)

# %%
params = {
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': 'auc',
    'max_depth': 15,
    'num_leaves': 120,
    'learning_rate': 0.15,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'verbose': 0
}
num_rounds = 500

lgbm = lgb.train(params,
                 lgb_train,
                 num_boost_round=num_rounds,
                 valid_sets=[lgb_train, lgb_valid], 
                 valid_names=['train', 'valid1'],
                 early_stopping_rounds=50)
# Out:
# [1]	train's auc: 0.667081	valid1's auc: 0.667503
# Training until validation scores don't improve for 50 rounds.
# [2]	train's auc: 0.673297	valid1's auc: 0.673049
# [3]	train's auc: 0.674735	valid1's auc: 0.674414
# [4]	train's auc: 0.675928	valid1's auc: 0.675818
# [5]	train's auc: 0.677962	valid1's auc: 0.677781
# [6]	train's auc: 0.679204	valid1's auc: 0.679102
# [7]	train's auc: 0.68102	valid1's auc: 0.680923
# [8]	train's auc: 0.684798	valid1's auc: 0.684689
# [9]	train's auc: 0.68489	valid1's auc: 0.684822
# [10]	train's auc: 0.685693	valid1's auc: 0.685343
# [11]	train's auc: 0.687817	valid1's auc: 0.687525
# [12]	train's auc: 0.688626	valid1's auc: 0.688311
# [13]	train's auc: 0.688999	valid1's auc: 0.688591
# [14]	train's auc: 0.690043	valid1's auc: 0.68957
# [15]	train's auc: 0.690701	valid1's auc: 0.690284
# [16]	train's auc: 0.691926	valid1's auc: 0.691485
# [17]	train's auc: 0.69298	valid1's auc: 0.692425
# [18]	train's auc: 0.694334	valid1's auc: 0.693883
# [19]	train's auc: 0.696208	valid1's auc: 0.69572
# [20]	train's auc: 0.697209	valid1's auc: 0.696621
# [21]	train's auc: 0.698381	valid1's auc: 0.69773
# [22]	train's auc: 0.699546	valid1's auc: 0.698796
# [23]	train's auc: 0.701071	valid1's auc: 0.700172
# [24]	train's auc: 0.702988	valid1's auc: 0.702002
# [25]	train's auc: 0.704753	valid1's auc: 0.70363
# [26]	train's auc: 0.706225	valid1's auc: 0.70495
# [27]	train's auc: 0.707904	valid1's auc: 0.70654
# [28]	train's auc: 0.708983	valid1's auc: 0.707547
# [29]	train's auc: 0.710501	valid1's auc: 0.708858
# [30]	train's auc: 0.71209	valid1's auc: 0.710242
# [31]	train's auc: 0.713044	valid1's auc: 0.711069
# [32]	train's auc: 0.714065	valid1's auc: 0.711925
# [33]	train's auc: 0.714731	valid1's auc: 0.712388
# [34]	train's auc: 0.715736	valid1's auc: 0.713216
# [35]	train's auc: 0.716519	valid1's auc: 0.713916
# [36]	train's auc: 0.717447	valid1's auc: 0.714714
# [37]	train's auc: 0.718366	valid1's auc: 0.715323
# [38]	train's auc: 0.719162	valid1's auc: 0.715974
# [39]	train's auc: 0.720078	valid1's auc: 0.71665
# [40]	train's auc: 0.720579	valid1's auc: 0.71706
# [41]	train's auc: 0.72136	valid1's auc: 0.717636
# [42]	train's auc: 0.722343	valid1's auc: 0.718406
# [43]	train's auc: 0.723176	valid1's auc: 0.71898
# [44]	train's auc: 0.723779	valid1's auc: 0.719348
# [45]	train's auc: 0.724492	valid1's auc: 0.719836
# [46]	train's auc: 0.724999	valid1's auc: 0.720051
# [47]	train's auc: 0.72575	valid1's auc: 0.720587
# [48]	train's auc: 0.726573	valid1's auc: 0.721212
# [49]	train's auc: 0.727273	valid1's auc: 0.721658
# [50]	train's auc: 0.727759	valid1's auc: 0.721917
# [51]	train's auc: 0.728383	valid1's auc: 0.722159
# [52]	train's auc: 0.729149	valid1's auc: 0.722755
# [53]	train's auc: 0.729539	valid1's auc: 0.723012
# [54]	train's auc: 0.729889	valid1's auc: 0.723238
# [55]	train's auc: 0.730479	valid1's auc: 0.723611
# [56]	train's auc: 0.730918	valid1's auc: 0.723779
# [57]	train's auc: 0.731382	valid1's auc: 0.723995
# [58]	train's auc: 0.731747	valid1's auc: 0.724265
# [59]	train's auc: 0.732343	valid1's auc: 0.724535
# [60]	train's auc: 0.732799	valid1's auc: 0.724795
# [61]	train's auc: 0.733207	valid1's auc: 0.724887
# [62]	train's auc: 0.733665	valid1's auc: 0.725164
# [63]	train's auc: 0.734074	valid1's auc: 0.725342
# [64]	train's auc: 0.734515	valid1's auc: 0.725588
# [65]	train's auc: 0.734789	valid1's auc: 0.725708
# [66]	train's auc: 0.735285	valid1's auc: 0.725826
# [67]	train's auc: 0.735616	valid1's auc: 0.725966
# [68]	train's auc: 0.736083	valid1's auc: 0.726111
# [69]	train's auc: 0.736534	valid1's auc: 0.726298
# [70]	train's auc: 0.737131	valid1's auc: 0.726711
# [71]	train's auc: 0.737446	valid1's auc: 0.7269
# [72]	train's auc: 0.737805	valid1's auc: 0.726993
# [73]	train's auc: 0.738104	valid1's auc: 0.727057
# [74]	train's auc: 0.738694	valid1's auc: 0.727331
# [75]	train's auc: 0.73907	valid1's auc: 0.727471
# [76]	train's auc: 0.739308	valid1's auc: 0.727577
# [77]	train's auc: 0.739647	valid1's auc: 0.727705
# [78]	train's auc: 0.739989	valid1's auc: 0.727818
# [79]	train's auc: 0.740239	valid1's auc: 0.727907
# [80]	train's auc: 0.740684	valid1's auc: 0.72807
# [81]	train's auc: 0.74085	valid1's auc: 0.728148
# [82]	train's auc: 0.741191	valid1's auc: 0.728239
# [83]	train's auc: 0.741546	valid1's auc: 0.72836
# [84]	train's auc: 0.74197	valid1's auc: 0.728443
# [85]	train's auc: 0.742229	valid1's auc: 0.728531
# [86]	train's auc: 0.742456	valid1's auc: 0.728615
# [87]	train's auc: 0.742676	valid1's auc: 0.72867
# [88]	train's auc: 0.743002	valid1's auc: 0.728727
# [89]	train's auc: 0.743556	valid1's auc: 0.72903
# [90]	train's auc: 0.743859	valid1's auc: 0.72913
# [91]	train's auc: 0.744211	valid1's auc: 0.729226
# [92]	train's auc: 0.744494	valid1's auc: 0.729268
# [93]	train's auc: 0.744739	valid1's auc: 0.729322
# [94]	train's auc: 0.744973	valid1's auc: 0.729413
# [95]	train's auc: 0.745278	valid1's auc: 0.729457
# [96]	train's auc: 0.74571	valid1's auc: 0.729541
# [97]	train's auc: 0.746167	valid1's auc: 0.729733
# [98]	train's auc: 0.746463	valid1's auc: 0.72983
# [99]	train's auc: 0.746789	valid1's auc: 0.729874
# [100]	train's auc: 0.747093	valid1's auc: 0.729941
# [101]	train's auc: 0.747551	valid1's auc: 0.73013
# [102]	train's auc: 0.747868	valid1's auc: 0.730212
# [103]	train's auc: 0.748083	valid1's auc: 0.730259
# [104]	train's auc: 0.748317	valid1's auc: 0.730394
# [105]	train's auc: 0.748689	valid1's auc: 0.73053
# [106]	train's auc: 0.748935	valid1's auc: 0.730607
# [107]	train's auc: 0.749325	valid1's auc: 0.730625
# [108]	train's auc: 0.749623	valid1's auc: 0.730701
# [109]	train's auc: 0.749967	valid1's auc: 0.730782
# [110]	train's auc: 0.750267	valid1's auc: 0.730855
# [111]	train's auc: 0.750568	valid1's auc: 0.730991
# [112]	train's auc: 0.750873	valid1's auc: 0.730995
# [113]	train's auc: 0.751197	valid1's auc: 0.731128
# [114]	train's auc: 0.751454	valid1's auc: 0.731181
# [115]	train's auc: 0.751687	valid1's auc: 0.731288
# [116]	train's auc: 0.751892	valid1's auc: 0.731359
# [117]	train's auc: 0.752271	valid1's auc: 0.731487
# [118]	train's auc: 0.752478	valid1's auc: 0.731518
# [119]	train's auc: 0.752725	valid1's auc: 0.731562
# [120]	train's auc: 0.752938	valid1's auc: 0.731624
# [121]	train's auc: 0.753372	valid1's auc: 0.731767
# [122]	train's auc: 0.753779	valid1's auc: 0.731824
# [123]	train's auc: 0.753976	valid1's auc: 0.731836
# [124]	train's auc: 0.754537	valid1's auc: 0.732143
# [125]	train's auc: 0.75491	valid1's auc: 0.732169
# [126]	train's auc: 0.755084	valid1's auc: 0.7322
# [127]	train's auc: 0.755298	valid1's auc: 0.732238
# [128]	train's auc: 0.755547	valid1's auc: 0.732305
# [129]	train's auc: 0.755834	valid1's auc: 0.732306
# [130]	train's auc: 0.756009	valid1's auc: 0.732344
# [131]	train's auc: 0.756212	valid1's auc: 0.732386
# [132]	train's auc: 0.756652	valid1's auc: 0.73258
# [133]	train's auc: 0.756883	valid1's auc: 0.732614
# [134]	train's auc: 0.757083	valid1's auc: 0.732613
# [135]	train's auc: 0.757435	valid1's auc: 0.732689
# [136]	train's auc: 0.757649	valid1's auc: 0.732703
# [137]	train's auc: 0.758011	valid1's auc: 0.732725
# [138]	train's auc: 0.758304	valid1's auc: 0.732765
# [139]	train's auc: 0.758556	valid1's auc: 0.732788
# [140]	train's auc: 0.758799	valid1's auc: 0.732805
# [141]	train's auc: 0.75909	valid1's auc: 0.732826
# [142]	train's auc: 0.759267	valid1's auc: 0.732863
# [143]	train's auc: 0.759434	valid1's auc: 0.732909
# [144]	train's auc: 0.759664	valid1's auc: 0.7329
# [145]	train's auc: 0.759856	valid1's auc: 0.732947
# [146]	train's auc: 0.76007	valid1's auc: 0.732917
# [147]	train's auc: 0.760264	valid1's auc: 0.732922
# [148]	train's auc: 0.76044	valid1's auc: 0.732965
# [149]	train's auc: 0.760975	valid1's auc: 0.733271
# [150]	train's auc: 0.76129	valid1's auc: 0.733352
# [151]	train's auc: 0.761603	valid1's auc: 0.733404
# [152]	train's auc: 0.761854	valid1's auc: 0.73341
# [153]	train's auc: 0.761997	valid1's auc: 0.733498
# [154]	train's auc: 0.762229	valid1's auc: 0.733512
# [155]	train's auc: 0.76242	valid1's auc: 0.73352
# [156]	train's auc: 0.762546	valid1's auc: 0.733525
# [157]	train's auc: 0.76272	valid1's auc: 0.733547
# [158]	train's auc: 0.763317	valid1's auc: 0.734043
# [159]	train's auc: 0.7635	valid1's auc: 0.734046
# [160]	train's auc: 0.763614	valid1's auc: 0.734033
# [161]	train's auc: 0.763876	valid1's auc: 0.734047
# [162]	train's auc: 0.764058	valid1's auc: 0.734065
# [163]	train's auc: 0.764349	valid1's auc: 0.734148
# [164]	train's auc: 0.764497	valid1's auc: 0.734167
# [165]	train's auc: 0.764654	valid1's auc: 0.734173
# [166]	train's auc: 0.764832	valid1's auc: 0.734187
# [167]	train's auc: 0.765003	valid1's auc: 0.734175
# [168]	train's auc: 0.76522	valid1's auc: 0.734185
# [169]	train's auc: 0.765449	valid1's auc: 0.734207
# [170]	train's auc: 0.7656	valid1's auc: 0.734246
# [171]	train's auc: 0.765785	valid1's auc: 0.734273
# [172]	train's auc: 0.765951	valid1's auc: 0.734285
# [173]	train's auc: 0.766137	valid1's auc: 0.734291
# [174]	train's auc: 0.766214	valid1's auc: 0.734295
# [175]	train's auc: 0.766474	valid1's auc: 0.734311
# [176]	train's auc: 0.766751	valid1's auc: 0.734342
# [177]	train's auc: 0.767003	valid1's auc: 0.734343
# [178]	train's auc: 0.767192	valid1's auc: 0.734344
# [179]	train's auc: 0.76741	valid1's auc: 0.734346
# [180]	train's auc: 0.76765	valid1's auc: 0.73435
# [181]	train's auc: 0.767889	valid1's auc: 0.734379
# [182]	train's auc: 0.768057	valid1's auc: 0.734405
# [183]	train's auc: 0.768311	valid1's auc: 0.734443
# [184]	train's auc: 0.768675	valid1's auc: 0.734637
# [185]	train's auc: 0.768998	valid1's auc: 0.734639
# [186]	train's auc: 0.769178	valid1's auc: 0.734672
# [187]	train's auc: 0.76951	valid1's auc: 0.734714
# [188]	train's auc: 0.769719	valid1's auc: 0.734788
# [189]	train's auc: 0.76993	valid1's auc: 0.734789
# [190]	train's auc: 0.770067	valid1's auc: 0.734785
# [191]	train's auc: 0.770224	valid1's auc: 0.734781
# [192]	train's auc: 0.77043	valid1's auc: 0.734797
# [193]	train's auc: 0.770669	valid1's auc: 0.734909
# [194]	train's auc: 0.770801	valid1's auc: 0.734921
# [195]	train's auc: 0.771008	valid1's auc: 0.734923
# [196]	train's auc: 0.771199	valid1's auc: 0.734917
# [197]	train's auc: 0.771326	valid1's auc: 0.734931
# [198]	train's auc: 0.771426	valid1's auc: 0.734935
# [199]	train's auc: 0.771597	valid1's auc: 0.734952
# [200]	train's auc: 0.771748	valid1's auc: 0.734952
# [201]	train's auc: 0.771981	valid1's auc: 0.734956
# [202]	train's auc: 0.772174	valid1's auc: 0.734946
# [203]	train's auc: 0.772394	valid1's auc: 0.734923
# [204]	train's auc: 0.772559	valid1's auc: 0.734989
# [205]	train's auc: 0.772821	valid1's auc: 0.735027
# [206]	train's auc: 0.772938	valid1's auc: 0.735047
# [207]	train's auc: 0.77313	valid1's auc: 0.735055
# [208]	train's auc: 0.773316	valid1's auc: 0.735035
# [209]	train's auc: 0.773612	valid1's auc: 0.73507
# [210]	train's auc: 0.773876	valid1's auc: 0.735104
# [211]	train's auc: 0.774074	valid1's auc: 0.735122
# [212]	train's auc: 0.774249	valid1's auc: 0.735131
# [213]	train's auc: 0.774442	valid1's auc: 0.735137
# [214]	train's auc: 0.774571	valid1's auc: 0.735167
# [215]	train's auc: 0.774754	valid1's auc: 0.735143
# [216]	train's auc: 0.774916	valid1's auc: 0.735119
# [217]	train's auc: 0.775214	valid1's auc: 0.735196
# [218]	train's auc: 0.775428	valid1's auc: 0.735204
# [219]	train's auc: 0.77578	valid1's auc: 0.735465
# [220]	train's auc: 0.77595	valid1's auc: 0.735513
# [221]	train's auc: 0.776065	valid1's auc: 0.735515
# [222]	train's auc: 0.776383	valid1's auc: 0.735545
# [223]	train's auc: 0.776599	valid1's auc: 0.735561
# [224]	train's auc: 0.776738	valid1's auc: 0.735554
# [225]	train's auc: 0.776922	valid1's auc: 0.735542
# [226]	train's auc: 0.77711	valid1's auc: 0.735528
# [227]	train's auc: 0.777436	valid1's auc: 0.735688
# [228]	train's auc: 0.777794	valid1's auc: 0.735735
# [229]	train's auc: 0.777926	valid1's auc: 0.735721
# [230]	train's auc: 0.778107	valid1's auc: 0.735703
# [231]	train's auc: 0.778204	valid1's auc: 0.735728
# [232]	train's auc: 0.778423	valid1's auc: 0.735788
# [233]	train's auc: 0.778598	valid1's auc: 0.735789
# [234]	train's auc: 0.77876	valid1's auc: 0.73579
# [235]	train's auc: 0.778935	valid1's auc: 0.735806
# [236]	train's auc: 0.779118	valid1's auc: 0.735814
# [237]	train's auc: 0.779489	valid1's auc: 0.73593
# [238]	train's auc: 0.779607	valid1's auc: 0.735942
# [239]	train's auc: 0.779773	valid1's auc: 0.735946
# [240]	train's auc: 0.779978	valid1's auc: 0.735969
# [241]	train's auc: 0.780086	valid1's auc: 0.735965
# [242]	train's auc: 0.780266	valid1's auc: 0.735958
# [243]	train's auc: 0.780354	valid1's auc: 0.735945
# [244]	train's auc: 0.780525	valid1's auc: 0.735935
# [245]	train's auc: 0.780724	valid1's auc: 0.73593
# [246]	train's auc: 0.781021	valid1's auc: 0.736022
# [247]	train's auc: 0.78116	valid1's auc: 0.736004
# [248]	train's auc: 0.781276	valid1's auc: 0.735993
# [249]	train's auc: 0.781388	valid1's auc: 0.735973
# [250]	train's auc: 0.781562	valid1's auc: 0.735954
# [251]	train's auc: 0.781661	valid1's auc: 0.735973
# [252]	train's auc: 0.781789	valid1's auc: 0.735971
# [253]	train's auc: 0.781976	valid1's auc: 0.735978
# [254]	train's auc: 0.782136	valid1's auc: 0.735997
# [255]	train's auc: 0.78223	valid1's auc: 0.736
# [256]	train's auc: 0.782467	valid1's auc: 0.735993
# [257]	train's auc: 0.782583	valid1's auc: 0.735991
# [258]	train's auc: 0.78275	valid1's auc: 0.73598
# [259]	train's auc: 0.782828	valid1's auc: 0.735988
# [260]	train's auc: 0.782953	valid1's auc: 0.735972
# [261]	train's auc: 0.783108	valid1's auc: 0.735958
# [262]	train's auc: 0.783282	valid1's auc: 0.735957
# [263]	train's auc: 0.783403	valid1's auc: 0.735934
# [264]	train's auc: 0.783522	valid1's auc: 0.735931
# [265]	train's auc: 0.783659	valid1's auc: 0.735944
# [266]	train's auc: 0.783844	valid1's auc: 0.735933
# [267]	train's auc: 0.78399	valid1's auc: 0.735923
# [268]	train's auc: 0.784155	valid1's auc: 0.735917
# [269]	train's auc: 0.784304	valid1's auc: 0.735926
# [270]	train's auc: 0.784472	valid1's auc: 0.735911
# [271]	train's auc: 0.78464	valid1's auc: 0.73594
# [272]	train's auc: 0.784816	valid1's auc: 0.735963
# [273]	train's auc: 0.785035	valid1's auc: 0.735953
# [274]	train's auc: 0.785217	valid1's auc: 0.735953
# [275]	train's auc: 0.785306	valid1's auc: 0.735951
# [276]	train's auc: 0.785475	valid1's auc: 0.735945
# [277]	train's auc: 0.785619	valid1's auc: 0.73592
# [278]	train's auc: 0.785753	valid1's auc: 0.735931
# [279]	train's auc: 0.785938	valid1's auc: 0.735938
# [280]	train's auc: 0.78608	valid1's auc: 0.735959
# [281]	train's auc: 0.786145	valid1's auc: 0.73596
# [282]	train's auc: 0.786228	valid1's auc: 0.73595
# [283]	train's auc: 0.786424	valid1's auc: 0.735963
# [284]	train's auc: 0.786587	valid1's auc: 0.735969
# [285]	train's auc: 0.786918	valid1's auc: 0.736061
# [286]	train's auc: 0.787198	valid1's auc: 0.7361
# [287]	train's auc: 0.787324	valid1's auc: 0.736105
# [288]	train's auc: 0.787505	valid1's auc: 0.736112
# [289]	train's auc: 0.787669	valid1's auc: 0.736097
# [290]	train's auc: 0.787782	valid1's auc: 0.736081
# [291]	train's auc: 0.787945	valid1's auc: 0.736092
# [292]	train's auc: 0.788047	valid1's auc: 0.736095
# [293]	train's auc: 0.7882	valid1's auc: 0.736118
# [294]	train's auc: 0.788279	valid1's auc: 0.736117
# [295]	train's auc: 0.788339	valid1's auc: 0.736126
# [296]	train's auc: 0.788526	valid1's auc: 0.736084
# [297]	train's auc: 0.78863	valid1's auc: 0.736077
# [298]	train's auc: 0.788742	valid1's auc: 0.73607
# [299]	train's auc: 0.788933	valid1's auc: 0.736167
# [300]	train's auc: 0.789141	valid1's auc: 0.736192
# [301]	train's auc: 0.789272	valid1's auc: 0.736205
# [302]	train's auc: 0.789404	valid1's auc: 0.736196
# [303]	train's auc: 0.789493	valid1's auc: 0.736205
# [304]	train's auc: 0.789657	valid1's auc: 0.736181
# [305]	train's auc: 0.78981	valid1's auc: 0.736186
# [306]	train's auc: 0.789962	valid1's auc: 0.736186
# [307]	train's auc: 0.790068	valid1's auc: 0.73618
# [308]	train's auc: 0.790193	valid1's auc: 0.736189
# [309]	train's auc: 0.790331	valid1's auc: 0.736177
# [310]	train's auc: 0.790393	valid1's auc: 0.736178
# [311]	train's auc: 0.790539	valid1's auc: 0.736187
# [312]	train's auc: 0.790608	valid1's auc: 0.736184
# [313]	train's auc: 0.790746	valid1's auc: 0.736183
# [314]	train's auc: 0.790808	valid1's auc: 0.736182
# [315]	train's auc: 0.791049	valid1's auc: 0.73622
# [316]	train's auc: 0.791222	valid1's auc: 0.736256
# [317]	train's auc: 0.791406	valid1's auc: 0.736243
# [318]	train's auc: 0.791558	valid1's auc: 0.736264
# [319]	train's auc: 0.791694	valid1's auc: 0.736279
# [320]	train's auc: 0.791827	valid1's auc: 0.736289
# [321]	train's auc: 0.791941	valid1's auc: 0.73627
# [322]	train's auc: 0.79203	valid1's auc: 0.736262
# [323]	train's auc: 0.792088	valid1's auc: 0.736257
# [324]	train's auc: 0.792208	valid1's auc: 0.736234
# [325]	train's auc: 0.792316	valid1's auc: 0.736243
# [326]	train's auc: 0.792435	valid1's auc: 0.736219
# [327]	train's auc: 0.792518	valid1's auc: 0.736226
# [328]	train's auc: 0.792651	valid1's auc: 0.736224
# [329]	train's auc: 0.792776	valid1's auc: 0.736222
# [330]	train's auc: 0.792979	valid1's auc: 0.736233
# [331]	train's auc: 0.793104	valid1's auc: 0.736228
# [332]	train's auc: 0.79322	valid1's auc: 0.736241
# [333]	train's auc: 0.793333	valid1's auc: 0.736225
# [334]	train's auc: 0.79343	valid1's auc: 0.736207
# [335]	train's auc: 0.793466	valid1's auc: 0.736204
# [336]	train's auc: 0.793618	valid1's auc: 0.7362
# [337]	train's auc: 0.79373	valid1's auc: 0.736204
# [338]	train's auc: 0.79381	valid1's auc: 0.736184
# [339]	train's auc: 0.793934	valid1's auc: 0.73619
# [340]	train's auc: 0.794053	valid1's auc: 0.736177
# [341]	train's auc: 0.794203	valid1's auc: 0.736139
# [342]	train's auc: 0.794316	valid1's auc: 0.736135
# [343]	train's auc: 0.79444	valid1's auc: 0.736151
# [344]	train's auc: 0.794551	valid1's auc: 0.736134
# [345]	train's auc: 0.794638	valid1's auc: 0.736139
# [346]	train's auc: 0.794793	valid1's auc: 0.736115
# [347]	train's auc: 0.794935	valid1's auc: 0.736118
# [348]	train's auc: 0.795072	valid1's auc: 0.736113
# [349]	train's auc: 0.795252	valid1's auc: 0.736094
# [350]	train's auc: 0.795357	valid1's auc: 0.736083
# [351]	train's auc: 0.795417	valid1's auc: 0.736085
# [352]	train's auc: 0.795645	valid1's auc: 0.736078
# [353]	train's auc: 0.79586	valid1's auc: 0.736079
# [354]	train's auc: 0.795939	valid1's auc: 0.736081
# [355]	train's auc: 0.796188	valid1's auc: 0.736066
# [356]	train's auc: 0.796519	valid1's auc: 0.736162
# [357]	train's auc: 0.796627	valid1's auc: 0.736144
# [358]	train's auc: 0.796765	valid1's auc: 0.736138
# [359]	train's auc: 0.796837	valid1's auc: 0.73613
# [360]	train's auc: 0.797011	valid1's auc: 0.736171
# [361]	train's auc: 0.797141	valid1's auc: 0.73616
# [362]	train's auc: 0.797321	valid1's auc: 0.736139
# [363]	train's auc: 0.79747	valid1's auc: 0.736122
# [364]	train's auc: 0.797557	valid1's auc: 0.736117
# [365]	train's auc: 0.797639	valid1's auc: 0.736111
# [366]	train's auc: 0.797792	valid1's auc: 0.736151
# [367]	train's auc: 0.79792	valid1's auc: 0.736139
# [368]	train's auc: 0.798036	valid1's auc: 0.736149
# [369]	train's auc: 0.798203	valid1's auc: 0.73615
# [370]	train's auc: 0.7983	valid1's auc: 0.736128
# Early stopping, best iteration is:
# [320]	train's auc: 0.791827	valid1's auc: 0.736289

# %%
leaves_valid = lgbm.predict(X_valid.astype(np.float32), pred_leaf=True)

# %%
with pu.profiler("transforming dense leaves to sparse matrix"):
    n_leaves = 120
    n_records, n_rounds = leaves_valid.shape
    indices = np.arange(0, n_rounds * n_leaves, n_leaves) + leaves_valid
    
    del leaves_valid
    gc.collect()
    
    data = np.ones(n_records * n_rounds).astype(np.int8)
    indices = indices.flatten()
    indptr = np.arange(0, (n_records + 1) * n_rounds, n_rounds)
    leaves_sparse_matrix = sparse.csr_matrix((data, indices, indptr), dtype=np.int8)
    del data
    del indices
    del indptr
    gc.collect()
# Out:
# [10:22:30] Finish transforming dense leaves to sparse matrix. △M: +895.07MB. △T: 36.5 seconds.

# %%
n_splits2 = 3  # use 3 instead of 5 to save time
skf2 = StratifiedKFold(n_splits=n_splits2)
split_indices2 = [(train_index2, valid_index2) for train_index2, valid_index2 in skf2.split(leaves_sparse_matrix, y_valid)]
aucs = np.zeros(n_splits2)

for i, (train_index2, valid_index2) in enumerate(split_indices2):
    X_vtr, y_vtr = leaves_sparse_matrix[train_index2, :], y_valid[train_index2]
    X_vv, y_vv = leaves_sparse_matrix[valid_index2, :], y_valid[valid_index2]
    # X_vtr, y_vtr = leaves_sparse_matrix[valid_index2, :], y_valid[valid_index2]  # for debug use
    # X_vv, y_vv = leaves_sparse_matrix[train_index2, :], y_valid[train_index2]
    
    print("[{}] start training fold {}/{}".format(pu.get_time_str(), i + 1, n_splits2))
    lr = LogisticRegression(solver='sag')
    lr.fit(X_vtr, y_vtr)
    proba_vv = lr.predict_proba(X_vv)
    
    aucs[i] = metrics.roc_auc_score(y_vv, proba_vv[:, 1])
    print("[{}] AUC: {}".format(pu.get_time_str(), aucs[i]))
    
print("AUC: {:.6f}(+/-{:.6f})".format(aucs.mean(), aucs.std()))
# Out:
# [10:23:06] start training fold 1/3
# /usr/local/lib/python3.5/dist-packages/sklearn/linear_model/sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# [11:14:12] AUC: 0.7315755465005951
# [11:14:44] start training fold 2/3
# [11:27:53] AUC: 0.7335304257180298
# [11:28:16] start training fold 3/3
# [11:40:01] AUC: 0.7339445326761025
# AUC: 0.733017(+/-0.001033)
