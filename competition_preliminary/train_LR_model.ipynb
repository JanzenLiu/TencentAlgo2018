# %%
import pandas as pd
import numpy as np
import pickle
import time
import os
from scipy.sparse import hstack
from sklearn import metrics
from sklearn.linear_model import LogisticRegression

# %%
data_dir = '../data/raw/preliminary_contest_data/'
ad_cnt_dir = '../data/nlp_count/preliminary_contest_data/byAdFeatureName/'
user_cnt_dir = '../data/nlp_count/preliminary_contest_data/byUserFeatureName/'
user_tfidf_dir = '../data/nlp_tfidf/preliminary_contest_data/byUserFeatureName/'

# %%
def load(filename, **kw):
    return pd.read_csv(os.path.join(data_dir, filename), **kw)

# %%
def load_pickle(filepath):
    obj = None
    with open(filepath, "rb") as f:
        obj = pickle.load(f)
    return obj

# %%
def load_ad_cnt(feat_name):
    filename = "adFeature.[featureName='{}'].pkl".format(feat_name)
    filepath = os.path.join(ad_cnt_dir, filename)
    index, matrix = load_pickle(filepath)
    
    filename = "aid.pkl".format(feat_name)
    filepath = os.path.join(ad_cnt_dir, filename)
    uid = load_pickle(filepath)
    
    return uid, (index, matrix)

# %%
def load_user_cnt(feat_name):
    filename = "userFeature.[featureName='{}'].pkl".format(feat_name)
    filepath = os.path.join(user_cnt_dir, filename)
    index, matrix = load_pickle(filepath)
    
    filename = "uid.pkl".format(feat_name)
    filepath = os.path.join(user_cnt_dir, filename)
    uid = load_pickle(filepath)
    
    return uid, (index, matrix)

# %%
def load_user_tfidf(feat_name):
    filename = "userFeature.[featureName='{}'].pkl".format(feat_name)
    filepath = os.path.join(user_tfidf_dir, filename)
    index, idf, matrix = load_pickle(filepath)
    
    filename = "uid.pkl".format(feat_name)
    filepath = os.path.join(user_tfidf_dir, filename)
    uid = load_pickle(filepath)
    
    return uid, (index, idf, matrix)

# %%
def get_time_str():
    return time.strftime("%H:%M:%S", time.gmtime())

# %%
df_train = load("train.csv")

# %%
uids, (ufeat_index, uvec) = load_user_cnt("interest1")
aids, (afeat_index, avec) = load_ad_cnt('aid')
uid_to_index = dict(zip(uids, list(range(len(uids)))))  # mapping from uids to distinct indices

# %%
print("====================")
print("LR on Count Features")
print("====================")
for aid in aids:
    df_selected = df_train[df_train['aid']==aid]
    u_index = df_selected['uid'].map(uid_to_index).values
    
    valid_ratio = 0.3
    train_size = int(df_selected.shape[0] * (1 - valid_ratio))
    
    X = uvec[u_index,:]
    y = (df_selected['label'].values + 1) / 2
    X_train, y_train = X[:train_size], y[:train_size]
    X_valid, y_valid = X[train_size:], y[train_size:]

    lr = LogisticRegression()
    
    print("Training LR on [aid='{}']...".format(aid))
    lr.fit(X_train, y_train)
    proba_valid = lr.predict_proba(X_valid)
    logloss = metrics.log_loss(y_valid, proba_valid)
    auc = metrics.roc_auc_score(y_valid, proba_valid[:,1])
    print("[{}] AUC: {:.6f} logloss: {:.6f}".format(get_time_str(), auc, logloss))
    print()
# Out:
# ====================
# LR on Count Features
# ====================
# Training LR on [aid='177']...
# [04:58:49] AUC: 0.544920 logloss: 0.196567
#
# Training LR on [aid='2050']...
# [04:59:00] AUC: 0.634029 logloss: 0.179728
#
# Training LR on [aid='1716']...
# [04:59:12] AUC: 0.607228 logloss: 0.185848
#
# Training LR on [aid='336']...
# [04:59:24] AUC: 0.573658 logloss: 0.220311
#
# Training LR on [aid='671']...
# [04:59:35] AUC: 0.632321 logloss: 0.194332
#
# Training LR on [aid='529']...
# [04:59:47] AUC: 0.537244 logloss: 0.184646
#
# Training LR on [aid='927']...
# [04:59:59] AUC: 0.590404 logloss: 0.179378
#
# Training LR on [aid='1714']...
# [05:00:11] AUC: 0.601591 logloss: 0.198046
#
# Training LR on [aid='977']...
# [05:00:23] AUC: 0.498722 logloss: 0.194986
#
# Training LR on [aid='450']...
# [05:00:34] AUC: 0.676067 logloss: 0.197756
#
# Training LR on [aid='1749']...
# [05:00:47] AUC: 0.591429 logloss: 0.184581
#
# Training LR on [aid='404']...
# [05:00:59] AUC: 0.612785 logloss: 0.194488
#
# Training LR on [aid='302']...
# [05:01:11] AUC: 0.563072 logloss: 0.194805
#
# Training LR on [aid='1202']...
# [05:01:24] AUC: 0.590633 logloss: 0.183915
#
# Training LR on [aid='838']...
# [05:01:35] AUC: 0.650484 logloss: 0.182337
#
# Training LR on [aid='1842']...
# [05:01:48] AUC: 0.579853 logloss: 0.202432
#
# Training LR on [aid='875']...
# [05:02:00] AUC: 0.542080 logloss: 0.200746
#
# Training LR on [aid='846']...
# [05:02:12] AUC: 0.657654 logloss: 0.188001
#
# Training LR on [aid='1962']...
# [05:02:23] AUC: 0.565814 logloss: 0.194978
#
# Training LR on [aid='1171']...
# [05:02:34] AUC: 0.662042 logloss: 0.188209
#
# Training LR on [aid='1781']...
# [05:02:46] AUC: 0.563092 logloss: 0.188364
#
# Training LR on [aid='1622']...
# [05:02:59] AUC: 0.669850 logloss: 0.183410
#
# Training LR on [aid='1254']...
# [05:03:11] AUC: 0.569500 logloss: 0.194622
#
# Training LR on [aid='231']...
# [05:03:24] AUC: 0.543889 logloss: 0.198002
#
# Training LR on [aid='191']...
# [05:03:37] AUC: 0.639013 logloss: 0.189254
#
# Training LR on [aid='113']...
# [05:03:48] AUC: 0.547890 logloss: 0.196192
#
# Training LR on [aid='1057']...
# [05:04:00] AUC: 0.600564 logloss: 0.192724
#
# Training LR on [aid='145']...
# [05:04:12] AUC: 0.608465 logloss: 0.177996
#
# Training LR on [aid='1284']...
# [05:04:24] AUC: 0.660979 logloss: 0.180163
#
# Training LR on [aid='86']...
# [05:04:35] AUC: 0.562806 logloss: 0.196433
#
# Training LR on [aid='686']...
# [05:04:47] AUC: 0.564838 logloss: 0.183365
#
# Training LR on [aid='1291']...
# [05:05:01] AUC: 0.631654 logloss: 0.185022
#
# Training LR on [aid='853']...
# [05:05:12] AUC: 0.561416 logloss: 0.174791
#
# Training LR on [aid='765']...
# [05:05:24] AUC: 0.588336 logloss: 0.191091
#
# Training LR on [aid='2031']...
# [05:05:37] AUC: 0.593645 logloss: 0.186108
#
# Training LR on [aid='1507']...
# [05:05:49] AUC: 0.551743 logloss: 0.189238
#
# Training LR on [aid='2054']...
# [05:06:00] AUC: 0.718066 logloss: 0.182291
#
# Training LR on [aid='1599']...
# [05:06:12] AUC: 0.570889 logloss: 0.203099
#
# Training LR on [aid='1338']...
# [05:06:24] AUC: 0.646872 logloss: 0.184741
#
# Training LR on [aid='1672']...
# [05:06:36] AUC: 0.605575 logloss: 0.206418
#
# Training LR on [aid='1350']...
# [05:06:48] AUC: 0.514334 logloss: 0.209214
#
# Training LR on [aid='1415']...
# [05:07:02] AUC: 0.572326 logloss: 0.189826
#
# Training LR on [aid='420']...
# [05:07:13] AUC: 0.562876 logloss: 0.192725
#
# Training LR on [aid='1021']...
# [05:07:27] AUC: 0.589242 logloss: 0.204090
#
# Training LR on [aid='1931']...
# [05:07:38] AUC: 0.527110 logloss: 0.186511
#
# Training LR on [aid='1925']...
# [05:07:50] AUC: 0.583116 logloss: 0.195625
#
# Training LR on [aid='432']...
# [05:08:02] AUC: 0.581555 logloss: 0.198105
#
# Training LR on [aid='1044']...
# [05:08:14] AUC: 0.567801 logloss: 0.185330
#
# Training LR on [aid='117']...
# [05:08:27] AUC: 0.633895 logloss: 0.186042
#
# Training LR on [aid='1930']...
# [05:08:39] AUC: 0.635066 logloss: 0.183006
#
# Training LR on [aid='1950']...
# [05:08:51] AUC: 0.543782 logloss: 0.187840
#
# Training LR on [aid='1621']...
# [05:09:02] AUC: 0.589151 logloss: 0.189026
#
# Training LR on [aid='206']...
# [05:09:14] AUC: 0.546500 logloss: 0.202222
#
# Training LR on [aid='2196']...
# [05:09:25] AUC: 0.536061 logloss: 0.207673
#
# Training LR on [aid='121']...
# [05:09:37] AUC: 0.613250 logloss: 0.174151
#
# Training LR on [aid='1508']...
# [05:09:49] AUC: 0.673718 logloss: 0.185024
#
# Training LR on [aid='2068']...
# [05:10:00] AUC: 0.775201 logloss: 0.173122
#
# Training LR on [aid='894']...
# [05:10:11] AUC: 0.576441 logloss: 0.194100
#
# Training LR on [aid='1317']...
# [05:10:23] AUC: 0.560481 logloss: 0.188227
#
# Training LR on [aid='1871']...
# [05:10:34] AUC: 0.529312 logloss: 0.191722
#
# Training LR on [aid='471']...
# [05:10:46] AUC: 0.614135 logloss: 0.194758
#
# Training LR on [aid='436']...
# [05:10:57] AUC: 0.506575 logloss: 0.193670
#
# Training LR on [aid='174']...
# [05:11:09] AUC: 0.613650 logloss: 0.185663
#
# Training LR on [aid='681']...
# [05:11:20] AUC: 0.617061 logloss: 0.189691
#
# Training LR on [aid='1957']...
# [05:11:32] AUC: 0.659342 logloss: 0.190455
#
# Training LR on [aid='1468']...
# [05:11:46] AUC: 0.603916 logloss: 0.187284
#
# Training LR on [aid='1242']...
# [05:11:58] AUC: 0.587125 logloss: 0.185540
#
# Training LR on [aid='1023']...
# [05:12:09] AUC: 0.609176 logloss: 0.188907
#
# Training LR on [aid='1991']...
# [05:12:20] AUC: 0.607147 logloss: 0.220931
#
# Training LR on [aid='1998']...
# [05:12:31] AUC: 0.518450 logloss: 0.183666
#
# Training LR on [aid='1966']...
# [05:12:42] AUC: 0.545936 logloss: 0.178804
#
# Training LR on [aid='903']...
# [05:12:54] AUC: 0.715524 logloss: 0.169926
#
# Training LR on [aid='2154']...
# [05:13:06] AUC: 0.443496 logloss: 0.208657
#
# Training LR on [aid='951']...
# [05:13:17] AUC: 0.535600 logloss: 0.219862
#
# Training LR on [aid='1407']...
# [05:13:29] AUC: 0.575175 logloss: 0.186947
#
# Training LR on [aid='1215']...
# [05:13:41] AUC: 0.587847 logloss: 0.190310
#
# Training LR on [aid='1429']...
# [05:13:52] AUC: 0.643675 logloss: 0.177879
#
# Training LR on [aid='1017']...
# [05:14:04] AUC: 0.607193 logloss: 0.187378
#
# Training LR on [aid='647']...
# [05:14:16] AUC: 0.568243 logloss: 0.176635
#
# Training LR on [aid='205']...
# [05:14:27] AUC: 0.675869 logloss: 0.187464
#
# Training LR on [aid='2048']...
# [05:14:39] AUC: 0.564674 logloss: 0.175696
#
# Training LR on [aid='1107']...
# [05:14:50] AUC: 0.694133 logloss: 0.188967
#
# Training LR on [aid='966']...
# [05:15:03] AUC: 0.574155 logloss: 0.187837
#
# Training LR on [aid='2216']...
# [05:15:15] AUC: 0.503429 logloss: 0.201864
#
# Training LR on [aid='1904']...
# [05:15:27] AUC: 0.512133 logloss: 0.189102
#
# Training LR on [aid='1277']...
# [05:15:38] AUC: 0.534966 logloss: 0.197199
#
# Training LR on [aid='562']...
# [05:15:50] AUC: 0.538841 logloss: 0.199696
#
# Training LR on [aid='272']...
# [05:16:02] AUC: 0.559531 logloss: 0.194456
#
# Training LR on [aid='561']...
# [05:16:16] AUC: 0.582256 logloss: 0.188028
#
# Training LR on [aid='164']...
# [05:16:27] AUC: 0.582365 logloss: 0.195732
#
# Training LR on [aid='1375']...
# [05:16:39] AUC: 0.619954 logloss: 0.193764
#
# Training LR on [aid='519']...
# [05:16:50] AUC: 0.636885 logloss: 0.187546
#
# Training LR on [aid='1819']...
# [05:17:02] AUC: 0.671998 logloss: 0.187057
#
# Training LR on [aid='1335']...
# [05:17:14] AUC: 0.552578 logloss: 0.201128
#
# Training LR on [aid='960']...
# [05:17:25] AUC: 0.563812 logloss: 0.190101
#
# Training LR on [aid='1847']...
# [05:17:37] AUC: 0.587643 logloss: 0.196605
#
# Training LR on [aid='1503']...
# [05:17:49] AUC: 0.627563 logloss: 0.193792
#
# Training LR on [aid='792']...
# [05:18:01] AUC: 0.561454 logloss: 0.186926
#
# Training LR on [aid='2205']...
# [05:18:13] AUC: 0.641329 logloss: 0.173744
#
# Training LR on [aid='1351']...
# [05:18:24] AUC: 0.608040 logloss: 0.191379
#
# Training LR on [aid='1728']...
# [05:18:36] AUC: 0.584881 logloss: 0.188869
#
# Training LR on [aid='1496']...
# [05:18:47] AUC: 0.573492 logloss: 0.192457
#
# Training LR on [aid='369']...
# [05:19:00] AUC: 0.507128 logloss: 0.192988
#
# Training LR on [aid='725']...
# [05:19:12] AUC: 0.625489 logloss: 0.196026
#
# Training LR on [aid='727']...
# [05:19:24] AUC: 0.594618 logloss: 0.181483
#
# Training LR on [aid='699']...
# [05:19:35] AUC: 0.576140 logloss: 0.188674
#
# Training LR on [aid='313']...
# [05:19:47] AUC: 0.666953 logloss: 0.167324
#
# Training LR on [aid='2197']...
# [05:19:58] AUC: 0.528753 logloss: 0.188990
#
# Training LR on [aid='1027']...
# [05:20:12] AUC: 0.668119 logloss: 0.191667
#
# Training LR on [aid='2047']...
# [05:20:24] AUC: 0.557839 logloss: 0.186453
# Training LR on [aid='1119']...
# [05:20:38] AUC: 0.574516 logloss: 0.192630
#
# Training LR on [aid='1449']...
# [05:20:49] AUC: 0.638877 logloss: 0.199388
#
# Training LR on [aid='886']...
# [05:21:00] AUC: 0.619390 logloss: 0.205170
#
# Training LR on [aid='1580']...
# [05:21:12] AUC: 0.522594 logloss: 0.208253
#
# Training LR on [aid='975']...
# [05:21:23] AUC: 0.572035 logloss: 0.193256
#
# Training LR on [aid='74']...
# [05:21:35] AUC: 0.533178 logloss: 0.181291
#
# Training LR on [aid='136']...
# [05:21:49] AUC: 0.577698 logloss: 0.187987
#
# Training LR on [aid='311']...
# [05:22:01] AUC: 0.681912 logloss: 0.178260
#
# Training LR on [aid='1140']...
# [05:22:13] AUC: 0.597353 logloss: 0.183828
#
# Training LR on [aid='1910']...
# [05:22:24] AUC: 0.612702 logloss: 0.188824
#
# Training LR on [aid='7']...
# [05:22:36] AUC: 0.589117 logloss: 0.190887
#
# Training LR on [aid='1827']...
# [05:22:48] AUC: 0.625602 logloss: 0.184897
#
# Training LR on [aid='1483']...
# [05:22:59] AUC: 0.710040 logloss: 0.175236
#
# Training LR on [aid='613']...
# [05:23:10] AUC: 0.736555 logloss: 0.176295
#
# Training LR on [aid='1746']...
# [05:23:22] AUC: 0.538172 logloss: 0.195592
#
# Training LR on [aid='1790']...
# [05:23:33] AUC: 0.672220 logloss: 0.195979
#
# Training LR on [aid='1230']...
# [05:23:45] AUC: 0.522100 logloss: 0.202514
#
# Training LR on [aid='692']...
# [05:24:02] AUC: 0.609544 logloss: 0.195139
#
# Training LR on [aid='1596']...
# [05:24:14] AUC: 0.611868 logloss: 0.185090
#
# Training LR on [aid='1671']...
# [05:24:26] AUC: 0.656687 logloss: 0.188268
#
# Training LR on [aid='212']...
# [05:24:38] AUC: 0.570011 logloss: 0.198779
#
# Training LR on [aid='543']...
# [05:24:49] AUC: 0.610345 logloss: 0.183724
#
# Training LR on [aid='939']...
# [05:25:01] AUC: 0.547981 logloss: 0.199334
#
# Training LR on [aid='932']...
# [05:25:12] AUC: 0.636660 logloss: 0.195625
#
# Training LR on [aid='1379']...
# [05:25:24] AUC: 0.656709 logloss: 0.186514
#
# Training LR on [aid='411']...
# [05:25:38] AUC: 0.612116 logloss: 0.188304
#
# Training LR on [aid='2112']...
# [05:25:50] AUC: 0.681231 logloss: 0.184331
#
# Training LR on [aid='18']...
# [05:26:01] AUC: 0.540357 logloss: 0.189381
#
# Training LR on [aid='1970']...
# [05:26:13] AUC: 0.554869 logloss: 0.194688
#
# Training LR on [aid='1894']...
# [05:26:25] AUC: 0.594142 logloss: 0.192605
#
# Training LR on [aid='2201']...
# [05:26:36] AUC: 0.688989 logloss: 0.178843
#
# Training LR on [aid='1841']...
# [05:26:47] AUC: 0.594211 logloss: 0.197052
#
# Training LR on [aid='6']...
# [05:26:59] AUC: 0.542142 logloss: 0.200188
#
# Training LR on [aid='516']...
# [05:27:10] AUC: 0.523217 logloss: 0.207482
#
# Training LR on [aid='2066']...
# [05:27:21] AUC: 0.537687 logloss: 0.193326
#
# Training LR on [aid='624']...
# [05:27:32] AUC: 0.565592 logloss: 0.187135
#
# Training LR on [aid='1605']...
# [05:27:45] AUC: 0.621965 logloss: 0.191160
#
# Training LR on [aid='1377']...
# [05:27:56] AUC: 0.653334 logloss: 0.187745
#
# Training LR on [aid='914']...
# [05:28:10] AUC: 0.580451 logloss: 0.187526
#
# Training LR on [aid='12']...
# [05:28:21] AUC: 0.608794 logloss: 0.191707
#
# Training LR on [aid='2169']...
# [05:28:32] AUC: 0.574257 logloss: 0.187557
#
# Training LR on [aid='1182']...
# [05:28:43] AUC: 0.579314 logloss: 0.184148
#
# Training LR on [aid='70']...
# [05:28:56] AUC: 0.669366 logloss: 0.179872
#
# Training LR on [aid='98']...
# [05:29:07] AUC: 0.580563 logloss: 0.198798
#
# Training LR on [aid='1201']...
# [05:29:19] AUC: 0.572136 logloss: 0.186365
#
# Training LR on [aid='286']...
# [05:29:30] AUC: 0.636277 logloss: 0.193333
#
# Training LR on [aid='2118']...
# [05:29:42] AUC: 0.593145 logloss: 0.191708
#
# Training LR on [aid='173']...
# [05:29:53] AUC: 0.571656 logloss: 0.195115
#
# Training LR on [aid='1512']...
# [05:30:04] AUC: 0.725827 logloss: 0.189341
#
# Training LR on [aid='748']...
# [05:30:16] AUC: 0.583539 logloss: 0.185909
#
# Training LR on [aid='1566']...
# [05:30:29] AUC: 0.595894 logloss: 0.190984
#
# Training LR on [aid='2044']...
# [05:30:40] AUC: 0.519073 logloss: 0.196013
#
# Training LR on [aid='1085']...
# [05:30:51] AUC: 0.498988 logloss: 0.196027
#
# Training LR on [aid='454']...
# [05:31:03] AUC: 0.589743 logloss: 0.184020
#
# Training LR on [aid='916']...
# [05:31:14] AUC: 0.665050 logloss: 0.179441
#
# Training LR on [aid='688']...
# [05:31:26] AUC: 0.667895 logloss: 0.184944
#
# Training LR on [aid='660']...
# [05:31:37] AUC: 0.525527 logloss: 0.185504
#
# Training LR on [aid='1635']...
# [05:31:48] AUC: 0.528632 logloss: 0.189209
#
# Training LR on [aid='1918']...
# [05:32:02] AUC: 0.596271 logloss: 0.188902
#
# Training LR on [aid='1530']...
# [05:32:14] AUC: 0.534548 logloss: 0.200182
#
# Training LR on [aid='389']...
# [05:32:26] AUC: 0.604037 logloss: 0.187764
#
# Training LR on [aid='1940']...
# [05:32:37] AUC: 0.662179 logloss: 0.196216
#
# Training LR on [aid='2013']...
# [05:32:49] AUC: 0.602689 logloss: 0.190103

# %%
uids, (ufeat_index, idf, uvec) = load_user_tfidf("interest1")

# %%
print("====================")
print("LR on TFIDF Features")
print("====================")
for aid in aids:
    df_selected = df_train[df_train['aid']==aid]
    u_index = df_selected['uid'].map(uid_to_index).values
    
    valid_ratio = 0.3
    train_size = int(df_selected.shape[0] * (1 - valid_ratio))
    
    X = uvec[u_index,:]
    y = (df_selected['label'].values + 1) / 2
    X_train, y_train = X[:train_size], y[:train_size]
    X_valid, y_valid = X[train_size:], y[train_size:]

    lr = LogisticRegression()
    
    print("Training LR on [aid='{}']...".format(aid))
    lr.fit(X_train, y_train)
    proba_valid = lr.predict_proba(X_valid)
    logloss = metrics.log_loss(y_valid, proba_valid)
    auc = metrics.roc_auc_score(y_valid, proba_valid[:,1])
    print("[{}] AUC: {:.6f} logloss: {:.6f}".format(get_time_str(), auc, logloss))
    print()
# Out:
# ====================
# LR on TFIDF Features
# ====================
# Training LR on [aid='177']...
# [06:21:42] AUC: 0.542810 logloss: 0.194485
#
# Training LR on [aid='2050']...
# [06:21:54] AUC: 0.638728 logloss: 0.178572
#
# Training LR on [aid='1716']...
# [06:22:06] AUC: 0.601042 logloss: 0.185841
#
# Training LR on [aid='336']...
# [06:22:18] AUC: 0.578140 logloss: 0.212666
#
# Training LR on [aid='671']...
# [06:22:30] AUC: 0.648403 logloss: 0.190905
#
# Training LR on [aid='529']...
# [06:22:42] AUC: 0.535082 logloss: 0.183888
#
# Training LR on [aid='927']...
# [06:22:54] AUC: 0.599216 logloss: 0.176448
#
# Training LR on [aid='1714']...
# [06:23:06] AUC: 0.599980 logloss: 0.197754
#
# Training LR on [aid='977']...
# [06:23:19] AUC: 0.491235 logloss: 0.191665
#
# Training LR on [aid='450']...
# [06:23:31] AUC: 0.646323 logloss: 0.199731
#
# Training LR on [aid='1749']...
# [06:23:43] AUC: 0.592385 logloss: 0.184306
#
# Training LR on [aid='404']...
# [06:23:56] AUC: 0.611377 logloss: 0.194242
#
# Training LR on [aid='302']...
# [06:24:08] AUC: 0.565456 logloss: 0.194760
#
# Training LR on [aid='1202']...
# [06:24:20] AUC: 0.608581 logloss: 0.181515
#
# Training LR on [aid='838']...
# [06:24:32] AUC: 0.645444 logloss: 0.180456
#
# Training LR on [aid='1842']...
# [06:24:44] AUC: 0.573940 logloss: 0.199870
#
# Training LR on [aid='875']...
# [06:24:56] AUC: 0.532674 logloss: 0.196646
#
# Training LR on [aid='846']...
# [06:25:08] AUC: 0.654084 logloss: 0.188342
#
# Training LR on [aid='1962']...
# [06:25:19] AUC: 0.561187 logloss: 0.194394
#
# Training LR on [aid='1171']...
# [06:25:31] AUC: 0.655955 logloss: 0.187465
#
# Training LR on [aid='1781']...
# [06:25:42] AUC: 0.558765 logloss: 0.188257
#
# Training LR on [aid='1622']...
# [06:25:54] AUC: 0.669793 logloss: 0.182867
#
# Training LR on [aid='1254']...
# [06:26:06] AUC: 0.564806 logloss: 0.194576
#
# Training LR on [aid='231']...
# [06:26:18] AUC: 0.549059 logloss: 0.197772
#
# Training LR on [aid='191']...
# [06:26:31] AUC: 0.636775 logloss: 0.189377
#
# Training LR on [aid='113']...
# [06:26:42] AUC: 0.574092 logloss: 0.193462
#
# Training LR on [aid='1057']...
# [06:26:55] AUC: 0.612689 logloss: 0.190186
#
# Training LR on [aid='145']...
# [06:27:07] AUC: 0.597136 logloss: 0.178050
#
# Training LR on [aid='1284']...
# [06:27:18] AUC: 0.663778 logloss: 0.178936
#
# Training LR on [aid='86']...
# [06:27:30] AUC: 0.586574 logloss: 0.192149
#
# Training LR on [aid='686']...
# [06:27:41] AUC: 0.559673 logloss: 0.182584
#
# Training LR on [aid='1291']...
# [06:27:54] AUC: 0.628481 logloss: 0.185352
#
# Training LR on [aid='853']...
# [06:28:06] AUC: 0.573469 logloss: 0.172985
#
# Training LR on [aid='765']...
# [06:28:18] AUC: 0.586094 logloss: 0.190723
#
# Training LR on [aid='2031']...
# [06:28:29] AUC: 0.592547 logloss: 0.185996
#
# Training LR on [aid='1507']...
# [06:28:41] AUC: 0.554935 logloss: 0.188495
#
# Training LR on [aid='2054']...
# [06:28:53] AUC: 0.714262 logloss: 0.180710
#
# Training LR on [aid='1599']...
# [06:29:04] AUC: 0.584542 logloss: 0.199610
#
# Training LR on [aid='1338']...
# [06:29:17] AUC: 0.646112 logloss: 0.184445
#
# Training LR on [aid='1672']...
# [06:29:29] AUC: 0.599834 logloss: 0.206010
#
# Training LR on [aid='1350']...
# [06:29:40] AUC: 0.521613 logloss: 0.203315
#
# Training LR on [aid='1415']...
# [06:29:53] AUC: 0.571664 logloss: 0.189751
#
# Training LR on [aid='420']...
# [06:30:05] AUC: 0.564285 logloss: 0.192298
#
# Training LR on [aid='1021']...
# [06:30:16] AUC: 0.589697 logloss: 0.203956
#
# Training LR on [aid='1931']...
# [06:30:27] AUC: 0.515522 logloss: 0.184761
#
# Training LR on [aid='1925']...
# [06:30:39] AUC: 0.585202 logloss: 0.191753
#
# Training LR on [aid='432']...
# [06:30:51] AUC: 0.577646 logloss: 0.198189
#
# Training LR on [aid='1044']...
# [06:31:03] AUC: 0.562348 logloss: 0.185108
#
# Training LR on [aid='117']...
# [06:31:15] AUC: 0.629310 logloss: 0.186358
#
# Training LR on [aid='1930']...
# [06:31:26] AUC: 0.637547 logloss: 0.182767
#
# Training LR on [aid='1950']...
# [06:31:38] AUC: 0.538958 logloss: 0.188006
#
# Training LR on [aid='1621']...
# [06:31:50] AUC: 0.589314 logloss: 0.188658
#
# Training LR on [aid='206']...
# [06:32:01] AUC: 0.543953 logloss: 0.201926
#
# Training LR on [aid='2196']...
# [06:32:13] AUC: 0.528206 logloss: 0.202954
#
# Training LR on [aid='121']...
# [06:32:24] AUC: 0.613888 logloss: 0.174535
#
# Training LR on [aid='1508']...
# [06:32:37] AUC: 0.674762 logloss: 0.184329
#
# Training LR on [aid='2068']...
# [06:32:49] AUC: 0.780096 logloss: 0.172315
#
# Training LR on [aid='894']...
# [06:33:01] AUC: 0.583662 logloss: 0.192200
#
# Training LR on [aid='1317']...
# [06:33:12] AUC: 0.577501 logloss: 0.186095
#
# Training LR on [aid='1871']...
# [06:33:23] AUC: 0.531303 logloss: 0.188665
#
# Training LR on [aid='471']...
# [06:33:34] AUC: 0.619369 logloss: 0.193928
#
# Training LR on [aid='436']...
# [06:33:46] AUC: 0.514171 logloss: 0.190214
#
# Training LR on [aid='174']...
# [06:33:57] AUC: 0.615512 logloss: 0.183980
#
# Training LR on [aid='681']...
# [06:34:08] AUC: 0.607139 logloss: 0.189348
#
# Training LR on [aid='1957']...
# [06:34:20] AUC: 0.645800 logloss: 0.191062
#
# Training LR on [aid='1468']...
# [06:34:33] AUC: 0.601435 logloss: 0.187420
#
# Training LR on [aid='1242']...
# [06:34:45] AUC: 0.591448 logloss: 0.178402
#
# Training LR on [aid='1023']...
# [06:34:56] AUC: 0.598227 logloss: 0.189072
#
# Training LR on [aid='1991']...
# [06:35:07] AUC: 0.603658 logloss: 0.218616
#
# Training LR on [aid='1998']...
# [06:35:19] AUC: 0.545375 logloss: 0.178492
#
# Training LR on [aid='1966']...
# [06:35:30] AUC: 0.549500 logloss: 0.176043
#
# Training LR on [aid='903']...
# [06:35:42] AUC: 0.716753 logloss: 0.171047
#
# Training LR on [aid='2154']...
# [06:35:53] AUC: 0.462391 logloss: 0.199978
#
# Training LR on [aid='951']...
# [06:36:05] AUC: 0.535403 logloss: 0.215580
#
# Training LR on [aid='1407']...
# [06:36:17] AUC: 0.572873 logloss: 0.186986
#
# Training LR on [aid='1215']...
# [06:36:28] AUC: 0.582673 logloss: 0.189817
#
# Training LR on [aid='1429']...
# [06:36:40] AUC: 0.644888 logloss: 0.174733
#
# Training LR on [aid='1017']...
# [06:36:52] AUC: 0.608137 logloss: 0.187233
#
# Training LR on [aid='647']...
# [06:37:04] AUC: 0.569038 logloss: 0.174556
#
# Training LR on [aid='205']...
# [06:37:15] AUC: 0.671759 logloss: 0.186502
#
# Training LR on [aid='2048']...
# [06:37:27] AUC: 0.569616 logloss: 0.174770
#
# Training LR on [aid='1107']...
# [06:37:38] AUC: 0.697082 logloss: 0.186943
#
# Training LR on [aid='966']...
# [06:37:50] AUC: 0.573209 logloss: 0.187846
#
# Training LR on [aid='2216']...
# [06:38:02] AUC: 0.497946 logloss: 0.200154
#
# Training LR on [aid='1904']...
# [06:38:13] AUC: 0.507935 logloss: 0.187633
#
# Training LR on [aid='1277']...
# [06:38:25] AUC: 0.535607 logloss: 0.194626
#
# Training LR on [aid='562']...
# [06:38:37] AUC: 0.548855 logloss: 0.197194
#
# Training LR on [aid='272']...
# [06:38:49] AUC: 0.558940 logloss: 0.190141
#
# Training LR on [aid='561']...
# [06:39:03] AUC: 0.582534 logloss: 0.187914
#
# Training LR on [aid='164']...
# [06:39:17] AUC: 0.596189 logloss: 0.193785
#
# Training LR on [aid='1375']...
# [06:39:31] AUC: 0.620867 logloss: 0.193894
#
# Training LR on [aid='519']...
# [06:39:43] AUC: 0.634708 logloss: 0.187544
#
# Training LR on [aid='1819']...
# [06:39:54] AUC: 0.671271 logloss: 0.186341
#
# Training LR on [aid='1335']...
# [06:40:06] AUC: 0.554760 logloss: 0.197895
#
# Training LR on [aid='960']...
# [06:40:17] AUC: 0.557324 logloss: 0.189744
#
# Training LR on [aid='1847']...
# [06:40:29] AUC: 0.598307 logloss: 0.193865
#
# Training LR on [aid='1503']...
# [06:40:40] AUC: 0.628324 logloss: 0.192091
#
# Training LR on [aid='792']...
# [06:40:52] AUC: 0.553438 logloss: 0.187205
#
# Training LR on [aid='2205']...
# [06:41:03] AUC: 0.640255 logloss: 0.172545
#
# Training LR on [aid='1351']...
# [06:41:14] AUC: 0.615154 logloss: 0.186222
#
# Training LR on [aid='1728']...
# [06:41:26] AUC: 0.584703 logloss: 0.188819
#
# Training LR on [aid='1496']...
# [06:41:38] AUC: 0.572423 logloss: 0.191903
#
# Training LR on [aid='369']...
# [06:41:49] AUC: 0.509107 logloss: 0.192389
#
# Training LR on [aid='725']...
# [06:42:01] AUC: 0.618991 logloss: 0.196016
#
# Training LR on [aid='727']...
# [06:42:13] AUC: 0.595351 logloss: 0.181568
#
# Training LR on [aid='699']...
# [06:42:25] AUC: 0.577714 logloss: 0.188205
#
# Training LR on [aid='313']...
# [06:42:36] AUC: 0.659878 logloss: 0.167621
#
# Training LR on [aid='2197']...
# [06:42:48] AUC: 0.513760 logloss: 0.187701
#
# Training LR on [aid='1027']...
# [06:42:59] AUC: 0.666754 logloss: 0.189294
#
# Training LR on [aid='2047']...
# [06:43:11] AUC: 0.552109 logloss: 0.185370
# Training LR on [aid='1119']...
# [06:43:25] AUC: 0.575194 logloss: 0.192627
#
# Training LR on [aid='1449']...
# [06:43:36] AUC: 0.633926 logloss: 0.197741
#
# Training LR on [aid='886']...
# [06:43:47] AUC: 0.624838 logloss: 0.201808
#
# Training LR on [aid='1580']...
# [06:44:00] AUC: 0.546902 logloss: 0.202157
#
# Training LR on [aid='975']...
# [06:44:11] AUC: 0.585039 logloss: 0.188606
#
# Training LR on [aid='74']...
# [06:44:23] AUC: 0.536525 logloss: 0.180792
#
# Training LR on [aid='136']...
# [06:44:36] AUC: 0.575153 logloss: 0.188037
#
# Training LR on [aid='311']...
# [06:44:48] AUC: 0.675366 logloss: 0.178775
#
# Training LR on [aid='1140']...
# [06:45:00] AUC: 0.599787 logloss: 0.183348
#
# Training LR on [aid='1910']...
# [06:45:12] AUC: 0.601613 logloss: 0.187058
#
# Training LR on [aid='7']...
# [06:45:24] AUC: 0.584835 logloss: 0.190421
#
# Training LR on [aid='1827']...
# [06:45:36] AUC: 0.623409 logloss: 0.184748
#
# Training LR on [aid='1483']...
# [06:45:47] AUC: 0.707010 logloss: 0.176236
#
# Training LR on [aid='613']...
# [06:45:59] AUC: 0.730259 logloss: 0.171496
#
# Training LR on [aid='1746']...
# [06:46:10] AUC: 0.531684 logloss: 0.190556
#
# Training LR on [aid='1790']...
# [06:46:21] AUC: 0.674570 logloss: 0.194392
#
# Training LR on [aid='1230']...
# [06:46:33] AUC: 0.516568 logloss: 0.199697
#
# Training LR on [aid='692']...
# [06:46:48] AUC: 0.609415 logloss: 0.195101
#
# Training LR on [aid='1596']...
# [06:47:01] AUC: 0.609217 logloss: 0.185079
#
# Training LR on [aid='1671']...
# [06:47:12] AUC: 0.652222 logloss: 0.186824
#
# Training LR on [aid='212']...
# [06:47:24] AUC: 0.565170 logloss: 0.198593
#
# Training LR on [aid='543']...
# [06:47:36] AUC: 0.608366 logloss: 0.183633
#
# Training LR on [aid='939']...
# [06:47:48] AUC: 0.557101 logloss: 0.198092
#
# Training LR on [aid='932']...
# [06:48:00] AUC: 0.639674 logloss: 0.194715
#
# Training LR on [aid='1379']...
# [06:48:13] AUC: 0.652383 logloss: 0.186916
#
# Training LR on [aid='411']...
# [06:48:27] AUC: 0.610497 logloss: 0.188432
#
# Training LR on [aid='2112']...
# [06:48:38] AUC: 0.674695 logloss: 0.184551
#
# Training LR on [aid='18']...
# [06:48:50] AUC: 0.555270 logloss: 0.187365
#
# Training LR on [aid='1970']...
# [06:49:01] AUC: 0.572248 logloss: 0.190920
#
# Training LR on [aid='1894']...
# [06:49:13] AUC: 0.604060 logloss: 0.190487
#
# Training LR on [aid='2201']...
# [06:49:24] AUC: 0.682197 logloss: 0.178534
#
# Training LR on [aid='1841']...
# [06:49:36] AUC: 0.604206 logloss: 0.195500
#
# Training LR on [aid='6']...
# [06:49:48] AUC: 0.523378 logloss: 0.198553
#
# Training LR on [aid='516']...
# [06:49:59] AUC: 0.525507 logloss: 0.201162
#
# Training LR on [aid='2066']...
# [06:50:11] AUC: 0.543418 logloss: 0.191241
#
# Training LR on [aid='624']...
# [06:50:22] AUC: 0.568930 logloss: 0.185267
#
# Training LR on [aid='1605']...
# [06:50:35] AUC: 0.617817 logloss: 0.191321
#
# Training LR on [aid='1377']...
# [06:50:47] AUC: 0.652955 logloss: 0.187612
#
# Training LR on [aid='914']...
# [06:51:00] AUC: 0.580844 logloss: 0.187515
#
# Training LR on [aid='12']...
# [06:51:11] AUC: 0.609409 logloss: 0.191770
#
# Training LR on [aid='2169']...
# [06:51:23] AUC: 0.575569 logloss: 0.184687
#
# Training LR on [aid='1182']...
# [06:51:34] AUC: 0.572404 logloss: 0.182890
#
# Training LR on [aid='70']...
# [06:51:47] AUC: 0.663010 logloss: 0.180683
#
# Training LR on [aid='98']...
# [06:51:59] AUC: 0.581221 logloss: 0.197962
#
# Training LR on [aid='1201']...
# [06:52:11] AUC: 0.573023 logloss: 0.185755
#
# Training LR on [aid='286']...
# [06:52:23] AUC: 0.629273 logloss: 0.193434
#
# Training LR on [aid='2118']...
# [06:52:35] AUC: 0.591324 logloss: 0.191780
#
# Training LR on [aid='173']...
# [06:52:47] AUC: 0.569024 logloss: 0.194856
#
# Training LR on [aid='1512']...
# [06:52:58] AUC: 0.727075 logloss: 0.187982
#
# Training LR on [aid='748']...
# [06:53:09] AUC: 0.587369 logloss: 0.185229
#
# Training LR on [aid='1566']...
# [06:53:22] AUC: 0.599860 logloss: 0.190718
#
# Training LR on [aid='2044']...
# [06:53:34] AUC: 0.508352 logloss: 0.195166
#
# Training LR on [aid='1085']...
# [06:53:46] AUC: 0.500342 logloss: 0.189006
#
# Training LR on [aid='454']...
# [06:53:58] AUC: 0.598312 logloss: 0.182133
#
# Training LR on [aid='916']...
# [06:54:10] AUC: 0.664904 logloss: 0.179341
#
# Training LR on [aid='688']...
# [06:54:24] AUC: 0.682351 logloss: 0.182972
#
# Training LR on [aid='660']...
# [06:54:36] AUC: 0.536199 logloss: 0.184112
#
# Training LR on [aid='1635']...
# [06:54:48] AUC: 0.539389 logloss: 0.187450
#
# Training LR on [aid='1918']...
# [06:55:01] AUC: 0.593137 logloss: 0.188959
#
# Training LR on [aid='1530']...
# [06:55:13] AUC: 0.533794 logloss: 0.200149
#
# Training LR on [aid='389']...
# [06:55:25] AUC: 0.602209 logloss: 0.187749
#
# Training LR on [aid='1940']...
# [06:55:37] AUC: 0.664615 logloss: 0.195853
#
# Training LR on [aid='2013']...
# [06:55:49] AUC: 0.602452 logloss: 0.189833
