# %%
import lightgbm as lgb
import pandas as pd
import numpy as np
import pickle
import os
from scipy.sparse import hstack

# %%
data_dir = '../data/raw/preliminary_contest_data/'
ad_cnt_dir = '../data/nlp_count/preliminary_contest_data/byAdFeatureName/'
user_cnt_dir = '../data/nlp_count/preliminary_contest_data/byUserFeatureName/'
user_tfidf_dir = '../data/nlp_tfidf/preliminary_contest_data/byUserFeatureName/'

# %%
def load(filename, **kw):
    return pd.read_csv(os.path.join(data_dir, filename), **kw)

# %%
def load_pickle(filepath):
    obj = None
    with open(filepath, "rb") as f:
        obj = pickle.load(f)
    return obj

# %%
def load_ad_cnt(feat_name):
    filename = "adFeature.[featureName='{}'].pkl".format(feat_name)
    filepath = os.path.join(ad_cnt_dir, filename)
    index, matrix = load_pickle(filepath)
    
    filename = "aid.pkl".format(feat_name)
    filepath = os.path.join(ad_cnt_dir, filename)
    uid = load_pickle(filepath)
    
    return uid, (index, matrix)

# %%
def load_user_cnt(feat_name):
    filename = "userFeature.[featureName='{}'].pkl".format(feat_name)
    filepath = os.path.join(user_cnt_dir, filename)
    index, matrix = load_pickle(filepath)
    
    filename = "uid.pkl".format(feat_name)
    filepath = os.path.join(user_cnt_dir, filename)
    uid = load_pickle(filepath)
    
    return uid, (index, matrix)

# %%
def load_user_tfidf(feat_name):
    filename = "userFeature.[featureName='{}'].pkl".format(feat_name)
    filepath = os.path.join(user_tfidf_dir, filename)
    index, idf, matrix = load_pickle(filepath)
    
    filename = "uid.pkl".format(feat_name)
    filepath = os.path.join(user_tfidf_dir, filename)
    uid = load_pickle(filepath)
    
    return uid, (index, idf, matrix)

# %%
df_train = load("train.csv")

# %%
uid, (ufeat_index, uvec) = load_user_cnt("interest1")
aid, (afeat_index, avec) = load_ad_cnt('aid')
uid_to_index = dict(zip(uid, list(range(len(uid)))))  # mapping from uids to distinct indices
aid_to_index = dict(zip(aid, list(range(len(aid)))))  # mapping from aids to distinct indices

a_index = df_train['aid'].map(aid_to_index).values  # list of indices for matrix joining
u_index = df_train['uid'].map(uid_to_index).values  # list of indices for matrix joining

X = hstack((avec[a_index,:], uvec[u_index,:])).tocsr()  # joined user and advertise matrix
y = (df_train['label'].values + 1) / 2

X_train, y_train = X[:6000000], y[:6000000]
X_valid, y_valid = X[6000000:], y[6000000:]

lgb_train = lgb.Dataset(X_train.astype(np.float32), y_train)
lgb_valid = lgb.Dataset(X_valid.astype(np.float32), y_valid)

# %%
lgb_train = lgb.Dataset(X_train.astype(np.float32), y_train)
lgb_valid = lgb.Dataset(X_valid.astype(np.float32), y_valid)

params = {
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': 'auc',
    'max_depth': 4,
    'num_leaves': 31,
    'learning_rate': 0.15,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'verbose': 0
}

gbm = lgb.train(params,
                lgb_train,
                num_boost_round=100,
                valid_sets=[lgb_train, lgb_valid], 
                valid_names=['train', 'valid1'])
# Out:
# [1]	train's auc: 0.552581	valid1's auc: 0.552446
# [2]	train's auc: 0.555142	valid1's auc: 0.55497
# [3]	train's auc: 0.557755	valid1's auc: 0.557258
# [4]	train's auc: 0.558614	valid1's auc: 0.557803
# [5]	train's auc: 0.558499	valid1's auc: 0.557781
# [6]	train's auc: 0.56004	valid1's auc: 0.559386
# [7]	train's auc: 0.560327	valid1's auc: 0.559746
# [8]	train's auc: 0.560874	valid1's auc: 0.560505
# [9]	train's auc: 0.562135	valid1's auc: 0.561793
# [10]	train's auc: 0.562448	valid1's auc: 0.562038
# [11]	train's auc: 0.562599	valid1's auc: 0.562182
# [12]	train's auc: 0.56346	valid1's auc: 0.563061
# [13]	train's auc: 0.563408	valid1's auc: 0.562998
# [14]	train's auc: 0.564594	valid1's auc: 0.564188
# [15]	train's auc: 0.565841	valid1's auc: 0.565321
# [16]	train's auc: 0.566676	valid1's auc: 0.566134
# [17]	train's auc: 0.567635	valid1's auc: 0.567215
# [18]	train's auc: 0.568158	valid1's auc: 0.567648
# [19]	train's auc: 0.568941	valid1's auc: 0.568212
# [20]	train's auc: 0.569756	valid1's auc: 0.569169
# [21]	train's auc: 0.570555	valid1's auc: 0.569886
# [22]	train's auc: 0.57152	valid1's auc: 0.570869
# [23]	train's auc: 0.572015	valid1's auc: 0.571205
# [24]	train's auc: 0.57259	valid1's auc: 0.571651
# [25]	train's auc: 0.573608	valid1's auc: 0.57254
# [26]	train's auc: 0.574386	valid1's auc: 0.573311
# [27]	train's auc: 0.575428	valid1's auc: 0.574111
# [28]	train's auc: 0.576592	valid1's auc: 0.575228
# [29]	train's auc: 0.577396	valid1's auc: 0.575856
# [30]	train's auc: 0.578104	valid1's auc: 0.576391
# [31]	train's auc: 0.578754	valid1's auc: 0.577
# [32]	train's auc: 0.579648	valid1's auc: 0.577804
# [33]	train's auc: 0.580182	valid1's auc: 0.57829
# [34]	train's auc: 0.580677	valid1's auc: 0.578713
# [35]	train's auc: 0.581288	valid1's auc: 0.579307
# [36]	train's auc: 0.582064	valid1's auc: 0.579978
# [37]	train's auc: 0.582783	valid1's auc: 0.580638
# [38]	train's auc: 0.583265	valid1's auc: 0.581071
# [39]	train's auc: 0.583675	valid1's auc: 0.581356
# [40]	train's auc: 0.584162	valid1's auc: 0.581758
# [41]	train's auc: 0.58475	valid1's auc: 0.582274
# [42]	train's auc: 0.585347	valid1's auc: 0.582826
# [43]	train's auc: 0.585727	valid1's auc: 0.583127
# [44]	train's auc: 0.586004	valid1's auc: 0.583341
# [45]	train's auc: 0.586293	valid1's auc: 0.583503
# [46]	train's auc: 0.587254	valid1's auc: 0.584432
# [47]	train's auc: 0.587519	valid1's auc: 0.584593
# [48]	train's auc: 0.588043	valid1's auc: 0.584995
# [49]	train's auc: 0.588682	valid1's auc: 0.585745
# [50]	train's auc: 0.589231	valid1's auc: 0.586232
# [51]	train's auc: 0.589704	valid1's auc: 0.58667
# [52]	train's auc: 0.59011	valid1's auc: 0.586999
# [53]	train's auc: 0.590426	valid1's auc: 0.587281
# [54]	train's auc: 0.590738	valid1's auc: 0.587536
# [55]	train's auc: 0.591086	valid1's auc: 0.587755
# [56]	train's auc: 0.591521	valid1's auc: 0.588099
# [57]	train's auc: 0.59194	valid1's auc: 0.588393
# [58]	train's auc: 0.592166	valid1's auc: 0.588535
# [59]	train's auc: 0.592432	valid1's auc: 0.588766
# [60]	train's auc: 0.592664	valid1's auc: 0.588874
# [61]	train's auc: 0.592856	valid1's auc: 0.588986
# [62]	train's auc: 0.593141	valid1's auc: 0.589185
# [63]	train's auc: 0.593468	valid1's auc: 0.589547
# [64]	train's auc: 0.593698	valid1's auc: 0.589669
# [65]	train's auc: 0.594059	valid1's auc: 0.589964
# [66]	train's auc: 0.594273	valid1's auc: 0.590067
# [67]	train's auc: 0.594417	valid1's auc: 0.590146
# [68]	train's auc: 0.594614	valid1's auc: 0.590268
# [69]	train's auc: 0.594845	valid1's auc: 0.590402
# [70]	train's auc: 0.594985	valid1's auc: 0.590463
# [71]	train's auc: 0.595237	valid1's auc: 0.590714
# [72]	train's auc: 0.595396	valid1's auc: 0.590774
# [73]	train's auc: 0.595519	valid1's auc: 0.590874
# [74]	train's auc: 0.595657	valid1's auc: 0.590928
# [75]	train's auc: 0.595834	valid1's auc: 0.590942
# [76]	train's auc: 0.596191	valid1's auc: 0.59126
# [77]	train's auc: 0.59636	valid1's auc: 0.591355
# [78]	train's auc: 0.596521	valid1's auc: 0.591457
# [79]	train's auc: 0.596893	valid1's auc: 0.591785
# [80]	train's auc: 0.597073	valid1's auc: 0.59183
# [81]	train's auc: 0.597235	valid1's auc: 0.591907
# [82]	train's auc: 0.597436	valid1's auc: 0.592041
# [83]	train's auc: 0.597694	valid1's auc: 0.592291
# [84]	train's auc: 0.597857	valid1's auc: 0.592411
# [85]	train's auc: 0.598012	valid1's auc: 0.592452
# [86]	train's auc: 0.598149	valid1's auc: 0.59249
# [87]	train's auc: 0.598258	valid1's auc: 0.592506
# [88]	train's auc: 0.59836	valid1's auc: 0.592536
# [89]	train's auc: 0.598981	valid1's auc: 0.593253
# [90]	train's auc: 0.599099	valid1's auc: 0.593312
# [91]	train's auc: 0.599227	valid1's auc: 0.593349
# [92]	train's auc: 0.599353	valid1's auc: 0.593424
# [93]	train's auc: 0.599495	valid1's auc: 0.59347
# [94]	train's auc: 0.599677	valid1's auc: 0.593577
# [95]	train's auc: 0.599808	valid1's auc: 0.593606
# [96]	train's auc: 0.599971	valid1's auc: 0.593644
# [97]	train's auc: 0.600088	valid1's auc: 0.593686
# [98]	train's auc: 0.600353	valid1's auc: 0.593912
# [99]	train's auc: 0.60064	valid1's auc: 0.594188
# [100]	train's auc: 0.600815	valid1's auc: 0.594304

# %%
uid, (ufeat_index, uidf, uvec) = load_user_tfidf("interest1")
uid_to_index = dict(zip(uid, list(range(len(uid)))))

u_index = df_train['uid'].map(uid_to_index).values

X = hstack((avec[a_index,:], uvec[u_index,:])).tocsr()

X_train = X[:6000000]
X_valid = X[6000000:]

lgb_train = lgb.Dataset(X_train.astype(np.float32), y_train)
lgb_valid = lgb.Dataset(X_valid.astype(np.float32), y_valid)

# %%
lgb_train = lgb.Dataset(X_train.astype(np.float32), y_train)
lgb_valid = lgb.Dataset(X_valid.astype(np.float32), y_valid)

params = {
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': 'auc',
    'max_depth': 4,
    'num_leaves': 31,
    'learning_rate': 0.15,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'verbose': 0
}

gbm = lgb.train(params,
                lgb_train,
                num_boost_round=100,
                valid_sets=[lgb_train, lgb_valid], 
                valid_names=['train', 'valid1'])
# Out:
# [1]	train's auc: 0.549305	valid1's auc: 0.549279
# [2]	train's auc: 0.550894	valid1's auc: 0.551084
# [3]	train's auc: 0.552355	valid1's auc: 0.55197
# [4]	train's auc: 0.552268	valid1's auc: 0.551556
# [5]	train's auc: 0.552621	valid1's auc: 0.55196
# [6]	train's auc: 0.552933	valid1's auc: 0.55253
# [7]	train's auc: 0.552965	valid1's auc: 0.552619
# [8]	train's auc: 0.553076	valid1's auc: 0.552511
# [9]	train's auc: 0.554256	valid1's auc: 0.553837
# [10]	train's auc: 0.555064	valid1's auc: 0.554635
# [11]	train's auc: 0.555854	valid1's auc: 0.555335
# [12]	train's auc: 0.557434	valid1's auc: 0.557021
# [13]	train's auc: 0.557664	valid1's auc: 0.55721
# [14]	train's auc: 0.558318	valid1's auc: 0.557913
# [15]	train's auc: 0.558687	valid1's auc: 0.558316
# [16]	train's auc: 0.559192	valid1's auc: 0.558748
# [17]	train's auc: 0.559447	valid1's auc: 0.558944
# [18]	train's auc: 0.559637	valid1's auc: 0.559122
# [19]	train's auc: 0.560076	valid1's auc: 0.55929
# [20]	train's auc: 0.560446	valid1's auc: 0.559711
# [21]	train's auc: 0.561222	valid1's auc: 0.560368
# [22]	train's auc: 0.561858	valid1's auc: 0.561018
# [23]	train's auc: 0.561984	valid1's auc: 0.561071
# [24]	train's auc: 0.562611	valid1's auc: 0.561594
# [25]	train's auc: 0.562841	valid1's auc: 0.561872
# [26]	train's auc: 0.563302	valid1's auc: 0.562203
# [27]	train's auc: 0.563622	valid1's auc: 0.562348
# [28]	train's auc: 0.563867	valid1's auc: 0.562517
# [29]	train's auc: 0.564392	valid1's auc: 0.562995
# [30]	train's auc: 0.565362	valid1's auc: 0.563852
# [31]	train's auc: 0.565782	valid1's auc: 0.564202
# [32]	train's auc: 0.566171	valid1's auc: 0.56448
# [33]	train's auc: 0.566856	valid1's auc: 0.565105
# [34]	train's auc: 0.567289	valid1's auc: 0.565459
# [35]	train's auc: 0.567629	valid1's auc: 0.565672
# [36]	train's auc: 0.567772	valid1's auc: 0.565811
# [37]	train's auc: 0.568741	valid1's auc: 0.566755
# [38]	train's auc: 0.568921	valid1's auc: 0.566864
# [39]	train's auc: 0.569339	valid1's auc: 0.567217
# [40]	train's auc: 0.569569	valid1's auc: 0.567316
# [41]	train's auc: 0.569803	valid1's auc: 0.56745
# [42]	train's auc: 0.570008	valid1's auc: 0.56765
# [43]	train's auc: 0.570344	valid1's auc: 0.567892
# [44]	train's auc: 0.570994	valid1's auc: 0.56841
# [45]	train's auc: 0.571272	valid1's auc: 0.568631
# [46]	train's auc: 0.571502	valid1's auc: 0.568821
# [47]	train's auc: 0.571663	valid1's auc: 0.568938
# [48]	train's auc: 0.572199	valid1's auc: 0.56944
# [49]	train's auc: 0.572567	valid1's auc: 0.569808
# [50]	train's auc: 0.57317	valid1's auc: 0.570435
# [51]	train's auc: 0.573534	valid1's auc: 0.570788
# [52]	train's auc: 0.573786	valid1's auc: 0.570992
# [53]	train's auc: 0.573896	valid1's auc: 0.571013
# [54]	train's auc: 0.574265	valid1's auc: 0.57123
# [55]	train's auc: 0.574543	valid1's auc: 0.57148
# [56]	train's auc: 0.57467	valid1's auc: 0.571515
# [57]	train's auc: 0.574824	valid1's auc: 0.571602
# [58]	train's auc: 0.574999	valid1's auc: 0.571701
# [59]	train's auc: 0.57517	valid1's auc: 0.571757
# [60]	train's auc: 0.575473	valid1's auc: 0.572023
# [61]	train's auc: 0.575601	valid1's auc: 0.572109
# [62]	train's auc: 0.575718	valid1's auc: 0.572204
# [63]	train's auc: 0.575859	valid1's auc: 0.572311
# [64]	train's auc: 0.576014	valid1's auc: 0.572418
# [65]	train's auc: 0.576111	valid1's auc: 0.572447
# [66]	train's auc: 0.576395	valid1's auc: 0.572754
# [67]	train's auc: 0.576568	valid1's auc: 0.572832
# [68]	train's auc: 0.576905	valid1's auc: 0.573159
# [69]	train's auc: 0.576971	valid1's auc: 0.573241
# [70]	train's auc: 0.577157	valid1's auc: 0.573372
# [71]	train's auc: 0.577288	valid1's auc: 0.573452
# [72]	train's auc: 0.577473	valid1's auc: 0.573541
# [73]	train's auc: 0.577831	valid1's auc: 0.573756
# [74]	train's auc: 0.578033	valid1's auc: 0.573835
# [75]	train's auc: 0.578142	valid1's auc: 0.573921
# [76]	train's auc: 0.578558	valid1's auc: 0.574328
# [77]	train's auc: 0.578726	valid1's auc: 0.574442
# [78]	train's auc: 0.578939	valid1's auc: 0.574642
# [79]	train's auc: 0.579015	valid1's auc: 0.574666
# [80]	train's auc: 0.579126	valid1's auc: 0.574776
# [81]	train's auc: 0.579209	valid1's auc: 0.574807
# [82]	train's auc: 0.579419	valid1's auc: 0.574964
# [83]	train's auc: 0.579545	valid1's auc: 0.575042
# [84]	train's auc: 0.579618	valid1's auc: 0.575089
# [85]	train's auc: 0.579849	valid1's auc: 0.575296
# [86]	train's auc: 0.580062	valid1's auc: 0.575372
# [87]	train's auc: 0.580137	valid1's auc: 0.57542
# [88]	train's auc: 0.580236	valid1's auc: 0.575431
# [89]	train's auc: 0.580354	valid1's auc: 0.575468
# [90]	train's auc: 0.580678	valid1's auc: 0.575716
# [91]	train's auc: 0.580864	valid1's auc: 0.575852
# [92]	train's auc: 0.581034	valid1's auc: 0.575925
# [93]	train's auc: 0.581155	valid1's auc: 0.575981
# [94]	train's auc: 0.581304	valid1's auc: 0.576044
# [95]	train's auc: 0.581343	valid1's auc: 0.576055
# [96]	train's auc: 0.58154	valid1's auc: 0.576211
# [97]	train's auc: 0.581686	valid1's auc: 0.576279
# [98]	train's auc: 0.581755	valid1's auc: 0.576306
# [99]	train's auc: 0.581849	valid1's auc: 0.576376
# [100]	train's auc: 0.581857	valid1's auc: 0.576349
