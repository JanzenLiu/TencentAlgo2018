# %%
from sklearn.model_selection import StratifiedShuffleSplit, StratifiedKFold
from contextlib import redirect_stdout
import scipy.sparse as sparse
import lightgbm as lgb
import pandas as pd
import numpy as np
import tqdm
import os
import gc
import sys
sys.path.append('../../../code/utils/')
sys.path.append('../../../code/')
import data_utils as du
import perf_utils as pu
import io_utils as iu
import config

# %%
input_folder = config.INPUT_DIR

def load_binary(mode="train"):
    if mode == "train":
        input_file = "train.raw.binary.pkl"
    elif mode == "test":
        input_file = "test1.raw.binary.pkl"
    else:
        raise ValueError("Unknown mode: {}".format(mode))
    input_path = os.path.join(input_folder, input_file)
    return du.load_pickle(input_path)


def load_multicount(mode="train"):
    if mode == "train":
        input_file = "train.raw.rowCount.pkl"
    elif mode == "test":
        input_file = "test1.raw.rowCount.pkl"
    else:
        raise ValueError("Unknown mode: {}".format(mode))
    input_path = os.path.join(input_folder, input_file)
    return du.load_pickle(input_path)


def load_stacking_bs_clickrate(mode="train"):
    if mode == "train":
        input_file = "train.cross.clickStats_v1.pkl"
    elif mode == "test":
        input_file = "test1.cross.clickStats_v1.pkl"
    else:
        raise ValueError("Unknown mode: {}".format(mode))
    input_path = os.path.join(input_folder, input_file)
    return du.load_pickle(input_path)

# %%
with pu.profiler("loading binary features"):
    bin_cols, X_bin = load_binary("train")

with pu.profiler("loading multi value count features"):
    ckr_cols, X_ckr = load_stacking_bs_clickrate("train")
    
assert X_bin.shape[1] == len(bin_cols)
assert X_ckr.shape[1] == len(ckr_cols)
assert X_bin.shape[0] == X_ckr.shape[0]
print("Binary Feature Shape: {}".format(X_bin.shape))
print("Cross Clicks Feature Shape: {}".format(X_ckr.shape))
# Out:
# [15:57:15] Finish loading binary features. △M: +3.26GB. △T: 9.8 seconds.
# [15:57:15] Finish loading multi value count features. △M: +268.54MB. △T: 0.8 seconds.
# Binary Feature Shape: (8798814, 419701)
# Cross Clicks Feature Shape: (8798814, 8)

# %%
with pu.profiler("joining data"):
    cols = bin_cols + ckr_cols
    X = sparse.hstack((X_bin, X_ckr))
    X = sparse.csr_matrix(X)
    del X_bin
    del X_ckr
    gc.collect()
    
print("Joined Data Shape: {}".format(X.shape))
print("Feature Names Count: {}".format(len(cols)))
print("Memory usage at this moment :{}".format(pu.get_memory_str()))
# Out:
# [16:00:11] Finish joining data. △M: +2.19GB. △T: 1.2 minutes.
# Joined Data Shape: (8798814, 419709)
# Feature Names Count: 419709
# Memory usage at this moment :5.81GB

# %%
df_train = du.load_raw_data("train")
y = df_train['label'].values.copy()
y = (y + 1) / 2  # -1, 1 -> 0, 1

# %%
n_splits = 3
sss = StratifiedShuffleSplit(n_splits=n_splits, test_size=1 / 3, random_state=20180505)
split_indices = [(train_index, valid_index) for train_index, valid_index in sss.split(df_train, y)]

# n_splits = 3  # use 3 instead of 5 to save time
# skf = StratifiedKFold(n_splits=n_splits)
# split_indices = [(train_index, valid_index) for train_index, valid_index in skf.split(df_train, y)]

# %%
with pu.profiler("splitting train/valid set"):
    train_index, valid_index = split_indices[0]
    X_train, X_valid = X[train_index], X[valid_index]
    y_train, y_valid = y[train_index], y[valid_index]
    assert X_train.shape[0] + X_valid.shape[0] == X.shape[0]
    
    del X
    gc.collect()
    
print("Training Set Size: {}".format(X_train.shape))
print("Validation Set Size: {}".format(X_valid.shape))
# Out:
# [16:04:09] Finish splitting train/valid set. △M: +79.91MB. △T: 48.4 seconds.
# Training Set Size: (5865876, 419709)
# Validation Set Size: (2932938, 419709)

# %%
with pu.profiler("preparing LightGBM data"):
    lgb_train = lgb.Dataset(X_train.astype(np.float32), y_train, feature_name=cols)
    lgb_valid = lgb.Dataset(X_valid.astype(np.float32), y_valid, feature_name=cols)
    gc.collect()
# Out:
# [16:04:17] Finish preparing LightGBM data. △M: +5.65GB. △T: 8.0 seconds.

# %%
log_folder = os.path.join(config.LOG_DIR, 'lgbm/pipeline/0505/')
log_file = 'v2.log'
log_path = os.path.join(log_folder, log_file)
os.makedirs(log_folder, exist_ok=True)

# %%
params = {
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': 'auc',
    'max_depth': 15,
    'num_leaves': 120,
    'learning_rate': 0.15,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'verbose': 0
}
num_rounds = 500

with iu.DuplicatedLogger(log_path):
    lgbm = lgb.train(params,
                     lgb_train,
                     num_boost_round=num_rounds,
                     valid_sets=[lgb_train, lgb_valid], 
                     valid_names=['train', 'valid1'],
                     early_stopping_rounds=50)
# Out:
# [1]	train's auc: 0.664869	valid1's auc: 0.663328
# Training until validation scores don't improve for 50 rounds.
# [2]	train's auc: 0.684749	valid1's auc: 0.683192
# [3]	train's auc: 0.686767	valid1's auc: 0.68536
# [4]	train's auc: 0.687861	valid1's auc: 0.686481
# [5]	train's auc: 0.688993	valid1's auc: 0.687545
# [6]	train's auc: 0.690176	valid1's auc: 0.688859
# [7]	train's auc: 0.691042	valid1's auc: 0.689639
# [8]	train's auc: 0.693546	valid1's auc: 0.691963
# [9]	train's auc: 0.694649	valid1's auc: 0.69309
# [10]	train's auc: 0.695311	valid1's auc: 0.693668
# [11]	train's auc: 0.697143	valid1's auc: 0.695521
# [12]	train's auc: 0.698508	valid1's auc: 0.696729
# [13]	train's auc: 0.698889	valid1's auc: 0.696939
# [14]	train's auc: 0.701022	valid1's auc: 0.698899
# [15]	train's auc: 0.702004	valid1's auc: 0.699779
# [16]	train's auc: 0.702665	valid1's auc: 0.700349
# [17]	train's auc: 0.703336	valid1's auc: 0.700943
# [18]	train's auc: 0.704249	valid1's auc: 0.701715
# [19]	train's auc: 0.70549	valid1's auc: 0.702823
# [20]	train's auc: 0.706304	valid1's auc: 0.703511
# [21]	train's auc: 0.707495	valid1's auc: 0.704675
# [22]	train's auc: 0.708799	valid1's auc: 0.705909
# [23]	train's auc: 0.709886	valid1's auc: 0.706924
# [24]	train's auc: 0.710993	valid1's auc: 0.707892
# [25]	train's auc: 0.712217	valid1's auc: 0.708945
# [26]	train's auc: 0.713381	valid1's auc: 0.70991
# [27]	train's auc: 0.714558	valid1's auc: 0.710863
# [28]	train's auc: 0.715636	valid1's auc: 0.711632
# [29]	train's auc: 0.716486	valid1's auc: 0.712259
# [30]	train's auc: 0.717309	valid1's auc: 0.712912
# [31]	train's auc: 0.718246	valid1's auc: 0.713622
# [32]	train's auc: 0.719207	valid1's auc: 0.714269
# [33]	train's auc: 0.720051	valid1's auc: 0.714915
# [34]	train's auc: 0.720988	valid1's auc: 0.71564
# [35]	train's auc: 0.721723	valid1's auc: 0.71617
# [36]	train's auc: 0.722461	valid1's auc: 0.716678
# [37]	train's auc: 0.723159	valid1's auc: 0.717296
# [38]	train's auc: 0.723803	valid1's auc: 0.717697
# [39]	train's auc: 0.724491	valid1's auc: 0.718146
# [40]	train's auc: 0.725186	valid1's auc: 0.7186
# [41]	train's auc: 0.725957	valid1's auc: 0.719111
# [42]	train's auc: 0.726579	valid1's auc: 0.719521
# [43]	train's auc: 0.727599	valid1's auc: 0.720335
# [44]	train's auc: 0.728182	valid1's auc: 0.720766
# [45]	train's auc: 0.728926	valid1's auc: 0.721307
# [46]	train's auc: 0.729469	valid1's auc: 0.721674
# [47]	train's auc: 0.730137	valid1's auc: 0.722067
# [48]	train's auc: 0.730839	valid1's auc: 0.722572
# [49]	train's auc: 0.731369	valid1's auc: 0.722854
# [50]	train's auc: 0.731792	valid1's auc: 0.723094
# [51]	train's auc: 0.732246	valid1's auc: 0.723338
# [52]	train's auc: 0.732798	valid1's auc: 0.723692
# [53]	train's auc: 0.733305	valid1's auc: 0.723999
# [54]	train's auc: 0.733811	valid1's auc: 0.724248
# [55]	train's auc: 0.734593	valid1's auc: 0.724715
# [56]	train's auc: 0.735105	valid1's auc: 0.725079
# [57]	train's auc: 0.735472	valid1's auc: 0.725196
# [58]	train's auc: 0.735977	valid1's auc: 0.725422
# [59]	train's auc: 0.736616	valid1's auc: 0.725856
# [60]	train's auc: 0.737058	valid1's auc: 0.726014
# [61]	train's auc: 0.737659	valid1's auc: 0.726356
# [62]	train's auc: 0.73808	valid1's auc: 0.726492
# [63]	train's auc: 0.738505	valid1's auc: 0.726676
# [64]	train's auc: 0.738993	valid1's auc: 0.726845
# [65]	train's auc: 0.739509	valid1's auc: 0.727074
# [66]	train's auc: 0.739941	valid1's auc: 0.72725
# [67]	train's auc: 0.740271	valid1's auc: 0.727437
# [68]	train's auc: 0.74066	valid1's auc: 0.727595
# [69]	train's auc: 0.740995	valid1's auc: 0.727708
# [70]	train's auc: 0.741377	valid1's auc: 0.727853
# [71]	train's auc: 0.741742	valid1's auc: 0.727957
# [72]	train's auc: 0.742046	valid1's auc: 0.728108
# [73]	train's auc: 0.742358	valid1's auc: 0.728194
# [74]	train's auc: 0.742961	valid1's auc: 0.728434
# [75]	train's auc: 0.743193	valid1's auc: 0.728526
# [76]	train's auc: 0.743492	valid1's auc: 0.728594
# [77]	train's auc: 0.743979	valid1's auc: 0.728865
# [78]	train's auc: 0.744439	valid1's auc: 0.729048
# [79]	train's auc: 0.744905	valid1's auc: 0.729158
# [80]	train's auc: 0.745199	valid1's auc: 0.729271
# [81]	train's auc: 0.745524	valid1's auc: 0.729377
# [82]	train's auc: 0.745811	valid1's auc: 0.729463
# [83]	train's auc: 0.746183	valid1's auc: 0.729631
# [84]	train's auc: 0.746709	valid1's auc: 0.729839
# [85]	train's auc: 0.746979	valid1's auc: 0.729958
# [86]	train's auc: 0.747355	valid1's auc: 0.730117
# [87]	train's auc: 0.747613	valid1's auc: 0.730152
# [88]	train's auc: 0.747909	valid1's auc: 0.730207
# [89]	train's auc: 0.748281	valid1's auc: 0.730432
# [90]	train's auc: 0.748644	valid1's auc: 0.730555
# [91]	train's auc: 0.748888	valid1's auc: 0.730638
# [92]	train's auc: 0.749177	valid1's auc: 0.73073
# [93]	train's auc: 0.749407	valid1's auc: 0.730803
# [94]	train's auc: 0.749749	valid1's auc: 0.730848
# [95]	train's auc: 0.750168	valid1's auc: 0.730994
# [96]	train's auc: 0.750572	valid1's auc: 0.731159
# [97]	train's auc: 0.750843	valid1's auc: 0.731273
# [98]	train's auc: 0.751147	valid1's auc: 0.731308
# [99]	train's auc: 0.751477	valid1's auc: 0.731425
# [100]	train's auc: 0.751848	valid1's auc: 0.731532
# [101]	train's auc: 0.752264	valid1's auc: 0.731682
# [102]	train's auc: 0.752534	valid1's auc: 0.731823
# [103]	train's auc: 0.752897	valid1's auc: 0.731941
# [104]	train's auc: 0.753349	valid1's auc: 0.732083
# [105]	train's auc: 0.753513	valid1's auc: 0.732097
# [106]	train's auc: 0.75371	valid1's auc: 0.732178
# [107]	train's auc: 0.753941	valid1's auc: 0.732242
# [108]	train's auc: 0.754177	valid1's auc: 0.732267
# [109]	train's auc: 0.754482	valid1's auc: 0.732316
# [110]	train's auc: 0.754737	valid1's auc: 0.732343
# [111]	train's auc: 0.754922	valid1's auc: 0.732382
# [112]	train's auc: 0.755308	valid1's auc: 0.732356
# [113]	train's auc: 0.755647	valid1's auc: 0.732397
# [114]	train's auc: 0.755846	valid1's auc: 0.73242
# [115]	train's auc: 0.756076	valid1's auc: 0.73247
# [116]	train's auc: 0.756362	valid1's auc: 0.732493
# [117]	train's auc: 0.756557	valid1's auc: 0.732528
# [118]	train's auc: 0.756802	valid1's auc: 0.732577
# [119]	train's auc: 0.757127	valid1's auc: 0.732676
# [120]	train's auc: 0.757528	valid1's auc: 0.732853
# [121]	train's auc: 0.75774	valid1's auc: 0.73292
# [122]	train's auc: 0.758134	valid1's auc: 0.732991
# [123]	train's auc: 0.758503	valid1's auc: 0.73311
# [124]	train's auc: 0.758801	valid1's auc: 0.733134
# [125]	train's auc: 0.759006	valid1's auc: 0.733191
# [126]	train's auc: 0.759202	valid1's auc: 0.733223
# [127]	train's auc: 0.759475	valid1's auc: 0.733233
# [128]	train's auc: 0.759757	valid1's auc: 0.733265
# [129]	train's auc: 0.760177	valid1's auc: 0.733463
# [130]	train's auc: 0.760394	valid1's auc: 0.733511
# [131]	train's auc: 0.760609	valid1's auc: 0.73357
# [132]	train's auc: 0.760857	valid1's auc: 0.733656
# [133]	train's auc: 0.761154	valid1's auc: 0.733699
# [134]	train's auc: 0.761409	valid1's auc: 0.733749
# [135]	train's auc: 0.761588	valid1's auc: 0.733761
# [136]	train's auc: 0.76186	valid1's auc: 0.73377
# [137]	train's auc: 0.762087	valid1's auc: 0.733781
# [138]	train's auc: 0.762329	valid1's auc: 0.733794
# [139]	train's auc: 0.762844	valid1's auc: 0.734045
# [140]	train's auc: 0.76314	valid1's auc: 0.73408
# [141]	train's auc: 0.763386	valid1's auc: 0.7341
# [142]	train's auc: 0.763545	valid1's auc: 0.734119
# [143]	train's auc: 0.763706	valid1's auc: 0.734128
# [144]	train's auc: 0.763901	valid1's auc: 0.734157
# [145]	train's auc: 0.764158	valid1's auc: 0.734207
# [146]	train's auc: 0.764362	valid1's auc: 0.734239
# [147]	train's auc: 0.764674	valid1's auc: 0.734263
# [148]	train's auc: 0.764937	valid1's auc: 0.734268
# [149]	train's auc: 0.765136	valid1's auc: 0.734287
# [150]	train's auc: 0.765374	valid1's auc: 0.73431
# [151]	train's auc: 0.765618	valid1's auc: 0.734385
# [152]	train's auc: 0.765853	valid1's auc: 0.734469
# [153]	train's auc: 0.766025	valid1's auc: 0.734485
# [154]	train's auc: 0.766191	valid1's auc: 0.734485
# [155]	train's auc: 0.766504	valid1's auc: 0.734563
# [156]	train's auc: 0.766714	valid1's auc: 0.734573
# [157]	train's auc: 0.766911	valid1's auc: 0.734605
# [158]	train's auc: 0.767153	valid1's auc: 0.734612
# [159]	train's auc: 0.767378	valid1's auc: 0.734619
# [160]	train's auc: 0.767566	valid1's auc: 0.734661
# [161]	train's auc: 0.767862	valid1's auc: 0.734748
# [162]	train's auc: 0.76803	valid1's auc: 0.734756
# [163]	train's auc: 0.768197	valid1's auc: 0.734775
# [164]	train's auc: 0.768367	valid1's auc: 0.734771
# [165]	train's auc: 0.768622	valid1's auc: 0.734768
# [166]	train's auc: 0.769141	valid1's auc: 0.73508
# [167]	train's auc: 0.769274	valid1's auc: 0.735092
# [168]	train's auc: 0.769514	valid1's auc: 0.735082
# [169]	train's auc: 0.769854	valid1's auc: 0.735141
# [170]	train's auc: 0.770032	valid1's auc: 0.735159
# [171]	train's auc: 0.770162	valid1's auc: 0.735189
# [172]	train's auc: 0.77027	valid1's auc: 0.735196
# [173]	train's auc: 0.770401	valid1's auc: 0.735208
# [174]	train's auc: 0.770581	valid1's auc: 0.73521
# [175]	train's auc: 0.770794	valid1's auc: 0.735225
# [176]	train's auc: 0.770999	valid1's auc: 0.735229
# [177]	train's auc: 0.771186	valid1's auc: 0.735239
# [178]	train's auc: 0.771463	valid1's auc: 0.735232
# [179]	train's auc: 0.771721	valid1's auc: 0.735213
# [180]	train's auc: 0.771926	valid1's auc: 0.735213
# [181]	train's auc: 0.772241	valid1's auc: 0.735292
# [182]	train's auc: 0.772515	valid1's auc: 0.735307
# [183]	train's auc: 0.772692	valid1's auc: 0.735325
# [184]	train's auc: 0.772887	valid1's auc: 0.735361
# [185]	train's auc: 0.773173	valid1's auc: 0.735393
# [186]	train's auc: 0.77338	valid1's auc: 0.735384
# [187]	train's auc: 0.773491	valid1's auc: 0.735374
# [188]	train's auc: 0.773745	valid1's auc: 0.735366
# [189]	train's auc: 0.773956	valid1's auc: 0.735353
# [190]	train's auc: 0.774156	valid1's auc: 0.735335
# [191]	train's auc: 0.77436	valid1's auc: 0.735352
# [192]	train's auc: 0.774578	valid1's auc: 0.735344
# [193]	train's auc: 0.774797	valid1's auc: 0.735365
# [194]	train's auc: 0.775013	valid1's auc: 0.735423
# [195]	train's auc: 0.775148	valid1's auc: 0.735464
# [196]	train's auc: 0.775307	valid1's auc: 0.735494
# [197]	train's auc: 0.775516	valid1's auc: 0.73548
# [198]	train's auc: 0.775659	valid1's auc: 0.735484
# [199]	train's auc: 0.775822	valid1's auc: 0.735541
# [200]	train's auc: 0.77606	valid1's auc: 0.73556
# [201]	train's auc: 0.776251	valid1's auc: 0.735554
# [202]	train's auc: 0.776417	valid1's auc: 0.735598
# [203]	train's auc: 0.776542	valid1's auc: 0.73559
# [204]	train's auc: 0.776634	valid1's auc: 0.735605
# [205]	train's auc: 0.776818	valid1's auc: 0.735601
# [206]	train's auc: 0.777091	valid1's auc: 0.735643
# [207]	train's auc: 0.777302	valid1's auc: 0.735628
# [208]	train's auc: 0.777643	valid1's auc: 0.735656
# [209]	train's auc: 0.777843	valid1's auc: 0.735652
# [210]	train's auc: 0.77793	valid1's auc: 0.735634
# [211]	train's auc: 0.77814	valid1's auc: 0.735653
# [212]	train's auc: 0.778284	valid1's auc: 0.735655
# [213]	train's auc: 0.77867	valid1's auc: 0.73588
# [214]	train's auc: 0.778879	valid1's auc: 0.735861
# [215]	train's auc: 0.779027	valid1's auc: 0.735877
# [216]	train's auc: 0.77927	valid1's auc: 0.735869
# [217]	train's auc: 0.779449	valid1's auc: 0.735886
# [218]	train's auc: 0.779676	valid1's auc: 0.735871
# [219]	train's auc: 0.779861	valid1's auc: 0.735864
# [220]	train's auc: 0.779928	valid1's auc: 0.735854
# [221]	train's auc: 0.779986	valid1's auc: 0.735851
# [222]	train's auc: 0.780213	valid1's auc: 0.735845
# [223]	train's auc: 0.780396	valid1's auc: 0.735848
# [224]	train's auc: 0.780526	valid1's auc: 0.735848
# [225]	train's auc: 0.780684	valid1's auc: 0.735855
# [226]	train's auc: 0.780734	valid1's auc: 0.735859
# [227]	train's auc: 0.780854	valid1's auc: 0.735857
# [228]	train's auc: 0.781124	valid1's auc: 0.735918
# [229]	train's auc: 0.781337	valid1's auc: 0.735918
# [230]	train's auc: 0.781495	valid1's auc: 0.735908
# [231]	train's auc: 0.781645	valid1's auc: 0.735938
# [232]	train's auc: 0.78174	valid1's auc: 0.735949
# [233]	train's auc: 0.781931	valid1's auc: 0.735992
# [234]	train's auc: 0.782082	valid1's auc: 0.735997
# [235]	train's auc: 0.782244	valid1's auc: 0.736034
# [236]	train's auc: 0.78243	valid1's auc: 0.736051
# [237]	train's auc: 0.782629	valid1's auc: 0.736034
# [238]	train's auc: 0.782813	valid1's auc: 0.736025
# [239]	train's auc: 0.783016	valid1's auc: 0.736015
# [240]	train's auc: 0.783185	valid1's auc: 0.736024
# [241]	train's auc: 0.78332	valid1's auc: 0.736019
# [242]	train's auc: 0.783489	valid1's auc: 0.736029
# [243]	train's auc: 0.783663	valid1's auc: 0.736028
# [244]	train's auc: 0.783815	valid1's auc: 0.736023
# [245]	train's auc: 0.784004	valid1's auc: 0.736038
# [246]	train's auc: 0.784111	valid1's auc: 0.73604
# [247]	train's auc: 0.784269	valid1's auc: 0.736042
# [248]	train's auc: 0.784425	valid1's auc: 0.736041
# [249]	train's auc: 0.784608	valid1's auc: 0.736045
# [250]	train's auc: 0.784836	valid1's auc: 0.736015
# [251]	train's auc: 0.784955	valid1's auc: 0.736003
# [252]	train's auc: 0.785107	valid1's auc: 0.735999
# [253]	train's auc: 0.785207	valid1's auc: 0.735999
# [254]	train's auc: 0.785409	valid1's auc: 0.736005
# [255]	train's auc: 0.785527	valid1's auc: 0.735999
# [256]	train's auc: 0.785687	valid1's auc: 0.73599
# [257]	train's auc: 0.785809	valid1's auc: 0.736002
# [258]	train's auc: 0.785872	valid1's auc: 0.735992
# [259]	train's auc: 0.786027	valid1's auc: 0.735979
# [260]	train's auc: 0.786224	valid1's auc: 0.735961
# [261]	train's auc: 0.786348	valid1's auc: 0.735958
# [262]	train's auc: 0.786463	valid1's auc: 0.73596
# [263]	train's auc: 0.786635	valid1's auc: 0.73595
# [264]	train's auc: 0.786957	valid1's auc: 0.736029
# [265]	train's auc: 0.787232	valid1's auc: 0.736011
# [266]	train's auc: 0.787365	valid1's auc: 0.736013
# [267]	train's auc: 0.78745	valid1's auc: 0.736027
# [268]	train's auc: 0.787553	valid1's auc: 0.736031
# [269]	train's auc: 0.787809	valid1's auc: 0.736114
# [270]	train's auc: 0.788099	valid1's auc: 0.73612
# [271]	train's auc: 0.788246	valid1's auc: 0.736119
# [272]	train's auc: 0.788413	valid1's auc: 0.736118
# [273]	train's auc: 0.788536	valid1's auc: 0.736106
# [274]	train's auc: 0.788673	valid1's auc: 0.736117
# [275]	train's auc: 0.788901	valid1's auc: 0.736126
# [276]	train's auc: 0.789174	valid1's auc: 0.73613
# [277]	train's auc: 0.789384	valid1's auc: 0.73613
# [278]	train's auc: 0.789516	valid1's auc: 0.736116
# [279]	train's auc: 0.78961	valid1's auc: 0.736128
# [280]	train's auc: 0.789772	valid1's auc: 0.736126
# [281]	train's auc: 0.789896	valid1's auc: 0.736122
# [282]	train's auc: 0.790025	valid1's auc: 0.736128
# [283]	train's auc: 0.790188	valid1's auc: 0.736108
# [284]	train's auc: 0.790383	valid1's auc: 0.736112
# [285]	train's auc: 0.790672	valid1's auc: 0.736167
# [286]	train's auc: 0.79087	valid1's auc: 0.736172
# [287]	train's auc: 0.791003	valid1's auc: 0.736161
# [288]	train's auc: 0.791221	valid1's auc: 0.736147
# [289]	train's auc: 0.791418	valid1's auc: 0.736135
# [290]	train's auc: 0.791506	valid1's auc: 0.736147
# [291]	train's auc: 0.791584	valid1's auc: 0.736133
# [292]	train's auc: 0.791743	valid1's auc: 0.736137
# [293]	train's auc: 0.791935	valid1's auc: 0.736108
# [294]	train's auc: 0.792084	valid1's auc: 0.736111
# [295]	train's auc: 0.792184	valid1's auc: 0.736126
# [296]	train's auc: 0.792214	valid1's auc: 0.736122
# [297]	train's auc: 0.792334	valid1's auc: 0.73613
# [298]	train's auc: 0.792441	valid1's auc: 0.736125
# [299]	train's auc: 0.79255	valid1's auc: 0.736111
# [300]	train's auc: 0.792685	valid1's auc: 0.736119
# [301]	train's auc: 0.792826	valid1's auc: 0.736114
# [302]	train's auc: 0.793016	valid1's auc: 0.736102
# [303]	train's auc: 0.793101	valid1's auc: 0.736112
# [304]	train's auc: 0.793194	valid1's auc: 0.736117
# [305]	train's auc: 0.793419	valid1's auc: 0.736102
# [306]	train's auc: 0.793637	valid1's auc: 0.736096
# [307]	train's auc: 0.793734	valid1's auc: 0.736088
# [308]	train's auc: 0.794097	valid1's auc: 0.736165
# [309]	train's auc: 0.794275	valid1's auc: 0.736164
# [310]	train's auc: 0.794338	valid1's auc: 0.736168
# [311]	train's auc: 0.794476	valid1's auc: 0.736169
# [312]	train's auc: 0.794627	valid1's auc: 0.736147
# [313]	train's auc: 0.794795	valid1's auc: 0.736132
# [314]	train's auc: 0.794946	valid1's auc: 0.736132
# [315]	train's auc: 0.79509	valid1's auc: 0.736114
# [316]	train's auc: 0.795221	valid1's auc: 0.736117
# [317]	train's auc: 0.795289	valid1's auc: 0.736114
# [318]	train's auc: 0.79547	valid1's auc: 0.736111
# [319]	train's auc: 0.795621	valid1's auc: 0.736084
# [320]	train's auc: 0.795738	valid1's auc: 0.736064
# [321]	train's auc: 0.79591	valid1's auc: 0.736053
# [322]	train's auc: 0.796017	valid1's auc: 0.73606
# [323]	train's auc: 0.796121	valid1's auc: 0.736052
# [324]	train's auc: 0.79629	valid1's auc: 0.736062
# [325]	train's auc: 0.796439	valid1's auc: 0.736052
# [326]	train's auc: 0.796688	valid1's auc: 0.736081
# [327]	train's auc: 0.796792	valid1's auc: 0.736067
# [328]	train's auc: 0.796914	valid1's auc: 0.736072
# [329]	train's auc: 0.797083	valid1's auc: 0.736072
# [330]	train's auc: 0.797163	valid1's auc: 0.736061
# [331]	train's auc: 0.797273	valid1's auc: 0.736047
# [332]	train's auc: 0.797413	valid1's auc: 0.73607
# [333]	train's auc: 0.7976	valid1's auc: 0.736076
# [334]	train's auc: 0.797773	valid1's auc: 0.736188
# [335]	train's auc: 0.797988	valid1's auc: 0.736194
# [336]	train's auc: 0.798136	valid1's auc: 0.736206
# [337]	train's auc: 0.798317	valid1's auc: 0.73619
# [338]	train's auc: 0.798529	valid1's auc: 0.736184
# [339]	train's auc: 0.798577	valid1's auc: 0.736178
# [340]	train's auc: 0.798727	valid1's auc: 0.736171
# [341]	train's auc: 0.798849	valid1's auc: 0.736145
# [342]	train's auc: 0.798947	valid1's auc: 0.736146
# [343]	train's auc: 0.799074	valid1's auc: 0.736179
# [344]	train's auc: 0.799214	valid1's auc: 0.736158
# [345]	train's auc: 0.799445	valid1's auc: 0.736139
# [346]	train's auc: 0.799601	valid1's auc: 0.736122
# [347]	train's auc: 0.79972	valid1's auc: 0.7361
# [348]	train's auc: 0.799876	valid1's auc: 0.736083
# [349]	train's auc: 0.799992	valid1's auc: 0.736085
# [350]	train's auc: 0.800078	valid1's auc: 0.736068
# [351]	train's auc: 0.800203	valid1's auc: 0.736064
# [352]	train's auc: 0.800269	valid1's auc: 0.736048
# [353]	train's auc: 0.800423	valid1's auc: 0.736048
# [354]	train's auc: 0.800529	valid1's auc: 0.736047
# [355]	train's auc: 0.800746	valid1's auc: 0.736029
# [356]	train's auc: 0.800836	valid1's auc: 0.736012
# [357]	train's auc: 0.800906	valid1's auc: 0.736015
# [358]	train's auc: 0.801004	valid1's auc: 0.736009
# [359]	train's auc: 0.801134	valid1's auc: 0.736005
# [360]	train's auc: 0.801276	valid1's auc: 0.736005
# [361]	train's auc: 0.801467	valid1's auc: 0.736014
# [362]	train's auc: 0.801608	valid1's auc: 0.736003
# [363]	train's auc: 0.801703	valid1's auc: 0.736001
# [364]	train's auc: 0.801824	valid1's auc: 0.735992
# [365]	train's auc: 0.80194	valid1's auc: 0.736015
# [366]	train's auc: 0.802078	valid1's auc: 0.736012
# [367]	train's auc: 0.802275	valid1's auc: 0.736032
# [368]	train's auc: 0.802399	valid1's auc: 0.736025
# [369]	train's auc: 0.802545	valid1's auc: 0.735998
# [370]	train's auc: 0.8027	valid1's auc: 0.735987
# [371]	train's auc: 0.802834	valid1's auc: 0.736011
# [372]	train's auc: 0.802989	valid1's auc: 0.736001
# [373]	train's auc: 0.803078	valid1's auc: 0.735998
# [374]	train's auc: 0.803185	valid1's auc: 0.736028
# [375]	train's auc: 0.803269	valid1's auc: 0.736042
# [376]	train's auc: 0.803406	valid1's auc: 0.736022
# [377]	train's auc: 0.803487	valid1's auc: 0.736019
# [378]	train's auc: 0.80364	valid1's auc: 0.736027
# [379]	train's auc: 0.803711	valid1's auc: 0.736022
# [380]	train's auc: 0.803804	valid1's auc: 0.736018
# [381]	train's auc: 0.803858	valid1's auc: 0.736026
# [382]	train's auc: 0.803961	valid1's auc: 0.736016
# [383]	train's auc: 0.80404	valid1's auc: 0.736016
# [384]	train's auc: 0.804116	valid1's auc: 0.736003
# [385]	train's auc: 0.804302	valid1's auc: 0.736013
# [386]	train's auc: 0.804483	valid1's auc: 0.736015
# Early stopping, best iteration is:
# [336]	train's auc: 0.798136	valid1's auc: 0.736206

# %%
log_file = 'v2.feature_importance.csv'
log_path = os.path.join(log_folder, log_file)

df_feature_importance = pd.DataFrame({"feature": cols, "importance": lgbm.feature_importance()})
df_feature_importance = df_feature_importance.sort_values("importance", ascending=False)
df_feature_importance.to_csv(log_path, index=False)
df_feature_importance.head(30)
# Out:
#                                      feature  importance
# 419701                 bsClickrate@aid_x_age        1301
# 419707                 bsClickrate@aid_x_LBS        1138
# 419705  bsClickrate@aid_x_consumptionAbility        1111
# 419703           bsClickrate@aid_x_education         994
# 419708                  impression@aid_x_LBS         858
# 419702                  impression@aid_x_age         696
# 419704            impression@aid_x_education         639
# 419706   impression@aid_x_consumptionAbility         635
# 419614                       creativeSize_59         287
# 419610                       creativeSize_22         196
# 419207                                  ct_1         157
# 1057                            interest2_54         156
# 419699                         productType_9         154
# 1092                         interest2_[nan]         146
# 419611                       creativeSize_35         134
# 915                             interest1_49         130
# 6                                   gender_2         117
# 419697                         productType_4         116
# 1061                            interest2_10         115
# 11                         marriageStatus_10         114
# 419640                       adCategoryId_51         111
# 1003                             interest1_6         100
# 419214                             carrier_1          97
# 419612                       creativeSize_42          97
# 902                             interest1_70          96
# 1002                            interest1_76          95
# 419630                       adCategoryId_21          93
# 1025                            interest2_63          88
# 419211                                  os_1          86
# 1082                            interest2_52          86

# %%
with pu.profiler("cleaning memory"):
    del lgb_train
    del lgb_valid
    del X_train
    del X_valid
    gc.collect()
# Out:
# [16:56:40] Finish cleaning memory. △M: -12.12GB. △T: 1.8 seconds.

# %%
with pu.profiler("loading binary features"):
    bin_cols, X_bin = load_binary("test")

with pu.profiler("loading multi value count features"):
    ckr_cols, X_ckr = load_stacking_bs_clickrate("test")
    
assert X_bin.shape[1] == len(bin_cols)
assert X_ckr.shape[1] == len(ckr_cols)
assert X_bin.shape[0] == X_ckr.shape[0]
print("Binary Feature Shape: {}".format(X_bin.shape))
print("Cross Clicks Feature Shape: {}".format(X_ckr.shape))

with pu.profiler("joining data"):
    cols = bin_cols + ckr_cols
    X = sparse.hstack((X_bin, X_ckr))
    X = sparse.csr_matrix(X)
    del X_bin
    del X_ckr
    gc.collect()
    
print("Joined Data Shape: {}".format(X.shape))
print("Feature Names Count: {}".format(len(cols)))
print("Memory usage at this moment :{}".format(pu.get_memory_str()))
# Out:
# [16:59:54] Finish loading binary features. △M: +676.47MB. △T: 1.1 seconds.
# [16:59:54] Finish loading multi value count features. △M: +0B. △T: 0.0 seconds.
# Binary Feature Shape: (2265989, 419701)
# Cross Clicks Feature Shape: (2265989, 8)
# [17:00:02] Finish joining data. △M: +814.61MB. △T: 8.4 seconds.
# Joined Data Shape: (2265989, 419709)
# Feature Names Count: 419709
# Memory usage at this moment :4.51GB

# %%
df_test = du.load_raw_data("test")
X = X.astype(np.float32)

with pu.profiler("making prediction on testing set"):
    proba_test = lgbm.predict(X)
    assert len(proba_test.shape) == 1
    assert proba_test.shape[0] == df_test.shape[0]
# Out:
# [17:00:44] Finish making prediction on testing set. △M: +16.0KB. △T: 32.0 seconds.

# %%
subm_folder = '../../../subm/lgbm/0505_v2'
subm_file = 'submission.csv'
subm_path = os.path.join(subm_folder, subm_file)
os.makedirs(subm_folder, exist_ok=True)

subm = df_test.copy()
subm["score"] = proba_test
subm.to_csv(subm_path, index=False)
