# %%
from sklearn.model_selection import StratifiedKFold
from collections import Counter
import lightgbm as lgb
import scipy.sparse as sparse
import pandas as pd
import numpy as np
import tqdm
import gc
import os
import sys
sys.path.append('../../../code/utils')
import data_utils as du
import perf_utils as pu

# %%
df_train = du.load_raw_data("train")
df_test = du.load_raw_data("test")
df_ad = du.load_raw_data("ad")

# %%
user_one_feat_names = ['age', 'gender', 'education', 'consumptionAbility', 'LBS',
                  'carrier', 'house']  # one user has only one value
user_multi_feat_names = ['marriageStatus', 'interest1', 'interest2', 'interest3',
                   'interest4', 'interest5', 'kw1', 'kw2', 'kw3', 'topic1',
                   'topic2', 'topic3', 'appIdInstall', 'appIdAction', 'ct', 'os']  # one user can have more than one value
user_feat_names = user_one_feat_names + user_multi_feat_names

# %%
ad_num_feat_names = ['creativeSize']
ad_cat_feat_names = ['advertiserId', 'campaignId', 'creativeId', 'adCategoryId', 'productId', 'productType']
ad_feat_names = ad_num_feat_names + ad_cat_feat_names

# %%
# both 'creativeId' and 'aid' are unique to advertise. so you can do nothing actually
# I just remove 'creativeId' and add 'aid' to make my intention clearer
ad_feat_names.remove("creativeId")  # every ad has a unique 'creativeId', so it's useless
ad_feat_names.append("aid")

# %%
with pu.profiler("loading and joining user and ad data"):
    X, feat_names = du.quick_join(ad_user=df_train, 
                                  user_feat_names=user_feat_names, 
                                  ad_feat_names=ad_feat_names)
    gc.collect()
print("Combined Matrix Shape: {}".format(X.shape))
print("Feature Names Count: {}".format(len(feat_names)))
print("Memory usage at this moment :{}".format(pu.get_memory_str()))
# Out:
# loading user matrices: 100%|██████████| 23/23 [12:34<00:00, 32.81s/it]
# loading ad matrices: 100%|██████████| 7/7 [01:44<00:00, 14.89s/it]
# [00:59:49] Finish loading and joining user and ad data. △M: +5.81GB. △T: 14.3 minutes.
# Combined Matrix Shape: (8798814, 419701)
# Feature Names Count: 419701
# Memory usage at this moment :6.14GB

# %%
y = df_train['label'].values
y = (y + 1) / 2
assert X.shape[0] == y.shape[0]

# %%
n_splits = 3  # use 3 instead of 5 to save time
skf = StratifiedKFold(n_splits=n_splits)
split_indices = [(train_index, valid_index) for train_index, valid_index in skf.split(df_train, y)]

# %%
X = sparse.csr_matrix(X)

# %%
train_index, valid_index = split_indices[0]

X_train, y_train = X[train_index, :], y[train_index]
X_valid, y_valid = X[valid_index, :], y[valid_index]

lgb_train = lgb.Dataset(X_train.astype(np.float32), y_train, feature_name=feat_names)
lgb_valid = lgb.Dataset(X_valid.astype(np.float32), y_valid, feature_name=feat_names)

# %%
params = {
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': 'auc',
    'max_depth': 15,
    'num_leaves': 120,
    'learning_rate': 0.15,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'verbose': 0
}
num_rounds = 500

lgbm = lgb.train(params,
                 lgb_train,
                 num_boost_round=num_rounds,
                 valid_sets=[lgb_train, lgb_valid], 
                 valid_names=['train', 'valid1'],
                 early_stopping_rounds=50)
# Out:
# [1]	train's auc: 0.663996	valid1's auc: 0.664082
# Training until validation scores don't improve for 50 rounds.
# [2]	train's auc: 0.674166	valid1's auc: 0.674161
# [3]	train's auc: 0.676528	valid1's auc: 0.676847
# [4]	train's auc: 0.677957	valid1's auc: 0.678417
# [5]	train's auc: 0.679264	valid1's auc: 0.679473
# [6]	train's auc: 0.679408	valid1's auc: 0.679541
# [7]	train's auc: 0.681295	valid1's auc: 0.681196
# [8]	train's auc: 0.682295	valid1's auc: 0.682272
# [9]	train's auc: 0.683165	valid1's auc: 0.683265
# [10]	train's auc: 0.684418	valid1's auc: 0.684477
# [11]	train's auc: 0.687867	valid1's auc: 0.68775
# [12]	train's auc: 0.688314	valid1's auc: 0.688098
# [13]	train's auc: 0.689342	valid1's auc: 0.689092
# [14]	train's auc: 0.690479	valid1's auc: 0.690262
# [15]	train's auc: 0.691191	valid1's auc: 0.690887
# [16]	train's auc: 0.693681	valid1's auc: 0.693229
# [17]	train's auc: 0.69461	valid1's auc: 0.694095
# [18]	train's auc: 0.695607	valid1's auc: 0.695136
# [237]	train's auc: 0.778906	valid1's auc: 0.735139
# [238]	train's auc: 0.778979	valid1's auc: 0.735137
# [239]	train's auc: 0.779315	valid1's auc: 0.735237
# [240]	train's auc: 0.779547	valid1's auc: 0.735235
# [241]	train's auc: 0.779684	valid1's auc: 0.735226
# [242]	train's auc: 0.779926	valid1's auc: 0.735249
# [243]	train's auc: 0.78013	valid1's auc: 0.73527
# [244]	train's auc: 0.780258	valid1's auc: 0.735267
# [245]	train's auc: 0.780433	valid1's auc: 0.735277
# [246]	train's auc: 0.780598	valid1's auc: 0.735282
# [247]	train's auc: 0.780749	valid1's auc: 0.735265
# [248]	train's auc: 0.780885	valid1's auc: 0.735266
# [249]	train's auc: 0.781003	valid1's auc: 0.735271
# [250]	train's auc: 0.781137	valid1's auc: 0.735283
# [251]	train's auc: 0.781253	valid1's auc: 0.735299
# [252]	train's auc: 0.781369	valid1's auc: 0.73532
# [253]	train's auc: 0.781507	valid1's auc: 0.735333
# [254]	train's auc: 0.781701	valid1's auc: 0.73539
# [255]	train's auc: 0.781904	valid1's auc: 0.735467
# [256]	train's auc: 0.782003	valid1's auc: 0.735484
# [257]	train's auc: 0.782131	valid1's auc: 0.735475
# [258]	train's auc: 0.782311	valid1's auc: 0.735482
# [259]	train's auc: 0.782441	valid1's auc: 0.735513
# [260]	train's auc: 0.782565	valid1's auc: 0.735491
# [261]	train's auc: 0.782726	valid1's auc: 0.735475
# [262]	train's auc: 0.782833	valid1's auc: 0.735477
# [263]	train's auc: 0.782987	valid1's auc: 0.735471
# [264]	train's auc: 0.783162	valid1's auc: 0.735462
# [265]	train's auc: 0.783293	valid1's auc: 0.735442
# [266]	train's auc: 0.783441	valid1's auc: 0.73546
# [267]	train's auc: 0.783641	valid1's auc: 0.735445
# [268]	train's auc: 0.783805	valid1's auc: 0.735441
# [269]	train's auc: 0.783952	valid1's auc: 0.735446
# [270]	train's auc: 0.784185	valid1's auc: 0.735435
# [271]	train's auc: 0.784306	valid1's auc: 0.735444
# [272]	train's auc: 0.784359	valid1's auc: 0.73542
# [273]	train's auc: 0.784515	valid1's auc: 0.735419
# [274]	train's auc: 0.7847	valid1's auc: 0.735435
# [275]	train's auc: 0.784858	valid1's auc: 0.735436
# [276]	train's auc: 0.78499	valid1's auc: 0.735418
# [277]	train's auc: 0.785137	valid1's auc: 0.735425
# [278]	train's auc: 0.785275	valid1's auc: 0.735423
# [279]	train's auc: 0.785468	valid1's auc: 0.735457
# [280]	train's auc: 0.785597	valid1's auc: 0.73546
# [281]	train's auc: 0.785747	valid1's auc: 0.735476
# [282]	train's auc: 0.785961	valid1's auc: 0.735483
# [283]	train's auc: 0.786115	valid1's auc: 0.735505
# [284]	train's auc: 0.78624	valid1's auc: 0.735516
# [285]	train's auc: 0.786571	valid1's auc: 0.735559
# [286]	train's auc: 0.786663	valid1's auc: 0.735574
# [287]	train's auc: 0.786813	valid1's auc: 0.735568
# [288]	train's auc: 0.787068	valid1's auc: 0.735599
# [289]	train's auc: 0.78721	valid1's auc: 0.735596
# [290]	train's auc: 0.787334	valid1's auc: 0.735592
# [291]	train's auc: 0.787453	valid1's auc: 0.735598
# [346]	train's auc: 0.79568	valid1's auc: 0.736096
# [347]	train's auc: 0.795808	valid1's auc: 0.736109
# [348]	train's auc: 0.796033	valid1's auc: 0.736153
# [349]	train's auc: 0.796145	valid1's auc: 0.736162
# [350]	train's auc: 0.796256	valid1's auc: 0.736139
# [351]	train's auc: 0.796395	valid1's auc: 0.73615
# [352]	train's auc: 0.796503	valid1's auc: 0.736158
# [353]	train's auc: 0.79656	valid1's auc: 0.736161
# [354]	train's auc: 0.796696	valid1's auc: 0.736147
# [355]	train's auc: 0.796862	valid1's auc: 0.736168
# [356]	train's auc: 0.796963	valid1's auc: 0.73619
# [357]	train's auc: 0.797109	valid1's auc: 0.736179
# [358]	train's auc: 0.797193	valid1's auc: 0.736165
# [359]	train's auc: 0.797258	valid1's auc: 0.736162
# [360]	train's auc: 0.797313	valid1's auc: 0.736143
# [361]	train's auc: 0.797386	valid1's auc: 0.736147
# [362]	train's auc: 0.797468	valid1's auc: 0.73615
# [363]	train's auc: 0.797629	valid1's auc: 0.736143
# [364]	train's auc: 0.797748	valid1's auc: 0.736151
# [365]	train's auc: 0.797836	valid1's auc: 0.736164
# [366]	train's auc: 0.797911	valid1's auc: 0.73615
# [367]	train's auc: 0.798128	valid1's auc: 0.73617
# [368]	train's auc: 0.798265	valid1's auc: 0.736145
# [369]	train's auc: 0.798401	valid1's auc: 0.736141
# [370]	train's auc: 0.798495	valid1's auc: 0.736153
# [371]	train's auc: 0.798667	valid1's auc: 0.736132
# [372]	train's auc: 0.798809	valid1's auc: 0.736105
# [373]	train's auc: 0.798947	valid1's auc: 0.736101
# [374]	train's auc: 0.799022	valid1's auc: 0.736097
# [375]	train's auc: 0.799134	valid1's auc: 0.736092
# [376]	train's auc: 0.799234	valid1's auc: 0.736091
# [377]	train's auc: 0.799398	valid1's auc: 0.736117
# [378]	train's auc: 0.799494	valid1's auc: 0.736091
# [379]	train's auc: 0.799641	valid1's auc: 0.736082
# [380]	train's auc: 0.799795	valid1's auc: 0.736087
# [381]	train's auc: 0.799934	valid1's auc: 0.736102
# Early stopping, best iteration is:
# [331]	train's auc: 0.793799	valid1's auc: 0.736201

# %%
df_feature_importance = pd.DataFrame({"feature": feat_names, "importance": lgbm.feature_importance()})

# %%
log_folder = "../../../log/lgbm/feature_importance"
log_file = "0430.csv"
log_path = os.path.join(log_folder, log_file)
os.makedirs(log_folder, exist_ok=True)

# %%
df_feature_importance = df_feature_importance.sort_values("importance", ascending=False)
df_feature_importance.to_csv(log_path, index=False)

# %%
df_feature_importance.head(30)
# Out:
#                      feature  importance
# 419224       creativeSize_59         360
# 3                      age_2         256
# 921             interest1_49         230
# 419220       creativeSize_22         228
# 419526         productType_9         206
# 419221       creativeSize_35         195
# 884        marriageStatus_10         192
# 419213                  ct_1         189
# 419524         productType_4         178
# 1063            interest2_54         171
# 1008            interest1_76         168
# 877                carrier_1         154
# 1                      age_1         145
# 419222       creativeSize_42         143
# 5                      age_5         139
# 18      consumptionAbility_1         139
# 11               education_7         134
# 6                   gender_2         134
# 1009             interest1_6         134
# 1220           interest5_129         133
# 1032            interest2_73         133
# 331690           topic1_9826         132
# 419467       adCategoryId_51         129
# 933             interest1_28         127
# 4                      age_3         125
# 890        marriageStatus_11         124
# 1249            interest5_72         121
# 1067            interest2_10         121
# 897             interest1_59         120
# 1039            interest2_70         120
