# %%
import pandas as pd
import numpy as np
import operator
import pickle
import os
import matplotlib.pyplot as plt
import sys
sys.path.append("../code/utils/")
import data_utils as du

# %%
df_train = du.load_raw_data("train")
aids = df_train["aid"].unique

# %%
aid_counts = df_train["aid"].value_counts()

# %%
sys.path.append("../code/analysis/")
from visualize_single_feature import SingleFeatureVisualizer

# %%
plt.close()
plt.figure(figsize=(40, 60))
plt.barh(aid_counts.index.astype('str'), aid_counts.values)
plt.title("'aid' Frequency in 'train.csv'", fontsize=22)
plt.xticks(fontsize=18, fontweight=700)
plt.yticks(fontsize=18, fontweight=700)
plt.gca().invert_yaxis()
plt.show()
