# %%
import scipy.sparse as sparse
import pandas as pd
import numpy as np
import tqdm
import sys
sys.path.append("../code/utils/")
sys.path.append("../code/analysis/")
import data_utils as du
from visualize_feature_cooccurrence import CooccurrenceVisualizer
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from glove import Glove

# %%
multi_feat_names = ['marriageStatus', 'interest1', 'interest2', 'interest3',
                   'interest4', 'interest5', 'kw1', 'kw2', 'kw3', 'topic1',
                   'topic2', 'topic3', 'appIdInstall', 'appIdAction', 'ct', 'os']  # 16 in total

# %%
df_train = du.load_raw_data("train")
df_ad = du.load_raw_data("ad")
aids = df_ad['aid'].values

# %%
# 'marriageStatus': 5
feat_name = 'interest1'
emb_dim = 10
val_index, cooc = du.load_preliminary_user_feature_coocurrence(feat_name)
glove = Glove(no_components=emb_dim, learning_rate=0.05)
glove.fit(cooc.tocoo().astype(np.float64), epochs=1000, verbose=False)

# word_vectors = glove.word_vectors
# cooc_glove = np.dot(word_vectors, word_vectors.T)
# cooc_glove = sparse.csr_matrix(cooc_glove)

# %%
# CooccurrenceVisualizer.plot_cooc(cooc_glove, val_index, feat_name)

# %%
word_vecs = {}
for val, index in val_index.items():
    word_vecs[val] = glove.word_vectors[index]

# %%
df_feat = du.load_user_feature(feat_name)
df_feat = df_feat.fillna("[nan]")
df_log = pd.DataFrame(columns=["model", "feature", "aid", "numRecords",
                               "binary_auc", "embedAvg_auc", "embedMax_auc"])
aids_selected = np.random.choice(aids, 20, replace=False)
valid_ratio = 0.3

for aid in aids_selected:
    # prepare common data
    print("Validating on [aid={}]...".format(aid))
    df_selected = df_train[df_train['aid']==aid].reset_index()
    y = df_selected['label'].values
    y = (y + 1) / 2
    num_users = df_selected.shape[0]
    train_size = int(num_users * (1 - valid_ratio))
    print("{} records selected.".format(num_users))
    
    # prepare embedding
    print("preparing data...")
    X_pool = []
    # for i in tqdm.tqdm(range(df_selected.shape[0])):
    #     row = df_selected.iloc[i]
    for i, row in df_selected.iterrows():
        # if i % 1000 == 0:
        #     print("{} done.".format(i))
        feat_str = df_feat[df_interest1["uid"]==row["uid"]][feat_name].values[0]
        try:
            feat_vals = feat_str.split()
            vecs = np.zeros((len(feat_vals), emb_dim))
            for i, feat in enumerate(feat_vals):
                vecs[i] += word_vecs[feat]
        except AttributeError:
            vecs = np.zeros((1, emb_dim))
            vecs[0] = word_vecs["[nan]"]
        X_pool.append(vecs)
    print("{} done.".format(num_users))

    # =====================
    # train on binary input
    # =====================
    # prepare data
    uids, (ufeat_index, uvec) = du.load_user_cnt(feat_name)
    uid_to_index = dict(zip(uids, list(range(len(uids)))))  # mapping from uids to distinct indices
    u_index = df_selected['uid'].map(uid_to_index).values
    X_binary = uvec[u_index,:]

    # split train/valid set
    X_train, y_train = X_binary[:train_size], y[:train_size]
    X_valid, y_valid = X_binary[train_size:], y[train_size:]

    # normal LR
    lr = LogisticRegression()
    lr.fit(X_train, y_train)
    proba_valid = lr.predict_proba(X_valid)
    auc_bin = metrics.roc_auc_score(y_valid, proba_valid[:, 1])
    logloss_bin = metrics.log_loss(y_valid, proba_valid[:, 1])
    print("[On Binary Input] AUC: {:.6f} logloss: {:.6f}".format(auc_bin, logloss_bin))
    
    # LR with balanced class weights
    lr = LogisticRegression(class_weight='balanced')
    lr.fit(X_train, y_train)
    proba_valid = lr.predict_proba(X_valid)
    auc_bin2 = metrics.roc_auc_score(y_valid, proba_valid[:, 1])
    logloss_bin2 = metrics.log_loss(y_valid, proba_valid[:, 1])
    print("[On Binary Input][Weighted] AUC: {:.6f} logloss: {:.6f}".format(auc_bin2, logloss_bin2))

    # =======================
    # average embedding input
    # =======================
    # prepare data
    X_avg = np.zeros((num_users, emb_dim))
    for i in range(num_users):
        X_avg[i] = X_pool[i].mean(axis=0)

    # split train/valid set
    X_train, y_train = X_avg[:train_size], y[:train_size]
    X_valid, y_valid = X_avg[train_size:], y[train_size:]

    # normal LR
    lr = LogisticRegression()
    lr.fit(X_train, y_train)
    proba_valid = lr.predict_proba(X_valid)
    auc_avg = metrics.roc_auc_score(y_valid, proba_valid[:, 1])
    logloss_avg = metrics.log_loss(y_valid, proba_valid[:, 1])
    print("[On Avg Embedding Input] AUC: {:.6f} logloss: {:.6f}".format(auc_avg, logloss_avg))
    
    # LR with balanced class weights
    lr = LogisticRegression(class_weight='balanced')
    lr.fit(X_train, y_train)
    proba_valid = lr.predict_proba(X_valid)
    auc_avg2 = metrics.roc_auc_score(y_valid, proba_valid[:, 1])
    logloss_avg2 = metrics.log_loss(y_valid, proba_valid[:, 1])
    print("[On Avg Embedding Input][Weighted] AUC: {:.6f} logloss: {:.6f}".format(auc_avg2, logloss_avg2))

    # ===================
    # max embedding input
    # ===================
    # prepare data
    X_max = np.zeros((num_users, emb_dim))
    for i in range(num_users):
        X_max[i] = X_pool[i].max(axis=0)

    # split train/valid set
    X_train, y_train = X_max[:train_size], y[:train_size]
    X_valid, y_valid = X_max[train_size:], y[train_size:]

    # normal LR
    lr = LogisticRegression()
    lr.fit(X_train, y_train)
    proba_valid = lr.predict_proba(X_valid)
    auc_max = metrics.roc_auc_score(y_valid, proba_valid[:, 1])
    logloss_max = metrics.log_loss(y_valid, proba_valid[:, 1])
    print("[On Max Embedding Input] AUC: {:.6f} logloss: {:.6f}".format(auc_max, logloss_max))
    
    # LR with balanced class weights
    lr = LogisticRegression(class_weight='balanced')
    lr.fit(X_train, y_train)
    proba_valid = lr.predict_proba(X_valid)
    auc_max2 = metrics.roc_auc_score(y_valid, proba_valid[:, 1])
    logloss_max2 = metrics.log_loss(y_valid, proba_valid[:, 1])
    print("[On Avg Embedding Input][Weighted] AUC: {:.6f} logloss: {:.6f}".format(auc_max2, logloss_max2))
    
    # ==========
    # update log
    # ==========
    df_log.loc[df_log.shape[0]] = {"model": "LR",
                                   "feature": feat_name,
                                   "aid": aid, 
                                   "numRecords": num_users,
                                   "binary_auc": auc_bin, 
                                   "embedAvg_auc": auc_avg,
                                   "embedMax_auc": auc_max}
    df_log.loc[df_log.shape[0]] = {"model": "LR[weighted]",
                                   "feature": feat_name,
                                   "aid": aid, 
                                   "numRecords": num_users,
                                   "binary_auc": auc_bin2, 
                                   "embedAvg_auc": auc_avg2,
                                   "embedMax_auc": auc_max2}
# Out:
# Validating on [aid=688]...
# 10224 records selected.
# preparing data...
# 10224 done.
# [On Binary Input] AUC: 0.667895 logloss: 0.184944
# [On Binary Input][Weighted] AUC: 0.655864 logloss: 0.622847
# [On Avg Embedding Input] AUC: 0.644558 logloss: 0.187240
# [On Avg Embedding Input][Weighted] AUC: 0.635217 logloss: 0.666936
# [On Max Embedding Input] AUC: 0.630995 logloss: 0.187754
# [On Avg Embedding Input][Weighted] AUC: 0.620564 logloss: 0.665548
# Validating on [aid=86]...
# 11917 records selected.
# preparing data...
# 11917 done.
# [On Binary Input] AUC: 0.562806 logloss: 0.196433
# [On Binary Input][Weighted] AUC: 0.565209 logloss: 0.644452
# [On Avg Embedding Input] AUC: 0.559907 logloss: 0.192360
# [On Avg Embedding Input][Weighted] AUC: 0.560754 logloss: 0.683189
# [On Max Embedding Input] AUC: 0.592499 logloss: 0.191048
# [On Avg Embedding Input][Weighted] AUC: 0.583355 logloss: 0.679888
# Validating on [aid=1991]...
# 12885 records selected.
# preparing data...
# 12885 done.
# [On Binary Input] AUC: 0.607147 logloss: 0.220931
# [On Binary Input][Weighted] AUC: 0.599473 logloss: 0.643547
# [On Avg Embedding Input] AUC: 0.606765 logloss: 0.217937
# [On Avg Embedding Input][Weighted] AUC: 0.603726 logloss: 0.673515
# [On Max Embedding Input] AUC: 0.553344 logloss: 0.220579
# [On Avg Embedding Input][Weighted] AUC: 0.552661 logloss: 0.676947
# Validating on [aid=686]...
# 22720 records selected.
# preparing data...
# 22720 done.
# [On Binary Input] AUC: 0.564838 logloss: 0.183365
# [On Binary Input][Weighted] AUC: 0.561420 logloss: 0.674445
# [On Avg Embedding Input] AUC: 0.550763 logloss: 0.182256
# [On Avg Embedding Input][Weighted] AUC: 0.547890 logloss: 0.685945
# [On Max Embedding Input] AUC: 0.553446 logloss: 0.182093
# [On Avg Embedding Input][Weighted] AUC: 0.542876 logloss: 0.686893
# Validating on [aid=1566]...
# 211522 records selected.
# preparing data...
# 211522 done.
# [On Binary Input] AUC: 0.595894 logloss: 0.190984
# [On Binary Input][Weighted] AUC: 0.596239 logloss: 0.676768
# [On Avg Embedding Input] AUC: 0.587114 logloss: 0.191983
# [On Avg Embedding Input][Weighted] AUC: 0.587265 logloss: 0.684817
# [On Max Embedding Input] AUC: 0.589892 logloss: 0.191714
# [On Avg Embedding Input][Weighted] AUC: 0.589522 logloss: 0.683467
# Validating on [aid=1671]...
# 12634 records selected.
# preparing data...
# 12634 done.
# [On Binary Input] AUC: 0.656687 logloss: 0.188268
# [On Binary Input][Weighted] AUC: 0.654147 logloss: 0.633917
# [On Avg Embedding Input] AUC: 0.646145 logloss: 0.188381
# [On Avg Embedding Input][Weighted] AUC: 0.656278 logloss: 0.668866
# [On Max Embedding Input] AUC: 0.614468 logloss: 0.189665
# [On Avg Embedding Input][Weighted] AUC: 0.625850 logloss: 0.672711
# Validating on [aid=1622]...
# 56201 records selected.
# preparing data...
# 56201 done.
# [On Binary Input] AUC: 0.669850 logloss: 0.183410
# [On Binary Input][Weighted] AUC: 0.667984 logloss: 0.631036
# [On Avg Embedding Input] AUC: 0.638277 logloss: 0.186602
# [On Avg Embedding Input][Weighted] AUC: 0.640910 logloss: 0.665266
# [On Max Embedding Input] AUC: 0.630491 logloss: 0.186672
# [On Avg Embedding Input][Weighted] AUC: 0.629876 logloss: 0.658581
# Validating on [aid=543]...
# 59535 records selected.
# preparing data...
# 59535 done.
# [On Binary Input] AUC: 0.610345 logloss: 0.183724
# [On Binary Input][Weighted] AUC: 0.609666 logloss: 0.667124
# [On Avg Embedding Input] AUC: 0.560182 logloss: 0.185832
# [On Avg Embedding Input][Weighted] AUC: 0.562315 logloss: 0.685384
# [On Max Embedding Input] AUC: 0.577340 logloss: 0.185155
# [On Avg Embedding Input][Weighted] AUC: 0.576313 logloss: 0.677940
# Validating on [aid=1847]...
# 8259 records selected.
# preparing data...
# 8259 done.
# [On Binary Input] AUC: 0.587643 logloss: 0.196605
# [On Binary Input][Weighted] AUC: 0.583917 logloss: 0.646760
# [On Avg Embedding Input] AUC: 0.584046 logloss: 0.194483
# [On Avg Embedding Input][Weighted] AUC: 0.587739 logloss: 0.674666
# [On Max Embedding Input] AUC: 0.574574 logloss: 0.194729
# [On Avg Embedding Input][Weighted] AUC: 0.571805 logloss: 0.673642
# Validating on [aid=1966]...
# 10894 records selected.
# preparing data...
# 10894 done.
# [On Binary Input] AUC: 0.545936 logloss: 0.178804
# [On Binary Input][Weighted] AUC: 0.549160 logloss: 0.651979
# [On Avg Embedding Input] AUC: 0.510887 logloss: 0.176409
# [On Avg Embedding Input][Weighted] AUC: 0.515348 logloss: 0.676602
# [On Max Embedding Input] AUC: 0.547870 logloss: 0.175282
# [On Avg Embedding Input][Weighted] AUC: 0.547261 logloss: 0.672623
# Validating on [aid=145]...
# 30441 records selected.
# preparing data...
# 30441 done.
# [On Binary Input] AUC: 0.608465 logloss: 0.177996
# [On Binary Input][Weighted] AUC: 0.606195 logloss: 0.664215
# [On Avg Embedding Input] AUC: 0.554721 logloss: 0.179403
# [On Avg Embedding Input][Weighted] AUC: 0.555305 logloss: 0.686602
# [On Max Embedding Input] AUC: 0.595756 logloss: 0.177660
# [On Avg Embedding Input][Weighted] AUC: 0.596697 logloss: 0.675929
# Validating on [aid=1819]...
# 28299 records selected.
# preparing data...
# 28299 done.
# [On Binary Input] AUC: 0.671998 logloss: 0.187057
# [On Binary Input][Weighted] AUC: 0.668487 logloss: 0.627758
# [On Avg Embedding Input] AUC: 0.631694 logloss: 0.190184
# [On Avg Embedding Input][Weighted] AUC: 0.635520 logloss: 0.661521
# [On Max Embedding Input] AUC: 0.643372 logloss: 0.189629
# [On Avg Embedding Input][Weighted] AUC: 0.642155 logloss: 0.661311
# Validating on [aid=671]...
# 9498 records selected.
# preparing data...
# 9498 done.
# [On Binary Input] AUC: 0.632321 logloss: 0.194332
# [On Binary Input][Weighted] AUC: 0.631059 logloss: 0.617620
# [On Avg Embedding Input] AUC: 0.616765 logloss: 0.194056
# [On Avg Embedding Input][Weighted] AUC: 0.623433 logloss: 0.667141
# [On Max Embedding Input] AUC: 0.600509 logloss: 0.194689
# [On Avg Embedding Input][Weighted] AUC: 0.609953 logloss: 0.656732
# Validating on [aid=1317]...
# 24985 records selected.
# preparing data...
# 24985 done.
# [On Binary Input] AUC: 0.560481 logloss: 0.188227
# [On Binary Input][Weighted] AUC: 0.556929 logloss: 0.674837
# [On Avg Embedding Input] AUC: 0.570108 logloss: 0.185499
# [On Avg Embedding Input][Weighted] AUC: 0.582776 logloss: 0.681789
# [On Max Embedding Input] AUC: 0.556592 logloss: 0.186221
# [On Avg Embedding Input][Weighted] AUC: 0.570626 logloss: 0.685122
# Validating on [aid=1377]...
# 86107 records selected.
# preparing data...
# 86107 done.
# [On Binary Input] AUC: 0.653334 logloss: 0.187745
# [On Binary Input][Weighted] AUC: 0.652370 logloss: 0.648864
# [On Avg Embedding Input] AUC: 0.621362 logloss: 0.191065
# [On Avg Embedding Input][Weighted] AUC: 0.620731 logloss: 0.671680
# [On Max Embedding Input] AUC: 0.631638 logloss: 0.189546
# [On Avg Embedding Input][Weighted] AUC: 0.631345 logloss: 0.664787
# Validating on [aid=1338]...
# 51460 records selected.
# preparing data...
# 51460 done.
# [On Binary Input] AUC: 0.646872 logloss: 0.184741
# [On Binary Input][Weighted] AUC: 0.644530 logloss: 0.654214
# [On Avg Embedding Input] AUC: 0.645705 logloss: 0.185280
# [On Avg Embedding Input][Weighted] AUC: 0.645131 logloss: 0.670729
# [On Max Embedding Input] AUC: 0.607718 logloss: 0.187393
# [On Avg Embedding Input][Weighted] AUC: 0.606562 logloss: 0.682315
# Validating on [aid=1027]...
# 9927 records selected.
# preparing data...
# 9927 done.
# [On Binary Input] AUC: 0.668119 logloss: 0.191667
# [On Binary Input][Weighted] AUC: 0.658697 logloss: 0.637065
# [On Avg Embedding Input] AUC: 0.639422 logloss: 0.192622
# [On Avg Embedding Input][Weighted] AUC: 0.640706 logloss: 0.673280
# [On Max Embedding Input] AUC: 0.646904 logloss: 0.191557
# [On Avg Embedding Input][Weighted] AUC: 0.642906 logloss: 0.669554
# Validating on [aid=681]...
# 21103 records selected.
# preparing data...
# 21103 done.
# [On Binary Input] AUC: 0.617061 logloss: 0.189691
# [On Binary Input][Weighted] AUC: 0.614287 logloss: 0.642904
# [On Avg Embedding Input] AUC: 0.585948 logloss: 0.190132
# [On Avg Embedding Input][Weighted] AUC: 0.580692 logloss: 0.680697
# [On Max Embedding Input] AUC: 0.596034 logloss: 0.189656
# [On Avg Embedding Input][Weighted] AUC: 0.593292 logloss: 0.681561
# Validating on [aid=1749]...
# 82076 records selected.
# preparing data...
# 82076 done.
# [On Binary Input] AUC: 0.591429 logloss: 0.184581
# [On Binary Input][Weighted] AUC: 0.588277 logloss: 0.671417
# [On Avg Embedding Input] AUC: 0.580955 logloss: 0.185046
# [On Avg Embedding Input][Weighted] AUC: 0.581286 logloss: 0.682649
# [On Max Embedding Input] AUC: 0.570533 logloss: 0.185346
# [On Avg Embedding Input][Weighted] AUC: 0.570346 logloss: 0.684827
# Validating on [aid=313]...
# 7031 records selected.
# preparing data...
# 7031 done.
# [On Binary Input] AUC: 0.666953 logloss: 0.167324
# [On Binary Input][Weighted] AUC: 0.635020 logloss: 0.630986
# [On Avg Embedding Input] AUC: 0.584637 logloss: 0.172309
# [On Avg Embedding Input][Weighted] AUC: 0.573302 logloss: 0.677408
# [On Max Embedding Input] AUC: 0.572776 logloss: 0.172063
# [On Avg Embedding Input][Weighted] AUC: 0.567932 logloss: 0.678767

# %%
df_log.groupby('model')[['binary_auc', 'embedAvg_auc', 'embedMax_auc']].mean()
# Out:
#               binary_auc  embedAvg_auc  embedMax_auc
# model
# LR              0.619304      0.595998      0.594338
# LR[weighted]    0.614946      0.596816      0.593595

# %%
df_log
# Out:
#            model    feature   aid numRecords  binary_auc  embedAvg_auc  \
# 0             LR  interest1   688      10224    0.667895      0.644558
# 1   LR[weighted]  interest1   688      10224    0.655864      0.635217
# 2             LR  interest1    86      11917    0.562806      0.559907
# 3   LR[weighted]  interest1    86      11917    0.565209      0.560754
# 4             LR  interest1  1991      12885    0.607147      0.606765
# 5   LR[weighted]  interest1  1991      12885    0.599473      0.603726
# 6             LR  interest1   686      22720    0.564838      0.550763
# 7   LR[weighted]  interest1   686      22720    0.561420      0.547890
# 8             LR  interest1  1566     211522    0.595894      0.587114
# 9   LR[weighted]  interest1  1566     211522    0.596239      0.587265
# 10            LR  interest1  1671      12634    0.656687      0.646145
# 11  LR[weighted]  interest1  1671      12634    0.654147      0.656278
# 12            LR  interest1  1622      56201    0.669850      0.638277
# 13  LR[weighted]  interest1  1622      56201    0.667984      0.640910
# 14            LR  interest1   543      59535    0.610345      0.560182
# 15  LR[weighted]  interest1   543      59535    0.609666      0.562315
# 16            LR  interest1  1847       8259    0.587643      0.584046
# 17  LR[weighted]  interest1  1847       8259    0.583917      0.587739
# 18            LR  interest1  1966      10894    0.545936      0.510887
# 19  LR[weighted]  interest1  1966      10894    0.549160      0.515348
# 20            LR  interest1   145      30441    0.608465      0.554721
# 21  LR[weighted]  interest1   145      30441    0.606195      0.555305
# 22            LR  interest1  1819      28299    0.671998      0.631694
# 23  LR[weighted]  interest1  1819      28299    0.668487      0.635520
# 24            LR  interest1   671       9498    0.632321      0.616765
# 25  LR[weighted]  interest1   671       9498    0.631059      0.623433
# 26            LR  interest1  1317      24985    0.560481      0.570108
# 27  LR[weighted]  interest1  1317      24985    0.556929      0.582776
# 28            LR  interest1  1377      86107    0.653334      0.621362
# 29  LR[weighted]  interest1  1377      86107    0.652370      0.620731
# 30            LR  interest1  1338      51460    0.646872      0.645705
# 31  LR[weighted]  interest1  1338      51460    0.644530      0.645131
# 32            LR  interest1  1027       9927    0.668119      0.639422
# 33  LR[weighted]  interest1  1027       9927    0.658697      0.640706
# 34            LR  interest1   681      21103    0.617061      0.585948
# 35  LR[weighted]  interest1   681      21103    0.614287      0.580692
# 36            LR  interest1  1749      82076    0.591429      0.580955
# 37  LR[weighted]  interest1  1749      82076    0.588277      0.581286
# 38            LR  interest1   313       7031    0.666953      0.584637
# 39  LR[weighted]  interest1   313       7031    0.635020      0.573302
#
#     embedMax_auc
# 0       0.630995
# 1       0.620564
# 2       0.592499
# 3       0.583355
# 4       0.553344
# 5       0.552661
# 6       0.553446
# 7       0.542876
# 8       0.589892
# 9       0.589522
# 10      0.614468
# 11      0.625850
# 12      0.630491
# 13      0.629876
# 14      0.577340
# 15      0.576313
# 16      0.574574
# 17      0.571805
# 18      0.547870
# 19      0.547261
# 20      0.595756
# 21      0.596697
# 22      0.643372
# 23      0.642155
# 24      0.600509
# 25      0.609953
# 26      0.556592
# 27      0.570626
# 28      0.631638
# 29      0.631345
# 30      0.607718
# 31      0.606562
# 32      0.646904
# 33      0.642906
# 34      0.596034
# 35      0.593292
# 36      0.570533
# 37      0.570346
# 38      0.572776
# 39      0.567932

# %%
# df_log[['binary_auc', 'embedAvg_auc', 'embedMax_auc']].mean()
# Out:
# binary_auc      0.553211
# embedAvg_auc    0.550122
# embedMax_auc    0.557878
# dtype: float64
