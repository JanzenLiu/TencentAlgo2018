# %%
from sklearn.model_selection import StratifiedShuffleSplit, StratifiedKFold
from sklearn import metrics
from contextlib import redirect_stdout
import scipy.sparse as sparse
import lightgbm as lgb
import pandas as pd
import numpy as np
import tqdm
import os
import gc
import sys
sys.path.append('../../../code/pipeline/')
sys.path.append('../../../code/utils/')
sys.path.append('../../../code/')
import data_pipeline as dp
import data_utils as du
import perf_utils as pu
import io_utils as iu
import config

# %%
# load multiple data and stack them together
dm = dp.DataManager(config.INPUT_DIR)
bin_loader = dm.build_data("raw", "binary")
lrstack_loader = dm.build_data("stacking", "lrSingleFeature_v1")
union_loader = dp.DataUnion(bin_loader, lrstack_loader)

with pu.profiler("loading training data"):
    cols_train, X_tv = union_loader.load("train")
    X_tv = sparse.csr_matrix(X_tv)
    gc.collect()

print("Train Data Shape: {}".format(X_tv.shape))
print("Train Column Numbers: {}".format(len(cols_train)))
# Out:
# [06:14:06] Finish loading training data. △M: +5.65GB. △T: 41.2 seconds.
# Train Data Shape: (8798814, 419708)
# Train Column Numbers: 419708

# %%
df_train = du.load_raw_data("train")
y = df_train['label'].values.copy()
y = (y + 1) / 2  # -1, 1 -> 0, 1

# %%
n_splits = 3
sss = StratifiedShuffleSplit(n_splits=n_splits, test_size=1 / 3, random_state=20180505)  # for reproducibility
split_indices = [(train_index, valid_index) for train_index, valid_index in sss.split(df_train, y)]

# n_splits = 3  # use 3 instead of 5 to save time
# skf = StratifiedKFold(n_splits=n_splits)
# split_indices = [(train_index, valid_index) for train_index, valid_index in skf.split(df_train, y)]

# %%
with pu.profiler("splitting train/valid set"):
    train_index, valid_index = split_indices[0]
    X_train, X_valid = X_tv[train_index, :], X_tv[valid_index, :]
    y_train, y_valid = y[train_index], y[valid_index]
    assert X_train.shape[0] + X_valid.shape[0] == X_tv.shape[0]
    
    del X_tv
    gc.collect()
    
print("Training Set Size: {}".format(X_train.shape))
print("Validation Set Size: {}".format(X_valid.shape))
# Out:
# [06:14:40] Finish splitting train/valid set. △M: +79.92MB. △T: 25.4 seconds.
# Training Set Size: (5865876, 419708)
# Validation Set Size: (2932938, 419708)

# %%
with pu.profiler("preparing LightGBM data"):
    lgb_train = lgb.Dataset(X_train.astype(np.float32), y_train, feature_name=cols_train)
    lgb_valid = lgb.Dataset(X_valid.astype(np.float32), y_valid, feature_name=cols_train)
    gc.collect()
# Out:
# [06:15:14] Finish preparing LightGBM data. △M: +5.58GB. △T: 4.1 seconds.

# %%
log_folder = os.path.join(config.LOG_DIR, 'lgbm/pipeline/0507/')
log_file = 'v1.log'
log_path = os.path.join(log_folder, log_file)
os.makedirs(log_folder, exist_ok=True)

# %%
params = {
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': 'auc',
    'max_depth': 15,
    'num_leaves': 120,
    'learning_rate': 0.15,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'verbose': 0
}
num_rounds = 500

with iu.DuplicatedLogger(log_path):
    lgbm = lgb.train(params,
                     lgb_train,
                     num_boost_round=num_rounds,
                     valid_sets=[lgb_train, lgb_valid], 
                     valid_names=['train', 'valid1'],
                     early_stopping_rounds=50)
# Out:
# [1]	train's auc: 0.678105	valid1's auc: 0.675381
# Training until validation scores don't improve for 50 rounds.
# [2]	train's auc: 0.686858	valid1's auc: 0.684212
# [3]	train's auc: 0.689127	valid1's auc: 0.686424
# [4]	train's auc: 0.689874	valid1's auc: 0.6872
# [5]	train's auc: 0.690997	valid1's auc: 0.688306
# [6]	train's auc: 0.692329	valid1's auc: 0.689584
# [7]	train's auc: 0.692651	valid1's auc: 0.689843
# [8]	train's auc: 0.693967	valid1's auc: 0.691168
# [9]	train's auc: 0.694863	valid1's auc: 0.691929
# [10]	train's auc: 0.6962	valid1's auc: 0.693234
# [11]	train's auc: 0.697218	valid1's auc: 0.69427
# [12]	train's auc: 0.697747	valid1's auc: 0.694756
# [13]	train's auc: 0.698762	valid1's auc: 0.695729
# [14]	train's auc: 0.701325	valid1's auc: 0.698184
# [15]	train's auc: 0.701986	valid1's auc: 0.698832
# [16]	train's auc: 0.703704	valid1's auc: 0.700516
# [17]	train's auc: 0.70449	valid1's auc: 0.701207
# [18]	train's auc: 0.705114	valid1's auc: 0.701784
# [19]	train's auc: 0.706062	valid1's auc: 0.702574
# [20]	train's auc: 0.707265	valid1's auc: 0.703738
# [21]	train's auc: 0.7081	valid1's auc: 0.704504
# [22]	train's auc: 0.708574	valid1's auc: 0.704942
# [23]	train's auc: 0.709176	valid1's auc: 0.705406
# [24]	train's auc: 0.710167	valid1's auc: 0.706325
# [25]	train's auc: 0.711164	valid1's auc: 0.707163
# [26]	train's auc: 0.712169	valid1's auc: 0.708088
# [27]	train's auc: 0.713097	valid1's auc: 0.708894
# [28]	train's auc: 0.713952	valid1's auc: 0.709736
# [29]	train's auc: 0.715078	valid1's auc: 0.710772
# [30]	train's auc: 0.715924	valid1's auc: 0.711438
# [31]	train's auc: 0.716844	valid1's auc: 0.712112
# [32]	train's auc: 0.71805	valid1's auc: 0.713227
# [33]	train's auc: 0.718952	valid1's auc: 0.714073
# [34]	train's auc: 0.719945	valid1's auc: 0.714921
# [35]	train's auc: 0.721057	valid1's auc: 0.715825
# [36]	train's auc: 0.722025	valid1's auc: 0.716547
# [37]	train's auc: 0.723068	valid1's auc: 0.717351
# [38]	train's auc: 0.723914	valid1's auc: 0.718
# [39]	train's auc: 0.724883	valid1's auc: 0.718752
# [40]	train's auc: 0.726086	valid1's auc: 0.719869
# [41]	train's auc: 0.72686	valid1's auc: 0.720436
# [42]	train's auc: 0.727836	valid1's auc: 0.721228
# [43]	train's auc: 0.728633	valid1's auc: 0.721869
# [44]	train's auc: 0.729307	valid1's auc: 0.7222
# [45]	train's auc: 0.729998	valid1's auc: 0.722631
# [46]	train's auc: 0.730944	valid1's auc: 0.723485
# [47]	train's auc: 0.731533	valid1's auc: 0.723816
# [48]	train's auc: 0.732362	valid1's auc: 0.724397
# [49]	train's auc: 0.732957	valid1's auc: 0.724817
# [50]	train's auc: 0.733595	valid1's auc: 0.725202
# [51]	train's auc: 0.734091	valid1's auc: 0.725459
# [52]	train's auc: 0.734611	valid1's auc: 0.725644
# [53]	train's auc: 0.735316	valid1's auc: 0.726161
# [54]	train's auc: 0.736079	valid1's auc: 0.726728
# [55]	train's auc: 0.736676	valid1's auc: 0.727067
# [56]	train's auc: 0.737088	valid1's auc: 0.727161
# [57]	train's auc: 0.73758	valid1's auc: 0.72744
# [58]	train's auc: 0.73817	valid1's auc: 0.727784
# [59]	train's auc: 0.73859	valid1's auc: 0.727915
# [60]	train's auc: 0.739189	valid1's auc: 0.728334
# [61]	train's auc: 0.739665	valid1's auc: 0.728559
# [62]	train's auc: 0.740059	valid1's auc: 0.728698
# [63]	train's auc: 0.740641	valid1's auc: 0.72906
# [64]	train's auc: 0.740988	valid1's auc: 0.729165
# [65]	train's auc: 0.741442	valid1's auc: 0.729344
# [66]	train's auc: 0.741897	valid1's auc: 0.729475
# [67]	train's auc: 0.742326	valid1's auc: 0.729595
# [68]	train's auc: 0.742698	valid1's auc: 0.729652
# [69]	train's auc: 0.743085	valid1's auc: 0.729716
# [70]	train's auc: 0.743552	valid1's auc: 0.729839
# [71]	train's auc: 0.743958	valid1's auc: 0.72997
# [72]	train's auc: 0.744353	valid1's auc: 0.730015
# [73]	train's auc: 0.744799	valid1's auc: 0.730116
# [74]	train's auc: 0.745137	valid1's auc: 0.73015
# [75]	train's auc: 0.745566	valid1's auc: 0.730242
# [76]	train's auc: 0.745852	valid1's auc: 0.730291
# [77]	train's auc: 0.746263	valid1's auc: 0.73054
# [78]	train's auc: 0.746727	valid1's auc: 0.730746
# [79]	train's auc: 0.747111	valid1's auc: 0.730821
# [80]	train's auc: 0.747438	valid1's auc: 0.73094
# [81]	train's auc: 0.74777	valid1's auc: 0.731031
# [82]	train's auc: 0.748139	valid1's auc: 0.731156
# [83]	train's auc: 0.748492	valid1's auc: 0.731209
# [84]	train's auc: 0.748694	valid1's auc: 0.731255
# [85]	train's auc: 0.749068	valid1's auc: 0.731345
# [86]	train's auc: 0.749338	valid1's auc: 0.731352
# [87]	train's auc: 0.749594	valid1's auc: 0.731414
# [88]	train's auc: 0.749895	valid1's auc: 0.731462
# [89]	train's auc: 0.750223	valid1's auc: 0.73144
# [90]	train's auc: 0.750497	valid1's auc: 0.731469
# [91]	train's auc: 0.750915	valid1's auc: 0.731595
# [92]	train's auc: 0.751249	valid1's auc: 0.731711
# [93]	train's auc: 0.751579	valid1's auc: 0.73175
# [94]	train's auc: 0.751854	valid1's auc: 0.731759
# [95]	train's auc: 0.752197	valid1's auc: 0.731815
# [96]	train's auc: 0.752403	valid1's auc: 0.731816
# [97]	train's auc: 0.752646	valid1's auc: 0.731861
# [98]	train's auc: 0.752856	valid1's auc: 0.731844
# [99]	train's auc: 0.753385	valid1's auc: 0.732189
# [100]	train's auc: 0.753696	valid1's auc: 0.732191
# [101]	train's auc: 0.75391	valid1's auc: 0.732219
# [102]	train's auc: 0.754206	valid1's auc: 0.73235
# [103]	train's auc: 0.754764	valid1's auc: 0.732696
# [104]	train's auc: 0.755114	valid1's auc: 0.732749
# [105]	train's auc: 0.755364	valid1's auc: 0.732849
# [106]	train's auc: 0.755636	valid1's auc: 0.73285
# [107]	train's auc: 0.755835	valid1's auc: 0.732859
# [108]	train's auc: 0.756226	valid1's auc: 0.732958
# [109]	train's auc: 0.756455	valid1's auc: 0.732949
# [110]	train's auc: 0.756657	valid1's auc: 0.732944
# [111]	train's auc: 0.756935	valid1's auc: 0.732945
# [112]	train's auc: 0.757123	valid1's auc: 0.732929
# [113]	train's auc: 0.757217	valid1's auc: 0.732919
# [114]	train's auc: 0.75748	valid1's auc: 0.732918
# [115]	train's auc: 0.757762	valid1's auc: 0.732942
# [116]	train's auc: 0.757924	valid1's auc: 0.732925
# [117]	train's auc: 0.758282	valid1's auc: 0.733036
# [118]	train's auc: 0.758568	valid1's auc: 0.733087
# [119]	train's auc: 0.758796	valid1's auc: 0.733081
# [120]	train's auc: 0.759065	valid1's auc: 0.733155
# [121]	train's auc: 0.759329	valid1's auc: 0.733169
# [122]	train's auc: 0.759461	valid1's auc: 0.733175
# [123]	train's auc: 0.759733	valid1's auc: 0.733194
# [124]	train's auc: 0.759996	valid1's auc: 0.733224
# [125]	train's auc: 0.760259	valid1's auc: 0.733191
# [126]	train's auc: 0.760494	valid1's auc: 0.733209
# [127]	train's auc: 0.760682	valid1's auc: 0.73322
# [128]	train's auc: 0.760851	valid1's auc: 0.733256
# [129]	train's auc: 0.761235	valid1's auc: 0.733422
# [130]	train's auc: 0.7617	valid1's auc: 0.733735
# [131]	train's auc: 0.761945	valid1's auc: 0.733755
# [132]	train's auc: 0.762181	valid1's auc: 0.733798
# [133]	train's auc: 0.762388	valid1's auc: 0.73381
# [134]	train's auc: 0.762587	valid1's auc: 0.733833
# [135]	train's auc: 0.762733	valid1's auc: 0.733846
# [136]	train's auc: 0.762963	valid1's auc: 0.733873
# [137]	train's auc: 0.76327	valid1's auc: 0.733915
# [138]	train's auc: 0.763305	valid1's auc: 0.733917
# [139]	train's auc: 0.763611	valid1's auc: 0.73395
# [140]	train's auc: 0.763803	valid1's auc: 0.733927
# [141]	train's auc: 0.764029	valid1's auc: 0.733923
# [142]	train's auc: 0.764279	valid1's auc: 0.733996
# [143]	train's auc: 0.764449	valid1's auc: 0.734013
# [144]	train's auc: 0.764614	valid1's auc: 0.734004
# [145]	train's auc: 0.76476	valid1's auc: 0.733991
# [146]	train's auc: 0.764847	valid1's auc: 0.733996
# [147]	train's auc: 0.76516	valid1's auc: 0.734091
# [148]	train's auc: 0.765304	valid1's auc: 0.734108
# [149]	train's auc: 0.76561	valid1's auc: 0.734134
# [150]	train's auc: 0.765774	valid1's auc: 0.734133
# [151]	train's auc: 0.766008	valid1's auc: 0.734144
# [152]	train's auc: 0.766202	valid1's auc: 0.734147
# [153]	train's auc: 0.766297	valid1's auc: 0.734142
# [154]	train's auc: 0.766608	valid1's auc: 0.734117
# [155]	train's auc: 0.766695	valid1's auc: 0.734103
# [156]	train's auc: 0.766754	valid1's auc: 0.734104
# [157]	train's auc: 0.766841	valid1's auc: 0.734108
# [158]	train's auc: 0.766951	valid1's auc: 0.7341
# [159]	train's auc: 0.767167	valid1's auc: 0.734112
# [160]	train's auc: 0.767564	valid1's auc: 0.734224
# [161]	train's auc: 0.767799	valid1's auc: 0.734219
# [162]	train's auc: 0.767895	valid1's auc: 0.734204
# [163]	train's auc: 0.768039	valid1's auc: 0.734204
# [164]	train's auc: 0.768196	valid1's auc: 0.734214
# [165]	train's auc: 0.768401	valid1's auc: 0.734212
# [166]	train's auc: 0.768594	valid1's auc: 0.734191
# [167]	train's auc: 0.768742	valid1's auc: 0.734187
# [168]	train's auc: 0.768808	valid1's auc: 0.73418
# [169]	train's auc: 0.769035	valid1's auc: 0.734184
# [170]	train's auc: 0.769203	valid1's auc: 0.734172
# [171]	train's auc: 0.76936	valid1's auc: 0.73418
# [172]	train's auc: 0.769502	valid1's auc: 0.734167
# [173]	train's auc: 0.769711	valid1's auc: 0.734145
# [174]	train's auc: 0.769798	valid1's auc: 0.734125
# [175]	train's auc: 0.769843	valid1's auc: 0.734125
# [176]	train's auc: 0.770017	valid1's auc: 0.734168
# [177]	train's auc: 0.770287	valid1's auc: 0.734181
# [178]	train's auc: 0.770773	valid1's auc: 0.734388
# [179]	train's auc: 0.771194	valid1's auc: 0.73461
# [180]	train's auc: 0.771403	valid1's auc: 0.734601
# [181]	train's auc: 0.771582	valid1's auc: 0.7346
# [182]	train's auc: 0.771865	valid1's auc: 0.734611
# [183]	train's auc: 0.772013	valid1's auc: 0.734594
# [184]	train's auc: 0.772199	valid1's auc: 0.734613
# [185]	train's auc: 0.772397	valid1's auc: 0.734671
# [186]	train's auc: 0.772542	valid1's auc: 0.734658
# [187]	train's auc: 0.7727	valid1's auc: 0.73467
# [188]	train's auc: 0.772743	valid1's auc: 0.73467
# [189]	train's auc: 0.772799	valid1's auc: 0.734663
# [190]	train's auc: 0.773071	valid1's auc: 0.734646
# [191]	train's auc: 0.77323	valid1's auc: 0.734651
# [192]	train's auc: 0.773378	valid1's auc: 0.734628
# [193]	train's auc: 0.773573	valid1's auc: 0.734631
# [194]	train's auc: 0.773627	valid1's auc: 0.734643
# [195]	train's auc: 0.77382	valid1's auc: 0.734666
# [196]	train's auc: 0.77406	valid1's auc: 0.734649
# [197]	train's auc: 0.774121	valid1's auc: 0.734641
# [198]	train's auc: 0.774356	valid1's auc: 0.73472
# [199]	train's auc: 0.774684	valid1's auc: 0.734756
# [200]	train's auc: 0.774857	valid1's auc: 0.734765
# [201]	train's auc: 0.775027	valid1's auc: 0.734759
# [202]	train's auc: 0.775172	valid1's auc: 0.734731
# [203]	train's auc: 0.775409	valid1's auc: 0.734774
# [204]	train's auc: 0.775611	valid1's auc: 0.734789
# [205]	train's auc: 0.775811	valid1's auc: 0.734776
# [206]	train's auc: 0.776028	valid1's auc: 0.734779
# [207]	train's auc: 0.776149	valid1's auc: 0.734821
# [208]	train's auc: 0.776284	valid1's auc: 0.734823
# [209]	train's auc: 0.776335	valid1's auc: 0.734816
# [210]	train's auc: 0.776514	valid1's auc: 0.734798
# [211]	train's auc: 0.776636	valid1's auc: 0.73478
# [212]	train's auc: 0.776849	valid1's auc: 0.73479
# [213]	train's auc: 0.776895	valid1's auc: 0.734798
# [214]	train's auc: 0.776949	valid1's auc: 0.734789
# [215]	train's auc: 0.777278	valid1's auc: 0.734914
# [216]	train's auc: 0.777515	valid1's auc: 0.734908
# [217]	train's auc: 0.777705	valid1's auc: 0.734939
# [218]	train's auc: 0.777865	valid1's auc: 0.734952
# [219]	train's auc: 0.778026	valid1's auc: 0.735059
# [220]	train's auc: 0.778264	valid1's auc: 0.735078
# [221]	train's auc: 0.778353	valid1's auc: 0.735062
# [222]	train's auc: 0.778478	valid1's auc: 0.735062
# [223]	train's auc: 0.778651	valid1's auc: 0.735051
# [224]	train's auc: 0.778773	valid1's auc: 0.73504
# [225]	train's auc: 0.778952	valid1's auc: 0.73502
# [226]	train's auc: 0.779268	valid1's auc: 0.735023
# [227]	train's auc: 0.779519	valid1's auc: 0.734996
# [228]	train's auc: 0.779573	valid1's auc: 0.734988
# [229]	train's auc: 0.779735	valid1's auc: 0.734986
# [230]	train's auc: 0.779861	valid1's auc: 0.734963
# [231]	train's auc: 0.779998	valid1's auc: 0.734947
# [232]	train's auc: 0.780314	valid1's auc: 0.734983
# [233]	train's auc: 0.780493	valid1's auc: 0.735015
# [234]	train's auc: 0.78062	valid1's auc: 0.735004
# [235]	train's auc: 0.780753	valid1's auc: 0.735002
# [236]	train's auc: 0.780912	valid1's auc: 0.735002
# [237]	train's auc: 0.780947	valid1's auc: 0.735003
# [238]	train's auc: 0.781079	valid1's auc: 0.735005
# [239]	train's auc: 0.781126	valid1's auc: 0.735001
# [240]	train's auc: 0.781356	valid1's auc: 0.734975
# [241]	train's auc: 0.781506	valid1's auc: 0.734971
# [242]	train's auc: 0.781621	valid1's auc: 0.734971
# [243]	train's auc: 0.781697	valid1's auc: 0.734984
# [244]	train's auc: 0.781778	valid1's auc: 0.734973
# [245]	train's auc: 0.781904	valid1's auc: 0.734979
# [246]	train's auc: 0.781953	valid1's auc: 0.734973
# [247]	train's auc: 0.782112	valid1's auc: 0.734963
# [248]	train's auc: 0.782268	valid1's auc: 0.73496
# [249]	train's auc: 0.782411	valid1's auc: 0.734954
# [250]	train's auc: 0.782721	valid1's auc: 0.735046
# [251]	train's auc: 0.782848	valid1's auc: 0.735048
# [252]	train's auc: 0.782896	valid1's auc: 0.735055
# [253]	train's auc: 0.783066	valid1's auc: 0.735031
# [254]	train's auc: 0.783127	valid1's auc: 0.735033
# [255]	train's auc: 0.783176	valid1's auc: 0.735033
# [256]	train's auc: 0.783343	valid1's auc: 0.735024
# [257]	train's auc: 0.783492	valid1's auc: 0.735004
# [258]	train's auc: 0.783677	valid1's auc: 0.73501
# [259]	train's auc: 0.783839	valid1's auc: 0.735006
# [260]	train's auc: 0.783954	valid1's auc: 0.735007
# [261]	train's auc: 0.784062	valid1's auc: 0.735012
# [262]	train's auc: 0.784282	valid1's auc: 0.735004
# [263]	train's auc: 0.784482	valid1's auc: 0.734999
# [264]	train's auc: 0.784626	valid1's auc: 0.734989
# [265]	train's auc: 0.784755	valid1's auc: 0.734989
# [266]	train's auc: 0.784885	valid1's auc: 0.734986
# [267]	train's auc: 0.784988	valid1's auc: 0.734969
# [268]	train's auc: 0.785125	valid1's auc: 0.734958
# [269]	train's auc: 0.785194	valid1's auc: 0.734958
# [270]	train's auc: 0.785378	valid1's auc: 0.734937
# Early stopping, best iteration is:
# [220]	train's auc: 0.778264	valid1's auc: 0.735078

# %%
log_file = 'v1.feature_importance.csv'
log_path = os.path.join(log_folder, log_file)

df_feature_importance = pd.DataFrame({"feature": cols_train, "importance": lgbm.feature_importance()})
df_feature_importance = df_feature_importance.sort_values("importance", ascending=False)
df_feature_importance.to_csv(log_path, index=False)
df_feature_importance.head(30)
# Out:
#                         feature  importance
# 419706        stackProba_LR_kw2         999
# 419707     stackProba_LR_topic2         857
# 419703  stackProba_LR_interest2         688
# 419705        stackProba_LR_kw1         633
# 419702  stackProba_LR_interest1         593
# 419704  stackProba_LR_interest5         554
# 419701        stackProba_LR_age         469
# 419614          creativeSize_59         217
# 419699            productType_9         145
# 6                      gender_2         134
# 419612          creativeSize_42         129
# 419610          creativeSize_22         117
# 419640          adCategoryId_51         114
# 11            marriageStatus_10         110
# 17            marriageStatus_11         105
# 915                interest1_49          99
# 419244                  aid_311          96
# 419611          creativeSize_35          92
# 1057               interest2_54          86
# 419207                     ct_1          79
# 3                         age_2          78
# 419518         campaignId_51385          78
# 1033               interest2_70          77
# 1050               interest2_24          74
# 4                         age_3          72
# 419507         campaignId_40405          70
# 1003                interest1_6          69
# 419641          adCategoryId_59          68
# 1                         age_1          67
# 1025               interest2_63          66

# %%
def online_auc(selector, y_true, y_pred, ret_verbose=False):
    assert selector.shape[0] == y_true.shape[0]
    assert selector.shape[0] == y_pred.shape[0]
    assert np.isnan(selector).sum() == 0
    
    select_vals = np.unique(selector)
    aucs = np.zeros(len(select_vals))
    
    for i, select_val in enumerate(select_vals):
        mask = (selector==select_val)
        y_true_selected = y_true[mask]
        y_pred_selected = y_pred[mask]
        aucs[i] = metrics.roc_auc_score(y_true_selected, y_pred_selected)
    
    if ret_verbose:
        df = pd.DataFrame({"selector": select_vals, "auc": aucs})
        return df
    else:
        return aucs.mean()

# %%
# df_valid = df_train.iloc[valid_index]
# proba_valid = lgbm.predict(X_valid)
df_score = online_auc(df_valid['aid'], y_valid, proba_valid, ret_verbose=True)
df_score
# Out:
#           auc  selector
# 0    0.657481         6
# 1    0.815082         7
# 2    0.856212        12
# 3    0.577631        18
# 4    0.863244        70
# 5    0.672458        74
# 6    0.614513        86
# 7    0.780009        98
# 8    0.533170       113
# 9    0.657214       117
# 10   0.834839       121
# 11   0.623319       136
# 12   0.760396       145
# 13   0.878724       164
# 14   0.767143       173
# 15   0.772978       174
# 16   0.644223       177
# 17   0.770369       191
# 18   0.883466       205
# 19   0.601449       206
# 20   0.604725       212
# 21   0.733374       231
# 22   0.753814       272
# 23   0.726862       286
# 24   0.682078       302
# 25   0.758177       311
# 26   0.857370       313
# 27   0.900000       336
# 28   0.573534       369
# 29   0.714516       389
# ..        ...       ...
# 143  0.650273      1918
# 144  0.581756      1925
# 145  0.913868      1930
# 146  0.566822      1931
# 147  0.874836      1940
# 148  0.809417      1950
# 149  0.915502      1957
# 150  0.599623      1962
# 151  0.876122      1966
# 152  0.802143      1970
# 153  0.663489      1991
# 154  0.648687      1998
# 155  0.771889      2013
# 156  0.829078      2031
# 157  0.704762      2044
# 158  0.569343      2047
# 159  0.644739      2048
# 160  0.764578      2050
# 161  0.949653      2054
# 162  0.664450      2066
# 163  0.792478      2068
# 164  0.695083      2112
# 165  0.715948      2118
# 166  0.561173      2154
# 167  0.708387      2169
# 168  0.597630      2196
# 169  0.707142      2197
# 170  0.791240      2201
# 171  0.876598      2205
# 172  0.591185      2216
#
# [173 rows x 2 columns]

# %%
online_auc = df_score['auc'].mean()
simple_auc = metrics.roc_auc_score(y_valid, proba_valid)
print("Online AUC: {:.6f}".format(online_auc))
print("Simple AUC: {:.6f}".format(simple_auc))
# Out:
# Online AUC: 0.728380
# Simple AUC: 0.735078

# %%
log_file = 'v1.online_auc.csv'
log_path = os.path.join(log_folder, log_file)
df_score.rename(columns={'selector': 'aid'}, inplace=True)
df_score = df_score[['aid', 'auc']]  # sort columns
df_score.to_csv(log_path, index=False)

# %%
with pu.profiler("cleaning memory"):
    del lgb_train
    del lgb_valid
    del X_train
    del X_valid
    gc.collect()
# Out:
# [06:50:57] Finish cleaning memory. △M: -12.17GB. △T: 1.6 seconds.

# %%
with pu.profiler("loading testing data"):
    cols_test, X_test = union_loader.load("test1")
    X_test = sparse.csr_matrix(X_test)
    gc.collect()

print("Train Data Shape: {}".format(X_test.shape))
print("Train Column Numbers: {}".format(len(cols_test)))
# Out:
# [06:52:33] Finish loading testing data. △M: +759.56MB. △T: 9.6 seconds.
# Train Data Shape: (2265989, 419708)
# Train Column Numbers: 419708

# %%
df_test = du.load_raw_data("test")
X_test = X_test.astype(np.float32)

with pu.profiler("making prediction on testing set"):
    proba_test = lgbm.predict(X_test)
    assert len(proba_test.shape) == 1
    assert proba_test.shape[0] == df_test.shape[0]
# Out:
# [06:53:43] Finish making prediction on testing set. △M: +464.0KB. △T: 22.0 seconds.

# %%
subm_folder = '../../../subm/lgbm/0507_v1'
subm_file = 'submission.csv'
subm_path = os.path.join(subm_folder, subm_file)
os.makedirs(subm_folder, exist_ok=True)

subm = df_test.copy()
subm["score"] = proba_test
subm.to_csv(subm_path, index=False)
