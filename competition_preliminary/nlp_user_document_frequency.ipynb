# %%
from tqdm import tqdm
from collections import Counter
import os
import sys
import numpy as np
import multiprocessing as mp
from time import gmtime, strftime
import gc
import pickle
import sys
sys.path.append('../code/utils')
from perf_utils import get_memory_str

# %%
DATA_DIR = '../data/raw/preliminary_contest_data/'
USER_DATA_FILE = 'userFeature.preliminary.data'
USER_DATA_PATH = os.path.join(DATA_DIR, USER_DATA_FILE)

# %%
def count_file_lines(filepath):
    f = open(filepath)
    for i, l in tqdm(enumerate(f.readlines())):
        pass
    return i + 1

# %%
# line_counts = count_file_lines(os.path.join(DATA_DIR, USER_DATA_FILE))  # comment this if you don't want to run it again
line_counts = 9686953  # uncomment this to save time
print("{} lines in userFeature.data".format(line_counts))
print("Memory Usage at this moment: {}".format(get_memory_str()))
# Out:
# 9686953 lines in userFeature.data
# Memory Usage at this moment: 51.11MB

# %%
lines = []
with open(USER_DATA_PATH) as f:
    for i in tqdm(range(line_counts)):
        line = f.readline().strip()
        lines.append(line)
print("Memory Usage at this moment: {}".format(get_memory_str()))
# Out:
# 100%|██████████| 9686953/9686953 [00:17<00:00, 556975.53it/s]
# Memory Usage at this moment: 4.21GB

# %%
feat_names = ["age", "gender", "marriageStatus", "education", "consumptionAbility", "LBS",
              "interest1", "interest2", "interest3", "interest4", "interest5",
              "kw1", "kw2", "kw3", "topic1", "topic2", "topic3", "appIdInstall",
              "appIdAction", "ct", "os", "carrier", "house"]


def fast_count_feature_from_lines(lines):  
    # no checking, no uid, so faster
    counters = {feat_name: Counter() for feat_name in feat_names}
    n_lines = len(lines)
    # for line in tqdm(lines):
    for line in lines:
        for feat in line.split("|")[1:]:
            arr = feat.split(" ")
            key = arr[0]
            vals = arr[1:]
            counters[key] += Counter(vals)
    # print("[{}] worker's task done.".format(strftime("%H:%M:%S", gmtime())))
    return counters

# %%
def split_list(lst, n_split=4):
    n_total = len(lst)
    step = int(np.ceil(n_total / n_split))
    splits = []
    for offset in range(0, n_total, step):
        splits.append(lst[offset:offset + step])
    return splits

# %%
def merge_counter_dicts(counter_dict_list):
    final_counter_dict = {}
    for feat_name in feat_names:
        final_counter = Counter()
        for counter_dict in counter_dict_list:
            final_counter += counter_dict[feat_name]
        final_counter_dict[feat_name] = final_counter
    return final_counter_dict

# %%
def batch_count_features(lines, n_procs=None, n_batches=None):
    print("[{}] Starting counting features.".format(strftime("%H:%M:%S", gmtime())))
    n_procs = mp.cpu_count() if n_procs is None else n_procs
    n_batches = mp.cpu_count() if n_batches is None else n_batches
    pool = mp.Pool(processes=n_procs)
    results = [pool.apply_async(fast_count_feature_from_lines, (batch, )) for batch in split_list(lines, n_procs)]
    pool.close()
    pool.join()
    counters_list = [result.get() for result in results]
    # print("[{}] All workers' tasks done. Combining results...".format(strftime("%H:%M:%S", gmtime())))
    final_counter_dict = merge_counter_dicts(counters_list)
    print("[{}] Combining Finished. Memory Usage: {}".format(strftime("%H:%M:%S", gmtime()), get_memory_str()))
    return final_counter_dict

# %%
n_batches = 500
line_batches = split_list(lines, n_batches)
counter_dicts = []
for i, line_batch in enumerate(line_batches):
    print("Batch {}/{}".format(i, n_batches))
    counter_dicts.append(batch_count_features(line_batch, 4))
print("Memory Usage at this moment: {}".format(get_memory_str()))
# Out:
# Batch 0/500
# [02:58:11] Starting counting features.
# [02:58:19] Combining Finished. Memory Usage: 4.31GB
# Batch 1/500
# [02:58:19] Starting counting features.
# [02:58:26] Combining Finished. Memory Usage: 4.32GB
# Batch 2/500
# [02:58:26] Starting counting features.
# [02:58:34] Combining Finished. Memory Usage: 4.32GB
# Batch 3/500
# [02:58:34] Starting counting features.
# [02:58:41] Combining Finished. Memory Usage: 4.33GB
# Batch 4/500
# [02:58:41] Starting counting features.
# [02:58:57] Combining Finished. Memory Usage: 4.33GB
# Batch 5/500
# [02:58:57] Starting counting features.
# [02:59:06] Combining Finished. Memory Usage: 4.34GB
# Batch 6/500
# [02:59:06] Starting counting features.
# [02:59:15] Combining Finished. Memory Usage: 4.34GB
# Batch 7/500
# [02:59:15] Starting counting features.
# [02:59:22] Combining Finished. Memory Usage: 4.35GB
# Batch 8/500
# [02:59:22] Starting counting features.
# [02:59:31] Combining Finished. Memory Usage: 4.35GB
# Batch 9/500
# [02:59:31] Starting counting features.
# [02:59:40] Combining Finished. Memory Usage: 4.36GB
# Batch 10/500
# [02:59:40] Starting counting features.
# [02:59:48] Combining Finished. Memory Usage: 4.36GB
# Batch 11/500
# [02:59:48] Starting counting features.
# [02:59:56] Combining Finished. Memory Usage: 4.37GB
# Batch 12/500
# [02:59:56] Starting counting features.
# [03:00:04] Combining Finished. Memory Usage: 4.37GB
# Batch 13/500
# [03:00:04] Starting counting features.
# [03:00:12] Combining Finished. Memory Usage: 4.38GB
# Batch 14/500
# [03:00:12] Starting counting features.
# [03:00:20] Combining Finished. Memory Usage: 4.38GB
# Batch 15/500
# [03:00:20] Starting counting features.
# [03:00:28] Combining Finished. Memory Usage: 4.39GB
# Batch 16/500
# [03:00:28] Starting counting features.
# [03:00:36] Combining Finished. Memory Usage: 4.39GB
# Batch 17/500
# [03:00:36] Starting counting features.
# [03:00:43] Combining Finished. Memory Usage: 4.4GB
# Batch 18/500
# [03:00:43] Starting counting features.
# [03:00:51] Combining Finished. Memory Usage: 4.41GB
# Batch 19/500
# [03:00:51] Starting counting features.
# [03:01:00] Combining Finished. Memory Usage: 4.41GB
# Batch 20/500
# [03:01:00] Starting counting features.
# [03:01:08] Combining Finished. Memory Usage: 4.42GB
# Batch 21/500
# [03:01:08] Starting counting features.
# [03:01:16] Combining Finished. Memory Usage: 4.42GB
# Batch 22/500
# [03:01:16] Starting counting features.
# [03:01:25] Combining Finished. Memory Usage: 4.43GB
# Batch 23/500
# [03:01:25] Starting counting features.
# [03:01:34] Combining Finished. Memory Usage: 4.43GB
# Batch 24/500
# [03:01:34] Starting counting features.
# [03:01:41] Combining Finished. Memory Usage: 4.44GB
# Batch 25/500
# [03:01:41] Starting counting features.
# [03:01:50] Combining Finished. Memory Usage: 4.44GB
# Batch 26/500
# [03:01:50] Starting counting features.
# [03:01:58] Combining Finished. Memory Usage: 4.45GB
# Batch 27/500
# [03:01:58] Starting counting features.
# [03:02:06] Combining Finished. Memory Usage: 4.45GB
# Batch 28/500
# [03:02:06] Starting counting features.
# [03:02:14] Combining Finished. Memory Usage: 4.46GB
# Batch 29/500
# [03:02:14] Starting counting features.
# [03:02:23] Combining Finished. Memory Usage: 4.46GB
# Batch 30/500
# [03:02:23] Starting counting features.
# [03:02:31] Combining Finished. Memory Usage: 4.47GB
# Batch 31/500
# [03:02:31] Starting counting features.
# [03:02:39] Combining Finished. Memory Usage: 4.48GB
# Batch 32/500
# [03:02:39] Starting counting features.
# [03:02:47] Combining Finished. Memory Usage: 4.48GB
# Batch 33/500
# [03:02:47] Starting counting features.
# [03:02:55] Combining Finished. Memory Usage: 4.49GB
# Batch 34/500
# [03:02:55] Starting counting features.
# [03:03:04] Combining Finished. Memory Usage: 4.49GB
# Batch 35/500
# [03:03:04] Starting counting features.
# [03:03:12] Combining Finished. Memory Usage: 4.5GB
# Batch 36/500
# [03:03:12] Starting counting features.
# [03:03:20] Combining Finished. Memory Usage: 4.5GB
# Batch 37/500
# [03:03:20] Starting counting features.
# [03:03:28] Combining Finished. Memory Usage: 4.51GB
# Batch 38/500
# [03:03:28] Starting counting features.
# [03:03:36] Combining Finished. Memory Usage: 4.51GB
# Batch 39/500
# [03:03:36] Starting counting features.
# [03:03:44] Combining Finished. Memory Usage: 4.52GB
# Batch 40/500
# [03:03:44] Starting counting features.
# [03:03:52] Combining Finished. Memory Usage: 4.53GB
# Batch 41/500
# [03:03:52] Starting counting features.
# [03:04:00] Combining Finished. Memory Usage: 4.53GB
# Batch 42/500
# [03:04:00] Starting counting features.
# [03:04:08] Combining Finished. Memory Usage: 4.54GB
# Batch 43/500
# [03:04:08] Starting counting features.
# [03:04:16] Combining Finished. Memory Usage: 4.54GB
# Batch 44/500
# [03:04:16] Starting counting features.
# [03:04:24] Combining Finished. Memory Usage: 4.54GB
# Batch 45/500
# [03:04:24] Starting counting features.
# [03:04:32] Combining Finished. Memory Usage: 4.55GB
# Batch 46/500
# [03:04:32] Starting counting features.
# [03:04:40] Combining Finished. Memory Usage: 4.56GB
# Batch 47/500
# [03:04:40] Starting counting features.
# [03:04:48] Combining Finished. Memory Usage: 4.56GB
# Batch 48/500
# [03:04:48] Starting counting features.
# [03:04:56] Combining Finished. Memory Usage: 4.57GB
# Batch 49/500
# [03:04:56] Starting counting features.
# [03:05:05] Combining Finished. Memory Usage: 4.58GB
# Batch 50/500
# [03:05:05] Starting counting features.
# [03:05:13] Combining Finished. Memory Usage: 4.58GB
# Batch 51/500
# [03:05:13] Starting counting features.
# [03:05:20] Combining Finished. Memory Usage: 4.59GB
# Batch 52/500
# [03:05:20] Starting counting features.
# [03:05:28] Combining Finished. Memory Usage: 4.59GB
# Batch 53/500
# [03:05:28] Starting counting features.
# [03:05:36] Combining Finished. Memory Usage: 4.59GB
# Batch 54/500
# [03:05:36] Starting counting features.
# [03:05:44] Combining Finished. Memory Usage: 4.6GB
# Batch 55/500
# [03:05:44] Starting counting features.
# [03:05:51] Combining Finished. Memory Usage: 4.61GB
# Batch 56/500
# [03:05:51] Starting counting features.
# [03:06:00] Combining Finished. Memory Usage: 4.61GB
# Batch 57/500
# [03:06:00] Starting counting features.
# [03:06:08] Combining Finished. Memory Usage: 4.62GB
# Batch 58/500
# [03:06:08] Starting counting features.
# [03:06:17] Combining Finished. Memory Usage: 4.62GB
# Batch 59/500
# [03:06:17] Starting counting features.
# [03:06:25] Combining Finished. Memory Usage: 4.63GB
# Batch 60/500
# [03:06:25] Starting counting features.
# [03:06:33] Combining Finished. Memory Usage: 4.63GB
# Batch 61/500
# [03:06:33] Starting counting features.
# [03:06:42] Combining Finished. Memory Usage: 4.64GB
# Batch 62/500
# [03:06:42] Starting counting features.
# [03:06:50] Combining Finished. Memory Usage: 4.64GB
# Batch 63/500
# [03:06:50] Starting counting features.
# [03:06:58] Combining Finished. Memory Usage: 4.65GB
# Batch 64/500
# [03:06:58] Starting counting features.
# [03:07:05] Combining Finished. Memory Usage: 4.65GB
# Batch 65/500
# [03:07:05] Starting counting features.
# [03:07:13] Combining Finished. Memory Usage: 4.66GB
# Batch 66/500
# [03:07:13] Starting counting features.
# [03:07:22] Combining Finished. Memory Usage: 4.67GB
# Batch 67/500
# [03:07:22] Starting counting features.
# [03:07:29] Combining Finished. Memory Usage: 4.67GB
# Batch 68/500
# [03:07:29] Starting counting features.
# [03:07:37] Combining Finished. Memory Usage: 4.68GB
# Batch 69/500
# [03:07:37] Starting counting features.
# [03:07:46] Combining Finished. Memory Usage: 4.68GB
# Batch 70/500
# [03:07:46] Starting counting features.
# [03:07:53] Combining Finished. Memory Usage: 4.69GB
# Batch 71/500
# [03:07:53] Starting counting features.
# [03:08:01] Combining Finished. Memory Usage: 4.69GB
# Batch 72/500
# [03:08:01] Starting counting features.
# [03:08:09] Combining Finished. Memory Usage: 4.7GB
# Batch 73/500
# [03:08:09] Starting counting features.
# [03:08:18] Combining Finished. Memory Usage: 4.7GB
# Batch 74/500
# [03:08:18] Starting counting features.
# [03:08:26] Combining Finished. Memory Usage: 4.71GB
# Batch 75/500
# [03:08:26] Starting counting features.
# [03:08:34] Combining Finished. Memory Usage: 4.72GB
# Batch 76/500
# [03:08:34] Starting counting features.
# [03:08:42] Combining Finished. Memory Usage: 4.72GB
# Batch 77/500
# [03:08:42] Starting counting features.
# [03:08:50] Combining Finished. Memory Usage: 4.73GB
# Batch 78/500
# [03:08:50] Starting counting features.
# [03:09:00] Combining Finished. Memory Usage: 4.73GB
# Batch 79/500
# [03:09:00] Starting counting features.
# [03:09:08] Combining Finished. Memory Usage: 4.74GB
# Batch 80/500
# [03:09:08] Starting counting features.
# [03:09:17] Combining Finished. Memory Usage: 4.74GB
# Batch 81/500
# [03:09:17] Starting counting features.
# [03:09:26] Combining Finished. Memory Usage: 4.75GB
# Batch 82/500
# [03:09:26] Starting counting features.
# [03:09:34] Combining Finished. Memory Usage: 4.75GB
# Batch 83/500
# [03:09:34] Starting counting features.
# [03:09:41] Combining Finished. Memory Usage: 4.76GB
# Batch 84/500
# [03:09:41] Starting counting features.
# [03:09:49] Combining Finished. Memory Usage: 4.77GB
# Batch 85/500
# [03:09:49] Starting counting features.
# [03:09:56] Combining Finished. Memory Usage: 4.77GB
# Batch 86/500
# [03:09:56] Starting counting features.
# [03:10:04] Combining Finished. Memory Usage: 4.77GB
# Batch 87/500
# [03:10:04] Starting counting features.
# [03:10:11] Combining Finished. Memory Usage: 4.78GB
# Batch 88/500
# [03:10:11] Starting counting features.
# [03:10:19] Combining Finished. Memory Usage: 4.79GB
# Batch 89/500
# [03:10:19] Starting counting features.
# [03:10:26] Combining Finished. Memory Usage: 4.79GB
# Batch 90/500
# [03:10:26] Starting counting features.
# [03:10:35] Combining Finished. Memory Usage: 4.8GB
# Batch 91/500
# [03:10:35] Starting counting features.
# [03:10:51] Combining Finished. Memory Usage: 4.8GB
# Batch 92/500
# [03:10:51] Starting counting features.
# [03:11:00] Combining Finished. Memory Usage: 4.81GB
# Batch 93/500
# [03:11:00] Starting counting features.
# [03:11:08] Combining Finished. Memory Usage: 4.81GB
# Batch 94/500
# [03:11:08] Starting counting features.
# [03:11:17] Combining Finished. Memory Usage: 4.82GB
# Batch 95/500
# [03:11:17] Starting counting features.
# [03:11:25] Combining Finished. Memory Usage: 4.82GB
# Batch 96/500
# [03:11:25] Starting counting features.
# [03:11:34] Combining Finished. Memory Usage: 4.83GB
# Batch 97/500
# [03:11:34] Starting counting features.
# [03:11:42] Combining Finished. Memory Usage: 4.83GB
# Batch 98/500
# [03:11:42] Starting counting features.
# [03:11:51] Combining Finished. Memory Usage: 4.84GB
# Batch 99/500
# [03:11:51] Starting counting features.
# [03:12:00] Combining Finished. Memory Usage: 4.85GB
# Batch 100/500
# [03:12:00] Starting counting features.
# [03:12:08] Combining Finished. Memory Usage: 4.85GB
# Batch 101/500
# [03:12:08] Starting counting features.
# [03:12:16] Combining Finished. Memory Usage: 4.86GB
# Batch 102/500
# [03:12:16] Starting counting features.
# [03:12:25] Combining Finished. Memory Usage: 4.86GB
# Batch 103/500
# [03:12:25] Starting counting features.
# [03:12:34] Combining Finished. Memory Usage: 4.87GB
# Batch 104/500
# [03:12:34] Starting counting features.
# [03:12:42] Combining Finished. Memory Usage: 4.87GB
# Batch 105/500
# [03:12:42] Starting counting features.
# [03:12:51] Combining Finished. Memory Usage: 4.88GB
# Batch 106/500
# [03:12:51] Starting counting features.
# [03:12:59] Combining Finished. Memory Usage: 4.88GB
# Batch 107/500
# [03:12:59] Starting counting features.
# [03:13:07] Combining Finished. Memory Usage: 4.89GB
# Batch 108/500
# [03:13:07] Starting counting features.
# [03:13:16] Combining Finished. Memory Usage: 4.89GB
# Batch 109/500
# [03:13:16] Starting counting features.
# [03:13:25] Combining Finished. Memory Usage: 4.9GB
# Batch 110/500
# [03:13:25] Starting counting features.
# [03:13:32] Combining Finished. Memory Usage: 4.91GB
# Batch 111/500
# [03:13:32] Starting counting features.
# [03:13:41] Combining Finished. Memory Usage: 4.91GB
# Batch 112/500
# [03:13:41] Starting counting features.
# [03:13:49] Combining Finished. Memory Usage: 4.92GB
# Batch 113/500
# [03:13:49] Starting counting features.
# [03:13:57] Combining Finished. Memory Usage: 4.92GB
# Batch 114/500
# [03:13:57] Starting counting features.
# [03:14:06] Combining Finished. Memory Usage: 4.93GB
# Batch 115/500
# [03:14:06] Starting counting features.
# [03:14:14] Combining Finished. Memory Usage: 4.93GB
# Batch 116/500
# [03:14:14] Starting counting features.
# [03:14:22] Combining Finished. Memory Usage: 4.94GB
# Batch 117/500
# [03:14:22] Starting counting features.
# [03:14:31] Combining Finished. Memory Usage: 4.94GB
# Batch 118/500
# [03:14:31] Starting counting features.
# [03:14:39] Combining Finished. Memory Usage: 4.95GB
# Batch 119/500
# [03:14:39] Starting counting features.
# [03:14:48] Combining Finished. Memory Usage: 4.96GB
# Batch 120/500
# [03:14:48] Starting counting features.
# [03:14:56] Combining Finished. Memory Usage: 4.96GB
# Batch 121/500
# [03:14:56] Starting counting features.
# [03:15:04] Combining Finished. Memory Usage: 4.97GB
# Batch 122/500
# [03:15:04] Starting counting features.
# [03:15:12] Combining Finished. Memory Usage: 4.97GB
# Batch 123/500
# [03:15:12] Starting counting features.
# [03:15:20] Combining Finished. Memory Usage: 4.98GB
# Batch 124/500
# [03:15:20] Starting counting features.
# [03:15:28] Combining Finished. Memory Usage: 4.98GB
# Batch 125/500
# [03:15:28] Starting counting features.
# [03:15:36] Combining Finished. Memory Usage: 4.99GB
# Batch 126/500
# [03:15:36] Starting counting features.
# [03:15:44] Combining Finished. Memory Usage: 5.0GB
# Batch 127/500
# [03:15:44] Starting counting features.
# [03:15:52] Combining Finished. Memory Usage: 5.0GB
# Batch 128/500
# [03:15:52] Starting counting features.
# [03:16:02] Combining Finished. Memory Usage: 5.0GB
# Batch 129/500
# [03:16:02] Starting counting features.
# [03:16:10] Combining Finished. Memory Usage: 5.01GB
# Batch 130/500
# [03:16:10] Starting counting features.
# [03:16:18] Combining Finished. Memory Usage: 5.01GB
# Batch 131/500
# [03:16:18] Starting counting features.
# [03:16:26] Combining Finished. Memory Usage: 5.02GB
# Batch 132/500
# [03:16:26] Starting counting features.
# [03:16:34] Combining Finished. Memory Usage: 5.03GB
# Batch 133/500
# [03:16:34] Starting counting features.
# [03:16:43] Combining Finished. Memory Usage: 5.03GB
# Batch 134/500
# [03:16:43] Starting counting features.
# [03:16:53] Combining Finished. Memory Usage: 5.04GB
# Batch 135/500
# [03:16:53] Starting counting features.
# [03:17:01] Combining Finished. Memory Usage: 5.04GB
# Batch 136/500
# [03:17:01] Starting counting features.
# [03:17:09] Combining Finished. Memory Usage: 5.05GB
# Batch 137/500
# [03:17:09] Starting counting features.
# [03:17:18] Combining Finished. Memory Usage: 5.05GB
# Batch 138/500
# [03:17:18] Starting counting features.
# [03:17:27] Combining Finished. Memory Usage: 5.06GB
# Batch 139/500
# [03:17:27] Starting counting features.
# [03:17:35] Combining Finished. Memory Usage: 5.07GB
# Batch 140/500
# [03:17:35] Starting counting features.
# [03:17:44] Combining Finished. Memory Usage: 5.07GB
# Batch 141/500
# [03:17:44] Starting counting features.
# [03:17:52] Combining Finished. Memory Usage: 5.08GB
# Batch 142/500
# [03:17:52] Starting counting features.
# [03:17:59] Combining Finished. Memory Usage: 5.08GB
# Batch 143/500
# [03:17:59] Starting counting features.
# [03:18:08] Combining Finished. Memory Usage: 5.09GB
# Batch 144/500
# [03:18:08] Starting counting features.
# [03:18:17] Combining Finished. Memory Usage: 5.09GB
# Batch 145/500
# [03:18:17] Starting counting features.
# [03:18:25] Combining Finished. Memory Usage: 5.09GB
# Batch 146/500
# [03:18:25] Starting counting features.
# [03:18:33] Combining Finished. Memory Usage: 5.1GB
# Batch 147/500
# [03:18:33] Starting counting features.
# [03:18:41] Combining Finished. Memory Usage: 5.11GB
# Batch 148/500
# [03:18:41] Starting counting features.
# [03:18:49] Combining Finished. Memory Usage: 5.11GB
# Batch 149/500
# [03:18:49] Starting counting features.
# [03:18:57] Combining Finished. Memory Usage: 5.12GB
# Batch 150/500
# [03:18:57] Starting counting features.
# [03:19:06] Combining Finished. Memory Usage: 5.12GB
# Batch 151/500
# [03:19:06] Starting counting features.
# [03:19:14] Combining Finished. Memory Usage: 5.13GB
# Batch 152/500
# [03:19:14] Starting counting features.
# [03:19:22] Combining Finished. Memory Usage: 5.13GB
# Batch 153/500
# [03:19:22] Starting counting features.
# [03:19:30] Combining Finished. Memory Usage: 5.14GB
# Batch 154/500
# [03:19:30] Starting counting features.
# [03:19:39] Combining Finished. Memory Usage: 5.14GB
# Batch 155/500
# [03:19:39] Starting counting features.
# [03:19:46] Combining Finished. Memory Usage: 5.15GB
# Batch 156/500
# [03:19:46] Starting counting features.
# [03:19:54] Combining Finished. Memory Usage: 5.15GB
# Batch 157/500
# [03:19:54] Starting counting features.
# [03:20:02] Combining Finished. Memory Usage: 5.16GB
# Batch 158/500
# [03:20:02] Starting counting features.
# [03:20:11] Combining Finished. Memory Usage: 5.17GB
# Batch 159/500
# [03:20:11] Starting counting features.
# [03:20:18] Combining Finished. Memory Usage: 5.17GB
# Batch 160/500
# [03:20:18] Starting counting features.
# [03:20:26] Combining Finished. Memory Usage: 5.17GB
# Batch 161/500
# [03:20:26] Starting counting features.
# [03:20:34] Combining Finished. Memory Usage: 5.18GB
# Batch 162/500
# [03:20:34] Starting counting features.
# [03:20:43] Combining Finished. Memory Usage: 5.19GB
# Batch 163/500
# [03:20:43] Starting counting features.
# [03:20:51] Combining Finished. Memory Usage: 5.19GB
# Batch 164/500
# [03:20:51] Starting counting features.
# [03:21:00] Combining Finished. Memory Usage: 5.19GB
# Batch 165/500
# [03:21:00] Starting counting features.
# [03:21:08] Combining Finished. Memory Usage: 5.2GB
# Batch 166/500
# [03:21:08] Starting counting features.
# [03:21:16] Combining Finished. Memory Usage: 5.21GB
# Batch 167/500
# [03:21:16] Starting counting features.
# [03:21:24] Combining Finished. Memory Usage: 5.22GB
# Batch 168/500
# [03:21:24] Starting counting features.
# [03:21:33] Combining Finished. Memory Usage: 5.22GB
# Batch 169/500
# [03:21:33] Starting counting features.
# [03:21:41] Combining Finished. Memory Usage: 5.22GB
# Batch 170/500
# [03:21:41] Starting counting features.
# [03:21:50] Combining Finished. Memory Usage: 5.23GB
# Batch 171/500
# [03:21:50] Starting counting features.
# [03:21:58] Combining Finished. Memory Usage: 5.23GB
# Batch 172/500
# [03:21:58] Starting counting features.
# [03:22:06] Combining Finished. Memory Usage: 5.24GB
# Batch 173/500
# [03:22:06] Starting counting features.
# [03:22:15] Combining Finished. Memory Usage: 5.25GB
# Batch 174/500
# [03:22:15] Starting counting features.
# [03:22:23] Combining Finished. Memory Usage: 5.25GB
# Batch 175/500
# [03:22:23] Starting counting features.
# [03:22:31] Combining Finished. Memory Usage: 5.25GB
# Batch 176/500
# [03:22:31] Starting counting features.
# [03:22:39] Combining Finished. Memory Usage: 5.27GB
# Batch 177/500
# [03:22:39] Starting counting features.
# [03:22:48] Combining Finished. Memory Usage: 5.27GB
# Batch 178/500
# [03:22:48] Starting counting features.
# [03:22:56] Combining Finished. Memory Usage: 5.27GB
# Batch 179/500
# [03:22:56] Starting counting features.
# [03:23:05] Combining Finished. Memory Usage: 5.28GB
# Batch 180/500
# [03:23:05] Starting counting features.
# [03:23:13] Combining Finished. Memory Usage: 5.29GB
# Batch 181/500
# [03:23:13] Starting counting features.
# [03:23:22] Combining Finished. Memory Usage: 5.29GB
# Batch 182/500
# [03:23:22] Starting counting features.
# [03:23:30] Combining Finished. Memory Usage: 5.3GB
# Batch 183/500
# [03:23:30] Starting counting features.
# [03:23:39] Combining Finished. Memory Usage: 5.3GB
# Batch 184/500
# [03:23:39] Starting counting features.
# [03:23:49] Combining Finished. Memory Usage: 5.3GB
# Batch 185/500
# [03:23:49] Starting counting features.
# [03:24:00] Combining Finished. Memory Usage: 5.31GB
# Batch 186/500
# [03:24:00] Starting counting features.
# [03:24:09] Combining Finished. Memory Usage: 5.31GB
# Batch 187/500
# [03:24:09] Starting counting features.
# [03:24:19] Combining Finished. Memory Usage: 5.32GB
# Batch 188/500
# [03:24:19] Starting counting features.
# [03:24:27] Combining Finished. Memory Usage: 5.33GB
# Batch 189/500
# [03:24:27] Starting counting features.
# [03:24:36] Combining Finished. Memory Usage: 5.33GB
# Batch 190/500
# [03:24:36] Starting counting features.
# [03:24:46] Combining Finished. Memory Usage: 5.34GB
# Batch 191/500
# [03:24:46] Starting counting features.
# [03:24:55] Combining Finished. Memory Usage: 5.34GB
# Batch 192/500
# [03:24:55] Starting counting features.
# [03:25:04] Combining Finished. Memory Usage: 5.35GB
# Batch 193/500
# [03:25:04] Starting counting features.
# [03:25:12] Combining Finished. Memory Usage: 5.36GB
# Batch 194/500
# [03:25:12] Starting counting features.
# [03:25:21] Combining Finished. Memory Usage: 5.36GB
# Batch 195/500
# [03:25:21] Starting counting features.
# [03:25:29] Combining Finished. Memory Usage: 5.36GB
# Batch 196/500
# [03:25:29] Starting counting features.
# [03:25:38] Combining Finished. Memory Usage: 5.37GB
# Batch 197/500
# [03:25:38] Starting counting features.
# [03:25:46] Combining Finished. Memory Usage: 5.38GB
# Batch 198/500
# [03:25:46] Starting counting features.
# [03:25:55] Combining Finished. Memory Usage: 5.39GB
# Batch 199/500
# [03:25:55] Starting counting features.
# [03:26:03] Combining Finished. Memory Usage: 5.39GB
# Batch 200/500
# [03:26:03] Starting counting features.
# [03:26:11] Combining Finished. Memory Usage: 5.39GB
# Batch 201/500
# [03:26:11] Starting counting features.
# [03:26:20] Combining Finished. Memory Usage: 5.4GB
# Batch 202/500
# [03:26:20] Starting counting features.
# [03:26:28] Combining Finished. Memory Usage: 5.41GB
# Batch 203/500
# [03:26:28] Starting counting features.
# [03:26:37] Combining Finished. Memory Usage: 5.41GB
# Batch 204/500
# [03:26:37] Starting counting features.
# [03:26:46] Combining Finished. Memory Usage: 5.41GB
# Batch 205/500
# [03:26:46] Starting counting features.
# [03:26:55] Combining Finished. Memory Usage: 5.42GB
# Batch 206/500
# [03:26:55] Starting counting features.
# [03:27:04] Combining Finished. Memory Usage: 5.43GB
# Batch 207/500
# [03:27:04] Starting counting features.
# [03:27:12] Combining Finished. Memory Usage: 5.43GB
# Batch 208/500
# [03:27:12] Starting counting features.
# [03:27:20] Combining Finished. Memory Usage: 5.43GB
# Batch 209/500
# [03:27:20] Starting counting features.
# [03:27:28] Combining Finished. Memory Usage: 5.44GB
# Batch 210/500
# [03:27:28] Starting counting features.
# [03:27:37] Combining Finished. Memory Usage: 5.45GB
# Batch 211/500
# [03:27:37] Starting counting features.
# [03:27:46] Combining Finished. Memory Usage: 5.45GB
# Batch 212/500
# [03:27:46] Starting counting features.
# [03:27:55] Combining Finished. Memory Usage: 5.46GB
# Batch 213/500
# [03:27:55] Starting counting features.
# [03:28:03] Combining Finished. Memory Usage: 5.46GB
# Batch 214/500
# [03:28:03] Starting counting features.
# [03:28:12] Combining Finished. Memory Usage: 5.47GB
# Batch 215/500
# [03:28:12] Starting counting features.
# [03:28:21] Combining Finished. Memory Usage: 5.47GB
# Batch 216/500
# [03:28:21] Starting counting features.
# [03:28:30] Combining Finished. Memory Usage: 5.48GB
# Batch 217/500
# [03:28:30] Starting counting features.
# [03:28:39] Combining Finished. Memory Usage: 5.49GB
# Batch 218/500
# [03:28:39] Starting counting features.
# [03:28:47] Combining Finished. Memory Usage: 5.49GB
# Batch 219/500
# [03:28:47] Starting counting features.
# [03:28:56] Combining Finished. Memory Usage: 5.5GB
# Batch 220/500
# [03:28:56] Starting counting features.
# [03:29:05] Combining Finished. Memory Usage: 5.5GB
# Batch 221/500
# [03:29:05] Starting counting features.
# [03:29:14] Combining Finished. Memory Usage: 5.51GB
# Batch 222/500
# [03:29:14] Starting counting features.
# [03:29:23] Combining Finished. Memory Usage: 5.51GB
# Batch 223/500
# [03:29:23] Starting counting features.
# [03:29:32] Combining Finished. Memory Usage: 5.52GB
# Batch 224/500
# [03:29:32] Starting counting features.
# [03:29:41] Combining Finished. Memory Usage: 5.52GB
# Batch 225/500
# [03:29:41] Starting counting features.
# [03:29:50] Combining Finished. Memory Usage: 5.53GB
# Batch 226/500
# [03:29:50] Starting counting features.
# [03:29:59] Combining Finished. Memory Usage: 5.54GB
# Batch 227/500
# [03:29:59] Starting counting features.
# [03:30:08] Combining Finished. Memory Usage: 5.54GB
# Batch 228/500
# [03:30:08] Starting counting features.
# [03:30:17] Combining Finished. Memory Usage: 5.54GB
# Batch 229/500
# [03:30:17] Starting counting features.
# [03:30:25] Combining Finished. Memory Usage: 5.55GB
# Batch 230/500
# [03:30:25] Starting counting features.
# [03:30:34] Combining Finished. Memory Usage: 5.56GB
# Batch 231/500
# [03:30:34] Starting counting features.
# [03:30:42] Combining Finished. Memory Usage: 5.56GB
# Batch 232/500
# [03:30:42] Starting counting features.
# [03:30:51] Combining Finished. Memory Usage: 5.57GB
# Batch 233/500
# [03:30:51] Starting counting features.
# [03:31:00] Combining Finished. Memory Usage: 5.58GB
# Batch 234/500
# [03:31:00] Starting counting features.
# [03:31:09] Combining Finished. Memory Usage: 5.58GB
# Batch 235/500
# [03:31:09] Starting counting features.
# [03:31:17] Combining Finished. Memory Usage: 5.58GB
# Batch 236/500
# [03:31:17] Starting counting features.
# [03:31:26] Combining Finished. Memory Usage: 5.59GB
# Batch 237/500
# [03:31:26] Starting counting features.
# [03:31:34] Combining Finished. Memory Usage: 5.59GB
# Batch 238/500
# [03:31:34] Starting counting features.
# [03:31:42] Combining Finished. Memory Usage: 5.6GB
# Batch 239/500
# [03:31:42] Starting counting features.
# [03:31:51] Combining Finished. Memory Usage: 5.61GB
# Batch 240/500
# [03:31:51] Starting counting features.
# [03:32:00] Combining Finished. Memory Usage: 5.61GB
# Batch 241/500
# [03:32:00] Starting counting features.
# [03:32:09] Combining Finished. Memory Usage: 5.62GB
# Batch 242/500
# [03:32:09] Starting counting features.
# [03:32:18] Combining Finished. Memory Usage: 5.62GB
# Batch 243/500
# [03:32:18] Starting counting features.
# [03:32:27] Combining Finished. Memory Usage: 5.63GB
# Batch 244/500
# [03:32:27] Starting counting features.
# [03:32:36] Combining Finished. Memory Usage: 5.63GB
# Batch 245/500
# [03:32:36] Starting counting features.
# [03:32:44] Combining Finished. Memory Usage: 5.64GB
# Batch 246/500
# [03:32:44] Starting counting features.
# [03:32:53] Combining Finished. Memory Usage: 5.64GB
# Batch 247/500
# [03:32:53] Starting counting features.
# [03:33:02] Combining Finished. Memory Usage: 5.65GB
# Batch 248/500
# [03:33:02] Starting counting features.
# [03:33:10] Combining Finished. Memory Usage: 5.66GB
# Batch 249/500
# [03:33:10] Starting counting features.
# [03:33:19] Combining Finished. Memory Usage: 5.66GB
# Batch 250/500
# [03:33:19] Starting counting features.
# [03:33:28] Combining Finished. Memory Usage: 5.66GB
# Batch 251/500
# [03:33:28] Starting counting features.
# [03:33:36] Combining Finished. Memory Usage: 5.67GB
# Batch 252/500
# [03:33:36] Starting counting features.
# [03:33:45] Combining Finished. Memory Usage: 5.68GB
# Batch 253/500
# [03:33:45] Starting counting features.
# [03:33:53] Combining Finished. Memory Usage: 5.68GB
# Batch 254/500
# [03:33:53] Starting counting features.
# [03:34:02] Combining Finished. Memory Usage: 5.69GB
# Batch 255/500
# [03:34:02] Starting counting features.
# [03:34:12] Combining Finished. Memory Usage: 5.69GB
# Batch 256/500
# [03:34:12] Starting counting features.
# [03:34:22] Combining Finished. Memory Usage: 5.7GB
# Batch 257/500
# [03:34:22] Starting counting features.
# [03:34:31] Combining Finished. Memory Usage: 5.7GB
# Batch 258/500
# [03:34:31] Starting counting features.
# [03:34:40] Combining Finished. Memory Usage: 5.71GB
# Batch 259/500
# [03:34:40] Starting counting features.
# [03:34:48] Combining Finished. Memory Usage: 5.71GB
# Batch 260/500
# [03:34:48] Starting counting features.
# [03:34:57] Combining Finished. Memory Usage: 5.72GB
# Batch 261/500
# [03:34:57] Starting counting features.
# [03:35:05] Combining Finished. Memory Usage: 5.72GB
# Batch 262/500
# [03:35:05] Starting counting features.
# [03:35:14] Combining Finished. Memory Usage: 5.73GB
# Batch 263/500
# [03:35:14] Starting counting features.
# [03:35:23] Combining Finished. Memory Usage: 5.74GB
# Batch 264/500
# [03:35:23] Starting counting features.
# [03:35:31] Combining Finished. Memory Usage: 5.74GB
# Batch 265/500
# [03:35:31] Starting counting features.
# [03:35:40] Combining Finished. Memory Usage: 5.75GB
# Batch 266/500
# [03:35:40] Starting counting features.
# [03:35:50] Combining Finished. Memory Usage: 5.75GB
# Batch 267/500
# [03:35:50] Starting counting features.
# [03:35:59] Combining Finished. Memory Usage: 5.76GB
# Batch 268/500
# [03:35:59] Starting counting features.
# [03:36:07] Combining Finished. Memory Usage: 5.76GB
# Batch 269/500
# [03:36:07] Starting counting features.
# [03:36:17] Combining Finished. Memory Usage: 5.77GB
# Batch 270/500
# [03:36:17] Starting counting features.
# [03:36:26] Combining Finished. Memory Usage: 5.77GB
# Batch 271/500
# [03:36:26] Starting counting features.
# [03:36:34] Combining Finished. Memory Usage: 5.78GB
# Batch 272/500
# [03:36:34] Starting counting features.
# [03:36:43] Combining Finished. Memory Usage: 5.78GB
# Batch 273/500
# [03:36:43] Starting counting features.
# [03:36:51] Combining Finished. Memory Usage: 5.79GB
# Batch 274/500
# [03:36:51] Starting counting features.
# [03:37:00] Combining Finished. Memory Usage: 5.79GB
# Batch 275/500
# [03:37:00] Starting counting features.
# [03:37:09] Combining Finished. Memory Usage: 5.8GB
# Batch 276/500
# [03:37:09] Starting counting features.
# [03:37:18] Combining Finished. Memory Usage: 5.81GB
# Batch 277/500
# [03:37:18] Starting counting features.
# [03:37:27] Combining Finished. Memory Usage: 5.81GB
# Batch 278/500
# [03:37:27] Starting counting features.
# [03:37:36] Combining Finished. Memory Usage: 5.82GB
# Batch 279/500
# [03:37:36] Starting counting features.
# [03:37:45] Combining Finished. Memory Usage: 5.82GB
# Batch 280/500
# [03:37:45] Starting counting features.
# [03:37:54] Combining Finished. Memory Usage: 5.83GB
# Batch 281/500
# [03:37:54] Starting counting features.
# [03:38:03] Combining Finished. Memory Usage: 5.83GB
# Batch 282/500
# [03:38:03] Starting counting features.
# [03:38:12] Combining Finished. Memory Usage: 5.84GB
# Batch 283/500
# [03:38:12] Starting counting features.
# [03:38:21] Combining Finished. Memory Usage: 5.84GB
# Batch 284/500
# [03:38:21] Starting counting features.
# [03:38:30] Combining Finished. Memory Usage: 5.85GB
# Batch 285/500
# [03:38:30] Starting counting features.
# [03:38:39] Combining Finished. Memory Usage: 5.85GB
# Batch 286/500
# [03:38:39] Starting counting features.
# [03:38:48] Combining Finished. Memory Usage: 5.86GB
# Batch 287/500
# [03:38:48] Starting counting features.
# [03:38:57] Combining Finished. Memory Usage: 5.87GB
# Batch 288/500
# [03:38:57] Starting counting features.
# [03:39:06] Combining Finished. Memory Usage: 5.87GB
# Batch 289/500
# [03:39:06] Starting counting features.
# [03:39:14] Combining Finished. Memory Usage: 5.88GB
# Batch 290/500
# [03:39:14] Starting counting features.
# [03:39:23] Combining Finished. Memory Usage: 5.88GB
# Batch 291/500
# [03:39:23] Starting counting features.
# [03:39:32] Combining Finished. Memory Usage: 5.88GB
# Batch 292/500
# [03:39:32] Starting counting features.
# [03:39:41] Combining Finished. Memory Usage: 5.89GB
# Batch 293/500
# [03:39:41] Starting counting features.
# [03:39:49] Combining Finished. Memory Usage: 5.89GB
# Batch 294/500
# [03:39:49] Starting counting features.
# [03:39:58] Combining Finished. Memory Usage: 5.9GB
# Batch 295/500
# [03:39:58] Starting counting features.
# [03:40:06] Combining Finished. Memory Usage: 5.91GB
# Batch 296/500
# [03:40:06] Starting counting features.
# [03:40:15] Combining Finished. Memory Usage: 5.91GB
# Batch 297/500
# [03:40:15] Starting counting features.
# [03:40:24] Combining Finished. Memory Usage: 5.92GB
# Batch 298/500
# [03:40:24] Starting counting features.
# [03:40:33] Combining Finished. Memory Usage: 5.92GB
# Batch 299/500
# [03:40:33] Starting counting features.
# [03:40:41] Combining Finished. Memory Usage: 5.93GB
# Batch 300/500
# [03:40:41] Starting counting features.
# [03:40:51] Combining Finished. Memory Usage: 5.94GB
# Batch 301/500
# [03:40:51] Starting counting features.
# [03:41:00] Combining Finished. Memory Usage: 5.94GB
# Batch 302/500
# [03:41:00] Starting counting features.
# [03:41:10] Combining Finished. Memory Usage: 5.95GB
# Batch 303/500
# [03:41:10] Starting counting features.
# [03:41:19] Combining Finished. Memory Usage: 5.95GB
# Batch 304/500
# [03:41:19] Starting counting features.
# [03:41:28] Combining Finished. Memory Usage: 5.96GB
# Batch 305/500
# [03:41:28] Starting counting features.
# [03:41:38] Combining Finished. Memory Usage: 5.96GB
# Batch 306/500
# [03:41:38] Starting counting features.
# [03:41:47] Combining Finished. Memory Usage: 5.97GB
# Batch 307/500
# [03:41:47] Starting counting features.
# [03:41:56] Combining Finished. Memory Usage: 5.97GB
# Batch 308/500
# [03:41:56] Starting counting features.
# [03:42:06] Combining Finished. Memory Usage: 5.98GB
# Batch 309/500
# [03:42:06] Starting counting features.
# [03:42:15] Combining Finished. Memory Usage: 5.98GB
# Batch 310/500
# [03:42:15] Starting counting features.
# [03:42:24] Combining Finished. Memory Usage: 5.99GB
# Batch 311/500
# [03:42:24] Starting counting features.
# [03:42:33] Combining Finished. Memory Usage: 6.0GB
# Batch 312/500
# [03:42:33] Starting counting features.
# [03:42:42] Combining Finished. Memory Usage: 6.0GB
# Batch 313/500
# [03:42:42] Starting counting features.
# [03:42:52] Combining Finished. Memory Usage: 6.01GB
# Batch 314/500
# [03:42:52] Starting counting features.
# [03:43:01] Combining Finished. Memory Usage: 6.01GB
# Batch 315/500
# [03:43:01] Starting counting features.
# [03:43:10] Combining Finished. Memory Usage: 6.02GB
# Batch 316/500
# [03:43:10] Starting counting features.
# [03:43:19] Combining Finished. Memory Usage: 6.02GB
# Batch 317/500
# [03:43:19] Starting counting features.
# [03:43:27] Combining Finished. Memory Usage: 6.03GB
# Batch 318/500
# [03:43:27] Starting counting features.
# [03:43:37] Combining Finished. Memory Usage: 6.03GB
# Batch 319/500
# [03:43:37] Starting counting features.
# [03:43:46] Combining Finished. Memory Usage: 6.04GB
# Batch 320/500
# [03:43:46] Starting counting features.
# [03:43:55] Combining Finished. Memory Usage: 6.04GB
# Batch 321/500
# [03:43:55] Starting counting features.
# [03:44:05] Combining Finished. Memory Usage: 6.05GB
# Batch 322/500
# [03:44:05] Starting counting features.
# [03:44:15] Combining Finished. Memory Usage: 6.05GB
# Batch 323/500
# [03:44:15] Starting counting features.
# [03:44:23] Combining Finished. Memory Usage: 6.06GB
# Batch 324/500
# [03:44:23] Starting counting features.
# [03:44:32] Combining Finished. Memory Usage: 6.07GB
# Batch 325/500
# [03:44:32] Starting counting features.
# [03:44:41] Combining Finished. Memory Usage: 6.07GB
# Batch 326/500
# [03:44:41] Starting counting features.
# [03:44:51] Combining Finished. Memory Usage: 6.07GB
# Batch 327/500
# [03:44:51] Starting counting features.
# [03:45:00] Combining Finished. Memory Usage: 6.08GB
# Batch 328/500
# [03:45:00] Starting counting features.
# [03:45:08] Combining Finished. Memory Usage: 6.09GB
# Batch 329/500
# [03:45:08] Starting counting features.
# [03:45:17] Combining Finished. Memory Usage: 6.09GB
# Batch 330/500
# [03:45:17] Starting counting features.
# [03:45:26] Combining Finished. Memory Usage: 6.1GB
# Batch 331/500
# [03:45:26] Starting counting features.
# [03:45:35] Combining Finished. Memory Usage: 6.11GB
# Batch 332/500
# [03:45:35] Starting counting features.
# [03:45:44] Combining Finished. Memory Usage: 6.11GB
# Batch 333/500
# [03:45:44] Starting counting features.
# [03:45:54] Combining Finished. Memory Usage: 6.11GB
# Batch 334/500
# [03:45:54] Starting counting features.
# [03:46:03] Combining Finished. Memory Usage: 6.12GB
# Batch 335/500
# [03:46:03] Starting counting features.
# [03:46:12] Combining Finished. Memory Usage: 6.13GB
# Batch 336/500
# [03:46:12] Starting counting features.
# [03:46:21] Combining Finished. Memory Usage: 6.13GB
# Batch 337/500
# [03:46:21] Starting counting features.
# [03:46:30] Combining Finished. Memory Usage: 6.13GB
# Batch 338/500
# [03:46:30] Starting counting features.
# [03:46:39] Combining Finished. Memory Usage: 6.14GB
# Batch 339/500
# [03:46:39] Starting counting features.
# [03:46:48] Combining Finished. Memory Usage: 6.14GB
# Batch 340/500
# [03:46:48] Starting counting features.
# [03:46:58] Combining Finished. Memory Usage: 6.15GB
# Batch 341/500
# [03:46:58] Starting counting features.
# [03:47:06] Combining Finished. Memory Usage: 6.15GB
# Batch 342/500
# [03:47:06] Starting counting features.
# [03:47:15] Combining Finished. Memory Usage: 6.16GB
# Batch 343/500
# [03:47:15] Starting counting features.
# [03:47:24] Combining Finished. Memory Usage: 6.16GB
# Batch 344/500
# [03:47:24] Starting counting features.
# [03:47:33] Combining Finished. Memory Usage: 6.17GB
# Batch 345/500
# [03:47:33] Starting counting features.
# [03:47:42] Combining Finished. Memory Usage: 6.18GB
# Batch 346/500
# [03:47:42] Starting counting features.
# [03:47:50] Combining Finished. Memory Usage: 6.18GB
# Batch 347/500
# [03:47:50] Starting counting features.
# [03:48:00] Combining Finished. Memory Usage: 6.19GB
# Batch 348/500
# [03:48:00] Starting counting features.
# [03:48:09] Combining Finished. Memory Usage: 6.19GB
# Batch 349/500
# [03:48:09] Starting counting features.
# [03:48:19] Combining Finished. Memory Usage: 6.2GB
# Batch 350/500
# [03:48:19] Starting counting features.
# [03:48:28] Combining Finished. Memory Usage: 6.21GB
# Batch 351/500
# [03:48:28] Starting counting features.
# [03:48:37] Combining Finished. Memory Usage: 6.21GB
# Batch 352/500
# [03:48:37] Starting counting features.
# [03:48:45] Combining Finished. Memory Usage: 6.22GB
# Batch 353/500
# [03:48:45] Starting counting features.
# [03:48:54] Combining Finished. Memory Usage: 6.22GB
# Batch 354/500
# [03:48:54] Starting counting features.
# [03:49:03] Combining Finished. Memory Usage: 6.22GB
# Batch 355/500
# [03:49:03] Starting counting features.
# [03:49:12] Combining Finished. Memory Usage: 6.24GB
# Batch 356/500
# [03:49:12] Starting counting features.
# [03:49:21] Combining Finished. Memory Usage: 6.24GB
# Batch 357/500
# [03:49:21] Starting counting features.
# [03:49:29] Combining Finished. Memory Usage: 6.25GB
# Batch 358/500
# [03:49:29] Starting counting features.
# [03:49:38] Combining Finished. Memory Usage: 6.25GB
# Batch 359/500
# [03:49:38] Starting counting features.
# [03:49:47] Combining Finished. Memory Usage: 6.25GB
# Batch 360/500
# [03:49:47] Starting counting features.
# [03:49:57] Combining Finished. Memory Usage: 6.26GB
# Batch 361/500
# [03:49:57] Starting counting features.
# [03:50:06] Combining Finished. Memory Usage: 6.27GB
# Batch 362/500
# [03:50:06] Starting counting features.
# [03:50:16] Combining Finished. Memory Usage: 6.27GB
# Batch 363/500
# [03:50:16] Starting counting features.
# [03:50:26] Combining Finished. Memory Usage: 6.28GB
# Batch 364/500
# [03:50:26] Starting counting features.
# [03:50:35] Combining Finished. Memory Usage: 6.28GB
# Batch 365/500
# [03:50:35] Starting counting features.
# [03:50:44] Combining Finished. Memory Usage: 6.29GB
# Batch 366/500
# [03:50:44] Starting counting features.
# [03:50:53] Combining Finished. Memory Usage: 6.29GB
# Batch 367/500
# [03:50:53] Starting counting features.
# [03:51:03] Combining Finished. Memory Usage: 6.3GB
# Batch 368/500
# [03:51:03] Starting counting features.
# [03:51:11] Combining Finished. Memory Usage: 6.3GB
# Batch 369/500
# [03:51:11] Starting counting features.
# [03:51:20] Combining Finished. Memory Usage: 6.31GB
# Batch 370/500
# [03:51:20] Starting counting features.
# [03:51:29] Combining Finished. Memory Usage: 6.31GB
# Batch 371/500
# [03:51:29] Starting counting features.
# [03:51:38] Combining Finished. Memory Usage: 6.32GB
# Batch 372/500
# [03:51:38] Starting counting features.
# [03:51:46] Combining Finished. Memory Usage: 6.32GB
# Batch 373/500
# [03:51:46] Starting counting features.
# [03:51:56] Combining Finished. Memory Usage: 6.33GB
# Batch 374/500
# [03:51:56] Starting counting features.
# [03:52:05] Combining Finished. Memory Usage: 6.34GB
# Batch 375/500
# [03:52:05] Starting counting features.
# [03:52:14] Combining Finished. Memory Usage: 6.34GB
# Batch 376/500
# [03:52:14] Starting counting features.
# [03:52:23] Combining Finished. Memory Usage: 6.35GB
# Batch 377/500
# [03:52:23] Starting counting features.
# [03:52:33] Combining Finished. Memory Usage: 6.35GB
# Batch 378/500
# [03:52:33] Starting counting features.
# [03:52:41] Combining Finished. Memory Usage: 6.36GB
# Batch 379/500
# [03:52:41] Starting counting features.
# [03:52:51] Combining Finished. Memory Usage: 6.36GB
# Batch 380/500
# [03:52:51] Starting counting features.
# [03:53:00] Combining Finished. Memory Usage: 6.37GB
# Batch 381/500
# [03:53:00] Starting counting features.
# [03:53:09] Combining Finished. Memory Usage: 6.37GB
# Batch 382/500
# [03:53:10] Starting counting features.
# [03:53:19] Combining Finished. Memory Usage: 6.38GB
# Batch 383/500
# [03:53:19] Starting counting features.
# [03:53:28] Combining Finished. Memory Usage: 6.39GB
# Batch 384/500
# [03:53:28] Starting counting features.
# [03:53:36] Combining Finished. Memory Usage: 6.39GB
# Batch 385/500
# [03:53:36] Starting counting features.
# [03:53:45] Combining Finished. Memory Usage: 6.4GB
# Batch 386/500
# [03:53:45] Starting counting features.
# [03:53:54] Combining Finished. Memory Usage: 6.4GB
# Batch 387/500
# [03:53:54] Starting counting features.
# [03:54:03] Combining Finished. Memory Usage: 6.4GB
# Batch 388/500
# [03:54:03] Starting counting features.
# [03:54:12] Combining Finished. Memory Usage: 6.41GB
# Batch 389/500
# [03:54:12] Starting counting features.
# [03:54:21] Combining Finished. Memory Usage: 6.42GB
# Batch 390/500
# [03:54:21] Starting counting features.
# [03:54:30] Combining Finished. Memory Usage: 6.42GB
# Batch 391/500
# [03:54:30] Starting counting features.
# [03:54:39] Combining Finished. Memory Usage: 6.43GB
# Batch 392/500
# [03:54:39] Starting counting features.
# [03:54:48] Combining Finished. Memory Usage: 6.43GB
# Batch 393/500
# [03:54:48] Starting counting features.
# [03:54:57] Combining Finished. Memory Usage: 6.44GB
# Batch 394/500
# [03:54:57] Starting counting features.
# [03:55:06] Combining Finished. Memory Usage: 6.45GB
# Batch 395/500
# [03:55:06] Starting counting features.
# [03:55:16] Combining Finished. Memory Usage: 6.45GB
# Batch 396/500
# [03:55:16] Starting counting features.
# [03:55:25] Combining Finished. Memory Usage: 6.45GB
# Batch 397/500
# [03:55:25] Starting counting features.
# [03:55:35] Combining Finished. Memory Usage: 6.46GB
# Batch 398/500
# [03:55:35] Starting counting features.
# [03:55:44] Combining Finished. Memory Usage: 6.47GB
# Batch 399/500
# [03:55:44] Starting counting features.
# [03:55:53] Combining Finished. Memory Usage: 6.47GB
# Batch 400/500
# [03:55:53] Starting counting features.
# [03:56:03] Combining Finished. Memory Usage: 6.48GB
# Batch 401/500
# [03:56:03] Starting counting features.
# [03:56:11] Combining Finished. Memory Usage: 6.48GB
# Batch 402/500
# [03:56:12] Starting counting features.
# [03:56:21] Combining Finished. Memory Usage: 6.49GB
# Batch 403/500
# [03:56:21] Starting counting features.
# [03:56:30] Combining Finished. Memory Usage: 6.49GB
# Batch 404/500
# [03:56:30] Starting counting features.
# [03:56:38] Combining Finished. Memory Usage: 6.5GB
# Batch 405/500
# [03:56:38] Starting counting features.
# [03:56:47] Combining Finished. Memory Usage: 6.51GB
# Batch 406/500
# [03:56:47] Starting counting features.
# [03:56:56] Combining Finished. Memory Usage: 6.51GB
# Batch 407/500
# [03:56:56] Starting counting features.
# [03:57:05] Combining Finished. Memory Usage: 6.52GB
# Batch 408/500
# [03:57:05] Starting counting features.
# [03:57:15] Combining Finished. Memory Usage: 6.52GB
# Batch 409/500
# [03:57:15] Starting counting features.
# [03:57:23] Combining Finished. Memory Usage: 6.52GB
# Batch 410/500
# [03:57:23] Starting counting features.
# [03:57:32] Combining Finished. Memory Usage: 6.53GB
# Batch 411/500
# [03:57:32] Starting counting features.
# [03:57:41] Combining Finished. Memory Usage: 6.54GB
# Batch 412/500
# [03:57:41] Starting counting features.
# [03:57:50] Combining Finished. Memory Usage: 6.54GB
# Batch 413/500
# [03:57:50] Starting counting features.
# [03:57:59] Combining Finished. Memory Usage: 6.55GB
# Batch 414/500
# [03:57:59] Starting counting features.
# [03:58:08] Combining Finished. Memory Usage: 6.56GB
# Batch 415/500
# [03:58:08] Starting counting features.
# [03:58:17] Combining Finished. Memory Usage: 6.56GB
# Batch 416/500
# [03:58:17] Starting counting features.
# [03:58:26] Combining Finished. Memory Usage: 6.57GB
# Batch 417/500
# [03:58:26] Starting counting features.
# [03:58:36] Combining Finished. Memory Usage: 6.57GB
# Batch 418/500
# [03:58:36] Starting counting features.
# [03:58:45] Combining Finished. Memory Usage: 6.58GB
# Batch 419/500
# [03:58:45] Starting counting features.
# [03:58:54] Combining Finished. Memory Usage: 6.58GB
# Batch 420/500
# [03:58:54] Starting counting features.
# [03:59:03] Combining Finished. Memory Usage: 6.58GB
# Batch 421/500
# [03:59:03] Starting counting features.
# [03:59:11] Combining Finished. Memory Usage: 6.59GB
# Batch 422/500
# [03:59:11] Starting counting features.
# [03:59:20] Combining Finished. Memory Usage: 6.6GB
# Batch 423/500
# [03:59:20] Starting counting features.
# [03:59:29] Combining Finished. Memory Usage: 6.6GB
# Batch 424/500
# [03:59:29] Starting counting features.
# [03:59:38] Combining Finished. Memory Usage: 6.61GB
# Batch 425/500
# [03:59:38] Starting counting features.
# [03:59:47] Combining Finished. Memory Usage: 6.61GB
# Batch 426/500
# [03:59:47] Starting counting features.
# [03:59:57] Combining Finished. Memory Usage: 6.62GB
# Batch 427/500
# [03:59:57] Starting counting features.
# [04:00:06] Combining Finished. Memory Usage: 6.62GB
# Batch 428/500
# [04:00:06] Starting counting features.
# [04:00:16] Combining Finished. Memory Usage: 6.63GB
# Batch 429/500
# [04:00:16] Starting counting features.
# [04:00:25] Combining Finished. Memory Usage: 6.63GB
# Batch 430/500
# [04:00:25] Starting counting features.
# [04:00:34] Combining Finished. Memory Usage: 6.64GB
# Batch 431/500
# [04:00:34] Starting counting features.
# [04:00:43] Combining Finished. Memory Usage: 6.65GB
# Batch 432/500
# [04:00:43] Starting counting features.
# [04:00:53] Combining Finished. Memory Usage: 6.65GB
# Batch 433/500
# [04:00:53] Starting counting features.
# [04:01:02] Combining Finished. Memory Usage: 6.66GB
# Batch 434/500
# [04:01:02] Starting counting features.
# [04:01:11] Combining Finished. Memory Usage: 6.66GB
# Batch 435/500
# [04:01:11] Starting counting features.
# [04:01:20] Combining Finished. Memory Usage: 6.67GB
# Batch 436/500
# [04:01:20] Starting counting features.
# [04:01:30] Combining Finished. Memory Usage: 6.67GB
# Batch 437/500
# [04:01:30] Starting counting features.
# [04:01:39] Combining Finished. Memory Usage: 6.68GB
# Batch 438/500
# [04:01:39] Starting counting features.
# [04:01:49] Combining Finished. Memory Usage: 6.68GB
# Batch 439/500
# [04:01:49] Starting counting features.
# [04:01:58] Combining Finished. Memory Usage: 6.69GB
# Batch 440/500
# [04:01:58] Starting counting features.
# [04:02:07] Combining Finished. Memory Usage: 6.69GB
# Batch 441/500
# [04:02:07] Starting counting features.
# [04:02:16] Combining Finished. Memory Usage: 6.7GB
# Batch 442/500
# [04:02:16] Starting counting features.
# [04:02:25] Combining Finished. Memory Usage: 6.7GB
# Batch 443/500
# [04:02:25] Starting counting features.
# [04:02:34] Combining Finished. Memory Usage: 6.71GB
# Batch 444/500
# [04:02:34] Starting counting features.
# [04:02:43] Combining Finished. Memory Usage: 6.71GB
# Batch 445/500
# [04:02:43] Starting counting features.
# [04:02:52] Combining Finished. Memory Usage: 6.72GB
# Batch 446/500
# [04:02:52] Starting counting features.
# [04:03:01] Combining Finished. Memory Usage: 6.73GB
# Batch 447/500
# [04:03:01] Starting counting features.
# [04:03:11] Combining Finished. Memory Usage: 6.73GB
# Batch 448/500
# [04:03:11] Starting counting features.
# [04:03:20] Combining Finished. Memory Usage: 6.73GB
# Batch 449/500
# [04:03:20] Starting counting features.
# [04:03:29] Combining Finished. Memory Usage: 6.74GB
# Batch 450/500
# [04:03:29] Starting counting features.
# [04:03:39] Combining Finished. Memory Usage: 6.75GB
# Batch 451/500
# [04:03:39] Starting counting features.
# [04:03:49] Combining Finished. Memory Usage: 6.76GB
# Batch 452/500
# [04:03:49] Starting counting features.
# [04:03:58] Combining Finished. Memory Usage: 6.76GB
# Batch 453/500
# [04:03:58] Starting counting features.
# [04:04:08] Combining Finished. Memory Usage: 6.77GB
# Batch 454/500
# [04:04:08] Starting counting features.
# [04:04:17] Combining Finished. Memory Usage: 6.77GB
# Batch 455/500
# [04:04:17] Starting counting features.
# [04:04:26] Combining Finished. Memory Usage: 6.78GB
# Batch 456/500
# [04:04:26] Starting counting features.
# [04:04:35] Combining Finished. Memory Usage: 6.78GB
# Batch 457/500
# [04:04:35] Starting counting features.
# [04:04:45] Combining Finished. Memory Usage: 6.79GB
# Batch 458/500
# [04:04:45] Starting counting features.
# [04:04:54] Combining Finished. Memory Usage: 6.79GB
# Batch 459/500
# [04:04:54] Starting counting features.
# [04:05:03] Combining Finished. Memory Usage: 6.8GB
# Batch 460/500
# [04:05:03] Starting counting features.
# [04:05:12] Combining Finished. Memory Usage: 6.8GB
# Batch 461/500
# [04:05:12] Starting counting features.
# [04:05:21] Combining Finished. Memory Usage: 6.81GB
# Batch 462/500
# [04:05:21] Starting counting features.
# [04:05:31] Combining Finished. Memory Usage: 6.81GB
# Batch 463/500
# [04:05:31] Starting counting features.
# [04:05:40] Combining Finished. Memory Usage: 6.82GB
# Batch 464/500
# [04:05:40] Starting counting features.
# [04:05:49] Combining Finished. Memory Usage: 6.82GB
# Batch 465/500
# [04:05:49] Starting counting features.
# [04:05:58] Combining Finished. Memory Usage: 6.83GB
# Batch 466/500
# [04:05:58] Starting counting features.
# [04:06:09] Combining Finished. Memory Usage: 6.83GB
# Batch 467/500
# [04:06:09] Starting counting features.
# [04:06:19] Combining Finished. Memory Usage: 6.84GB
# Batch 468/500
# [04:06:19] Starting counting features.
# [04:06:29] Combining Finished. Memory Usage: 6.84GB
# Batch 469/500
# [04:06:29] Starting counting features.
# [04:06:40] Combining Finished. Memory Usage: 6.85GB
# Batch 470/500
# [04:06:40] Starting counting features.
# [04:06:49] Combining Finished. Memory Usage: 6.86GB
# Batch 471/500
# [04:06:49] Starting counting features.
# [04:06:59] Combining Finished. Memory Usage: 6.86GB
# Batch 472/500
# [04:06:59] Starting counting features.
# [04:07:08] Combining Finished. Memory Usage: 6.87GB
# Batch 473/500
# [04:07:08] Starting counting features.
# [04:07:17] Combining Finished. Memory Usage: 6.87GB
# Batch 474/500
# [04:07:17] Starting counting features.
# [04:07:27] Combining Finished. Memory Usage: 6.88GB
# Batch 475/500
# [04:07:27] Starting counting features.
# [04:07:37] Combining Finished. Memory Usage: 6.88GB
# Batch 476/500
# [04:07:37] Starting counting features.
# [04:07:47] Combining Finished. Memory Usage: 6.89GB
# Batch 477/500
# [04:07:47] Starting counting features.
# [04:07:56] Combining Finished. Memory Usage: 6.89GB
# Batch 478/500
# [04:07:56] Starting counting features.
# [04:08:05] Combining Finished. Memory Usage: 6.9GB
# Batch 479/500
# [04:08:05] Starting counting features.
# [04:08:14] Combining Finished. Memory Usage: 6.91GB
# Batch 480/500
# [04:08:14] Starting counting features.
# [04:08:24] Combining Finished. Memory Usage: 6.91GB
# Batch 481/500
# [04:08:24] Starting counting features.
# [04:08:33] Combining Finished. Memory Usage: 6.92GB
# Batch 482/500
# [04:08:33] Starting counting features.
# [04:08:42] Combining Finished. Memory Usage: 6.92GB
# Batch 483/500
# [04:08:42] Starting counting features.
# [04:08:52] Combining Finished. Memory Usage: 6.93GB
# Batch 484/500
# [04:08:52] Starting counting features.
# [04:09:01] Combining Finished. Memory Usage: 6.94GB
# Batch 485/500
# [04:09:01] Starting counting features.
# [04:09:10] Combining Finished. Memory Usage: 6.93GB
# Batch 486/500
# [04:09:10] Starting counting features.
# [04:09:20] Combining Finished. Memory Usage: 6.94GB
# Batch 487/500
# [04:09:20] Starting counting features.
# [04:09:29] Combining Finished. Memory Usage: 6.95GB
# Batch 488/500
# [04:09:29] Starting counting features.
# [04:09:39] Combining Finished. Memory Usage: 6.95GB
# Batch 489/500
# [04:09:39] Starting counting features.
# [04:09:48] Combining Finished. Memory Usage: 6.96GB
# Batch 490/500
# [04:09:48] Starting counting features.
# [04:09:58] Combining Finished. Memory Usage: 6.96GB
# Batch 491/500
# [04:09:58] Starting counting features.
# [04:10:07] Combining Finished. Memory Usage: 6.97GB
# Batch 492/500
# [04:10:07] Starting counting features.
# [04:10:17] Combining Finished. Memory Usage: 6.97GB
# Batch 493/500
# [04:10:17] Starting counting features.
# [04:10:27] Combining Finished. Memory Usage: 6.98GB
# Batch 494/500
# [04:10:27] Starting counting features.
# [04:10:35] Combining Finished. Memory Usage: 6.99GB
# Batch 495/500
# [04:10:35] Starting counting features.
# [04:10:45] Combining Finished. Memory Usage: 6.99GB
# Batch 496/500
# [04:10:45] Starting counting features.
# [04:10:55] Combining Finished. Memory Usage: 7.0GB
# Batch 497/500
# [04:10:55] Starting counting features.
# [04:11:04] Combining Finished. Memory Usage: 7.0GB
# Batch 498/500
# [04:11:04] Starting counting features.
# [04:11:14] Combining Finished. Memory Usage: 7.01GB
# Batch 499/500
# [04:11:14] Starting counting features.
# [04:11:23] Combining Finished. Memory Usage: 7.01GB
# Memory Usage at this moment: 7.0GB

# %%
print("[{}] Starting merging results.".format(strftime("%H:%M:%S", gmtime())))
counter_dict = merge_counter_dicts(counter_dicts)
print("[{}] Merging done.".format(strftime("%H:%M:%S", gmtime())))
print("Memory Usage at this moment: {}".format(get_memory_str()))
# Out:
# [04:11:23] Starting merging results.
# [04:11:55] Merging done.
# Memory Usage at this moment: 7.03GB

# %%
while len(counter_dicts) > 0:
    del counter_dicts[0]
del counter_dicts
gc.collect()
print("Memory Usage at this moment: {}".format(get_memory_str()))
# Out:
# Memory Usage at this moment: 6.91GB

# %%
def counter_to_csv(counter, filepath):
    with open(filepath, "w") as f:
        f.write("value,counts\n")
        for k, v in counter.most_common():
            f.write("{},{}\n".format(k, v))

# %%
out_folder = out_folder = '../data/counter/preliminary_contest_data/'
os.makedirs(out_folder, exist_ok=True)
for feat_name, counter in counter_dict.items():
    out_file = "userFeature.[featureName='{}'].csv".format(feat_name)
    out_path = os.path.join(out_folder, out_file)
    counter_to_csv(counter, out_path)

# %%
def save_as_pickle(obj, filepath):
    with open(filepath, "wb") as f:
        pickle.dump(obj, f)

# %%
vocab_folder = '../data/vocabulary/preliminary_contest_data/'
os.makedirs(vocab_folder, exist_ok=True)
for feat_name, counter in counter_dict.items():
    vocab_file = "userFeature.[featureName='{}'].pkl".format(feat_name)
    vocab_path = os.path.join(vocab_folder, vocab_file)
    save_as_pickle(list(counter.keys()), vocab_path)

# %%
def merge_counter_dict(counter_dict):
    final_counter = Counter()
    for name, counter in counter_dict.items():
        new_counter = Counter({"{}_{}".format(name, k): v for k, v in counter.items()})
        final_counter += new_counter
    return final_counter

# %%
large_counter = merge_counter_dict(counter_dict)
print("Memory Usage at this moment: {}".format(get_memory_str())) 
print("Cleaning memory...")
for feat_name in feat_names:
    del counter_dict[feat_name]
del counter_dict
gc.collect()
print("Memory Usage at this moment: {}".format(get_memory_str()))
# Out:
# Memory Usage at this moment: 6.91GB
# Cleaning memory...
# Memory Usage at this moment: 5.77GB

# %%
out_folder = '../data/counter/preliminary_contest_data/'
out_file = "userFeature.csv"
out_path = os.path.join(out_folder, out_file)
counter_to_csv(large_counter, out_path)

# %%
vocab_folder = '../data/vocabulary/preliminary_contest_data/'
vocab_file = "userFeature.pkl"
vocab_path = os.path.join(vocab_folder, vocab_file)
save_as_pickle(list(large_counter.keys()), vocab_path)

# %%
print("Total feature value(word) counts: {}".format(len(large_counter)))
# Out:
# Total feature value(word) counts: 419204
