# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import time
import os
import gc
import tqdm
from sklearn import metrics
from sklearn.preprocessing import StandardScaler, RobustScaler, Normalizer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold
import sys
sys.path.append('../../../code/utils/')
sys.path.append('../../../code/feature/')
import data_utils as du
import perf_utils as pu
from clickrate import NaiveSmoothedClickrate

# %%
click_history_folder = "../../../data/click_history/simple_cross/byUserFeatureName/"

# %%
def load_user_history(user_feat_name, ad_feat_name, ad_feat_val):
    folder = os.path.join(click_history_folder, "[featureName='{}']".format(user_feat_name))
    filename = "[{}='{}'].csv".format(ad_feat_name, ad_feat_val)
    filepath = os.path.join(folder, filename)
    return pd.read_csv(filepath)

# %%
ad_num_feat_names = ['creativeSize']
ad_cat_feat_names = ['aid', 'advertiserId', 'campaignId', 'creativeId', 'adCategoryId', 'productId', 'productType']
ad_feat_names = ad_num_feat_names + ad_cat_feat_names

# %%
user_one_feat_names = ['age', 'gender', 'education', 'consumptionAbility', 'LBS',
                  'carrier', 'house']  # one user has only one value
user_multi_feat_names = ['marriageStatus', 'interest1', 'interest2', 'interest3',
                   'interest4', 'interest5', 'kw1', 'kw2', 'kw3', 'topic1',
                   'topic2', 'topic3', 'appIdInstall', 'appIdAction', 'ct', 'os'] 
user_feat_names = user_one_feat_names + user_multi_feat_names

# %%
df_train = du.load_raw_data("train")
y = df_train['label'].values
y = (y + 1) / 2
df_ad = du.load_raw_data("ad")

# %%
avals = {ad_feat_name: df_ad[ad_feat_name].unique() for ad_feat_name in ad_feat_names}

# %%
clickrate_folder = "../../../data/clickrate_ns/simple_cross/byUserFeatureName/"  # ns for naive smoothing
os.makedirs(clickrate_folder, exist_ok=True)

# %%
for user_feat_name in user_feat_names:
    for ad_feat_name in ad_feat_names:
        # define output path and data structure to keep the records
        out_folder = os.path.join(clickrate_folder, "[featureName='{}']".format(user_feat_name))
        out_file = "[adFeatureName='{}'].csv".format(ad_feat_name)
        out_path = os.path.join(out_folder, out_file)
        os.makedirs(out_folder, exist_ok=True)
        df_clickrate = pd.DataFrame(columns=["ad_val", "user_val", "ns_clickrate", "click", "impression"])

        for aval in tqdm.tqdm(avals[ad_feat_name], desc="Fitting ad['{}'] x user['{}']...".format(ad_feat_name, 
                                                                                                  user_feat_name)):
            # prepare data
            feat_stats = load_user_history(user_feat_name, ad_feat_name, aval)
            feat_stats = feat_stats[feat_stats['value'] != 'all']
            feat_stats["impression"] = feat_stats["positive"] + feat_stats["negative"]
            feat_stats = feat_stats.rename(columns={"positive": "click", "value": "user_val"})

            # fit naive smoothing
            imps = feat_stats["impression"].values
            clks = feat_stats["click"].values
            ns = NaiveSmoothedClickrate()
            ns.fit(imps, clks)

            # transform raw feature to bayesian smoothed click rate
            ns_crs = ns.transform(imps, clks)
            feat_stats["ns_clickrate"] = ns_crs

            # update global info for current feature
            feat_stats["ad_val"] = aval
            df_clickrate = df_clickrate.append(feat_stats[["ad_val", "user_val", 
                                                           "ns_clickrate", "click", "impression"]])

        df_clickrate["click"] = df_clickrate["click"].astype(int)
        df_clickrate["impression"] = df_clickrate["impression"].astype(int)
        df_clickrate = df_clickrate.sort_values(["ns_clickrate", "click"], ascending=False)
        df_clickrate.to_csv(out_path, columns=["ad_val", "user_val", "ns_clickrate", "click", "impression"], index=False)
        
        del df_clickrate
        del feat_stats
        del ns_crs
        del imps
        del clks
        gc.collect()
# Out:
# Fitting ad['creativeSize'] x user['age']...: 100%|██████████| 15/15 [00:00<00:00, 21.39it/s]
# Fitting ad['productType'] x user['consumptionAbility']...: 100%|██████████| 4/4 [00:00<00:00, 23.09it/s]
# Fitting ad['creativeSize'] x user['LBS']...: 100%|██████████| 15/15 [00:00<00:00, 23.13it/s]
# Fitting ad['aid'] x user['LBS']...: 100%|██████████| 173/173 [00:08<00:00, 19.64it/s]
# Fitting ad['advertiserId'] x user['LBS']...: 100%|██████████| 79/79 [00:03<00:00, 21.82it/s]
# Fitting ad['campaignId'] x user['LBS']...: 100%|██████████| 138/138 [00:06<00:00, 20.58it/s]
# Fitting ad['creativeId'] x user['LBS']...: 100%|██████████| 173/173 [00:08<00:00, 20.07it/s]
# Fitting ad['adCategoryId'] x user['LBS']...: 100%|██████████| 40/40 [00:01<00:00, 23.57it/s]
# Fitting ad['productId'] x user['LBS']...: 100%|██████████| 33/33 [00:01<00:00, 23.69it/s]
# Fitting ad['productType'] x user['LBS']...: 100%|██████████| 4/4 [00:00<00:00, 22.69it/s]
# Fitting ad['creativeSize'] x user['carrier']...: 100%|██████████| 15/15 [00:00<00:00, 24.96it/s]
# Fitting ad['aid'] x user['carrier']...: 100%|██████████| 173/173 [00:07<00:00, 24.54it/s]
# Fitting ad['advertiserId'] x user['carrier']...: 100%|██████████| 79/79 [00:03<00:00, 24.16it/s]
# Fitting ad['campaignId'] x user['carrier']...: 100%|██████████| 138/138 [00:05<00:00, 24.51it/s]
# Fitting ad['creativeId'] x user['carrier']...: 100%|██████████| 173/173 [00:06<00:00, 24.80it/s]
# Fitting ad['adCategoryId'] x user['carrier']...: 100%|██████████| 40/40 [00:01<00:00, 24.78it/s]
# Fitting ad['productId'] x user['carrier']...: 100%|██████████| 33/33 [00:01<00:00, 24.57it/s]
# Fitting ad['productType'] x user['carrier']...: 100%|██████████| 4/4 [00:00<00:00, 23.19it/s]
# Fitting ad['creativeSize'] x user['house']...: 100%|██████████| 15/15 [00:00<00:00, 25.74it/s]
# Fitting ad['aid'] x user['house']...: 100%|██████████| 173/173 [00:06<00:00, 24.99it/s]
# Fitting ad['advertiserId'] x user['house']...: 100%|██████████| 79/79 [00:03<00:00, 24.31it/s]
# Fitting ad['campaignId'] x user['house']...: 100%|██████████| 138/138 [00:05<00:00, 24.02it/s]
# Fitting ad['creativeId'] x user['house']...: 100%|██████████| 173/173 [00:08<00:00, 21.29it/s]
# Fitting ad['adCategoryId'] x user['house']...: 100%|██████████| 40/40 [00:01<00:00, 25.00it/s]
# Fitting ad['productId'] x user['house']...: 100%|██████████| 33/33 [00:01<00:00, 24.33it/s]
# Fitting ad['productType'] x user['house']...: 100%|██████████| 4/4 [00:00<00:00, 24.03it/s]
# Fitting ad['creativeSize'] x user['marriageStatus']...: 100%|██████████| 15/15 [00:00<00:00, 24.24it/s]
# Fitting ad['aid'] x user['marriageStatus']...: 100%|██████████| 173/173 [00:07<00:00, 22.28it/s]
# Fitting ad['advertiserId'] x user['marriageStatus']...: 100%|██████████| 79/79 [00:03<00:00, 25.08it/s]
# Fitting ad['campaignId'] x user['marriageStatus']...: 100%|██████████| 138/138 [00:05<00:00, 23.67it/s]
# Fitting ad['creativeId'] x user['marriageStatus']...: 100%|██████████| 173/173 [00:06<00:00, 25.14it/s]
# Fitting ad['adCategoryId'] x user['marriageStatus']...: 100%|██████████| 40/40 [00:01<00:00, 25.80it/s]
# Fitting ad['creativeId'] x user['interest4']...: 100%|██████████| 173/173 [00:07<00:00, 23.45it/s]
# Fitting ad['adCategoryId'] x user['interest4']...: 100%|██████████| 40/40 [00:01<00:00, 23.90it/s]
# Fitting ad['productId'] x user['interest4']...: 100%|██████████| 33/33 [00:01<00:00, 24.36it/s]
# Fitting ad['productType'] x user['interest4']...: 100%|██████████| 4/4 [00:00<00:00, 24.57it/s]
# Fitting ad['creativeSize'] x user['interest5']...: 100%|██████████| 15/15 [00:00<00:00, 24.00it/s]
# Fitting ad['aid'] x user['interest5']...: 100%|██████████| 173/173 [00:07<00:00, 23.11it/s]
# Fitting ad['advertiserId'] x user['interest5']...: 100%|██████████| 79/79 [00:03<00:00, 23.62it/s]
# Fitting ad['campaignId'] x user['interest5']...: 100%|██████████| 138/138 [00:06<00:00, 22.46it/s]
# Fitting ad['creativeId'] x user['interest5']...: 100%|██████████| 173/173 [00:08<00:00, 19.73it/s]
# Fitting ad['adCategoryId'] x user['interest5']...: 100%|██████████| 40/40 [00:01<00:00, 22.29it/s]
# Fitting ad['productId'] x user['interest5']...: 100%|██████████| 33/33 [00:01<00:00, 23.57it/s]
# Fitting ad['productType'] x user['interest5']...: 100%|██████████| 4/4 [00:00<00:00, 21.92it/s]
# Fitting ad['creativeSize'] x user['kw1']...: 100%|██████████| 15/15 [00:07<00:00,  1.98it/s]
# Fitting ad['aid'] x user['kw1']...: 100%|██████████| 173/173 [12:26<00:00,  4.32s/it]
# Fitting ad['advertiserId'] x user['kw1']...: 100%|██████████| 79/79 [02:49<00:00,  2.15s/it]
# Fitting ad['campaignId'] x user['kw1']...: 100%|██████████| 138/138 [08:35<00:00,  3.73s/it]
# Fitting ad['creativeId'] x user['kw1']...: 100%|██████████| 173/173 [13:43<00:00,  4.76s/it]
# Fitting ad['adCategoryId'] x user['kw1']...: 100%|██████████| 40/40 [00:48<00:00,  1.22s/it]
# Fitting ad['productId'] x user['kw1']...: 100%|██████████| 33/33 [00:33<00:00,  1.02s/it]
# Fitting ad['productType'] x user['kw1']...: 100%|██████████| 4/4 [00:01<00:00,  2.47it/s]
# Fitting ad['creativeSize'] x user['kw2']...: 100%|██████████| 15/15 [00:01<00:00,  9.11it/s]
# Fitting ad['aid'] x user['kw2']...: 100%|██████████| 173/173 [02:31<00:00,  1.14it/s]
# Fitting ad['advertiserId'] x user['kw2']...: 100%|██████████| 79/79 [00:30<00:00,  2.57it/s]
# Fitting ad['campaignId'] x user['kw2']...: 100%|██████████| 138/138 [01:38<00:00,  1.40it/s]
# Fitting ad['creativeId'] x user['kw2']...: 100%|██████████| 173/173 [02:30<00:00,  1.15it/s]
# Fitting ad['adCategoryId'] x user['kw2']...: 100%|██████████| 40/40 [00:07<00:00,  5.19it/s]
# Fitting ad['productId'] x user['kw2']...: 100%|██████████| 33/33 [00:05<00:00,  5.66it/s]
# Fitting ad['productType'] x user['kw2']...: 100%|██████████| 4/4 [00:00<00:00, 10.06it/s]
# Fitting ad['advertiserId'] x user['appIdInstall']...: 100%|██████████| 79/79 [00:41<00:00,  1.91it/s]
# Fitting ad['campaignId'] x user['appIdInstall']...: 100%|██████████| 138/138 [02:05<00:00,  1.10it/s]
# Fitting ad['creativeId'] x user['appIdInstall']...: 100%|██████████| 173/173 [03:15<00:00,  1.13s/it]
# Fitting ad['adCategoryId'] x user['appIdInstall']...: 100%|██████████| 40/40 [00:10<00:00,  3.78it/s]
# Fitting ad['productId'] x user['appIdInstall']...: 100%|██████████| 33/33 [00:07<00:00,  4.45it/s]
# Fitting ad['productType'] x user['appIdInstall']...: 100%|██████████| 4/4 [00:00<00:00,  8.12it/s]
# Fitting ad['creativeSize'] x user['appIdAction']...: 100%|██████████| 15/15 [00:00<00:00, 20.25it/s]
# Fitting ad['aid'] x user['appIdAction']...: 100%|██████████| 173/173 [00:17<00:00,  9.69it/s]
# Fitting ad['advertiserId'] x user['appIdAction']...: 100%|██████████| 79/79 [00:05<00:00, 13.82it/s]
# Fitting ad['campaignId'] x user['appIdAction']...: 100%|██████████| 138/138 [00:12<00:00, 10.65it/s]
# Fitting ad['creativeId'] x user['appIdAction']...: 100%|██████████| 173/173 [00:20<00:00,  8.32it/s]
# Fitting ad['adCategoryId'] x user['appIdAction']...: 100%|██████████| 40/40 [00:02<00:00, 15.58it/s]
# Fitting ad['productId'] x user['appIdAction']...: 100%|██████████| 33/33 [00:02<00:00, 16.20it/s]
# Fitting ad['productType'] x user['appIdAction']...: 100%|██████████| 4/4 [00:00<00:00, 19.23it/s]
# Fitting ad['creativeSize'] x user['ct']...: 100%|██████████| 15/15 [00:00<00:00, 19.18it/s]
# Fitting ad['aid'] x user['ct']...: 100%|██████████| 173/173 [00:07<00:00, 22.50it/s]
# Fitting ad['advertiserId'] x user['ct']...: 100%|██████████| 79/79 [00:03<00:00, 22.96it/s]
# Fitting ad['campaignId'] x user['ct']...: 100%|██████████| 138/138 [00:06<00:00, 22.17it/s]
# Fitting ad['creativeId'] x user['ct']...: 100%|██████████| 173/173 [00:08<00:00, 20.37it/s]
# Fitting ad['adCategoryId'] x user['ct']...: 100%|██████████| 40/40 [00:01<00:00, 22.21it/s]
# Fitting ad['productId'] x user['ct']...: 100%|██████████| 33/33 [00:01<00:00, 22.07it/s]
# Fitting ad['productType'] x user['ct']...: 100%|██████████| 4/4 [00:00<00:00, 22.34it/s]
# Fitting ad['creativeSize'] x user['os']...: 100%|██████████| 15/15 [00:00<00:00, 23.02it/s]
# Fitting ad['aid'] x user['os']...: 100%|██████████| 173/173 [00:07<00:00, 23.46it/s]
# Fitting ad['advertiserId'] x user['os']...: 100%|██████████| 79/79 [00:03<00:00, 24.28it/s]
# Fitting ad['campaignId'] x user['os']...: 100%|██████████| 138/138 [00:06<00:00, 21.08it/s]
# Fitting ad['creativeId'] x user['os']...: 100%|██████████| 173/173 [00:07<00:00, 24.00it/s]
# Fitting ad['adCategoryId'] x user['os']...: 100%|██████████| 40/40 [00:01<00:00, 23.62it/s]
# Fitting ad['productId'] x user['os']...: 100%|██████████| 33/33 [00:01<00:00, 24.42it/s]
# Fitting ad['productType'] x user['os']...: 100%|██████████| 4/4 [00:00<00:00, 23.86it/s]
