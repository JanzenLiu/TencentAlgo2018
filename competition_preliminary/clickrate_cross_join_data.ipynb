# %%
from sklearn.model_selection import StratifiedKFold
import scipy.sparse as sparse
import lightgbm as lgb
import pandas as pd
import numpy as np
import tqdm
import os
import gc
import sys
sys.path.append('../code/utils/')
import data_utils as du
import perf_utils as pu

# %%
user_one_feat_names = ['age', 'gender', 'education', 'consumptionAbility', 'LBS',
                  'carrier', 'house']  # one user has only one value
user_multi_feat_names = ['marriageStatus', 'interest1', 'interest2', 'interest3',
                   'interest4', 'interest5', 'kw1', 'kw2', 'kw3', 'topic1',
                   'topic2', 'topic3', 'appIdInstall', 'appIdAction', 'ct', 'os']  # one user can have more than one value
user_feat_names = user_one_feat_names + user_multi_feat_names

ad_num_feat_names = ['creativeSize']
ad_cat_feat_names = ['advertiserId', 'campaignId', 'creativeId', 'adCategoryId', 'productId', 'productType']
ad_feat_names = ad_num_feat_names + ad_cat_feat_names


# both 'creativeId' and 'aid' are unique to advertise. so you can do nothing actually
# I just remove 'creativeId' and add 'aid' to make my intention clearer
ad_feat_names.remove("creativeId")  # every ad has a unique 'creativeId', so it's useless
ad_feat_names.append("aid")

# %%
df_train = du.load_raw_data("train")
df_test = du.load_raw_data("test")
df_ad = du.load_raw_data("ad")
ad_user = pd.merge(df_train, df_ad, on='aid', how='left')

# %%
clickrate_folder = "../data/clickrate_bs/simple_cross/byUserFeatureName/"

# %%
def sort_ad_user_pairs(pairs):
    new_pairs = {}
    for ad_feat_name, user_feat_name in pairs:
        if user_feat_name not in new_pairs:
            new_pairs[user_feat_name] = [ad_feat_name]
        else:
            new_pairs[user_feat_name].append(ad_feat_name)
    return new_pairs

# %%
def join_clickrate_bs(ad_user, ad_feat_name, user_feat_name, stage='preliminary'):
    # given ad_feat_name and user_feat_name
    ad_user = ad_user.copy()  # copy instance to avoid modifying the original instance
    
    # prepare ad feature
    if ad_feat_name not in ad_user.columns:
        df_ad = du.load_raw_data("ad", stage=stage)
        ad_user = pd.merge(ad_user, df_ad, on='aid', how='left')
        del df_ad
        gc.collect()
        print(0)
        print(ad_user.head(5))
        
    # prepare user feature (original value)
    if user_feat_name not in ad_user.columns:
        df_feat = du.load_user_feature(user_feat_name)
        ad_user = pd.merge(ad_user, df_feat, on="uid", how="left")
        del df_feat
        gc.collect()
    ad_user[user_feat_name] = ad_user[user_feat_name].astype('str')   # for joining convenience
    
    # prepare click rates
    in_folder = os.path.join(clickrate_folder, "[featureName='{}']".format(user_feat_name))
    in_file = "[adFeatureName='{}'].csv".format(ad_feat_name)
    in_path = os.path.join(in_folder, in_file)
    df_clickrate = pd.read_csv(in_path)
    df_clickrate = df_clickrate.rename(columns={"ad_val": ad_feat_name, 
                                            "user_val": user_feat_name})
    df_clickrate[user_feat_name] = df_clickrate[user_feat_name].astype(str)  # for joining convenience
    assert ad_user[user_feat_name].dtype == df_clickrate[user_feat_name].dtype
    
    # join click rate
    ad_user = pd.merge(ad_user, df_clickrate, 
                         on=[ad_feat_name, user_feat_name], how='left')
    ad_user = ad_user[['aid', 'uid', 'bs_clickrate', 'click', 'impression']]
    gc.collect()
    
    return ad_user

# %%
with pu.profiler("loading and joining cross statistics data"):
    pairs = [("aid", "age"), ("aid", "education"), ("aid", "consumptionAbility"), ("aid", "LBS")]
    cross_stats_cols = []
    for ad_feat_name, user_feat_name in pairs:
        clickrate_col = "bs_clickrate_{}_x_{}".format(ad_feat_name, user_feat_name)
        impression_col = "impression_{}_x_{}".format(ad_feat_name, user_feat_name)
        df_new = join_clickrate_bs(ad_user, ad_feat_name, user_feat_name)
        df_new = df_new.drop(["aid", "uid", "click"], axis=1)
        df_new = df_new.rename(columns={"bs_clickrate": clickrate_col,
                                        "impression": impression_col})
        df_new = df_new[[clickrate_col, impression_col]]
        ad_user = pd.concat([ad_user, df_new], axis=1)
        cross_stats_cols += [clickrate_col, impression_col]

        del df_new
        gc.collect()

    X_cross_stats = sparse.csr_matrix(ad_user[cross_stats_cols].values).astype(np.float32)
    del ad_user
    gc.collect()
print("Combined Matrix Shape: {}".format(X_cross_stats.shape))
print("Feature Names Count: {}".format(len(cross_stats_cols)))
print("Memory usage at this moment :{}".format(pu.get_memory_str()))
# Out:
# [16:41:20] Finish loading and joining cross statistics data. △M: -147.57MB. △T: 2.4 minutes.
# Combined Matrix Shape: (8798814, 8)
# Feature Names Count: 8
# Memory usage at this moment :912.39MB

# %%
with pu.profiler("loading and joining user and ad data"):
    X_bin, bin_cols = du.quick_join(ad_user=df_train, 
                                    user_feat_names=user_feat_names, 
                                    ad_feat_names=ad_feat_names)
    gc.collect()
print("Combined Matrix Shape: {}".format(X_bin.shape))
print("Feature Names Count: {}".format(len(bin_cols)))
print("Memory usage at this moment :{}".format(pu.get_memory_str()))
# Out:
# loading user matrices: 100%|██████████| 23/23 [17:03<00:00, 44.52s/it]
# loading ad matrices: 100%|██████████| 7/7 [03:00<00:00, 25.83s/it]
# [17:01:25] Finish loading and joining user and ad data. △M: +5.79GB. △T: 20.1 minutes.
# Combined Matrix Shape: (8798814, 419701)
# Feature Names Count: 419701
# Memory usage at this moment :6.68GB

# %%
with pu.profiler("joining binary matrix and cross statistics matrix"):
    cols = bin_cols + cross_stats_cols
    X = sparse.hstack((X_bin, X_cross_stats))
    del X_bin
    del X_cross_stats
    gc.collect()
print("Combined Matrix Shape: {}".format(X.shape))
print("Feature Names Count: {}".format(len(cols)))
print("Memory usage at this moment :{}".format(pu.get_memory_str()))
# Out:
# [17:01:52] Finish joining binary matrix and cross statistics matrix. △M: +2.15GB. △T: 27.2 seconds.
# Combined Matrix Shape: (8798814, 419709)
# Feature Names Count: 419709
# Memory usage at this moment :8.83GB

# %%
X = sparse.csr_matrix(X)
y = df_train['label'].values
y = (y + 1) / 2
assert X.shape[0] == y.shape[0]

# %%
n_splits = 3  # use 3 instead of 5 to save time
skf = StratifiedKFold(n_splits=n_splits)
split_indices = [(train_index, valid_index) for train_index, valid_index in skf.split(df_train, y)]

# %%
train_index, valid_index = split_indices[0]

X_train, y_train = X[train_index, :], y[train_index]
X_valid, y_valid = X[valid_index, :], y[valid_index]

lgb_train = lgb.Dataset(X_train.astype(np.float32), y_train, feature_name=cols)
lgb_valid = lgb.Dataset(X_valid.astype(np.float32), y_valid, feature_name=cols)

# %%
params = {
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': 'auc',
    'max_depth': 15,
    'num_leaves': 120,
    'learning_rate': 0.15,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'verbose': 0
}
num_rounds = 500

lgbm = lgb.train(params,
                 lgb_train,
                 num_boost_round=num_rounds,
                 valid_sets=[lgb_train, lgb_valid], 
                 valid_names=['train', 'valid1'],
                 early_stopping_rounds=50)
# Out:
# [1]	train's auc: 0.68484	valid1's auc: 0.685018
# Training until validation scores don't improve for 50 rounds.
# [2]	train's auc: 0.691126	valid1's auc: 0.691331
# [3]	train's auc: 0.694338	valid1's auc: 0.694385
# [4]	train's auc: 0.696307	valid1's auc: 0.696218
# [5]	train's auc: 0.697171	valid1's auc: 0.697025
# [6]	train's auc: 0.698671	valid1's auc: 0.698426
# [7]	train's auc: 0.700093	valid1's auc: 0.699786
# [8]	train's auc: 0.701593	valid1's auc: 0.701201
# [9]	train's auc: 0.702446	valid1's auc: 0.701967
# [10]	train's auc: 0.703492	valid1's auc: 0.703022
# [11]	train's auc: 0.705684	valid1's auc: 0.705042
# [12]	train's auc: 0.706682	valid1's auc: 0.705953
# [13]	train's auc: 0.708131	valid1's auc: 0.707339
# [14]	train's auc: 0.710096	valid1's auc: 0.709224
# [15]	train's auc: 0.712041	valid1's auc: 0.71111
# [16]	train's auc: 0.712576	valid1's auc: 0.711544
# [17]	train's auc: 0.714292	valid1's auc: 0.713344
# [18]	train's auc: 0.71521	valid1's auc: 0.714162
# [19]	train's auc: 0.717318	valid1's auc: 0.716141
# [20]	train's auc: 0.718252	valid1's auc: 0.716925
# [21]	train's auc: 0.719354	valid1's auc: 0.717939
# [22]	train's auc: 0.720776	valid1's auc: 0.719241
# [23]	train's auc: 0.721983	valid1's auc: 0.720346
# [24]	train's auc: 0.723171	valid1's auc: 0.721467
# [25]	train's auc: 0.724174	valid1's auc: 0.722327
# [26]	train's auc: 0.725546	valid1's auc: 0.723667
# [27]	train's auc: 0.726678	valid1's auc: 0.724646
# [28]	train's auc: 0.727745	valid1's auc: 0.725513
# [29]	train's auc: 0.728819	valid1's auc: 0.726439
# [30]	train's auc: 0.729894	valid1's auc: 0.727379
# [31]	train's auc: 0.730846	valid1's auc: 0.728124
# [32]	train's auc: 0.731748	valid1's auc: 0.728786
# [33]	train's auc: 0.732613	valid1's auc: 0.72944
# [34]	train's auc: 0.733439	valid1's auc: 0.730087
# [35]	train's auc: 0.734235	valid1's auc: 0.730743
# [36]	train's auc: 0.735221	valid1's auc: 0.731563
# [37]	train's auc: 0.736004	valid1's auc: 0.732173
# [38]	train's auc: 0.736833	valid1's auc: 0.732768
# [39]	train's auc: 0.737859	valid1's auc: 0.73361
# [40]	train's auc: 0.738707	valid1's auc: 0.73422
# [41]	train's auc: 0.739447	valid1's auc: 0.734738
# [42]	train's auc: 0.740057	valid1's auc: 0.735149
# [43]	train's auc: 0.740772	valid1's auc: 0.735697
# [44]	train's auc: 0.741366	valid1's auc: 0.736114
# [45]	train's auc: 0.742278	valid1's auc: 0.73695
# [46]	train's auc: 0.742748	valid1's auc: 0.737157
# [47]	train's auc: 0.743541	valid1's auc: 0.737827
# [48]	train's auc: 0.744137	valid1's auc: 0.738201
# [49]	train's auc: 0.744675	valid1's auc: 0.738499
# [50]	train's auc: 0.745087	valid1's auc: 0.738745
# [51]	train's auc: 0.745627	valid1's auc: 0.739083
# [52]	train's auc: 0.746431	valid1's auc: 0.739734
# [53]	train's auc: 0.746911	valid1's auc: 0.74002
# [54]	train's auc: 0.74774	valid1's auc: 0.740643
# [55]	train's auc: 0.748157	valid1's auc: 0.740864
# [56]	train's auc: 0.748617	valid1's auc: 0.74108
# [57]	train's auc: 0.749018	valid1's auc: 0.741304
# [58]	train's auc: 0.749348	valid1's auc: 0.741466
# [59]	train's auc: 0.749742	valid1's auc: 0.741673
# [60]	train's auc: 0.750106	valid1's auc: 0.741877
# [61]	train's auc: 0.750573	valid1's auc: 0.742067
# [62]	train's auc: 0.751044	valid1's auc: 0.742354
# [63]	train's auc: 0.751413	valid1's auc: 0.742533
# [64]	train's auc: 0.752045	valid1's auc: 0.742978
# [65]	train's auc: 0.75255	valid1's auc: 0.743223
# [66]	train's auc: 0.75308	valid1's auc: 0.743554
# [67]	train's auc: 0.75333	valid1's auc: 0.743628
# [68]	train's auc: 0.753751	valid1's auc: 0.743815
# [69]	train's auc: 0.754225	valid1's auc: 0.744
# [70]	train's auc: 0.754573	valid1's auc: 0.744122
# [71]	train's auc: 0.754857	valid1's auc: 0.744238
# [72]	train's auc: 0.755321	valid1's auc: 0.744399
# [73]	train's auc: 0.755612	valid1's auc: 0.744533
# [74]	train's auc: 0.755874	valid1's auc: 0.744639
# [75]	train's auc: 0.756181	valid1's auc: 0.744754
# [76]	train's auc: 0.756573	valid1's auc: 0.744901
# [77]	train's auc: 0.756878	valid1's auc: 0.745038
# [78]	train's auc: 0.757361	valid1's auc: 0.745361
# [79]	train's auc: 0.757776	valid1's auc: 0.745534
# [80]	train's auc: 0.758035	valid1's auc: 0.745674
# [81]	train's auc: 0.758433	valid1's auc: 0.745802
# [82]	train's auc: 0.758733	valid1's auc: 0.745916
# [83]	train's auc: 0.75901	valid1's auc: 0.746032
# [84]	train's auc: 0.759178	valid1's auc: 0.746069
# [85]	train's auc: 0.759548	valid1's auc: 0.74615
# [86]	train's auc: 0.759879	valid1's auc: 0.746196
# [87]	train's auc: 0.760211	valid1's auc: 0.746323
# [88]	train's auc: 0.760644	valid1's auc: 0.746396
# [89]	train's auc: 0.761246	valid1's auc: 0.746678
# [90]	train's auc: 0.761778	valid1's auc: 0.747012
# [91]	train's auc: 0.762167	valid1's auc: 0.747145
# [92]	train's auc: 0.762449	valid1's auc: 0.747232
# [93]	train's auc: 0.762732	valid1's auc: 0.74735
# [94]	train's auc: 0.763119	valid1's auc: 0.74741
# [95]	train's auc: 0.763331	valid1's auc: 0.747487
# [96]	train's auc: 0.763755	valid1's auc: 0.747636
# [97]	train's auc: 0.764068	valid1's auc: 0.747689
# [98]	train's auc: 0.764407	valid1's auc: 0.747811
# [99]	train's auc: 0.764738	valid1's auc: 0.747867
# [100]	train's auc: 0.764911	valid1's auc: 0.747917
# [101]	train's auc: 0.765209	valid1's auc: 0.747979
# [102]	train's auc: 0.765476	valid1's auc: 0.748075
# [103]	train's auc: 0.765833	valid1's auc: 0.748179
# [104]	train's auc: 0.766156	valid1's auc: 0.748219
# [105]	train's auc: 0.766382	valid1's auc: 0.748323
# [106]	train's auc: 0.766648	valid1's auc: 0.74837
# [107]	train's auc: 0.766915	valid1's auc: 0.748421
# [108]	train's auc: 0.767248	valid1's auc: 0.748517
# [109]	train's auc: 0.767578	valid1's auc: 0.748589
# [110]	train's auc: 0.767793	valid1's auc: 0.748672
# [111]	train's auc: 0.767973	valid1's auc: 0.748737
# [112]	train's auc: 0.768456	valid1's auc: 0.749032
# [113]	train's auc: 0.768787	valid1's auc: 0.749079
# [114]	train's auc: 0.76898	valid1's auc: 0.749129
# [115]	train's auc: 0.769238	valid1's auc: 0.749172
# [116]	train's auc: 0.769557	valid1's auc: 0.749208
# [117]	train's auc: 0.769847	valid1's auc: 0.749231
# [118]	train's auc: 0.770134	valid1's auc: 0.749313
# [119]	train's auc: 0.770356	valid1's auc: 0.749342
# [120]	train's auc: 0.770645	valid1's auc: 0.749422
# [121]	train's auc: 0.770906	valid1's auc: 0.749475
# [122]	train's auc: 0.771104	valid1's auc: 0.749515
# [123]	train's auc: 0.771315	valid1's auc: 0.749546
# [124]	train's auc: 0.771582	valid1's auc: 0.749586
# [125]	train's auc: 0.772161	valid1's auc: 0.749923
# [126]	train's auc: 0.772503	valid1's auc: 0.750008
# [127]	train's auc: 0.772794	valid1's auc: 0.750065
# [128]	train's auc: 0.773048	valid1's auc: 0.750081
# [129]	train's auc: 0.773325	valid1's auc: 0.750171
# [130]	train's auc: 0.773751	valid1's auc: 0.750251
# [131]	train's auc: 0.774017	valid1's auc: 0.750298
# [132]	train's auc: 0.774416	valid1's auc: 0.750511
# [133]	train's auc: 0.774595	valid1's auc: 0.750536
# [134]	train's auc: 0.774821	valid1's auc: 0.750606
# [135]	train's auc: 0.775014	valid1's auc: 0.750652
# [136]	train's auc: 0.775176	valid1's auc: 0.750662
# [137]	train's auc: 0.775397	valid1's auc: 0.75067
# [138]	train's auc: 0.775603	valid1's auc: 0.750682
# [139]	train's auc: 0.775941	valid1's auc: 0.750702
# [140]	train's auc: 0.776175	valid1's auc: 0.750733
# [141]	train's auc: 0.776397	valid1's auc: 0.750759
# [142]	train's auc: 0.776664	valid1's auc: 0.750788
# [143]	train's auc: 0.776894	valid1's auc: 0.75086
# [144]	train's auc: 0.777105	valid1's auc: 0.750879
# [145]	train's auc: 0.777278	valid1's auc: 0.750932
# [146]	train's auc: 0.777539	valid1's auc: 0.750981
# [147]	train's auc: 0.777884	valid1's auc: 0.751058
# [148]	train's auc: 0.778193	valid1's auc: 0.751066
# [149]	train's auc: 0.778338	valid1's auc: 0.751075
# [150]	train's auc: 0.778447	valid1's auc: 0.751094
# [151]	train's auc: 0.778778	valid1's auc: 0.751123
# [152]	train's auc: 0.779018	valid1's auc: 0.751151
# [153]	train's auc: 0.779184	valid1's auc: 0.751166
# [154]	train's auc: 0.779509	valid1's auc: 0.751244
# [155]	train's auc: 0.779762	valid1's auc: 0.751302
# [156]	train's auc: 0.779941	valid1's auc: 0.751329
# [157]	train's auc: 0.78012	valid1's auc: 0.751338
# [158]	train's auc: 0.780457	valid1's auc: 0.751406
# [159]	train's auc: 0.780736	valid1's auc: 0.751418
# [160]	train's auc: 0.78088	valid1's auc: 0.751433
# [161]	train's auc: 0.781103	valid1's auc: 0.751445
# [162]	train's auc: 0.78137	valid1's auc: 0.751463
# [163]	train's auc: 0.781587	valid1's auc: 0.751464
# [164]	train's auc: 0.781828	valid1's auc: 0.751495
# [165]	train's auc: 0.781986	valid1's auc: 0.751519
# [166]	train's auc: 0.782099	valid1's auc: 0.751547
# [167]	train's auc: 0.782227	valid1's auc: 0.751564
# [168]	train's auc: 0.782433	valid1's auc: 0.751566
# [169]	train's auc: 0.782688	valid1's auc: 0.751542
# [170]	train's auc: 0.782993	valid1's auc: 0.751573
# [171]	train's auc: 0.783204	valid1's auc: 0.751623
# [172]	train's auc: 0.783331	valid1's auc: 0.751626
# [173]	train's auc: 0.783465	valid1's auc: 0.751619
# [174]	train's auc: 0.78361	valid1's auc: 0.751644
# [175]	train's auc: 0.78374	valid1's auc: 0.751679
# [176]	train's auc: 0.783868	valid1's auc: 0.751713
# [177]	train's auc: 0.784024	valid1's auc: 0.751728
# [178]	train's auc: 0.784319	valid1's auc: 0.751734
# [179]	train's auc: 0.784494	valid1's auc: 0.751774
# [180]	train's auc: 0.784746	valid1's auc: 0.751766
# [181]	train's auc: 0.784899	valid1's auc: 0.751785
# [182]	train's auc: 0.7851	valid1's auc: 0.751794
# [183]	train's auc: 0.785318	valid1's auc: 0.751816
# [184]	train's auc: 0.785513	valid1's auc: 0.751823
# [185]	train's auc: 0.785678	valid1's auc: 0.751835
# [186]	train's auc: 0.785855	valid1's auc: 0.751868
# [187]	train's auc: 0.786006	valid1's auc: 0.751883
# [188]	train's auc: 0.786171	valid1's auc: 0.751894
# [189]	train's auc: 0.786339	valid1's auc: 0.751925
# [190]	train's auc: 0.786533	valid1's auc: 0.751942
# [191]	train's auc: 0.786679	valid1's auc: 0.751958
# [192]	train's auc: 0.786878	valid1's auc: 0.751978
# [193]	train's auc: 0.787044	valid1's auc: 0.752001
# [194]	train's auc: 0.787153	valid1's auc: 0.751988
# [195]	train's auc: 0.787303	valid1's auc: 0.751982
# [196]	train's auc: 0.787394	valid1's auc: 0.751986
# [197]	train's auc: 0.787587	valid1's auc: 0.752015
# [198]	train's auc: 0.78782	valid1's auc: 0.752025
# [199]	train's auc: 0.787954	valid1's auc: 0.752017
# [200]	train's auc: 0.788136	valid1's auc: 0.752029
# [201]	train's auc: 0.788355	valid1's auc: 0.752053
# [202]	train's auc: 0.788526	valid1's auc: 0.752094
# [203]	train's auc: 0.78872	valid1's auc: 0.752109
# [204]	train's auc: 0.788958	valid1's auc: 0.752117
# [205]	train's auc: 0.78924	valid1's auc: 0.752269
# [206]	train's auc: 0.789398	valid1's auc: 0.752274
# [207]	train's auc: 0.789538	valid1's auc: 0.752269
# [208]	train's auc: 0.7897	valid1's auc: 0.752272
# [209]	train's auc: 0.78986	valid1's auc: 0.752277
# [210]	train's auc: 0.790183	valid1's auc: 0.752292
# [211]	train's auc: 0.790322	valid1's auc: 0.752279
# [212]	train's auc: 0.790483	valid1's auc: 0.752278
# [213]	train's auc: 0.790605	valid1's auc: 0.752277
# [214]	train's auc: 0.790777	valid1's auc: 0.752276
# [215]	train's auc: 0.79108	valid1's auc: 0.752335
# [216]	train's auc: 0.791253	valid1's auc: 0.752319
# [217]	train's auc: 0.791328	valid1's auc: 0.75232
# [218]	train's auc: 0.791415	valid1's auc: 0.75231
# [219]	train's auc: 0.791553	valid1's auc: 0.752316
# [220]	train's auc: 0.79169	valid1's auc: 0.752309
# [221]	train's auc: 0.791834	valid1's auc: 0.752307
# [222]	train's auc: 0.791989	valid1's auc: 0.752349
# [223]	train's auc: 0.792409	valid1's auc: 0.752605
# [224]	train's auc: 0.792749	valid1's auc: 0.752625
# [225]	train's auc: 0.792975	valid1's auc: 0.752629
# [226]	train's auc: 0.793125	valid1's auc: 0.752637
# [227]	train's auc: 0.793277	valid1's auc: 0.752624
# [228]	train's auc: 0.793494	valid1's auc: 0.752625
# [229]	train's auc: 0.793688	valid1's auc: 0.752622
# [230]	train's auc: 0.793835	valid1's auc: 0.752621
# [231]	train's auc: 0.794106	valid1's auc: 0.752667
# [232]	train's auc: 0.794297	valid1's auc: 0.752662
# [233]	train's auc: 0.794595	valid1's auc: 0.752674
# [234]	train's auc: 0.794721	valid1's auc: 0.752678
# [235]	train's auc: 0.794862	valid1's auc: 0.752684
# [236]	train's auc: 0.795052	valid1's auc: 0.752706
# [237]	train's auc: 0.795152	valid1's auc: 0.752716
# [238]	train's auc: 0.795353	valid1's auc: 0.752759
# [239]	train's auc: 0.795418	valid1's auc: 0.752758
# [240]	train's auc: 0.795635	valid1's auc: 0.752767
# [241]	train's auc: 0.795909	valid1's auc: 0.752818
# [242]	train's auc: 0.796089	valid1's auc: 0.752853
# [243]	train's auc: 0.796284	valid1's auc: 0.752854
# [244]	train's auc: 0.796422	valid1's auc: 0.752835
# [245]	train's auc: 0.796604	valid1's auc: 0.752825
# [246]	train's auc: 0.796839	valid1's auc: 0.752813
# [247]	train's auc: 0.796935	valid1's auc: 0.752831
# [248]	train's auc: 0.797163	valid1's auc: 0.752837
# [249]	train's auc: 0.797353	valid1's auc: 0.752827
# [250]	train's auc: 0.797543	valid1's auc: 0.75285
# [251]	train's auc: 0.797668	valid1's auc: 0.752861
# [252]	train's auc: 0.797814	valid1's auc: 0.752843
# [253]	train's auc: 0.797989	valid1's auc: 0.752848
# [254]	train's auc: 0.798241	valid1's auc: 0.752859
# [255]	train's auc: 0.798558	valid1's auc: 0.752903
# [256]	train's auc: 0.798908	valid1's auc: 0.753024
# [257]	train's auc: 0.799011	valid1's auc: 0.753028
# [258]	train's auc: 0.799115	valid1's auc: 0.753026
# [259]	train's auc: 0.799445	valid1's auc: 0.753179
# [260]	train's auc: 0.79972	valid1's auc: 0.753154
# [261]	train's auc: 0.799857	valid1's auc: 0.753136
# [262]	train's auc: 0.799953	valid1's auc: 0.753158
# [263]	train's auc: 0.800103	valid1's auc: 0.753177
# [264]	train's auc: 0.800351	valid1's auc: 0.753194
# [265]	train's auc: 0.800497	valid1's auc: 0.753193
# [266]	train's auc: 0.800664	valid1's auc: 0.753197
# [267]	train's auc: 0.80076	valid1's auc: 0.753187
# [268]	train's auc: 0.800948	valid1's auc: 0.753205
# [269]	train's auc: 0.801126	valid1's auc: 0.753187
# [270]	train's auc: 0.801276	valid1's auc: 0.753188
# [271]	train's auc: 0.801444	valid1's auc: 0.753193
# [272]	train's auc: 0.801585	valid1's auc: 0.753206
# [273]	train's auc: 0.801729	valid1's auc: 0.753189
# [274]	train's auc: 0.801845	valid1's auc: 0.753194
# [275]	train's auc: 0.801931	valid1's auc: 0.753183
# [276]	train's auc: 0.802131	valid1's auc: 0.753158
# [277]	train's auc: 0.802209	valid1's auc: 0.753166
# [278]	train's auc: 0.802389	valid1's auc: 0.753157
# [279]	train's auc: 0.802593	valid1's auc: 0.753147
# [280]	train's auc: 0.802786	valid1's auc: 0.753139
# [281]	train's auc: 0.802866	valid1's auc: 0.753134
# [282]	train's auc: 0.802915	valid1's auc: 0.753129
# [283]	train's auc: 0.802973	valid1's auc: 0.753116
# [284]	train's auc: 0.803046	valid1's auc: 0.753105
# [285]	train's auc: 0.803091	valid1's auc: 0.753098
# [286]	train's auc: 0.803257	valid1's auc: 0.753108
# [287]	train's auc: 0.803322	valid1's auc: 0.753119
# [288]	train's auc: 0.803473	valid1's auc: 0.753128
# [289]	train's auc: 0.803607	valid1's auc: 0.753117
# [290]	train's auc: 0.803708	valid1's auc: 0.753129
# [291]	train's auc: 0.803799	valid1's auc: 0.753123
# [292]	train's auc: 0.803889	valid1's auc: 0.753109
# [293]	train's auc: 0.803977	valid1's auc: 0.753111
# [294]	train's auc: 0.804159	valid1's auc: 0.753122
# [295]	train's auc: 0.804312	valid1's auc: 0.753122
# [296]	train's auc: 0.80447	valid1's auc: 0.753099
# [297]	train's auc: 0.804616	valid1's auc: 0.753092
# [298]	train's auc: 0.804883	valid1's auc: 0.753207
# [299]	train's auc: 0.805028	valid1's auc: 0.753209
# [300]	train's auc: 0.805139	valid1's auc: 0.753221
# [301]	train's auc: 0.805299	valid1's auc: 0.75321
# [302]	train's auc: 0.805422	valid1's auc: 0.753211
# [303]	train's auc: 0.80551	valid1's auc: 0.753205
# [304]	train's auc: 0.805656	valid1's auc: 0.753212
# [305]	train's auc: 0.805734	valid1's auc: 0.75321
# [306]	train's auc: 0.805922	valid1's auc: 0.753208
# [307]	train's auc: 0.80605	valid1's auc: 0.753197
# [308]	train's auc: 0.806238	valid1's auc: 0.75318
# [309]	train's auc: 0.806443	valid1's auc: 0.753198
# [310]	train's auc: 0.806491	valid1's auc: 0.753195
# [311]	train's auc: 0.806634	valid1's auc: 0.753209
# [312]	train's auc: 0.806701	valid1's auc: 0.753207
# [313]	train's auc: 0.806827	valid1's auc: 0.753193
# [314]	train's auc: 0.806947	valid1's auc: 0.753166
# [315]	train's auc: 0.807157	valid1's auc: 0.753181
# [316]	train's auc: 0.807304	valid1's auc: 0.75317
# [317]	train's auc: 0.807457	valid1's auc: 0.753187
# [318]	train's auc: 0.807588	valid1's auc: 0.753196
# [319]	train's auc: 0.807712	valid1's auc: 0.753191
# [320]	train's auc: 0.807861	valid1's auc: 0.753167
# [321]	train's auc: 0.808045	valid1's auc: 0.753163
# [322]	train's auc: 0.808173	valid1's auc: 0.75317
# [323]	train's auc: 0.808354	valid1's auc: 0.753175
# [324]	train's auc: 0.808398	valid1's auc: 0.753169
# [325]	train's auc: 0.808513	valid1's auc: 0.753162
# [326]	train's auc: 0.808668	valid1's auc: 0.753166
# [327]	train's auc: 0.808798	valid1's auc: 0.753181
# [328]	train's auc: 0.808957	valid1's auc: 0.75318
# [329]	train's auc: 0.809104	valid1's auc: 0.753178
# [330]	train's auc: 0.809197	valid1's auc: 0.753173
# [331]	train's auc: 0.809341	valid1's auc: 0.753166
# [332]	train's auc: 0.809513	valid1's auc: 0.75316
# [333]	train's auc: 0.809669	valid1's auc: 0.753167
# [334]	train's auc: 0.809805	valid1's auc: 0.753172
# [335]	train's auc: 0.809944	valid1's auc: 0.753156
# [336]	train's auc: 0.810019	valid1's auc: 0.753168
# [337]	train's auc: 0.810149	valid1's auc: 0.753156
# [338]	train's auc: 0.810306	valid1's auc: 0.753133
# [339]	train's auc: 0.810414	valid1's auc: 0.753132
# [340]	train's auc: 0.810549	valid1's auc: 0.753148
# [341]	train's auc: 0.810669	valid1's auc: 0.753151
# [342]	train's auc: 0.810807	valid1's auc: 0.75315
# [343]	train's auc: 0.810935	valid1's auc: 0.75315
# [344]	train's auc: 0.811093	valid1's auc: 0.753118
# [345]	train's auc: 0.811255	valid1's auc: 0.753118
# [346]	train's auc: 0.811416	valid1's auc: 0.753099
# [347]	train's auc: 0.811493	valid1's auc: 0.753104
# [348]	train's auc: 0.811605	valid1's auc: 0.753096
# [349]	train's auc: 0.811698	valid1's auc: 0.753094
# [350]	train's auc: 0.811844	valid1's auc: 0.753113
# Early stopping, best iteration is:
# [300]	train's auc: 0.805139	valid1's auc: 0.753221

# %%
df_feature_importance = pd.DataFrame({"feature": cols, "importance": lgbm.feature_importance()})
df_feature_importance = df_feature_importance.sort_values("importance", ascending=False)
df_feature_importance.head(30)
# Out:
#                                       feature  importance
# 419707                 bs_clickrate_aid_x_LBS        1296
# 419701                 bs_clickrate_aid_x_age        1038
# 419708                   impression_aid_x_LBS        1032
# 419703           bs_clickrate_aid_x_education         778
# 419705  bs_clickrate_aid_x_consumptionAbility         763
# 419704             impression_aid_x_education         504
# 419702                   impression_aid_x_age         478
# 419706    impression_aid_x_consumptionAbility         456
# 419224                        creativeSize_59         274
# 419220                        creativeSize_22         178
# 419213                                   ct_1         165
# 1063                             interest2_54         163
# 419526                          productType_9         143
# 6                                    gender_2         140
# 1098                          interest2_[nan]         134
# 921                              interest1_49         117
# 419221                        creativeSize_35         116
# 419457                        adCategoryId_21         102
# 1067                             interest2_10          98
# 419467                        adCategoryId_51          98
# 419222                        creativeSize_42          97
# 3                                       age_2          94
# 1039                             interest2_70          94
# 1008                             interest1_76          93
# 884                         marriageStatus_10          93
# 1009                              interest1_6          92
# 419524                          productType_4          92
# 1031                             interest2_63          91
# 297368                              kw2_80452          81
# 1180                             interest5_52          79

# %%
# out_folder = "../data/clickrate_bs/simple_cross/joined/preliminary_contest_data/simple/"  
# out_file = "train[userFeatureName='{}'].pkl".format(ad_feat_name, user_feat_name)
# out_path = os.path.join(out_folder, out_file)
# os.makedirs(out_folder, makedirs=True)
# df_new.to_pickle(out_path, columns=["bs_clickrate"], index=False)

# %%
# given DataFrame `ad_user` with 'aid' and 'uid'
# load all ad feature and join `ad_user` on 'aid'
# for each adFeature x userMultiFeature:
#     load user feature and join `ad_user` on 'uid'
#     load adFeat x userFeat clickrate
#     for each record ('aid', 'uid') in `ad_user`:
#        find all cross clickrate for the feature values
